# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import sys
from time import time
import os

# %pylab inline
pylab.rcParams['figure.figsize'] = (20.0, 10.0)

# %load_ext autoreload
# %autoreload 2

sys.path.append('..')

import isolation
import sample_players
import run_match
import my_baseline_player as custom

from multiprocessing.pool import ThreadPool as Pool
from functools import partial
# Out:
# Populating the interactive namespace from numpy and matplotlib
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# /Users/antelinvestigacionydesarrollo/anaconda3/envs/aind/lib/python3.5/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['time']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %% [markdown]
# ### Let's use a dictionary to represent a Node

# %%
class State:
    """ Mock class to test the functions. """
    def __init__(self, name):
        self.name = name
        
    def actions(self):
        return [1,2,3,4]
    
    def result(self, action):
        return State('{}_{}'.format(self.name, str(action)))
    
    def terminal_test(self):
        return len(self.name.split('_')) >=3
    
    def utility(self, player_id):
        return player_id
        
    def __str__(self):
        return self.name

# %%
def new_node(state, parent=None, from_action=None, N=0, Q=0, children=None):
    node = {'state': state,
            'parent': parent,
            'from_action': from_action,
            'N': N,
            'Q': Q
           }
    if children == None:
        node['children'] = list()
    else:
        node['children'] = children
    if parent is not None:
        parent['children'].append(node)
    return node

# %%
root = new_node(State('root'))
root
# Out:
# {'N': 0,
#  'Q': 0,
#  'children': [],
#  'from_action': None,
#  'parent': None,
#  'state': <__main__.State at 0x117efc710>}

# %%
node1 = new_node(State('state_1'), root, from_action=1)

# %%
root
# Out:
# {'N': 0,
#  'Q': 0,
#  'children': [{'N': 0,
#    'Q': 0,
#    'children': [],
#    'from_action': 1,
#    'parent': {...},
#    'state': <__main__.State at 0x117efc7f0>}],
#  'from_action': None,
#  'parent': None,
#  'state': <__main__.State at 0x117efc710>}

# %%
node1
# Out:
# {'N': 0,
#  'Q': 0,
#  'children': [],
#  'from_action': 1,
#  'parent': {'N': 0,
#   'Q': 0,
#   'children': [{...}],
#   'from_action': None,
#   'parent': None,
#   'state': <__main__.State at 0x117efc710>},
#  'state': <__main__.State at 0x117efc7f0>}

# %%
node2 = new_node(State('state_2'), root, from_action=2, N=2, Q=1)
node2
# Out:
# {'N': 2,
#  'Q': 1,
#  'children': [],
#  'from_action': 2,
#  'parent': {'N': 0,
#   'Q': 0,
#   'children': [{'N': 0,
#     'Q': 0,
#     'children': [],
#     'from_action': 1,
#     'parent': {...},
#     'state': <__main__.State at 0x117efc7f0>},
#    {...}],
#   'from_action': None,
#   'parent': None,
#   'state': <__main__.State at 0x117efc710>},
#  'state': <__main__.State at 0x117efeeb8>}

# %% [markdown]
# ## Let's redefine the mcts functions, but this time without taking into account the multiple parents issue.

# %% [markdown]
# ### Best child

# %%
def ucb(node, c=1):
    if node['N'] == 0:
        if c != 0:
            return float('inf')
        else:
            return 0
    return (node['Q'] / node['N']) + c * math.sqrt((2 * math.log(node['N'])) / node['N'])

def best_node(node_list, c=1):
    return max(node_list, key=partial(ucb, c=c))

def best_child(node, c=1):
    return best_node(node['children'], c)

# %%
ucb(node1)
# Out:
# inf

# %%
ucb(node2)
# Out:
# 1.3325546111576978

# %%
best_child(root)
# Out:
# {'N': 0,
#  'Q': 0,
#  'children': [],
#  'from_action': 1,
#  'parent': {'N': 0,
#   'Q': 0,
#   'children': [{...},
#    {'N': 2,
#     'Q': 1,
#     'children': [],
#     'from_action': 2,
#     'parent': {...},
#     'state': <__main__.State at 0x117efeeb8>}],
#   'from_action': None,
#   'parent': None,
#   'state': <__main__.State at 0x117efc710>},
#  'state': <__main__.State at 0x117efc7f0>}

# %%
best_child(root, c=0)
# Out:
# {'N': 2,
#  'Q': 1,
#  'children': [],
#  'from_action': 2,
#  'parent': {'N': 0,
#   'Q': 0,
#   'children': [{'N': 0,
#     'Q': 0,
#     'children': [],
#     'from_action': 1,
#     'parent': {...},
#     'state': <__main__.State at 0x117efc7f0>},
#    {...}],
#   'from_action': None,
#   'parent': None,
#   'state': <__main__.State at 0x117efc710>},
#  'state': <__main__.State at 0x117efeeb8>}

# %% [markdown]
# ### Expand

# %%
def expand(node):
    a = random.choice(unexplored_actions(node))
    child = new_node(state=node['state'].result(a), 
                     parent=node, 
                     from_action=a)
    node['children'].append(child)
    return child

# %%
expand(root)
# Out:
# {'N': 0,
#  'Q': 0,
#  'children': [],
#  'from_action': 3,
#  'parent': {'N': 0,
#   'Q': 0,
#   'children': [{'N': 0,
#     'Q': 0,
#     'children': [],
#     'from_action': 1,
#     'parent': {...},
#     'state': <__main__.State at 0x117efc7f0>},
#    {'N': 2,
#     'Q': 1,
#     'children': [],
#     'from_action': 2,
#     'parent': {...},
#     'state': <__main__.State at 0x117efeeb8>},
#    {...},
#    {...}],
#   'from_action': None,
#   'parent': None,
#   'state': <__main__.State at 0x117efc710>},
#  'state': <__main__.State at 0x117eab6a0>}

# %%
expand(root)
# Out:
# {'N': 0,
#  'Q': 0,
#  'children': [],
#  'from_action': 4,
#  'parent': {'N': 0,
#   'Q': 0,
#   'children': [{'N': 0,
#     'Q': 0,
#     'children': [],
#     'from_action': 1,
#     'parent': {...},
#     'state': <__main__.State at 0x117efc7f0>},
#    {'N': 2,
#     'Q': 1,
#     'children': [],
#     'from_action': 2,
#     'parent': {...},
#     'state': <__main__.State at 0x117efeeb8>},
#    {'N': 0,
#     'Q': 0,
#     'children': [],
#     'from_action': 3,
#     'parent': {...},
#     'state': <__main__.State at 0x117eab6a0>},
#    {'N': 0,
#     'Q': 0,
#     'children': [],
#     'from_action': 3,
#     'parent': {...},
#     'state': <__main__.State at 0x117eab6a0>},
#    {...},
#    {...}],
#   'from_action': None,
#   'parent': None,
#   'state': <__main__.State at 0x117efc710>},
#  'state': <__main__.State at 0x117efecc0>}

# %% [markdown]
# ### Tree policy

# %%
def unexplored_actions(node):
    return list(set(node['state'].actions()) - \
                set(child['from_action'] for child in node['children']))

# %%
unexplored_actions(root)
# Out:
# []

# %%
unexplored_actions(node1)
# Out:
# [1, 2, 3, 4]

# %%
def is_fully_expanded(node):
    return len(unexplored_actions(node)) == 0

# %%
is_fully_expanded(root)
# Out:
# True

# %%
def tree_policy(node, nodes=None):
    print('tree_policy got this node:')
    print(node)
    if nodes is None:
        nodes = dict()
    temp_node = node
    while not temp_node['state'].terminal_test():
        if is_fully_expanded(temp_node):
            temp_node = best_child(temp_node)
        else:
            child = expand(temp_node)
            if child['state'] not in nodes.keys():
                nodes[child['state']] = [child]
            else:
                nodes[child['state']].append(child)
            return child
    return temp_node

# %%
root = new_node(State('root'))

# %%
nodes = dict()
child = tree_policy(root, nodes)
print(child['state'])
child
# Out:
# not fully expanded
# tree_policy nodes: 1
# root_4
# {'N': 0,
#  'Q': 0,
#  'children': [],
#  'from_action': 4,
#  'parent': {'N': 0,
#   'Q': 0,
#   'children': [{...}, {...}],
#   'from_action': None,
#   'parent': None,
#   'state': <__main__.State at 0x117f29550>},
#  'state': <__main__.State at 0x117f290b8>}

# %%
print(len(nodes))
nodes
# Out:
# 1
# {<__main__.State at 0x117f290b8>: [{'N': 0,
#    'Q': 0,
#    'children': [],
#    'from_action': 4,
#    'parent': {'N': 0,
#     'Q': 0,
#     'children': [{...}, {...}],
#     'from_action': None,
#     'parent': None,
#     'state': <__main__.State at 0x117f29550>},
#    'state': <__main__.State at 0x117f290b8>}]}

# %%
child = tree_policy(root)
print(child['state'])
child
# Out:
# not fully expanded
# tree_policy nodes: 1
# root_2
# {'N': 0,
#  'Q': 0,
#  'children': [],
#  'from_action': 2,
#  'parent': {'N': 0,
#   'Q': 0,
#   'children': [{'N': 0,
#     'Q': 0,
#     'children': [],
#     'from_action': 4,
#     'parent': {...},
#     'state': <__main__.State at 0x117f290b8>},
#    {'N': 0,
#     'Q': 0,
#     'children': [],
#     'from_action': 4,
#     'parent': {...},
#     'state': <__main__.State at 0x117f290b8>},
#    {...},
#    {...}],
#   'from_action': None,
#   'parent': None,
#   'state': <__main__.State at 0x117f29550>},
#  'state': <__main__.State at 0x117f29e10>}

# %%
child = tree_policy(root)
print(child['state'])
child
# Out:
# not fully expanded
# tree_policy nodes: 1
# root_1
# {'N': 0,
#  'Q': 0,
#  'children': [],
#  'from_action': 1,
#  'parent': {'N': 0,
#   'Q': 0,
#   'children': [{'N': 0,
#     'Q': 0,
#     'children': [],
#     'from_action': 4,
#     'parent': {...},
#     'state': <__main__.State at 0x117f290b8>},
#    {'N': 0,
#     'Q': 0,
#     'children': [],
#     'from_action': 4,
#     'parent': {...},
#     'state': <__main__.State at 0x117f290b8>},
#    {'N': 0,
#     'Q': 0,
#     'children': [],
#     'from_action': 2,
#     'parent': {...},
#     'state': <__main__.State at 0x117f29e10>},
#    {'N': 0,
#     'Q': 0,
#     'children': [],
#     'from_action': 2,
#     'parent': {...},
#     'state': <__main__.State at 0x117f29e10>},
#    {...},
#    {...}],
#   'from_action': None,
#   'parent': None,
#   'state': <__main__.State at 0x117f29550>},
#  'state': <__main__.State at 0x117f29278>}

# %%
child = tree_policy(root)
print(child['state'])
child
# Out:
# not fully expanded
# tree_policy nodes: 1
# root_3
# {'N': 0,
#  'Q': 0,
#  'children': [],
#  'from_action': 3,
#  'parent': {'N': 0,
#   'Q': 0,
#   'children': [{'N': 0,
#     'Q': 0,
#     'children': [],
#     'from_action': 4,
#     'parent': {...},
#     'state': <__main__.State at 0x117f290b8>},
#    {'N': 0,
#     'Q': 0,
#     'children': [],
#     'from_action': 4,
#     'parent': {...},
#     'state': <__main__.State at 0x117f290b8>},
#    {'N': 0,
#     'Q': 0,
#     'children': [],
#     'from_action': 2,
#     'parent': {...},
#     'state': <__main__.State at 0x117f29e10>},
#    {'N': 0,
#     'Q': 0,
#     'children': [],
#     'from_action': 2,
#     'parent': {...},
#     'state': <__main__.State at 0x117f29e10>},
#    {'N': 0,
#     'Q': 0,
#     'children': [],
#     'from_action': 1,
#     'parent': {...},
#     'state': <__main__.State at 0x117f29278>},
#    {'N': 0,
#     'Q': 0,
#     'children': [],
#     'from_action': 1,
#     'parent': {...},
#     'state': <__main__.State at 0x117f29278>},
#    {...},
#    {...}],
#   'from_action': None,
#   'parent': None,
#   'state': <__main__.State at 0x117f29550>},
#  'state': <__main__.State at 0x117f297f0>}

# %%
child = tree_policy(root)
print(child['state'])
child
# Out:
# fully
# not fully expanded
# tree_policy nodes: 1
# root_4_3
# {'N': 0,
#  'Q': 0,
#  'children': [],
#  'from_action': 3,
#  'parent': {'N': 0,
#   'Q': 0,
#   'children': [{...}, {...}],
#   'from_action': 4,
#   'parent': {'N': 0,
#    'Q': 0,
#    'children': [{...},
#     {...},
#     {'N': 0,
#      'Q': 0,
#      'children': [],
#      'from_action': 2,
#      'parent': {...},
#      'state': <__main__.State at 0x117f29e10>},
#     {'N': 0,
#      'Q': 0,
#      'children': [],
#      'from_action': 2,
#      'parent': {...},
#      'state': <__main__.State at 0x117f29e10>},
#     {'N': 0,
#      'Q': 0,
#      'children': [],
#      'from_action': 1,
#      'parent': {...},
#      'state': <__main__.State at 0x117f29278>},
#     {'N': 0,
#      'Q': 0,
#      'children': [],
#      'from_action': 1,
#      'parent': {...},
#      'state': <__main__.State at 0x117f29278>},
#     {'N': 0,
#      'Q': 0,
#      'children': [],
#      'from_action': 3,
#      'parent': {...},
#      'state': <__main__.State at 0x117f297f0>},
#     {'N': 0,
#      'Q': 0,
#      'children': [],
#      'from_action': 3,
#      'parent': {...},
#      'state': <__main__.State at 0x117f297f0>}],
#    'from_action': None,
#    'parent': None,
#    'state': <__main__.State at 0x117f29550>},
#   'state': <__main__.State at 0x117f290b8>},
#  'state': <__main__.State at 0x117f29cc0>}

# %%
child = tree_policy(root)
print(child['state'])
child
# Out:
# fully
# not fully expanded
# tree_policy nodes: 1
# root_4_1
# {'N': 0,
#  'Q': 0,
#  'children': [],
#  'from_action': 1,
#  'parent': {'N': 0,
#   'Q': 0,
#   'children': [{'N': 0,
#     'Q': 0,
#     'children': [],
#     'from_action': 3,
#     'parent': {...},
#     'state': <__main__.State at 0x117f29cc0>},
#    {'N': 0,
#     'Q': 0,
#     'children': [],
#     'from_action': 3,
#     'parent': {...},
#     'state': <__main__.State at 0x117f29cc0>},
#    {...},
#    {...}],
#   'from_action': 4,
#   'parent': {'N': 0,
#    'Q': 0,
#    'children': [{...},
#     {...},
#     {'N': 0,
#      'Q': 0,
#      'children': [],
#      'from_action': 2,
#      'parent': {...},
#      'state': <__main__.State at 0x117f29e10>},
#     {'N': 0,
#      'Q': 0,
#      'children': [],
#      'from_action': 2,
#      'parent': {...},
#      'state': <__main__.State at 0x117f29e10>},
#     {'N': 0,
#      'Q': 0,
#      'children': [],
#      'from_action': 1,
#      'parent': {...},
#      'state': <__main__.State at 0x117f29278>},
#     {'N': 0,
#      'Q': 0,
#      'children': [],
#      'from_action': 1,
#      'parent': {...},
#      'state': <__main__.State at 0x117f29278>},
#     {'N': 0,
#      'Q': 0,
#      'children': [],
#      'from_action': 3,
#      'parent': {...},
#      'state': <__main__.State at 0x117f297f0>},
#     {'N': 0,
#      'Q': 0,
#      'children': [],
#      'from_action': 3,
#      'parent': {...},
#      'state': <__main__.State at 0x117f297f0>}],
#    'from_action': None,
#    'parent': None,
#    'state': <__main__.State at 0x117f29550>},
#   'state': <__main__.State at 0x117f290b8>},
#  'state': <__main__.State at 0x117f295f8>}

# %%
child = tree_policy(root)
print(child['state'])
child
# Out:
# fully
# not fully expanded
# tree_policy nodes: 1
# root_4_4
# {'N': 0,
#  'Q': 0,
#  'children': [],
#  'from_action': 4,
#  'parent': {'N': 0,
#   'Q': 0,
#   'children': [{'N': 0,
#     'Q': 0,
#     'children': [],
#     'from_action': 3,
#     'parent': {...},
#     'state': <__main__.State at 0x117f29cc0>},
#    {'N': 0,
#     'Q': 0,
#     'children': [],
#     'from_action': 3,
#     'parent': {...},
#     'state': <__main__.State at 0x117f29cc0>},
#    {'N': 0,
#     'Q': 0,
#     'children': [],
#     'from_action': 1,
#     'parent': {...},
#     'state': <__main__.State at 0x117f295f8>},
#    {'N': 0,
#     'Q': 0,
#     'children': [],
#     'from_action': 1,
#     'parent': {...},
#     'state': <__main__.State at 0x117f295f8>},
#    {...},
#    {...}],
#   'from_action': 4,
#   'parent': {'N': 0,
#    'Q': 0,
#    'children': [{...},
#     {...},
#     {'N': 0,
#      'Q': 0,
#      'children': [],
#      'from_action': 2,
#      'parent': {...},
#      'state': <__main__.State at 0x117f29e10>},
#     {'N': 0,
#      'Q': 0,
#      'children': [],
#      'from_action': 2,
#      'parent': {...},
#      'state': <__main__.State at 0x117f29e10>},
#     {'N': 0,
#      'Q': 0,
#      'children': [],
#      'from_action': 1,
#      'parent': {...},
#      'state': <__main__.State at 0x117f29278>},
#     {'N': 0,
#      'Q': 0,
#      'children': [],
#      'from_action': 1,
#      'parent': {...},
#      'state': <__main__.State at 0x117f29278>},
#     {'N': 0,
#      'Q': 0,
#      'children': [],
#      'from_action': 3,
#      'parent': {...},
#      'state': <__main__.State at 0x117f297f0>},
#     {'N': 0,
#      'Q': 0,
#      'children': [],
#      'from_action': 3,
#      'parent': {...},
#      'state': <__main__.State at 0x117f297f0>}],
#    'from_action': None,
#    'parent': None,
#    'state': <__main__.State at 0x117f29550>},
#   'state': <__main__.State at 0x117f290b8>},
#  'state': <__main__.State at 0x117f29f98>}

# %%
child = tree_policy(root)
print(child['state'])
child
# Out:
# fully
# not fully expanded
# tree_policy nodes: 1
# root_4_2
# {'N': 0,
#  'Q': 0,
#  'children': [],
#  'from_action': 2,
#  'parent': {'N': 0,
#   'Q': 0,
#   'children': [{'N': 0,
#     'Q': 0,
#     'children': [],
#     'from_action': 3,
#     'parent': {...},
#     'state': <__main__.State at 0x117f29cc0>},
#    {'N': 0,
#     'Q': 0,
#     'children': [],
#     'from_action': 3,
#     'parent': {...},
#     'state': <__main__.State at 0x117f29cc0>},
#    {'N': 0,
#     'Q': 0,
#     'children': [],
#     'from_action': 1,
#     'parent': {...},
#     'state': <__main__.State at 0x117f295f8>},
#    {'N': 0,
#     'Q': 0,
#     'children': [],
#     'from_action': 1,
#     'parent': {...},
#     'state': <__main__.State at 0x117f295f8>},
#    {'N': 0,
#     'Q': 0,
#     'children': [],
#     'from_action': 4,
#     'parent': {...},
#     'state': <__main__.State at 0x117f29f98>},
#    {'N': 0,
#     'Q': 0,
#     'children': [],
#     'from_action': 4,
#     'parent': {...},
#     'state': <__main__.State at 0x117f29f98>},
#    {...},
#    {...}],
#   'from_action': 4,
#   'parent': {'N': 0,
#    'Q': 0,
#    'children': [{...},
#     {...},
#     {'N': 0,
#      'Q': 0,
#      'children': [],
#      'from_action': 2,
#      'parent': {...},
#      'state': <__main__.State at 0x117f29e10>},
#     {'N': 0,
#      'Q': 0,
#      'children': [],
#      'from_action': 2,
#      'parent': {...},
#      'state': <__main__.State at 0x117f29e10>},
#     {'N': 0,
#      'Q': 0,
#      'children': [],
#      'from_action': 1,
#      'parent': {...},
#      'state': <__main__.State at 0x117f29278>},
#     {'N': 0,
#      'Q': 0,
#      'children': [],
#      'from_action': 1,
#      'parent': {...},
#      'state': <__main__.State at 0x117f29278>},
#     {'N': 0,
#      'Q': 0,
#      'children': [],
#      'from_action': 3,
#      'parent': {...},
#      'state': <__main__.State at 0x117f297f0>},
#     {'N': 0,
#      'Q': 0,
#      'children': [],
#      'from_action': 3,
#      'parent': {...},
#      'state': <__main__.State at 0x117f297f0>}],
#    'from_action': None,
#    'parent': None,
#    'state': <__main__.State at 0x117f29550>},
#   'state': <__main__.State at 0x117f290b8>},
#  'state': <__main__.State at 0x117f2eeb8>}

# %%
child = tree_policy(root)
print(child['state'])
child
# Out:
# fully
# fully
# root_4_3
# {'N': 0,
#  'Q': 0,
#  'children': [],
#  'from_action': 3,
#  'parent': {'N': 0,
#   'Q': 0,
#   'children': [{...},
#    {...},
#    {'N': 0,
#     'Q': 0,
#     'children': [],
#     'from_action': 1,
#     'parent': {...},
#     'state': <__main__.State at 0x117f295f8>},
#    {'N': 0,
#     'Q': 0,
#     'children': [],
#     'from_action': 1,
#     'parent': {...},
#     'state': <__main__.State at 0x117f295f8>},
#    {'N': 0,
#     'Q': 0,
#     'children': [],
#     'from_action': 4,
#     'parent': {...},
#     'state': <__main__.State at 0x117f29f98>},
#    {'N': 0,
#     'Q': 0,
#     'children': [],
#     'from_action': 4,
#     'parent': {...},
#     'state': <__main__.State at 0x117f29f98>},
#    {'N': 0,
#     'Q': 0,
#     'children': [],
#     'from_action': 2,
#     'parent': {...},
#     'state': <__main__.State at 0x117f2eeb8>},
#    {'N': 0,
#     'Q': 0,
#     'children': [],
#     'from_action': 2,
#     'parent': {...},
#     'state': <__main__.State at 0x117f2eeb8>}],
#   'from_action': 4,
#   'parent': {'N': 0,
#    'Q': 0,
#    'children': [{...},
#     {...},
#     {'N': 0,
#      'Q': 0,
#      'children': [],
#      'from_action': 2,
#      'parent': {...},
#      'state': <__main__.State at 0x117f29e10>},
#     {'N': 0,
#      'Q': 0,
#      'children': [],
#      'from_action': 2,
#      'parent': {...},
#      'state': <__main__.State at 0x117f29e10>},
#     {'N': 0,
#      'Q': 0,
#      'children': [],
#      'from_action': 1,
#      'parent': {...},
#      'state': <__main__.State at 0x117f29278>},
#     {'N': 0,
#      'Q': 0,
#      'children': [],
#      'from_action': 1,
#      'parent': {...},
#      'state': <__main__.State at 0x117f29278>},
#     {'N': 0,
#      'Q': 0,
#      'children': [],
#      'from_action': 3,
#      'parent': {...},
#      'state': <__main__.State at 0x117f297f0>},
#     {'N': 0,
#      'Q': 0,
#      'children': [],
#      'from_action': 3,
#      'parent': {...},
#      'state': <__main__.State at 0x117f297f0>}],
#    'from_action': None,
#    'parent': None,
#    'state': <__main__.State at 0x117f29550>},
#   'state': <__main__.State at 0x117f290b8>},
#  'state': <__main__.State at 0x117f29cc0>}

# %%
child = tree_policy(root)
print(child['state'])
child
# Out:
# fully
# fully
# root_4_3
# {'N': 0,
#  'Q': 0,
#  'children': [],
#  'from_action': 3,
#  'parent': {'N': 0,
#   'Q': 0,
#   'children': [{...},
#    {...},
#    {'N': 0,
#     'Q': 0,
#     'children': [],
#     'from_action': 1,
#     'parent': {...},
#     'state': <__main__.State at 0x117f295f8>},
#    {'N': 0,
#     'Q': 0,
#     'children': [],
#     'from_action': 1,
#     'parent': {...},
#     'state': <__main__.State at 0x117f295f8>},
#    {'N': 0,
#     'Q': 0,
#     'children': [],
#     'from_action': 4,
#     'parent': {...},
#     'state': <__main__.State at 0x117f29f98>},
#    {'N': 0,
#     'Q': 0,
#     'children': [],
#     'from_action': 4,
#     'parent': {...},
#     'state': <__main__.State at 0x117f29f98>},
#    {'N': 0,
#     'Q': 0,
#     'children': [],
#     'from_action': 2,
#     'parent': {...},
#     'state': <__main__.State at 0x117f2eeb8>},
#    {'N': 0,
#     'Q': 0,
#     'children': [],
#     'from_action': 2,
#     'parent': {...},
#     'state': <__main__.State at 0x117f2eeb8>}],
#   'from_action': 4,
#   'parent': {'N': 0,
#    'Q': 0,
#    'children': [{...},
#     {...},
#     {'N': 0,
#      'Q': 0,
#      'children': [],
#      'from_action': 2,
#      'parent': {...},
#      'state': <__main__.State at 0x117f29e10>},
#     {'N': 0,
#      'Q': 0,
#      'children': [],
#      'from_action': 2,
#      'parent': {...},
#      'state': <__main__.State at 0x117f29e10>},
#     {'N': 0,
#      'Q': 0,
#      'children': [],
#      'from_action': 1,
#      'parent': {...},
#      'state': <__main__.State at 0x117f29278>},
#     {'N': 0,
#      'Q': 0,
#      'children': [],
#      'from_action': 1,
#      'parent': {...},
#      'state': <__main__.State at 0x117f29278>},
#     {'N': 0,
#      'Q': 0,
#      'children': [],
#      'from_action': 3,
#      'parent': {...},
#      'state': <__main__.State at 0x117f297f0>},
#     {'N': 0,
#      'Q': 0,
#      'children': [],
#      'from_action': 3,
#      'parent': {...},
#      'state': <__main__.State at 0x117f297f0>}],
#    'from_action': None,
#    'parent': None,
#    'state': <__main__.State at 0x117f29550>},
#   'state': <__main__.State at 0x117f290b8>},
#  'state': <__main__.State at 0x117f29cc0>}

# %% [markdown]
# ### Backup

# %%
def backup_negamax(node, reward):
    temp_node = node
    temp_node['N'] += 1
    temp_node['Q'] += reward
    while temp_node['parent'] is not None:
        temp_node = temp_node['parent']
        temp_node['N'] += 1
        temp_node['Q'] += reward

# %% [markdown]
# ### Default policy is kept unchanged, as it works with states

# %%
player_id = 0
def default_policy(state):
    temp_state = state
    while not temp_state.terminal_test():
        a = random.choice(temp_state.actions())
        temp_state = temp_state.result(a)

    return temp_state.utility(player_id)

# %% [markdown]
# ### UCT Search

# %% [markdown]
# ### First, I will define a function to update the tree with a new root. The problem is that nodes have to be identified by states, but states are reachable from many paths. To avoid joining the nodes with the same state (can be done in a posterior iteration of the algorithm), I will just choose the node with the best ucb value as the root. That way all nodes have a unique parent

# %%
def get_root_node(state, nodes=None):
    """
    nodes = {
        state1: [node1_1, node1_2], 
        state2: [node2_1],
        state3: [node3_1, node3_2, node3_3]
    }
    """
    if nodes is None:
        nodes = dict()
    if state not in nodes.keys():
        node = new_node(state)
        nodes[state] = [node]
        return node, nodes
    else:
        return best_node(nodes[state]), nodes

# %%
def uct_search(root_n, nodes=None):
    """ 
    nodes contains a dictionary of state:node with the nodes that have 
    already been visited.
    """
    edge_node = tree_policy(root_n, nodes)
    reward = default_policy(edge_node['state'])
    backup_negamax(edge_node, reward)
    return best_child(root_n, 0)['from_action'], nodes  # Greedy, so c = 0

# %%
nodes = dict()

# %%
root_n, nodes = get_root_node(State('root'))
uct_search(root_n, nodes)
# Out:
# not fully expanded
# tree_policy nodes: 2
# (3,
#  {<__main__.State at 0x117f2eba8>: [{'N': 1,
#     'Q': 0,
#     'children': [{'N': 1,
#       'Q': 0,
#       'children': [],
#       'from_action': 3,
#       'parent': {...},
#       'state': <__main__.State at 0x117f2ecf8>},
#      {'N': 1,
#       'Q': 0,
#       'children': [],
#       'from_action': 3,
#       'parent': {...},
#       'state': <__main__.State at 0x117f2ecf8>}],
#     'from_action': None,
#     'parent': None,
#     'state': <__main__.State at 0x117f2eba8>}],
#   <__main__.State at 0x117f2ecf8>: [{'N': 1,
#     'Q': 0,
#     'children': [],
#     'from_action': 3,
#     'parent': {'N': 1,
#      'Q': 0,
#      'children': [{...}, {...}],
#      'from_action': None,
#      'parent': None,
#      'state': <__main__.State at 0x117f2eba8>},
#     'state': <__main__.State at 0x117f2ecf8>}]})

# %%
root_s = State('root')
nodes = dict()
root_n, nodes = get_root_node(root_s, nodes)
root_n['parent'] = None  # Set this one as the new root
root_n['from_action'] = None  # Just for completeness, not used by now

for i in range(500):
    action, nodes = uct_search(root_n, nodes)
    print('\niter {}: action {}, nodes {}'.format(i, action, len(nodes)))
    print([str(state) for state in nodes.keys()])
    # Place to save the best move so far...
# Out:
# tree_policy got this node:
# {'state': <__main__.State object at 0x117f35b38>, 'from_action': None, 'Q': 0, 'N': 0, 'children': [], 'parent': None}
#
# iter 0: action 1, nodes 2
# ['root_1', 'root']
# tree_policy got this node:
# {'state': <__main__.State object at 0x117f35b38>, 'from_action': None, 'Q': 0, 'N': 1, 'children': [{'state': <__main__.State object at 0x117f35438>, 'from_action': 1, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35438>, 'from_action': 1, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}], 'parent': None}
#
# iter 1: action 1, nodes 3
# ['root_4', 'root_1', 'root']
# tree_policy got this node:
# {'state': <__main__.State object at 0x117f35b38>, 'from_action': None, 'Q': 0, 'N': 2, 'children': [{'state': <__main__.State object at 0x117f35438>, 'from_action': 1, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35438>, 'from_action': 1, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35518>, 'from_action': 4, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35518>, 'from_action': 4, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}], 'parent': None}
#
# iter 2: action 1, nodes 4
# ['root_4', 'root_1', 'root', 'root_3']
# tree_policy got this node:
# {'state': <__main__.State object at 0x117f35b38>, 'from_action': None, 'Q': 0, 'N': 3, 'children': [{'state': <__main__.State object at 0x117f35438>, 'from_action': 1, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35438>, 'from_action': 1, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35518>, 'from_action': 4, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35518>, 'from_action': 4, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35ef0>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35ef0>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}], 'parent': None}
#
# iter 3: action 1, nodes 5
# ['root_4', 'root_1', 'root', 'root_2', 'root_3']
# tree_policy got this node:
# {'state': <__main__.State object at 0x117f35b38>, 'from_action': None, 'Q': 0, 'N': 4, 'children': [{'state': <__main__.State object at 0x117f35438>, 'from_action': 1, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35438>, 'from_action': 1, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35518>, 'from_action': 4, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35518>, 'from_action': 4, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35ef0>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35ef0>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35ac8>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35ac8>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}], 'parent': None}
#
# iter 4: action 1, nodes 6
# ['root_4', 'root_1', 'root_1_4', 'root_2', 'root', 'root_3']
# tree_policy got this node:
# {'state': <__main__.State object at 0x117f35b38>, 'from_action': None, 'Q': 0, 'N': 5, 'children': [{'state': <__main__.State object at 0x117f35438>, 'from_action': 1, 'Q': 0, 'N': 2, 'children': [{'state': <__main__.State object at 0x117f35cc0>, 'from_action': 4, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35cc0>, 'from_action': 4, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}], 'parent': {...}}, {'state': <__main__.State object at 0x117f35438>, 'from_action': 1, 'Q': 0, 'N': 2, 'children': [{'state': <__main__.State object at 0x117f35cc0>, 'from_action': 4, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35cc0>, 'from_action': 4, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}], 'parent': {...}}, {'state': <__main__.State object at 0x117f35518>, 'from_action': 4, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35518>, 'from_action': 4, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35ef0>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35ef0>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35ac8>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35ac8>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}], 'parent': None}
#
# iter 5: action 1, nodes 7
# ['root_4', 'root_1', 'root_1_2', 'root_1_4', 'root_2', 'root', 'root_3']
# tree_policy got this node:
# {'state': <__main__.State object at 0x117f35b38>, 'from_action': None, 'Q': 0, 'N': 6, 'children': [{'state': <__main__.State object at 0x117f35438>, 'from_action': 1, 'Q': 0, 'N': 3, 'children': [{'state': <__main__.State object at 0x117f35cc0>, 'from_action': 4, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35cc0>, 'from_action': 4, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35e48>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35e48>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}], 'parent': {...}}, {'state': <__main__.State object at 0x117f35438>, 'from_action': 1, 'Q': 0, 'N': 3, 'children': [{'state': <__main__.State object at 0x117f35cc0>, 'from_action': 4, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35cc0>, 'from_action': 4, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35e48>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35e48>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}], 'parent': {...}}, {'state': <__main__.State object at 0x117f35518>, 'from_action': 4, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35518>, 'from_action': 4, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35ef0>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35ef0>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35ac8>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35ac8>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}], 'parent': None}
#
# iter 6: action 1, nodes 8
# ['root_4', 'root_1', 'root_1_2', 'root_1_3', 'root_1_4', 'root_2', 'root', 'root_3']
# tree_policy got this node:
# {'state': <__main__.State object at 0x117f35b38>, 'from_action': None, 'Q': 0, 'N': 7, 'children': [{'state': <__main__.State object at 0x117f35438>, 'from_action': 1, 'Q': 0, 'N': 4, 'children': [{'state': <__main__.State object at 0x117f35cc0>, 'from_action': 4, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35cc0>, 'from_action': 4, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35e48>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35e48>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35780>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35780>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}], 'parent': {...}}, {'state': <__main__.State object at 0x117f35438>, 'from_action': 1, 'Q': 0, 'N': 4, 'children': [{'state': <__main__.State object at 0x117f35cc0>, 'from_action': 4, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35cc0>, 'from_action': 4, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35e48>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35e48>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35780>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35780>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}], 'parent': {...}}, {'state': <__main__.State object at 0x117f35518>, 'from_action': 4, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35518>, 'from_action': 4, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35ef0>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35ef0>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35ac8>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35ac8>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}], 'parent': None}
#
# iter 7: action 1, nodes 9
# ['root_4', 'root_1', 'root_1_2', 'root_1_1', 'root_1_3', 'root_1_4', 'root_2', 'root', 'root_3']
# tree_policy got this node:
# {'state': <__main__.State object at 0x117f35b38>, 'from_action': None, 'Q': 0, 'N': 8, 'children': [{'state': <__main__.State object at 0x117f35438>, 'from_action': 1, 'Q': 0, 'N': 5, 'children': [{'state': <__main__.State object at 0x117f35cc0>, 'from_action': 4, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35cc0>, 'from_action': 4, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35e48>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35e48>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35780>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35780>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f356d8>, 'from_action': 1, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f356d8>, 'from_action': 1, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}], 'parent': {...}}, {'state': <__main__.State object at 0x117f35438>, 'from_action': 1, 'Q': 0, 'N': 5, 'children': [{'state': <__main__.State object at 0x117f35cc0>, 'from_action': 4, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35cc0>, 'from_action': 4, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35e48>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35e48>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35780>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35780>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f356d8>, 'from_action': 1, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f356d8>, 'from_action': 1, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}], 'parent': {...}}, {'state': <__main__.State object at 0x117f35518>, 'from_action': 4, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35518>, 'from_action': 4, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35ef0>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35ef0>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35ac8>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35ac8>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}], 'parent': None}
#
# iter 8: action 1, nodes 9
# ['root_4', 'root_1', 'root_1_2', 'root_1_1', 'root_1_3', 'root_1_4', 'root_2', 'root', 'root_3']
# tree_policy got this node:
# {'state': <__main__.State object at 0x117f35b38>, 'from_action': None, 'Q': 0, 'N': 9, 'children': [{'state': <__main__.State object at 0x117f35438>, 'from_action': 1, 'Q': 0, 'N': 6, 'children': [{'state': <__main__.State object at 0x117f35cc0>, 'from_action': 4, 'Q': 0, 'N': 2, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35cc0>, 'from_action': 4, 'Q': 0, 'N': 2, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35e48>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35e48>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35780>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35780>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f356d8>, 'from_action': 1, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f356d8>, 'from_action': 1, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}], 'parent': {...}}, {'state': <__main__.State object at 0x117f35438>, 'from_action': 1, 'Q': 0, 'N': 6, 'children': [{'state': <__main__.State object at 0x117f35cc0>, 'from_action': 4, 'Q': 0, 'N': 2, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35cc0>, 'from_action': 4, 'Q': 0, 'N': 2, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35e48>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35e48>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35780>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35780>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f356d8>, 'from_action': 1, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f356d8>, 'from_action': 1, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}], 'parent': {...}}, {'state': <__main__.State object at 0x117f35518>, 'from_action': 4, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35518>, 'from_action': 4, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35ef0>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35ef0>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35ac8>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35ac8>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}], 'parent': None}
#
# iter 9: action 1, nodes 9
# ['root_4', 'root_1', 'root_1_2', 'root_1_1', 'root_1_3', 'root_1_4', 'root_2', 'root', 'root_3']
# tree_policy got this node:
# {'state': <__main__.State object at 0x117f35b38>, 'from_action': None, 'Q': 0, 'N': 10, 'children': [{'state': <__main__.State object at 0x117f35438>, 'from_action': 1, 'Q': 0, 'N': 7, 'children': [{'state': <__main__.State object at 0x117f35cc0>, 'from_action': 4, 'Q': 0, 'N': 3, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35cc0>, 'from_action': 4, 'Q': 0, 'N': 3, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35e48>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35e48>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35780>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35780>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f356d8>, 'from_action': 1, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f356d8>, 'from_action': 1, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}], 'parent': {...}}, {'state': <__main__.State object at 0x117f35438>, 'from_action': 1, 'Q': 0, 'N': 7, 'children': [{'state': <__main__.State object at 0x117f35cc0>, 'from_action': 4, 'Q': 0, 'N': 3, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35cc0>, 'from_action': 4, 'Q': 0, 'N': 3, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35e48>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35e48>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35780>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35780>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f356d8>, 'from_action': 1, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f356d8>, 'from_action': 1, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}], 'parent': {...}}, {'state': <__main__.State object at 0x117f35518>, 'from_action': 4, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35518>, 'from_action': 4, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35ef0>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35ef0>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35ac8>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35ac8>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}], 'parent': None}
#
# iter 10: action 1, nodes 9
# ['root_4', 'root_1', 'root_1_2', 'root_1_1', 'root_1_3', 'root_1_4', 'root_2', 'root', 'root_3']
# tree_policy got this node:
# {'state': <__main__.State object at 0x117f35b38>, 'from_action': None, 'Q': 0, 'N': 11, 'children': [{'state': <__main__.State object at 0x117f35438>, 'from_action': 1, 'Q': 0, 'N': 8, 'children': [{'state': <__main__.State object at 0x117f35cc0>, 'from_action': 4, 'Q': 0, 'N': 4, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35cc0>, 'from_action': 4, 'Q': 0, 'N': 4, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35e48>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35e48>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35780>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35780>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f356d8>, 'from_action': 1, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f356d8>, 'from_action': 1, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}], 'parent': {...}}, {'state': <__main__.State object at 0x117f35438>, 'from_action': 1, 'Q': 0, 'N': 8, 'children': [{'state': <__main__.State object at 0x117f35cc0>, 'from_action': 4, 'Q': 0, 'N': 4, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35cc0>, 'from_action': 4, 'Q': 0, 'N': 4, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35e48>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35e48>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35780>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35780>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f356d8>, 'from_action': 1, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f356d8>, 'from_action': 1, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}], 'parent': {...}}, {'state': <__main__.State object at 0x117f35518>, 'from_action': 4, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35518>, 'from_action': 4, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35ef0>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35ef0>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35ac8>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35ac8>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}], 'parent': None}
#
# iter 11: action 1, nodes 9
# ['root_4', 'root_1', 'root_1_2', 'root_1_1', 'root_1_3', 'root_1_4', 'root_2', 'root', 'root_3']
# tree_policy got this node:
# {'state': <__main__.State object at 0x117f35b38>, 'from_action': None, 'Q': 0, 'N': 12, 'children': [{'state': <__main__.State object at 0x117f35438>, 'from_action': 1, 'Q': 0, 'N': 9, 'children': [{'state': <__main__.State object at 0x117f35cc0>, 'from_action': 4, 'Q': 0, 'N': 5, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35cc0>, 'from_action': 4, 'Q': 0, 'N': 5, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35e48>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35e48>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35780>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35780>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f356d8>, 'from_action': 1, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f356d8>, 'from_action': 1, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}], 'parent': {...}}, {'state': <__main__.State object at 0x117f35438>, 'from_action': 1, 'Q': 0, 'N': 9, 'children': [{'state': <__main__.State object at 0x117f35cc0>, 'from_action': 4, 'Q': 0, 'N': 5, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35cc0>, 'from_action': 4, 'Q': 0, 'N': 5, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35e48>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35e48>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35780>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35780>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f356d8>, 'from_action': 1, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f356d8>, 'from_action': 1, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}], 'parent': {...}}, {'state': <__main__.State object at 0x117f35518>, 'from_action': 4, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35518>, 'from_action': 4, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35ef0>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35ef0>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35ac8>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35ac8>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}], 'parent': None}
#
# iter 12: action 1, nodes 9
# ['root_4', 'root_1', 'root_1_2', 'root_1_1', 'root_1_3', 'root_1_4', 'root_2', 'root', 'root_3']
# tree_policy got this node:
# {'state': <__main__.State object at 0x117f35b38>, 'from_action': None, 'Q': 0, 'N': 13, 'children': [{'state': <__main__.State object at 0x117f35438>, 'from_action': 1, 'Q': 0, 'N': 10, 'children': [{'state': <__main__.State object at 0x117f35cc0>, 'from_action': 4, 'Q': 0, 'N': 6, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35cc0>, 'from_action': 4, 'Q': 0, 'N': 6, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35e48>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35e48>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35780>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35780>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f356d8>, 'from_action': 1, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f356d8>, 'from_action': 1, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}], 'parent': {...}}, {'state': <__main__.State object at 0x117f35438>, 'from_action': 1, 'Q': 0, 'N': 10, 'children': [{'state': <__main__.State object at 0x117f35cc0>, 'from_action': 4, 'Q': 0, 'N': 6, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35cc0>, 'from_action': 4, 'Q': 0, 'N': 6, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35e48>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35e48>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35780>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35780>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f356d8>, 'from_action': 1, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f356d8>, 'from_action': 1, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}], 'parent': {...}}, {'state': <__main__.State object at 0x117f35518>, 'from_action': 4, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35518>, 'from_action': 4, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35ef0>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35ef0>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35ac8>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35ac8>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}], 'parent': None}
#
# iter 13: action 1, nodes 9
# ['root_4', 'root_1', 'root_1_2', 'root_1_1', 'root_1_3', 'root_1_4', 'root_2', 'root', 'root_3']
# tree_policy got this node:
# {'state': <__main__.State object at 0x117f35b38>, 'from_action': None, 'Q': 0, 'N': 14, 'children': [{'state': <__main__.State object at 0x117f35438>, 'from_action': 1, 'Q': 0, 'N': 11, 'children': [{'state': <__main__.State object at 0x117f35cc0>, 'from_action': 4, 'Q': 0, 'N': 7, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35cc0>, 'from_action': 4, 'Q': 0, 'N': 7, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35e48>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35e48>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35780>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35780>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f356d8>, 'from_action': 1, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f356d8>, 'from_action': 1, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}], 'parent': {...}}, {'state': <__main__.State object at 0x117f35438>, 'from_action': 1, 'Q': 0, 'N': 11, 'children': [{'state': <__main__.State object at 0x117f35cc0>, 'from_action': 4, 'Q': 0, 'N': 7, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35cc0>, 'from_action': 4, 'Q': 0, 'N': 7, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35e48>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35e48>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35780>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35780>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f356d8>, 'from_action': 1, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f356d8>, 'from_action': 1, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}], 'parent': {...}}, {'state': <__main__.State object at 0x117f35518>, 'from_action': 4, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35518>, 'from_action': 4, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35ef0>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35ef0>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35ac8>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35ac8>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}], 'parent': None}
#
# iter 14: action 1, nodes 9
# ['root_4', 'root_1', 'root_1_2', 'root_1_1', 'root_1_3', 'root_1_4', 'root_2', 'root', 'root_3']
# tree_policy got this node:
# {'state': <__main__.State object at 0x117f35b38>, 'from_action': None, 'Q': 0, 'N': 15, 'children': [{'state': <__main__.State object at 0x117f35438>, 'from_action': 1, 'Q': 0, 'N': 12, 'children': [{'state': <__main__.State object at 0x117f35cc0>, 'from_action': 4, 'Q': 0, 'N': 8, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35cc0>, 'from_action': 4, 'Q': 0, 'N': 8, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35e48>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35e48>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35780>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35780>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f356d8>, 'from_action': 1, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f356d8>, 'from_action': 1, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}], 'parent': {...}}, {'state': <__main__.State object at 0x117f35438>, 'from_action': 1, 'Q': 0, 'N': 12, 'children': [{'state': <__main__.State object at 0x117f35cc0>, 'from_action': 4, 'Q': 0, 'N': 8, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35cc0>, 'from_action': 4, 'Q': 0, 'N': 8, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35e48>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35e48>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35780>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35780>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f356d8>, 'from_action': 1, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f356d8>, 'from_action': 1, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}], 'parent': {...}}, {'state': <__main__.State object at 0x117f35518>, 'from_action': 4, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35518>, 'from_action': 4, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35ef0>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35ef0>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35ac8>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35ac8>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}], 'parent': None}
#
# iter 15: action 1, nodes 9
# ['root_4', 'root_1', 'root_1_2', 'root_1_1', 'root_1_3', 'root_1_4', 'root_2', 'root', 'root_3']
# tree_policy got this node:
# {'state': <__main__.State object at 0x117f35b38>, 'from_action': None, 'Q': 0, 'N': 16, 'children': [{'state': <__main__.State object at 0x117f35438>, 'from_action': 1, 'Q': 0, 'N': 13, 'children': [{'state': <__main__.State object at 0x117f35cc0>, 'from_action': 4, 'Q': 0, 'N': 9, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35cc0>, 'from_action': 4, 'Q': 0, 'N': 9, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35e48>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35e48>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35780>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35780>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f356d8>, 'from_action': 1, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f356d8>, 'from_action': 1, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}], 'parent': {...}}, {'state': <__main__.State object at 0x117f35438>, 'from_action': 1, 'Q': 0, 'N': 13, 'children': [{'state': <__main__.State object at 0x117f35cc0>, 'from_action': 4, 'Q': 0, 'N': 9, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35cc0>, 'from_action': 4, 'Q': 0, 'N': 9, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35e48>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35e48>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35780>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35780>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f356d8>, 'from_action': 1, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f356d8>, 'from_action': 1, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}], 'parent': {...}}, {'state': <__main__.State object at 0x117f35518>, 'from_action': 4, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35518>, 'from_action': 4, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35ef0>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35ef0>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35ac8>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35ac8>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}], 'parent': None}
#
# iter 16: action 1, nodes 9
# ['root_4', 'root_1', 'root_1_2', 'root_1_1', 'root_1_3', 'root_1_4', 'root_2', 'root', 'root_3']
# tree_policy got this node:
# {'state': <__main__.State object at 0x117f35b38>, 'from_action': None, 'Q': 0, 'N': 17, 'children': [{'state': <__main__.State object at 0x117f35438>, 'from_action': 1, 'Q': 0, 'N': 14, 'children': [{'state': <__main__.State object at 0x117f35cc0>, 'from_action': 4, 'Q': 0, 'N': 10, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35cc0>, 'from_action': 4, 'Q': 0, 'N': 10, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35e48>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35e48>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35780>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35780>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f356d8>, 'from_action': 1, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f356d8>, 'from_action': 1, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}], 'parent': {...}}, {'state': <__main__.State object at 0x117f35438>, 'from_action': 1, 'Q': 0, 'N': 14, 'children': [{'state': <__main__.State object at 0x117f35cc0>, 'from_action': 4, 'Q': 0, 'N': 10, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35cc0>, 'from_action': 4, 'Q': 0, 'N': 10, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35e48>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35e48>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35780>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35780>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f356d8>, 'from_action': 1, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f356d8>, 'from_action': 1, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}], 'parent': {...}}, {'state': <__main__.State object at 0x117f35518>, 'from_action': 4, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35518>, 'from_action': 4, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35ef0>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35ef0>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35ac8>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35ac8>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}], 'parent': None}
#
# iter 17: action 1, nodes 9
# ['root_4', 'root_1', 'root_1_2', 'root_1_1', 'root_1_3', 'root_1_4', 'root_2', 'root', 'root_3']
# tree_policy got this node:
# {'state': <__main__.State object at 0x117f35b38>, 'from_action': None, 'Q': 0, 'N': 18, 'children': [{'state': <__main__.State object at 0x117f35438>, 'from_action': 1, 'Q': 0, 'N': 15, 'children': [{'state': <__main__.State object at 0x117f35cc0>, 'from_action': 4, 'Q': 0, 'N': 11, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35cc0>, 'from_action': 4, 'Q': 0, 'N': 11, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35e48>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35e48>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35780>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35780>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f356d8>, 'from_action': 1, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f356d8>, 'from_action': 1, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}], 'parent': {...}}, {'state': <__main__.State object at 0x117f35438>, 'from_action': 1, 'Q': 0, 'N': 15, 'children': [{'state': <__main__.State object at 0x117f35cc0>, 'from_action': 4, 'Q': 0, 'N': 11, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35cc0>, 'from_action': 4, 'Q': 0, 'N': 11, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35e48>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35e48>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35780>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35780>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f356d8>, 'from_action': 1, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f356d8>, 'from_action': 1, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}], 'parent': {...}}, {'state': <__main__.State object at 0x117f35518>, 'from_action': 4, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35518>, 'from_action': 4, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35ef0>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35ef0>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35ac8>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35ac8>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}], 'parent': None}
#
# iter 18: action 1, nodes 9
# ['root_4', 'root_1', 'root_1_2', 'root_1_1', 'root_1_3', 'root_1_4', 'root_2', 'root', 'root_3']
# tree_policy got this node:
# {'state': <__main__.State object at 0x117f35b38>, 'from_action': None, 'Q': 0, 'N': 19, 'children': [{'state': <__main__.State object at 0x117f35438>, 'from_action': 1, 'Q': 0, 'N': 16, 'children': [{'state': <__main__.State object at 0x117f35cc0>, 'from_action': 4, 'Q': 0, 'N': 12, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35cc0>, 'from_action': 4, 'Q': 0, 'N': 12, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35e48>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35e48>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35780>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35780>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f356d8>, 'from_action': 1, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f356d8>, 'from_action': 1, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}], 'parent': {...}}, {'state': <__main__.State object at 0x117f35438>, 'from_action': 1, 'Q': 0, 'N': 16, 'children': [{'state': <__main__.State object at 0x117f35cc0>, 'from_action': 4, 'Q': 0, 'N': 12, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35cc0>, 'from_action': 4, 'Q': 0, 'N': 12, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35e48>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35e48>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35780>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35780>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f356d8>, 'from_action': 1, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f356d8>, 'from_action': 1, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}], 'parent': {...}}, {'state': <__main__.State object at 0x117f35518>, 'from_action': 4, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35518>, 'from_action': 4, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35ef0>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35ef0>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35ac8>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35ac8>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}], 'parent': None}
#
# iter 19: action 1, nodes 9
# ['root_4', 'root_1', 'root_1_2', 'root_1_1', 'root_1_3', 'root_1_4', 'root_2', 'root', 'root_3']
# tree_policy got this node:
# ...
#
# iter 494: action 1, nodes 9
# ['root_4', 'root_1', 'root_1_2', 'root_1_1', 'root_1_3', 'root_1_4', 'root_2', 'root', 'root_3']
# tree_policy got this node:
# {'state': <__main__.State object at 0x117f35b38>, 'from_action': None, 'Q': 0, 'N': 495, 'children': [{'state': <__main__.State object at 0x117f35438>, 'from_action': 1, 'Q': 0, 'N': 492, 'children': [{'state': <__main__.State object at 0x117f35cc0>, 'from_action': 4, 'Q': 0, 'N': 488, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35cc0>, 'from_action': 4, 'Q': 0, 'N': 488, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35e48>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35e48>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35780>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35780>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f356d8>, 'from_action': 1, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f356d8>, 'from_action': 1, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}], 'parent': {...}}, {'state': <__main__.State object at 0x117f35438>, 'from_action': 1, 'Q': 0, 'N': 492, 'children': [{'state': <__main__.State object at 0x117f35cc0>, 'from_action': 4, 'Q': 0, 'N': 488, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35cc0>, 'from_action': 4, 'Q': 0, 'N': 488, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35e48>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35e48>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35780>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35780>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f356d8>, 'from_action': 1, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f356d8>, 'from_action': 1, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}], 'parent': {...}}, {'state': <__main__.State object at 0x117f35518>, 'from_action': 4, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35518>, 'from_action': 4, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35ef0>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35ef0>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35ac8>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35ac8>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}], 'parent': None}
#
# iter 495: action 1, nodes 9
# ['root_4', 'root_1', 'root_1_2', 'root_1_1', 'root_1_3', 'root_1_4', 'root_2', 'root', 'root_3']
# tree_policy got this node:
# {'state': <__main__.State object at 0x117f35b38>, 'from_action': None, 'Q': 0, 'N': 496, 'children': [{'state': <__main__.State object at 0x117f35438>, 'from_action': 1, 'Q': 0, 'N': 493, 'children': [{'state': <__main__.State object at 0x117f35cc0>, 'from_action': 4, 'Q': 0, 'N': 489, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35cc0>, 'from_action': 4, 'Q': 0, 'N': 489, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35e48>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35e48>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35780>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35780>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f356d8>, 'from_action': 1, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f356d8>, 'from_action': 1, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}], 'parent': {...}}, {'state': <__main__.State object at 0x117f35438>, 'from_action': 1, 'Q': 0, 'N': 493, 'children': [{'state': <__main__.State object at 0x117f35cc0>, 'from_action': 4, 'Q': 0, 'N': 489, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35cc0>, 'from_action': 4, 'Q': 0, 'N': 489, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35e48>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35e48>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35780>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35780>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f356d8>, 'from_action': 1, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f356d8>, 'from_action': 1, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}], 'parent': {...}}, {'state': <__main__.State object at 0x117f35518>, 'from_action': 4, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35518>, 'from_action': 4, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35ef0>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35ef0>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35ac8>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35ac8>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}], 'parent': None}
#
# iter 496: action 1, nodes 9
# ['root_4', 'root_1', 'root_1_2', 'root_1_1', 'root_1_3', 'root_1_4', 'root_2', 'root', 'root_3']
# tree_policy got this node:
# {'state': <__main__.State object at 0x117f35b38>, 'from_action': None, 'Q': 0, 'N': 497, 'children': [{'state': <__main__.State object at 0x117f35438>, 'from_action': 1, 'Q': 0, 'N': 494, 'children': [{'state': <__main__.State object at 0x117f35cc0>, 'from_action': 4, 'Q': 0, 'N': 490, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35cc0>, 'from_action': 4, 'Q': 0, 'N': 490, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35e48>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35e48>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35780>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35780>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f356d8>, 'from_action': 1, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f356d8>, 'from_action': 1, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}], 'parent': {...}}, {'state': <__main__.State object at 0x117f35438>, 'from_action': 1, 'Q': 0, 'N': 494, 'children': [{'state': <__main__.State object at 0x117f35cc0>, 'from_action': 4, 'Q': 0, 'N': 490, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35cc0>, 'from_action': 4, 'Q': 0, 'N': 490, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35e48>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35e48>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35780>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35780>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f356d8>, 'from_action': 1, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f356d8>, 'from_action': 1, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}], 'parent': {...}}, {'state': <__main__.State object at 0x117f35518>, 'from_action': 4, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35518>, 'from_action': 4, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35ef0>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35ef0>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35ac8>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35ac8>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}], 'parent': None}
#
# iter 497: action 1, nodes 9
# ['root_4', 'root_1', 'root_1_2', 'root_1_1', 'root_1_3', 'root_1_4', 'root_2', 'root', 'root_3']
# tree_policy got this node:
# {'state': <__main__.State object at 0x117f35b38>, 'from_action': None, 'Q': 0, 'N': 498, 'children': [{'state': <__main__.State object at 0x117f35438>, 'from_action': 1, 'Q': 0, 'N': 495, 'children': [{'state': <__main__.State object at 0x117f35cc0>, 'from_action': 4, 'Q': 0, 'N': 491, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35cc0>, 'from_action': 4, 'Q': 0, 'N': 491, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35e48>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35e48>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35780>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35780>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f356d8>, 'from_action': 1, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f356d8>, 'from_action': 1, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}], 'parent': {...}}, {'state': <__main__.State object at 0x117f35438>, 'from_action': 1, 'Q': 0, 'N': 495, 'children': [{'state': <__main__.State object at 0x117f35cc0>, 'from_action': 4, 'Q': 0, 'N': 491, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35cc0>, 'from_action': 4, 'Q': 0, 'N': 491, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35e48>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35e48>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35780>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35780>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f356d8>, 'from_action': 1, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f356d8>, 'from_action': 1, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}], 'parent': {...}}, {'state': <__main__.State object at 0x117f35518>, 'from_action': 4, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35518>, 'from_action': 4, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35ef0>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35ef0>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35ac8>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35ac8>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}], 'parent': None}
#
# iter 498: action 1, nodes 9
# ['root_4', 'root_1', 'root_1_2', 'root_1_1', 'root_1_3', 'root_1_4', 'root_2', 'root', 'root_3']
# tree_policy got this node:
# {'state': <__main__.State object at 0x117f35b38>, 'from_action': None, 'Q': 0, 'N': 499, 'children': [{'state': <__main__.State object at 0x117f35438>, 'from_action': 1, 'Q': 0, 'N': 496, 'children': [{'state': <__main__.State object at 0x117f35cc0>, 'from_action': 4, 'Q': 0, 'N': 492, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35cc0>, 'from_action': 4, 'Q': 0, 'N': 492, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35e48>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35e48>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35780>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35780>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f356d8>, 'from_action': 1, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f356d8>, 'from_action': 1, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}], 'parent': {...}}, {'state': <__main__.State object at 0x117f35438>, 'from_action': 1, 'Q': 0, 'N': 496, 'children': [{'state': <__main__.State object at 0x117f35cc0>, 'from_action': 4, 'Q': 0, 'N': 492, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35cc0>, 'from_action': 4, 'Q': 0, 'N': 492, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35e48>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35e48>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35780>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35780>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f356d8>, 'from_action': 1, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f356d8>, 'from_action': 1, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}], 'parent': {...}}, {'state': <__main__.State object at 0x117f35518>, 'from_action': 4, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35518>, 'from_action': 4, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35ef0>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35ef0>, 'from_action': 3, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35ac8>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}, {'state': <__main__.State object at 0x117f35ac8>, 'from_action': 2, 'Q': 0, 'N': 1, 'children': [], 'parent': {...}}], 'parent': None}
#
# iter 499: action 1, nodes 9
# ['root_4', 'root_1', 'root_1_2', 'root_1_1', 'root_1_3', 'root_1_4', 'root_2', 'root', 'root_3']

# %%
root_s

# %%
len(nodes)
# Out:
# 9

# %%
nodes
# Out:
# {<__main__.State at 0x117f48ba8>: [{'N': 1,
#    'Q': 0,
#    'children': [{'N': 1,
#      'Q': 0,
#      'children': [],
#      'from_action': 1,
#      'parent': {...},
#      'state': <__main__.State at 0x117f48a20>},
#     {'N': 1,
#      'Q': 0,
#      'children': [],
#      'from_action': 1,
#      'parent': {...},
#      'state': <__main__.State at 0x117f48a20>}],
#    'from_action': None,
#    'parent': None,
#    'state': <__main__.State at 0x117f48ba8>}],
#  <__main__.State at 0x117f48a20>: [{'N': 1,
#    'Q': 0,
#    'children': [],
#    'from_action': 1,
#    'parent': {'N': 1,
#     'Q': 0,
#     'children': [{...}, {...}],
#     'from_action': None,
#     'parent': None,
#     'state': <__main__.State at 0x117f48ba8>},
#    'state': <__main__.State at 0x117f48a20>}]}

# %%
best_node(list(nodes.values()))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-440-6bcc5ea78054> in <module>()
# ----> 1 best_node(list(nodes.values()))
#
# <ipython-input-345-5d279aa9e5b3> in best_node(node_list, c)
#       8
#       9 def best_node(node_list, c=1):
# ---> 10     return max(node_list, key=partial(ucb, c=c))
#      11
#      12 def best_child(node, c=1):
#
# <ipython-input-345-5d279aa9e5b3> in ucb(node, c)
#       1 def ucb(node, c=1):
# ----> 2     if node['N'] == 0:
#       3         if c != 0:
#       4             return float('inf')
#       5         else:
#
# TypeError: list indices must be integers or slices, not str

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import sys
from time import time
import os

# %pylab inline
pylab.rcParams['figure.figsize'] = (20.0, 10.0)

# %load_ext autoreload
# %autoreload 2

sys.path.append('..')

import isolation
import sample_players
import run_match
import my_custom_player as custom
# Out:
# Populating the interactive namespace from numpy and matplotlib
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# /Users/antelinvestigacionydesarrollo/anaconda3/envs/aind/lib/python3.5/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['time']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
# Constant parameteres
time_limit = 150
num_matches = 3

# Create the agents that will play
agent_names = ('CustomPlayer1', 'CustomPlayer2')
agent1 = isolation.Agent(custom.CustomPlayer, agent_names[0])
agent2 = isolation.Agent(custom.CustomPlayer, agent_names[1])
agents = (agent1, agent2)

# Get the initial states
root = isolation.Isolation()

# Generate the matches
matches = [(agents, state, time_limit, match_id) 
           for match_id, state in enumerate([root]*num_matches)]

# %%
winner, game_history, match_id = isolation.play(matches[0])
# Out:
# THE NODE WAS NOT IN THE NODES
# NEW CALL. nodes: 0
# searching...
# tree
# default
# backup
# best
# action 114, nodes 1
#
# searching...
# tree
# default
# backup
# best
# action 114, nodes 2
#
# searching...
# tree
# default
# backup
# best
# action 114, nodes 3
#
# searching...
# tree
# default
# backup
# best
# action 114, nodes 4
#
# searching...
# tree
# default
# THE NODE WAS NOT IN THE NODES
# NEW CALL. nodes: 0
# searching...
# tree
# default
# backup
# best
# action 81, nodes 1
#
# searching...
# tree
# default
# backup
# best
# action 55, nodes 2
#
# searching...
# tree
# default
# backup
# best
# action 55, nodes 3
#
# searching...
# tree
# default
# backup
# best
# action 55, nodes 4
#
# searching...
# tree
# default
# backup
# best
# action 55, nodes 5
#
# searching...
# tree
# default
# backup
# best
# action 55, nodes 6
#
# searching...
# THE NODE WAS NOT IN THE NODES
# NEW CALL. nodes: 0
# searching...
# tree
# default
# backup
# best
# action -27, nodes 1
#
# searching...
# tree
# default
# backup
# best
# action -27, nodes 2
#
# searching...
# tree
# default
# backup
# best
# action -27, nodes 3
#
# searching...
# tree
# default
# backup
# best
# action -27, nodes 4
#
# searching...
# tree
# default
# backup
# best
# action -27, nodes 5
#
# searching...
# tree
# default
# backup
# best
# action -27, nodes 6
#
# searching...
# THE NODE WAS NOT IN THE NODES
# NEW CALL. nodes: 0
# searching...
# tree
# default
# backup
# best
# action 25, nodes 1
#
# searching...
# tree
# default
# backup
# best
# action -15, nodes 2
#
# searching...
# tree
# default
# backup
# best
# action -15, nodes 3
#
# searching...
# tree
# default
# backup
# best
# action -15, nodes 4
#
# searching...
# tree
# default
# backup
# best
# action -15, nodes 5
#
# searching...
# tree
# default
# backup
# action -15, nodes 6
# best
#
# searching...
# THE NODE WAS NOT IN THE NODES
# NEW CALL. nodes: 0
# searching...
# tree
# default
# backup
# best
# action -15, nodes 1
#
# searching...
# tree
# default
# backup
# best
# action -15, nodes 2
#
# searching...
# tree
# default
# backup
# best
# action -15, nodes 3
#
# searching...
# tree
# default
# backup
# best
# action -15, nodes 4
#
# searching...
# tree
# default
# backup
# best
# action -27, nodes 5
#
# searching...
# tree
# default
# backup
# best
# action -27, nodes 6
#
# searching...
# THE NODE WAS NOT IN THE NODES
# NEW CALL. nodes: 0
# searching...
# tree
# default
# backup
# best
# action 27, nodes 1
#
# searching...
# tree
# default
# backup
# best
# action -25, nodes 2
#
# searching...
# tree
# default
# backup
# best
# action -25, nodes 3
#
# searching...
# tree
# default
# backup
# best
# action -25, nodes 4
#
# searching...
# tree
# default
# backup
# best
# action -25, nodes 5
#
# searching...
# THE NODE WAS NOT IN THE NODES
# NEW CALL. nodes: 0
# searching...
# tree
# default
# backup
# best
# action -11, nodes 1
#
# searching...
# tree
# default
# backup
# best
# action -11, nodes 2
#
# searching...
# tree
# default
# backup
# best
# action -25, nodes 3
#
# searching...
# tree
# default
# backup
# best
# action -25, nodes 4
#
# searching...
# tree
# default
# backup
# best
# action -25, nodes 5
#
# searching...
# tree
# default
# THE NODE WAS NOT IN THE NODES
# NEW CALL. nodes: 0
# searching...
# tree
# default
# backup
# best
# action 27, nodes 1
#
# searching...
# tree
# default
# backup
# best
# action 27, nodes 2
#
# searching...
# tree
# default
# backup
# best
# action 27, nodes 3
#
# searching...
# tree
# default
# backup
# best
# action 27, nodes 4
#
# searching...
# tree
# default
# backup
# best
# action -15, nodes 5
#
# searching...
# tree
# default
# backup
# best
# action -15, nodes 6
#
# searching...
# THE NODE WAS NOT IN THE NODES
# NEW CALL. nodes: 0
# searching...
# tree
# default
# backup
# best
# action 27, nodes 1
#
# searching...
# default
# tree
# backup
# best
# action 27, nodes 2
#
# searching...
# tree
# default
# backup
# best
# action 27, nodes 3
#
# searching...
# tree
# default
# backup
# best
# action 27, nodes 4
#
# searching...
# tree
# default
# backup
# best
# action 27, nodes 5
#
# searching...
# tree
# default
# backup
# best
# action 27, nodes 6
#
# searching...
# THE NODE WAS NOT IN THE NODES
# NEW CALL. nodes: 0
# searching...
# tree
# default
# backup
# best
# action 27, nodes 1
#
# searching...
# tree
# default
# backup
# best
# action 27, nodes 2
#
# searching...
# tree
# default
# backup
# best
# action 27, nodes 3
#
# searching...
# tree
# default
# backup
# best
# action 27, nodes 4
#
# searching...
# tree
# default
# backup
# best
# action 27, nodes 5
#
# searching...
# tree
# default
# backup
# best
# action 27, nodes 6
#
# searching...
# tree
# default
# backup
# best
# action 27, nodes 7
#
# searching...
# FOUND THE ROOT NODE
# Possible nodes: 1
# NEW CALL. nodes: 6
# searching...
# tree
# default
# backup
# best
# action 11, nodes 7
#
# searching...
# tree
# default
# backup
# best
# action 11, nodes 8
#
# searching...
# tree
# default
# backup
# best
# action 11, nodes 9
#
# searching...
# tree
# default
# backup
# best
# action 11, nodes 10
#
# searching...
# tree
# default
# backup
# best
# action 11, nodes 11
#
# searching...
# tree
# default
# backup
# best
# action 11, nodes 12
#
# searching...
# FOUND THE ROOT NODE
# Possible nodes: 1
# NEW CALL. nodes: 7
# searching...
# tree
# default
# backup
# best
# action -11, nodes 8
#
# searching...
# tree
# default
# backup
# best
# action -11, nodes 9
#
# searching...
# tree
# default
# backup
# best
# action -11, nodes 10
#
# searching...
# tree
# default
# backup
# best
# action -11, nodes 11
#
# searching...
# tree
# default
# backup
# best
# action -11, nodes 12
#
# searching...
# THE NODE WAS NOT IN THE NODES
# NEW CALL. nodes: 0
# searching...
# tree
# default
# backup
# best
# action 11, nodes 1
#
# searching...
# tree
# default
# backup
# best
# action 11, nodes 2
#
# searching...
# tree
# default
# backup
# best
# action 11, nodes 3
#
# searching...
# tree
# default
# backup
# best
# action 11, nodes 4
#
# searching...
# tree
# default
# backup
# best
# action 11, nodes 5
#
# searching...
# tree
# default
# backup
# best
# action 11, nodes 6
#
# searching...
# tree
# default
# THE NODE WAS NOT IN THE NODES
# NEW CALL. nodes: 0
# searching...
# tree
# default
# backup
# best
# action 25, nodes 1
#
# searching...
# tree
# default
# backup
# best
# action 25, nodes 2
#
# searching...
# tree
# default
# backup
# best
# action 25, nodes 3
#
# searching...
# tree
# default
# backup
# best
# action 25, nodes 4
#
# searching...
# tree
# default
# backup
# best
# action 25, nodes 5
#
# searching...
# tree
# default
# backup
# best
# action 25, nodes 6
#
# searching...
# tree
# default
# backup
# best
# action 25, nodes 7
#
# searching...
# THE NODE WAS NOT IN THE NODES
# NEW CALL. nodes: 0
# searching...
# tree
# default
# backup
# best
# action -15, nodes 1
#
# searching...
# tree
# default
# backup
# best
# action -15, nodes 2
#
# searching...
# tree
# default
# backup
# best
# action -15, nodes 3
#
# searching...
# tree
# default
# backup
# best
# action -15, nodes 4
#
# searching...
# tree
# default
# backup
# best
# action -15, nodes 5
#
# searching...
# tree
# default
# backup
# best
# action -15, nodes 6
#
# searching...
# tree
# default
# backup
# best
# action -15, nodes 7
#
# searching...
# THE NODE WAS NOT IN THE NODES
# NEW CALL. nodes: 0
# searching...
# tree
# default
# backup
# best
# action 27, nodes 1
#
# searching...
# tree
# default
# backup
# best
# action -27, nodes 2
#
# searching...
# tree
# default
# backup
# best
# action -27, nodes 3
#
# searching...
# tree
# default
# backup
# best
# action -27, nodes 4
#
# searching...
# tree
# default
# backup
# best
# action -27, nodes 5
#
# searching...
# tree
# default
# backup
# best
# action -27, nodes 6
#
# searching...
# THE NODE WAS NOT IN THE NODES
# NEW CALL. nodes: 0
# searching...
# tree
# default
# backup
# best
# action 25, nodes 1
#
# searching...
# tree
# default
# backup
# best
# action 25, nodes 2
#
# searching...
# tree
# default
# backup
# best
# action 25, nodes 3
#
# searching...
# tree
# default
# backup
# best
# action 25, nodes 4
#
# searching...
# tree
# default
# backup
# best
# action 25, nodes 5
#
# searching...
# tree
# default
# backup
# best
# action 25, nodes 6
#
# searching...
# tree
# default
# THE NODE WAS NOT IN THE NODES
# NEW CALL. nodes: 0
# searching...
# tree
# default
# backup
# best
# action -11, nodes 1
#
# searching...
# tree
# default
# backup
# best
# action -11, nodes 2
#
# searching...
# tree
# default
# backup
# best
# action -11, nodes 3
#
# searching...
# tree
# default
# backup
# best
# action -11, nodes 4
#
# searching...
# tree
# default
# backup
# best
# action -11, nodes 5
#
# searching...
# tree
# default
# backup
# best
# action -11, nodes 6
#
# searching...
# tree
# default
# THE NODE WAS NOT IN THE NODES
# NEW CALL. nodes: 0
# searching...
# tree
# default
# backup
# best
# action 15, nodes 1
#
# searching...
# tree
# default
# backup
# best
# action 15, nodes 2
#
# searching...
# tree
# default
# backup
# best
# action 15, nodes 3
#
# searching...
# tree
# default
# backup
# best
# action 15, nodes 4
#
# searching...
# tree
# default
# backup
# best
# action 15, nodes 5
#
# searching...
# tree
# default
# backup
# best
# action 15, nodes 6
#
# searching...
# tree
# default
# backup
# best
# action 15, nodes 7
#
# searching...
# FOUND THE ROOT NODE
# Possible nodes: 1
# NEW CALL. nodes: 7
# searching...
# tree
# default
# backup
# best
# action 27, nodes 8
#
# searching...
# tree
# default
# backup
# best
# action 27, nodes 9
#
# searching...
# tree
# default
# backup
# best
# action 27, nodes 10
#
# searching...
# tree
# default
# backup
# best
# action 27, nodes 11
#
# searching...
# tree
# default
# backup
# best
# action 27, nodes 12
#
# searching...
# tree
# default
# backup
# best
# action 27, nodes 13
#
# searching...
# tree
# default
# backup
# best
# action 27, nodes 14
#
# searching...
# FOUND THE ROOT NODE
# Possible nodes: 1
# NEW CALL. nodes: 7
# searching...
# tree
# default
# backup
# best
# action -27, nodes 8
#
# searching...
# tree
# default
# backup
# best
# action -11, nodes 9
#
# searching...
# tree
# default
# backup
# best
# action -27, nodes 10
#
# searching...
# tree
# default
# backup
# best
# action -27, nodes 11
#
# searching...
# tree
# default
# backup
# best
# action -27, nodes 12
#
# searching...
# tree
# default
# backup
# best
# action -27, nodes 13
#
# searching...
# tree
# default
# backup
# best
# action -27, nodes 14
#
# searching...
# FOUND THE ROOT NODE
# Possible nodes: 1
# NEW CALL. nodes: 14
# searching...
# tree
# default
# backup
# best
# action 15, nodes 15
#
# searching...
# tree
# default
# backup
# best
# action 15, nodes 16
#
# searching...
# tree
# default
# backup
# best
# action 15, nodes 17
#
# searching...
# tree
# default
# backup
# best
# action 15, nodes 18
#
# searching...
# tree
# default
# backup
# best
# action 15, nodes 19
#
# searching...
# tree
# default
# backup
# best
# action 15, nodes 20
#
# searching...
# tree
# default
# FOUND THE ROOT NODE
# Possible nodes: 1
# NEW CALL. nodes: 14
# searching...
# tree
# default
# backup
# best
# action 11, nodes 15
#
# searching...
# tree
# default
# backup
# best
# action 11, nodes 16
#
# searching...
# tree
# default
# backup
# best
# action 11, nodes 17
#
# searching...
# tree
# default
# backup
# best
# action 11, nodes 18
#
# searching...
# tree
# default
# backup
# best
# action 11, nodes 19
#
# searching...
# tree
# default
# backup
# best
# action 11, nodes 20
#
# searching...
# tree
# default
# backup
# best
# action 11, nodes 21
#
# searching...
# FOUND THE ROOT NODE
# Possible nodes: 1
# NEW CALL. nodes: 21
# searching...
# tree
# default
# backup
# best
# action 11, nodes 22
#
# searching...
# tree
# default
# backup
# best
# action 11, nodes 23
#
# searching...
# tree
# default
# backup
# best
# action 11, nodes 24
#
# searching...
# tree
# default
# backup
# best
# action 11, nodes 25
#
# searching...
# tree
# default
# backup
# best
# action 11, nodes 26
#
# searching...
# tree
# default
# backup
# best
# action 11, nodes 27
#
# searching...
# tree
# default
# backup
# best
# action 11, nodes 28
#
# searching...
# THE NODE WAS NOT IN THE NODES
# NEW CALL. nodes: 0
# searching...
# tree
# default
# backup
# best
# action 15, nodes 1
#
# searching...
# tree
# default
# backup
# best
# action 15, nodes 2
#
# searching...
# tree
# default
# backup
# best
# action 15, nodes 3
#
# searching...
# tree
# default
# backup
# best
# action 15, nodes 4
#
# searching...
# tree
# default
# backup
# best
# action 15, nodes 5
#
# searching...
# tree
# default
# backup
# best
# action 15, nodes 6
#
# searching...
# tree
# default
# THE NODE WAS NOT IN THE NODES
# NEW CALL. nodes: 0
# searching...
# tree
# default
# backup
# best
# action 11, nodes 1
#
# searching...
# tree
# default
# backup
# best
# action 11, nodes 2
#
# searching...
# tree
# default
# backup
# best
# action 27, nodes 3
#
# searching...
# tree
# default
# backup
# best
# action 27, nodes 4
#
# searching...
# tree
# default
# backup
# best
# action 27, nodes 5
#
# searching...
# tree
# default
# backup
# best
# action 27, nodes 6
#
# searching...
# FOUND THE ROOT NODE
# Possible nodes: 1
# NEW CALL. nodes: 7
# searching...
# tree
# default
# backup
# best
# action -11, nodes 8
#
# searching...
# tree
# default
# backup
# best
# action -11, nodes 9
#
# searching...
# tree
# default
# backup
# best
# action -11, nodes 10
#
# searching...
# tree
# default
# backup
# best
# action -11, nodes 11
#
# searching...
# tree
# default
# backup
# best
# action -11, nodes 12
#
# searching...
# tree
# default
# backup
# best
# action -11, nodes 13
#
# searching...
# tree
# default
# backup
# best
# action -11, nodes 14
#
# searching...
# THE NODE WAS NOT IN THE NODES
# NEW CALL. nodes: 0
# searching...
# tree
# default
# backup
# best
# action 15, nodes 1
#
# searching...
# tree
# default
# backup
# best
# action 15, nodes 2
#
# searching...
# tree
# default
# backup
# best
# action 15, nodes 3
#
# searching...
# tree
# default
# backup
# best
# action 15, nodes 4
#
# searching...
# tree
# default
# backup
# best
# action 15, nodes 5
#
# searching...
# tree
# default
# backup
# best
# action 15, nodes 6
#
# searching...
# tree
# default
# backup
# best
# action 15, nodes 7
#
# searching...
# FOUND THE ROOT NODE
# Possible nodes: 1
# NEW CALL. nodes: 14
# searching...
# tree
# default
# backup
# best
# action -25, nodes 15
#
# searching...
# tree
# default
# backup
# best
# action -11, nodes 16
#
# searching...
# tree
# default
# backup
# best
# action -11, nodes 17
#
# searching...
# tree
# default
# backup
# best
# action -11, nodes 18
#
# searching...
# tree
# default
# backup
# best
# action -25, nodes 19
#
# searching...
# tree
# default
# backup
# best
# action -25, nodes 20
#
# searching...
# tree
# default
# backup
# best
# action -25, nodes 21
#
# searching...
# THE NODE WAS NOT IN THE NODES
# NEW CALL. nodes: 0
# searching...
# tree
# default
# backup
# best
# action 15, nodes 1
#
# searching...
# tree
# default
# backup
# best
# action 15, nodes 2
#
# searching...
# tree
# default
# backup
# best
# action 15, nodes 3
#
# searching...
# tree
# default
# backup
# best
# action 15, nodes 4
#
# searching...
# tree
# default
# backup
# best
# action 15, nodes 5
#
# searching...
# tree
# default
# backup
# best
# action 15, nodes 6
#
# searching...
# tree
# default
# backup
# best
# action 15, nodes 7
#
# searching...
# FOUND THE ROOT NODE
# Possible nodes: 1
# NEW CALL. nodes: 21
# searching...
# tree
# default
# backup
# best
# action -11, nodes 22
#
# searching...
# tree
# default
# backup
# best
# action -11, nodes 23
#
# searching...
# tree
# default
# backup
# best
# action -11, nodes 24
#
# searching...
# tree
# default
# backup
# best
# action -25, nodes 25
#
# searching...
# tree
# default
# backup
# best
# action -11, nodes 26
#
# tree
# searching...
# default
# backup
# best
# action -11, nodes 27
#
# searching...
# tree
# default
# backup
# best
# action -11, nodes 28
#
# searching...
# tree
# default
# FOUND THE ROOT NODE
# Possible nodes: 1
# NEW CALL. nodes: 7
# searching...
# tree
# default
# backup
# best
# action -25, nodes 8
#
# searching...
# tree
# default
# backup
# best
# action -27, nodes 9
#
# searching...
# tree
# default
# backup
# best
# action -27, nodes 10
#
# searching...
# tree
# default
# backup
# best
# action -27, nodes 11
#
# searching...
# tree
# default
# backup
# best
# action -25, nodes 12
#
# searching...
# tree
# default
# backup
# best
# action -25, nodes 13
#
# searching...
# tree
# default
# backup
# best
# action -25, nodes 14
#
# searching...
# FOUND THE ROOT NODE
# Possible nodes: 1
# NEW CALL. nodes: 29
# searching...
# tree
# default
# backup
# best
# action -27, nodes 30
#
# searching...
# tree
# default
# backup
# best
# action -27, nodes 31
#
# searching...
# tree
# default
# backup
# best
# action -27, nodes 32
#
# searching...
# tree
# default
# backup
# best
# action -27, nodes 33
#
# searching...
# tree
# default
# backup
# best
# action -27, nodes 34
#
# searching...
# tree
# default
# backup
# best
# action -27, nodes 35
#
# searching...
# tree
# default
# backup
# best
# action -27, nodes 36
#
# searching...
# THE NODE WAS NOT IN THE NODES
# NEW CALL. nodes: 0
# searching...
# tree
# default
# backup
# best
# action 11, nodes 1
#
# searching...
# tree
# default
# backup
# best
# action 11, nodes 2
#
# searching...
# tree
# default
# backup
# best
# action 11, nodes 3
#
# searching...
# tree
# default
# backup
# best
# action 11, nodes 4
#
# searching...
# tree
# default
# backup
# best
# action 11, nodes 5
#
# searching...
# tree
# default
# backup
# best
# action 11, nodes 6
#
# searching...
# tree
# default
# backup
# best
# action 11, nodes 7
#
# searching...
# FOUND THE ROOT NODE
# Possible nodes: 1
# NEW CALL. nodes: 36
# searching...
# tree
# default
# backup
# best
# action -11, nodes 37
#
# searching...
# tree
# default
# backup
# best
# action -11, nodes 38
#
# searching...
# tree
# default
# backup
# best
# action -11, nodes 39
#
# searching...
# tree
# default
# backup
# best
# action -27, nodes 40
#
# searching...
# tree
# default
# backup
# best
# action 25, nodes 41
#
# searching...
# tree
# default
# backup
# best
# action 25, nodes 42
#
# searching...
# tree
# default
# backup
# best
# action 25, nodes 43
#
# searching...
# FOUND THE ROOT NODE
# Possible nodes: 1
# NEW CALL. nodes: 7
# searching...
# tree
# default
# backup
# best
# action 11, nodes 8
#
# searching...
# tree
# default
# backup
# best
# action -25, nodes 9
#
# searching...
# tree
# default
# backup
# best
# action 11, nodes 10
#
# searching...
# tree
# default
# backup
# best
# action 11, nodes 11
#
# searching...
# tree
# default
# best
# backup
# action 11, nodes 12
#
# searching...
# tree
# default
# FOUND THE ROOT NODE
# Possible nodes: 1
# NEW CALL. nodes: 43
# searching...
# tree
# default
# backup
# best
# action 11, nodes 44
#
# searching...
# tree
# default
# backup
# best
# action -27, nodes 45
#
# searching...
# tree
# default
# backup
# best
# action -27, nodes 46
#
# searching...
# tree
# default
# backup
# best
# action -27, nodes 47
#
# searching...
# tree
# default
# backup
# best
# action -27, nodes 48
#
# searching...
# tree
# default
# backup
# best
# action -27, nodes 49
#
# searching...
# tree
# default
# backup
# best
# action -27, nodes 50
#
# searching...
# FOUND THE ROOT NODE
# Possible nodes: 1
# NEW CALL. nodes: 13
# searching...
# tree
# default
# backup
# best
# action -15, nodes 14
#
# searching...
# tree
# default
# backup
# best
# action -15, nodes 15
#
# searching...
# tree
# default
# backup
# best
# action -15, nodes 16
#
# searching...
# tree
# default
# backup
# best
# action -15, nodes 17
#
# searching...
# tree
# default
# backup
# best
# action -15, nodes 18
#
# searching...
# tree
# default
# backup
# best
# action -15, nodes 19
#
# searching...
# tree
# default
# backup
# best
# action -15, nodes 20
#
# searching...
# tree
# default
# backup
# best
# action -15, nodes 21
#
# searching...
# THE NODE WAS NOT IN THE NODES
# NEW CALL. nodes: 0
# searching...
# tree
# default
# backup
# best
# action -11, nodes 1
#
# searching...
# tree
# default
# backup
# best
# action -11, nodes 2
#
# searching...
# tree
# default
# backup
# best
# action -11, nodes 3
#
# searching...
# tree
# default
# backup
# best
# action -11, nodes 4
#
# searching...
# tree
# default
# backup
# best
# action -11, nodes 5
#
# searching...
# tree
# default
# backup
# best
# action -11, nodes 6
#
# searching...
# tree
# default
# FOUND THE ROOT NODE
# Possible nodes: 1
# NEW CALL. nodes: 21
# searching...
# tree
# default
# backup
# best
# action -15, nodes 22
#
# searching...
# tree
# default
# backup
# best
# action -15, nodes 23
#
# searching...
# tree
# default
# backup
# best
# action -15, nodes 24
#
# searching...
# tree
# default
# backup
# best
# action -15, nodes 25
#
# searching...
# tree
# default
# backup
# best
# action -15, nodes 26
#
# searching...
# tree
# default
# backup
# best
# action -15, nodes 27
#
# searching...
# tree
# default
# backup
# best
# action -15, nodes 28
#
# searching...
# tree
# default
# backup
# best
# action -15, nodes 29
#
# searching...
# tree
# default
# THE NODE WAS NOT IN THE NODES
# NEW CALL. nodes: 0
# searching...
# tree
# default
# backup
# best
# action -11, nodes 1
#
# searching...
# tree
# default
# backup
# best
# action 25, nodes 2
#
# searching...
# tree
# default
# backup
# best
# action 25, nodes 3
#
# searching...
# tree
# default
# backup
# best
# action 25, nodes 4
#
# searching...
# tree
# default
# backup
# best
# action 25, nodes 5
#
# searching...
# tree
# default
# backup
# best
# action 25, nodes 6
#
# searching...
# tree
# default
# backup
# best
# action 27, nodes 7
#
# searching...
# tree
# default
# backup
# best
# action 27, nodes 8
#
# searching...
# FOUND THE ROOT NODE
# Possible nodes: 1
# NEW CALL. nodes: 30
# searching...
# tree
# default
# backup
# best
# action -27, nodes 31
#
# searching...
# tree
# default
# backup
# best
# action -27, nodes 32
#
# searching...
# tree
# default
# backup
# best
# action -27, nodes 33
#
# searching...
# tree
# default
# backup
# best
# action -27, nodes 34
#
# searching...
# tree
# default
# backup
# best
# action -27, nodes 35
#
# searching...
# tree
# default
# backup
# best
# action -27, nodes 36
#
# searching...
# tree
# default
# backup
# best
# action -27, nodes 37
#
# searching...
# THE NODE WAS NOT IN THE NODES
# NEW CALL. nodes: 0
# searching...
# tree
# default
# backup
# best
# action -15, nodes 1
#
# searching...
# tree
# default
# backup
# best
# action -25, nodes 2
#
# searching...
# tree
# default
# backup
# best
# action -25, nodes 3
#
# searching...
# tree
# default
# backup
# best
# action -25, nodes 4
#
# searching...
# tree
# default
# backup
# best
# action -15, nodes 5
#
# searching...
# tree
# default
# backup
# best
# action -15, nodes 6
#
# searching...
# tree
# default
# backup
# best
# action -15, nodes 7
#
# searching...
# tree
# default
# backup
# best
# action -15, nodes 8
#
# searching...
# FOUND THE ROOT NODE
# Possible nodes: 1
# NEW CALL. nodes: 37
# searching...
# tree
# default
# backup
# best
# action 15, nodes 38
#
# searching...
# tree
# default
# backup
# best
# action 15, nodes 39
#
# searching...
# tree
# default
# backup
# best
# action 15, nodes 40
#
# searching...
# tree
# default
# backup
# best
# action 15, nodes 41
#
# searching...
# tree
# default
# backup
# best
# action 15, nodes 42
#
# searching...
# tree
# default
# backup
# best
# action 15, nodes 43
#
# searching...
# tree
# default
# backup
# best
# action 15, nodes 44
#
# searching...
# tree
# default
# backup
# best
# action 15, nodes 45
#
# searching...
# FOUND THE ROOT NODE
# Possible nodes: 1
# NEW CALL. nodes: 8
# searching...
# tree
# default
# backup
# best
# action -11, nodes 9
#
# searching...
# tree
# default
# backup
# best
# action -11, nodes 10
#
# searching...
# tree
# default
# backup
# best
# action -11, nodes 11
#
# searching...
# tree
# default
# backup
# best
# action -11, nodes 12
#
# searching...
# tree
# default
# backup
# best
# action -11, nodes 13
#
# searching...
# tree
# default
# backup
# best
# action -11, nodes 14
#
# searching...
# tree
# default
# backup
# best
# action -11, nodes 15
#
# searching...
# FOUND THE ROOT NODE
# Possible nodes: 1
# NEW CALL. nodes: 45
# searching...
# tree
# default
# backup
# best
# action -25, nodes 46
#
# searching...
# tree
# default
# backup
# best
# action -25, nodes 47
#
# searching...
# tree
# default
# backup
# best
# action -25, nodes 48
#
# searching...
# tree
# default
# backup
# best
# action -25, nodes 49
#
# searching...
# tree
# default
# backup
# best
# action -25, nodes 50
#
# searching...
# tree
# default
# backup
# best
# action -25, nodes 51
#
# searching...
# tree
# default
# backup
# best
# action -25, nodes 52
#
# searching...
# tree
# default
# backup
# best
# action -25, nodes 53
#
# searching...
# FOUND THE ROOT NODE
# Possible nodes: 1
# NEW CALL. nodes: 15
# searching...
# tree
# default
# backup
# best
# action 25, nodes 16
#
# searching...
# tree
# default
# backup
# best
# action 25, nodes 17
#
# searching...
# tree
# default
# backup
# best
# action 25, nodes 18
#
# searching...
# tree
# default
# backup
# best
# action 25, nodes 19
#
# searching...
# tree
# default
# backup
# best
# action 25, nodes 20
#
# searching...
# tree
# default
# backup
# best
# action 25, nodes 21
#
# searching...
# tree
# default
# backup
# best
# action 25, nodes 22
#
# searching...
# FOUND THE ROOT NODE
# Possible nodes: 1
# NEW CALL. nodes: 53
# searching...
# tree
# default
# backup
# best
# action 11, nodes 54
#
# searching...
# tree
# default
# backup
# best
# action -25, nodes 55
#
# searching...
# tree
# default
# backup
# best
# action -25, nodes 56
#
# searching...
# tree
# default
# backup
# best
# action -25, nodes 57
#
# searching...
# tree
# default
# backup
# best
# action -25, nodes 58
#
# searching...
# tree
# default
# backup
# best
# action -15, nodes 59
#
# searching...
# tree
# default
# backup
# best
# action -15, nodes 60
#
# searching...
# tree
# default
# FOUND THE ROOT NODE
# Possible nodes: 1
# NEW CALL. nodes: 22
# searching...
# tree
# default
# backup
# best
# action 27, nodes 23
#
# searching...
# tree
# default
# backup
# best
# action 27, nodes 24
#
# searching...
# tree
# default
# backup
# best
# action 27, nodes 25
#
# searching...
# tree
# default
# backup
# best
# action 27, nodes 26
#
# searching...
# tree
# default
# backup
# best
# action 27, nodes 27
#
# searching...
# tree
# default
# backup
# best
# action 27, nodes 28
#
# searching...
# tree
# default
# backup
# best
# action 27, nodes 29
#
# searching...
# tree
# default
# FOUND THE ROOT NODE
# Possible nodes: 1
# NEW CALL. nodes: 61
# searching...
# tree
# default
# backup
# best
# action -11, nodes 62
#
# searching...
# tree
# default
# backup
# best
# action -11, nodes 63
#
# searching...
# tree
# default
# backup
# best
# action -15, nodes 64
#
# searching...
# tree
# default
# backup
# best
# action -15, nodes 65
#
# searching...
# tree
# default
# backup
# best
# action -15, nodes 66
#
# searching...
# tree
# default
# backup
# best
# action -15, nodes 67
#
# searching...
# tree
# default
# backup
# best
# action -11, nodes 68
#
# searching...
# tree
# default
# backup
# best
# action -11, nodes 69
#
# searching...
# tree
# default
# FOUND THE ROOT NODE
# Possible nodes: 1
# NEW CALL. nodes: 30
# searching...
# tree
# default
# backup
# best
# action 11, nodes 31
#
# searching...
# tree
# default
# backup
# best
# action 11, nodes 32
#
# searching...
# tree
# default
# backup
# best
# action 11, nodes 33
#
# searching...
# tree
# default
# backup
# best
# action 11, nodes 34
#
# searching...
# tree
# default
# backup
# best
# action 11, nodes 35
#
# searching...
# tree
# default
# backup
# best
# action 11, nodes 36
#
# searching...
# tree
# default
# backup
# best
# action 11, nodes 37
#
# searching...
# tree
# default
# backup
# best
# action 11, nodes 38
#
# searching...
# FOUND THE ROOT NODE
# Possible nodes: 1
# NEW CALL. nodes: 70
# searching...
# tree
# default
# backup
# best
# action 25, nodes 71
#
# searching...
# tree
# default
# backup
# best
# action 25, nodes 72
#
# searching...
# tree
# default
# backup
# best
# action 27, nodes 73
#
# searching...
# tree
# default
# backup
# best
# action 27, nodes 74
#
# searching...
# tree
# default
# backup
# best
# action 27, nodes 75
#
# searching...
# tree
# default
# backup
# best
# action -11, nodes 76
#
# searching...
# tree
# default
# backup
# best
# action 25, nodes 77
#
# searching...
# tree
# default
# backup
# best
# action 25, nodes 78
#
# searching...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-85c39f703717> in <module>()
# ----> 1 winner, game_history, match_id = isolation.play(matches[0])
#
# ~/git_repos/artificial-intelligence/Projects/3_Adversarial Search/isolation/__init__.py in play(args)
#      66
#      67
# ---> 68 def play(args): return _play(*args)  # multithreading ThreadPool.map doesn't expand args
#      69
#      70
#
# ~/git_repos/artificial-intelligence/Projects/3_Adversarial Search/isolation/__init__.py in _play(agents, game_state, time_limit, match_id)
#     103
#     104         try:
# --> 105             action = fork_get_action(game_state, players[active_idx], time_limit)
#     106         except Empty:
#     107             logger.info(
#
# ~/git_repos/artificial-intelligence/Projects/3_Adversarial Search/isolation/__init__.py in fork_get_action(game_state, active_player, time_limit)
#     174
#     175     if listener.poll():
# --> 176         active_player.context = listener.recv()  # preserve any internal state
#     177     while True:  # treat the queue as LIFO
#     178         action = action_queue.get_nowait()  # raises Empty if agent did not respond
#
# ~/anaconda3/envs/aind/lib/python3.5/multiprocessing/connection.py in recv(self)
#     248         self._check_closed()
#     249         self._check_readable()
# --> 250         buf = self._recv_bytes()
#     251         return ForkingPickler.loads(buf.getbuffer())
#     252
#
# ~/anaconda3/envs/aind/lib/python3.5/multiprocessing/connection.py in _recv_bytes(self, maxsize)
#     409         if maxsize is not None and size > maxsize:
#     410             return None
# --> 411         return self._recv(size)
#     412
#     413     def _poll(self, timeout):
#
# ~/anaconda3/envs/aind/lib/python3.5/multiprocessing/connection.py in _recv(self, size, read)
#     377         remaining = size
#     378         while remaining > 0:
# --> 379             chunk = read(handle, remaining)
#     380             n = len(chunk)
#     381             if n == 0:
#
# KeyboardInterrupt:

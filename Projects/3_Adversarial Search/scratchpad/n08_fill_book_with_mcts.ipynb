# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import sys
from time import time
import os

# %pylab inline
pylab.rcParams['figure.figsize'] = (20.0, 10.0)

# %load_ext autoreload
# %autoreload 2

sys.path.append('..')

import isolation
import sample_players
import run_match
import my_baseline_player as custom
import book as b

from multiprocessing.pool import ThreadPool as Pool
import pickle
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /home/miguel/anaconda3/envs/aind/lib/python3.5/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['time']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
with open('first_book.pkl', 'rb') as file:
    data = pickle.load(file)

# %%
data
# Out:
# {(Isolation(board=41198632737088974515941243613079551, ply_count=3, locs=(108, 83)),
#   <Action.ESE: -15>): 0,
#  (Isolation(board=40143957350286345584047904549496831, ply_count=3, locs=(106, 110)),
#   <Action.WSW: -11>): 0,
#  (Isolation(board=41523161126567869041879413484939263, ply_count=3, locs=(86, 53)),
#   <Action.SSW: -25>): 0,
#  (Isolation(board=41523161203939122082683630076618751, ply_count=3, locs=(31, 17)),
#   <Action.ESE: -15>): 0,
#  (Isolation(board=41523161203939122082683626855589879, ply_count=3, locs=(30, 32)),
#   <Action.WSW: -11>): 0,
#  (Isolation(board=41198484184284260270308255718172671, ply_count=3, locs=(108, 83)),
#   <Action.ESE: -15>): 0,
#  (Isolation(board=41520625901529739768237212624218111, ply_count=3, locs=(55, 101)),
#   <Action.ENE: 11>): 0,
#  (Isolation(board=41523161203939122082679234042521599, ply_count=3, locs=(42, 20)),
#   <Action.NNW: 27>): 0,
#  (Isolation(board=41523161203939122078180032462645247, ply_count=3, locs=(52, 16)),
#   <Action.WNW: 15>): 0,
#  (Isolation(board=41523161203934397410357753298282495, ply_count=3, locs=(61, 26)),
#   <Action.NNW: 27>): 0,
#  (Isolation(board=41523161203939122082683632224298879, ply_count=1, locs=(7, None)),
#   20): 4,
#  (Isolation(board=41523161203939122010625488162121727, ply_count=3, locs=(39, 56)),
#   <Action.SSW: -25>): 0,
#  (Isolation(board=41522834387768455594385879502678015, ply_count=3, locs=(68, 98)),
#   <Action.SSW: -25>): 0,
#  (Isolation(board=41198632746760381072717539522373631, ply_count=3, locs=(108, 47)),
#   <Action.ENE: 11>): 0,
#  (Isolation(board=20753339944499623666884603717609471, ply_count=3, locs=(99, 66)),
#   <Action.WSW: -11>): 0,
#  (Isolation(board=41523161203939048259678539830257663, ply_count=3, locs=(66, 29)),
#   <Action.SSW: -25>): 0,
#  (Isolation(board=41523161049196615442628840951638015, ply_count=3, locs=(60, 59)),
#   <Action.ESE: -15>): 0,
#  (Isolation(board=41523161203929677349717892665436157, ply_count=3, locs=(28, 73)),
#   <Action.NNE: 25>): 0,
#  (Isolation(board=41523161203939122082683065280227327, ply_count=3, locs=(23, 39)),
#   <Action.NNW: 27>): 0,
#  (Isolation(board=41523131493378031659604444968904703, ply_count=3, locs=(94, 93)),
#   <Action.WNW: 15>): 0,
#  (Isolation(board=41523161203938900685725950690715647, ply_count=3, locs=(55, 67)),
#   <Action.SSE: -27>): 0,
#  (Isolation(board=38927012755328895010469129188534271, ply_count=3, locs=(84, 111)),
#   <Action.WSW: -11>): 0,
#  (Isolation(board=41523161126530090690980808254023679, ply_count=3, locs=(75, 52)),
#   <Action.NNW: 27>): 0,
#  (Isolation(board=41523161203937941491027730440906719, ply_count=3, locs=(45, 5)),
#   <Action.WNW: 15>): 0,
#  (Isolation(board=41523161203920232616747755596802047, ply_count=3, locs=(17, 74)),
#   <Action.ENE: 11>): 0,
#  (Isolation(board=41523161202730011795628265954076671, ply_count=3, locs=(80, 67)),
#   <Action.SSE: -27>): 0,
#  (Isolation(board=41522527359296194854148817077135359, ply_count=3, locs=(84, 18)),
#   <Action.WSW: -11>): 0,
#  (Isolation(board=41523151300418807799641432964196349, ply_count=3, locs=(1, 93)),
#   <Action.WSW: -11>): 0,
#  (Isolation(board=41520625902738665623880638817888255, ply_count=1, locs=(101, None)),
#   18): 8,
#  (Isolation(board=41523161202730048689116413373179903, ply_count=2, locs=(67, 80)),
#   <Action.WSW: -11>): 0,
#  (Isolation(board=41523161203939120893698146226399231, ply_count=3, locs=(60, 55)),
#   <Action.ENE: 11>): 0,
#  (Isolation(board=41523161203937941346877357992962047, ply_count=3, locs=(57, 70)),
#   <Action.WNW: 15>): 0,
#  (Isolation(board=41441714652874458343637469043353599, ply_count=2, locs=(106, 98)),
#   <Action.SSE: -27>): 1,
#  (Isolation(board=38927012697300455813064524692449279, ply_count=3, locs=(86, 44)),
#   <Action.ENE: 11>): 0,
#  (Isolation(board=41522527378610673769085666001414143, ply_count=3, locs=(99, 73)),
#   <Action.ENE: 11>): 0,
#  (Isolation(board=41523161199103418804224016013813759, ply_count=3, locs=(40, 82)),
#   <Action.WNW: 15>): 0,
#  (Isolation(board=41523161203334658019954804440164351, ply_count=3, locs=(60, 79)),
#   <Action.NNW: 27>): 0,
#  (Isolation(board=41442031565524515400987826030897151, ply_count=3, locs=(23, 106)),
#   <Action.WSW: -11>): 0,
#  (Isolation(board=41522527378636646784741449050089471, ply_count=2, locs=(99, 71)),
#   <Action.SSW: -25>): 2,
#  (Isolation(board=41523161203939122064527946470647807, ply_count=3, locs=(39, 47)),
#   <Action.SSE: -27>): 0,
#  (Isolation(board=41523161203901343150521607899834367, ply_count=3, locs=(75, 44)),
#   <Action.SSE: -27>): 0,
#  (Isolation(board=41523161203939117470997613662693375, ply_count=2, locs=(27, 62)),
#   <Action.NNW: 27>): -3,
#  (Isolation(board=41523161203936759710491895775881215, ply_count=3, locs=(60, 55)),
#   <Action.WSW: -11>): 0,
#  (Isolation(board=41523161203938826934760860148557823, ply_count=3, locs=(44, 68)),
#   <Action.NNE: 25>): 0,
#  (Isolation(board=41523156244925410023474757579565055, ply_count=3, locs=(92, 82)),
#   <Action.SSW: -25>): 0,
#  (Isolation(board=41523161203939048259678540367112191, ply_count=3, locs=(55, 14)),
#   <Action.NNE: 25>): 0,
#  (Isolation(board=41523161203939122078177833573607423, ply_count=3, locs=(52, 16)),
#   <Action.WNW: 15>): 0,
#  (Isolation(board=41523161203938826934776251700733951, ply_count=3, locs=(68, 31)),
#   <Action.SSW: -25>): 0,
#  (Isolation(board=41523161203939048295634769618659327, ply_count=3, locs=(66, 46)),
#   <Action.SSW: -25>): 0,
#  (Isolation(board=41523161199103271230272525849061375, ply_count=2, locs=(67, 82)),
#   <Action.NNE: 25>): 3,
#  (Isolation(board=41198642650280695337886077694240767, ply_count=2, locs=(54, 108)),
#   <Action.NNE: 25>): 3,
#  (Isolation(board=41523158728059043511923081889179647, ply_count=2, locs=(29, 91)),
#   <Action.NNE: 25>): -3,
#  (Isolation(board=41523161203920232616189203690022909, ply_count=3, locs=(49, 1)),
#   <Action.NNW: 27>): 0,
#  (Isolation(board=41522527378639007967978485826054143, ply_count=3, locs=(17, 99)),
#   <Action.SSW: -25>): 0,
#  (Isolation(board=41523141396895984759405209339291647, ply_count=3, locs=(94, 71)),
#   <Action.NNW: 27>): 0,
#  (Isolation(board=41360822694111691176495943971235839, ply_count=3, locs=(107, 82)),
#   <Action.NNW: 27>): 0,
#  (Isolation(board=41523161194267678632277351895918591, ply_count=3, locs=(40, 83)),
#   <Action.WSW: -11>): 0,
#  (Isolation(board=41523161203939048286699588375537663, ply_count=3, locs=(66, 53)),
#   <Action.SSW: -25>): 0,
#  (Isolation(board=41523161203334656866962939679074303, ply_count=3, locs=(61, 79)),
#   <Action.WNW: 15>): 0,
#  (Isolation(board=41360901925900982899677425039304687, ply_count=3, locs=(80, 4)),
#   <Action.NNE: 25>): 0,
#  (Isolation(board=40225086950619788947882857371527167, ply_count=3, locs=(110, 34)),
#   <Action.NNE: 25>): 1,
#  (Isolation(board=41523161201521196656478079036680191, ply_count=2, locs=(81, 66)),
#   <Action.NNW: 27>): 1,
#  (Isolation(board=41523161203939047142785283023431679, ply_count=3, locs=(66, 60)),
#   <Action.NNW: 27>): 0,
#  (Isolation(board=20753953962758592706666889815779327, ply_count=3, locs=(94, 114)),
#   <Action.ESE: -15>): 3,
#  (Isolation(board=41523161203937941491062914812995567, ply_count=2, locs=(70, 4)),
#   <Action.SSW: -25>): 3,
#  (Isolation(board=41522487745214937721980020305422335, ply_count=3, locs=(95, 99)),
#   <Action.SSW: -25>): 0,
#  (Isolation(board=41523161203939122082683563236386815, ply_count=2, locs=(28, 36)),
#   <Action.ENE: 11>): 0,
#  (Isolation(board=41522527378034545040161170775861247, ply_count=3, locs=(79, 99)),
#   <Action.SSE: -27>): 0,
#  (Isolation(board=41523161184596161394895876240959487, ply_count=3, locs=(67, 84)),
#   <Action.NNE: 25>): 0,
#  (Isolation(board=41522527373798582323041497528657919, ply_count=3, locs=(99, 82)),
#   <Action.ENE: 11>): 0,
#  (Isolation(board=20753973769799811424446458831562751, ply_count=2, locs=(57, 114)),
#   <Action.ENE: 11>): 0,
#  (Isolation(board=41523161203939048295143837676857343, ply_count=3, locs=(39, 49)),
#   <Action.NNE: 25>): 0,
#  (Isolation(board=41523141396898345366185891858475007, ply_count=3, locs=(67, 59)),
#   <Action.WSW: -11>): 0,
#  (Isolation(board=41523161126548980161415886462248959, ply_count=2, locs=(86, 74)),
#   <Action.SSE: -27>): -3,
#  (Isolation(board=41523161203939122082683632224003967, ply_count=3, locs=(7, 15)),
#   <Action.WNW: 15>): 0,
#  (Isolation(board=41523161203939122010608445999802367, ply_count=3, locs=(44, 56)),
#   <Action.SSW: -25>): 0,
#  (Isolation(board=41523161203901340844696190872184831, ply_count=3, locs=(75, 61)),
#   <Action.NNE: 25>): 0,
#  (Isolation(board=41482596384731818165093510441592831, ply_count=3, locs=(48, 105)),
#   <Action.WSW: -11>): 0,
#  (Isolation(board=41198484193955666827084551627466751, ply_count=3, locs=(108, 47)),
#   <Action.ENE: 11>): 0,
#  (Isolation(board=41523161184596308968849565429000191, ply_count=1, locs=(84, None)),
#   69): 8,
#  (Isolation(board=41523161196685567128967060157097983, ply_count=3, locs=(55, 81)),
#   <Action.SSW: -25>): 0,
#  (Isolation(board=36328329044201476812108707666061311, ply_count=3, locs=(112, 71)),
#   <Action.WSW: -11>): 0,
#  (Isolation(board=41523161203939120929181585477986303, ply_count=3, locs=(49, 44)),
#   <Action.SSE: -27>): 0,
#  (Isolation(board=38927012774666985901935514414475263, ply_count=2, locs=(72, 111)),
#   <Action.SSE: -27>): -3,
#  (Isolation(board=41523151300116428770785186061215743, ply_count=3, locs=(93, 67)),
#   <Action.SSE: -27>): 0,
#  (Isolation(board=41523161203934399716165561027127295, ply_count=3, locs=(45, 34)),
#   <Action.SSE: -27>): 0,
#  (Isolation(board=41523161203939122046654818025465855, ply_count=2, locs=(55, 34)),
#   <Action.NNW: 27>): -3,
#  (Isolation(board=41523161203920231463267699083175935, ply_count=3, locs=(74, 60)),
#   <Action.ESE: -15>): 0,
#  (Isolation(board=41523161203939122082595671291979775, ply_count=3, locs=(21, 44)),
#   <Action.SSW: -25>): 0,
#  (Isolation(board=41523151300078797412874818575919103, ply_count=3, locs=(93, 75)),
#   <Action.ESE: -15>): 0,
#  (Isolation(board=40874124077279455515283253119412223, ply_count=3, locs=(109, 28)),
#   <Action.NNE: 25>): -1,
#  (Isolation(board=41523161203936760899424600920680447, ply_count=3, locs=(44, 32)),
#   <Action.SSE: -27>): 0,
#  (Isolation(board=41523161203936759746520692794845179, ply_count=3, locs=(60, 2)),
#   <Action.NNW: 27>): 0,
#  (Isolation(board=41523161203636890618772775675881463, ply_count=3, locs=(53, 3)),
#   <Action.NNW: 27>): 0,
#  (Isolation(board=41523161203939122082648447717992447, ply_count=2, locs=(45, 27)),
#   <Action.NNE: 25>): -3,
#  (Isolation(board=41523161203939119776838423920240639, ply_count=3, locs=(26, 61)),
#   <Action.SSW: -25>): 0,
#  (Isolation(board=41523161203939121497198088480090111, ply_count=3, locs=(59, 53)),
#   <Action.WNW: 15>): 0,
#  (Isolation(board=41523081975776607818275669936171007, ply_count=2, locs=(46, 96)),
#   <Action.NNE: 25>): 3,
#  (Isolation(board=41523081975776607818346038680348671, ply_count=1, locs=(96, None)),
#   93): 2,
#  (Isolation(board=41523161184596306662936187471128575, ply_count=3, locs=(46, 84)),
#   <Action.WNW: 15>): 0,
#  (Isolation(board=41523161199103381910735868594743295, ply_count=3, locs=(65, 82)),
#   <Action.ESE: -15>): 0,
#  (Isolation(board=41523161202730196263069003049560047, ply_count=3, locs=(15, 80)),
#   <Action.WNW: 15>): 0,
#  (Isolation(board=41523161203939120929762119025420287, ply_count=3, locs=(33, 21)),
#   <Action.NNW: 27>): 0,
#  (Isolation(board=41523161203939122082681433199994879, ply_count=2, locs=(20, 41)),
#   <Action.ESE: -15>): -3,
#  (Isolation(board=41523161203939122082683631685314559, ply_count=3, locs=(14, 21)),
#   <Action.WSW: -11>): 0,
#  (Isolation(board=41523161203938531786868873324652543, ply_count=3, locs=(42, 69)),
#   <Action.ENE: 11>): 0,
#  (Isolation(board=41522844281617658468411826604337151, ply_count=3, locs=(83, 42)),
#   <Action.WSW: -11>): 0,
#  (Isolation(board=41523161203632168117181917209552895, ply_count=3, locs=(72, 78)),
#   <Action.WNW: 15>): 0,
#  (Isolation(board=41523161203939122082120681734006779, ply_count=3, locs=(2, 49)),
#   <Action.SSE: -27>): 0,
#  (Isolation(board=41523141396898493516599165118834175, ply_count=3, locs=(36, 94)),
#   <Action.SSE: -27>): 0,
#  (Isolation(board=41523161203939122082401607483385855, ply_count=3, locs=(23, 39)),
#   <Action.NNW: 27>): 0,
#  (Isolation(board=40874124096622268629117320183113711, ply_count=3, locs=(15, 109)),
#   <Action.SSE: -27>): 0,
#  (Isolation(board=41523161203939122082677034080790527, ply_count=3, locs=(41, 42)),
#   <Action.ESE: -15>): 0,
#  (Isolation(board=41523161203939121505941403870423039, ply_count=3, locs=(48, 30)),
#   <Action.ESE: -15>): 0,
#  (Isolation(board=41198642650280693049987098245851135, ply_count=3, locs=(46, 108)),
#   <Action.SSE: -27>): 0,
#  (Isolation(board=41523161203939122064669233580468223, ply_count=3, locs=(54, 17)),
#   <Action.ENE: 11>): 0,
#  (Isolation(board=41360822698947394454954460133189631, ply_count=3, locs=(107, 29)),
#   <Action.SSE: -27>): 0,
#  (Isolation(board=41523161203939122046637241945548799, ply_count=3, locs=(44, 30)),
#   <Action.SSE: -27>): 0,
#  (Isolation(board=41523161203938527175046517602904063, ply_count=3, locs=(47, 69)),
#   <Action.WNW: 15>): 0,
#  (Isolation(board=38927012755328894578123564960966655, ply_count=3, locs=(84, 59)),
#   <Action.NNW: 27>): 0,
#  (Isolation(board=41523161203937941490491168766552063, ply_count=3, locs=(70, 49)),
#   <Action.NNE: 25>): 0,
#  (Isolation(board=41523161203929677345214293172283391, ply_count=3, locs=(27, 73)),
#   <Action.NNE: 25>): 3,
#  (Isolation(board=41523121589856684358894118041020411, ply_count=3, locs=(70, 2)),
#   <Action.NNE: 25>): 0,
#  (Isolation(board=41523161203936760863343031638550527, ply_count=3, locs=(71, 55)),
#   <Action.ENE: 11>): 0,
#  (Isolation(board=41523161203938531786873273518647231, ply_count=2, locs=(6, 69)),
#   <Action.NNW: 27>): 1,
#  (Isolation(board=36330864340568443601742029519841279, ply_count=3, locs=(82, 112)),
#   <Action.WSW: -11>): 0,
#  (Isolation(board=41523161203938826934774054690744319, ply_count=3, locs=(42, 68)),
#   <Action.NNW: 27>): 0,
#  (Isolation(board=41523161184596308968849565429000191, ply_count=1, locs=(84, None)),
#   66): -10,
#  (Isolation(board=41523161203939122082683562967950847, ply_count=3, locs=(9, 29)),
#   <Action.NNW: 27>): 0,
#  (Isolation(board=41523141396898493516590437745289215, ply_count=2, locs=(43, 94)),
#   <Action.NNW: 27>): -3,
#  (Isolation(board=41482596384429586134010575821203455, ply_count=3, locs=(105, 60)),
#   <Action.NNW: 27>): 0,
#  (Isolation(board=41442031564920052491180528497584127, ply_count=3, locs=(106, 27)),
#   <Action.WSW: -11>): 0,
#  (Isolation(board=41523161184595718384808830571636735, ply_count=3, locs=(84, 58)),
#   <Action.NNE: 25>): 0,
#  (Isolation(board=41523161202730159369579756118861823, ply_count=3, locs=(80, 40)),
#   <Action.NNW: 27>): 0,
#  (Isolation(board=41360822660261768227286327079462911, ply_count=3, locs=(85, 107)),
#   <Action.SSW: -25>): 0,
#  (Isolation(board=41523161203939122073658840783513599, ply_count=2, locs=(53, 44)),
#   <Action.WNW: 15>): 0,
#  (Isolation(board=41523158726850117692308436071475199, ply_count=3, locs=(80, 34)),
#   <Action.ENE: 11>): 0,
#  (Isolation(board=41523161184596308968779196684822527, ply_count=2, locs=(84, 46)),
#   <Action.ESE: -15>): 0,
#  (Isolation(board=41523161203939122082648447852177406, ply_count=3, locs=(15, 45)),
#   <Action.SSE: -27>): 0,
#  (Isolation(board=41520625902719776157949160235984895, ply_count=3, locs=(74, 20)),
#   <Action.ENE: 11>): 0,
#  (Isolation(board=38927012774671708268418384059688955, ply_count=2, locs=(2, 111)),
#   <Action.WNW: 15>): -3,
#  (Isolation(board=41523161203939122082683622560622591, ply_count=2, locs=(30, 33)),
#   <Action.NNW: 27>): -1,
#  (Isolation(board=41523161126567869627347347854845951, ply_count=3, locs=(23, 86)),
#   <Action.ESE: -15>): 0,
#  (Isolation(board=41523161201521270434447174620145663, ply_count=2, locs=(81, 53)),
#   <Action.WSW: -11>): 0,
#  (Isolation(board=36330864345404294310033549772711935, ply_count=3, locs=(42, 112)),
#   <Action.WSW: -11>): 0,
#  (Isolation(board=41523161203933809420249666385078271, ply_count=3, locs=(47, 69)),
#   <Action.SSW: -25>): 0,
#  (Isolation(board=41523161203334658591911965706151935, ply_count=3, locs=(79, 59)),
#   <Action.ESE: -15>): 0,
#  (Isolation(board=41523161203939122082542877556074495, ply_count=2, locs=(34, 47)),
#   <Action.NNW: 27>): -3,
#  (Isolation(board=41523161203901343146035600458508287, ply_count=3, locs=(75, 52)),
#   <Action.NNW: 27>): 0,
#  (Isolation(board=41523161126530090695484407344523263, ply_count=3, locs=(86, 29)),
#   <Action.WSW: -11>): 0,
#  (Isolation(board=41523161203939122082672632813053951, ply_count=3, locs=(32, 41)),
#   <Action.SSW: -25>): 0,
#  (Isolation(board=41523161203939085171181086295713727, ply_count=3, locs=(65, 6)),
#   <Action.NNW: 27>): 0,
#  (Isolation(board=41523161203939121794453254998845431, ply_count=3, locs=(3, 58)),
#   <Action.ENE: 11>): 0,
#  (Isolation(board=20753973769799811568561646907418623, ply_count=1, locs=(114, None)),
#   23): 0,
#  (Isolation(board=41523101782816941236525257713510399, ply_count=3, locs=(68, 94)),
#   <Action.ENE: 11>): 0,
#  (Isolation(board=41523161203934399572085573966358527, ply_count=3, locs=(72, 29)),
#   <Action.NNE: 25>): 0,
#  (Isolation(board=41523161203939122010617242093348863, ply_count=2, locs=(43, 56)),
#   <Action.NNE: 25>): -1,
#  (Isolation(board=41523158726848937100687735840040959, ply_count=3, locs=(80, 70)),
#   <Action.ESE: -15>): 0,
#  (Isolation(board=41523161203939122082683630881990655, ply_count=3, locs=(17, 30)),
#   <Action.ESE: -15>): 0,
#  (Isolation(board=41523161203939122082666040038246399, ply_count=2, locs=(44, 13)),
#   <Action.ENE: 11>): 0,
#  (Isolation(board=41523161203938531786851283286091775, ply_count=3, locs=(44, 42)),
#   <Action.WSW: -11>): 0,
#  (Isolation(board=41523161203939122078180032595879903, ply_count=3, locs=(5, 52)),
#   <Action.WSW: -11>): 0,
#  (Isolation(board=41523161184596308968848465917364223, ply_count=3, locs=(13, 84)),
#   <Action.SSW: -25>): 0,
#  (Isolation(board=41523161203939122064660436548052991, ply_count=3, locs=(43, 30)),
#   <Action.SSW: -25>): 0,
#  (Isolation(board=41523161203937941491054118719842303, ply_count=3, locs=(70, 17)),
#   <Action.NNW: 27>): 0,
#  (Isolation(board=40225086950619788947882874543007743, ply_count=3, locs=(110, 23)),
#   <Action.ESE: -15>): 0,
#  (Isolation(board=41523161202730196109946615718995967, ply_count=3, locs=(80, 57)),
#   <Action.NNE: 25>): 0,
#  (Isolation(board=41523161203939122010590819454543871, ply_count=3, locs=(56, 35)),
#   <Action.NNW: 27>): 0,
#  (Isolation(board=41523161203939122082683630075701247, ply_count=3, locs=(16, 20)),
#   <Action.WNW: 15>): 0,
#  (Isolation(board=41523161203939121938564045028190207, ply_count=3, locs=(57, 42)),
#   <Action.SSE: -27>): 0,
#  (Isolation(board=41523161203939122082683632090081279, ply_count=1, locs=(27, None)),
#   16): 8,
#  (Isolation(board=41523161203939122082542894734894591, ply_count=3, locs=(9, 47)),
#   <Action.NNE: 25>): 0,
#  (Isolation(board=40874124096622268629117320183113727, ply_count=2, locs=(109, 15)),
#   <Action.ESE: -15>): 3,
#  (Isolation(board=41523161203937941346912542365050879, ply_count=3, locs=(70, 57)),
#   <Action.WSW: -11>): 0,
#  (Isolation(board=41523161049196617172011097593473021, ply_count=3, locs=(28, 87)),
#   <Action.NNW: 27>): 0,
#  (Isolation(board=41523161203939122082683632089556975, ply_count=3, locs=(4, 27)),
#   <Action.SSW: -25>): 0,
#  (Isolation(board=41523161203901305104411023036639231, ply_count=3, locs=(60, 65)),
#   <Action.WSW: -11>): 0,
#  (Isolation(board=41523002723435577161715861642274815, ply_count=3, locs=(97, 84)),
#   <Action.SSE: -27>): 0,
#  (Isolation(board=41523161203939117470997613796845567, ply_count=2, locs=(16, 62)),
#   <Action.WSW: -11>): 3,
#  (Isolation(board=40225086989305415175550973782255359, ply_count=3, locs=(8, 110)),
#   <Action.ESE: -15>): 0,
#  (Isolation(board=40225086989305415175550999552059391, ply_count=2, locs=(33, 110)),
#   <Action.WSW: -11>): 0,
#  (Isolation(board=41523161203939122082683631150524411, ply_count=3, locs=(30, 2)),
#   <Action.ENE: 11>): 0,
#  (Isolation(board=41523160894453964687381575776593919, ply_count=3, locs=(67, 88)),
#   <Action.ENE: 11>): 0,
#  (Isolation(board=41523151300418807799606248658954239, ply_count=3, locs=(18, 93)),
#   <Action.WSW: -11>): 0,
#  (Isolation(board=41523161126529500399674049175742463, ply_count=3, locs=(86, 69)),
#   <Action.ENE: 11>): 0,
#  (Isolation(board=41523161203933809276275215797577727, ply_count=3, locs=(57, 69)),
#   <Action.NNW: 27>): 0,
#  (Isolation(board=41523161203939122082683597864297471, ply_count=3, locs=(35, 18)),
#   <Action.NNW: 27>): 0,
#  (Isolation(board=41523081975776312670440859327522815, ply_count=2, locs=(68, 96)),
#   <Action.WNW: 15>): 0,
#  (Isolation(board=41523081975773656339294245152090111, ply_count=3, locs=(69, 71)),
#   <Action.ESE: -15>): 0,
#  (Isolation(board=41523161203938531498642897366935547, ply_count=3, locs=(69, 2)),
#   <Action.ENE: 11>): 0,
#  (Isolation(board=40224453164005301060850259790383103, ply_count=3, locs=(99, 13)),
#   <Action.WSW: -11>): 0,
#  (Isolation(board=41523161184586864235881627115317247, ply_count=3, locs=(84, 41)),
#   <Action.ENE: 11>): 0,
#  (Isolation(board=41523161203939122082666040035633151, ply_count=3, locs=(19, 21)),
#   <Action.ESE: -15>): 0,
#  (Isolation(board=41523161203636890627779974930491391, ply_count=2, locs=(78, 17)),
#   <Action.SSW: -25>): -6,
#  (Isolation(board=41523161199103418767914843529799679, ply_count=3, locs=(82, 48)),
#   <Action.ESE: -15>): 0,
#  (Isolation(board=39576049881988561721984696100841471, ply_count=2, locs=(110, 109)),
#   <Action.SSW: -25>): -3,
#  (Isolation(board=41523161203937941491062912665511935, ply_count=2, locs=(70, 31)),
#   <Action.ESE: -15>): 0,
#  (Isolation(board=41523161203939121506222862472570879, ply_count=3, locs=(59, 28)),
#   <Action.WSW: -11>): 0,
#  (Isolation(board=41522844291289065016326058726647807, ply_count=3, locs=(26, 98)),
#   <Action.WSW: -11>): 0,
#  (Isolation(board=41523161203937941455034117794031611, ply_count=3, locs=(55, 2)),
#   <Action.NNE: 25>): 0,
#  (Isolation(board=41360901927109908719292054213978111, ply_count=2, locs=(15, 107)),
#   <Action.ENE: 11>): 1,
#  (Isolation(board=41523161203939122082613263480088559, ply_count=3, locs=(15, 46)),
#   <Action.SSE: -27>): 0,
#  (Isolation(board=41523161049196617172011097861646207, ply_count=3, locs=(18, 87)),
#   <Action.NNE: 25>): 0,
#  (Isolation(board=41502878794335470394236490370508799, ply_count=3, locs=(43, 104)),
#   <Action.SSW: -25>): 0,
#  (Isolation(board=41523161203939048295689745200048127, ply_count=2, locs=(66, 44)),
#   <Action.NNE: 25>): 0,
#  (Isolation(board=41523161203939122082683563504297967, ply_count=3, locs=(4, 36)),
#   <Action.SSE: -27>): 0,
#  (Isolation(board=41523161201520680129629616659752959, ply_count=3, locs=(54, 69)),
#   <Action.ENE: 11>): 0,
#  (Isolation(board=41523161202730196263051410863024127, ply_count=3, locs=(19, 80)),
#   <Action.ESE: -15>): 0,
#  (Isolation(board=41523161203937941491062914745853951, ply_count=3, locs=(15, 70)),
#   <Action.SSE: -27>): 0,
#  (Isolation(board=41523161202730196263069003049592831, ply_count=1, locs=(80, None)),
#   70): -10,
#  (Isolation(board=40225086979634008618598790372255743, ply_count=3, locs=(83, 45)),
#   <Action.NNW: 27>): 0,
#  (Isolation(board=41279772286277450398367006859454463, ply_count=3, locs=(106, 107)),
#   <Action.ESE: -15>): 0,
#  (Isolation(board=41523161203939122082674836129179583, ply_count=3, locs=(21, 43)),
#   <Action.SSW: -25>): 0,
#  (Isolation(board=40874124096622266323203942225274879, ply_count=3, locs=(61, 109)),
#   <Action.WSW: -11>): 0,
#  (Isolation(board=41523161203920232616189203687925759, ply_count=3, locs=(74, 21)),
#   <Action.NNE: 25>): -1,
#  (Isolation(board=41523161203939120929762088962746367, ply_count=3, locs=(60, 32)),
#   <Action.SSE: -27>): 0,
#  (Isolation(board=41523161201520680147639617122723839, ply_count=3, locs=(69, 81)),
#   <Action.SSW: -25>): 0,
#  (Isolation(board=41521893513444341805999372755789823, ply_count=3, locs=(85, 80)),
#   <Action.ENE: 11>): 0,
#  (Isolation(board=41523002747614093554008442988914623, ply_count=3, locs=(6, 97)),
#   <Action.ENE: 11>): 0,
#  (Isolation(board=41523151300418807799641432494434287, ply_count=3, locs=(4, 93)),
#   <Action.ENE: 11>): 0,
#  (Isolation(board=41523161184596308248273625049720831, ply_count=3, locs=(84, 57)),
#   <Action.WSW: -11>): 0,
#  (Isolation(board=41523161203939122082639647464220671, ply_count=3, locs=(32, 45)),
#   <Action.NNE: 25>): 0,
#  (Isolation(board=41523161203939048295705138362836991, ply_count=2, locs=(41, 66)),
#   <Action.NNW: 27>): -1,
#  (Isolation(board=41523121531829425609012635066427391, ply_count=3, locs=(95, 85)),
#   <Action.ENE: 11>): 0,
#  (Isolation(board=41522844291289065007318309783201791, ply_count=3, locs=(39, 98)),
#   <Action.SSW: -25>): 0,
#  (Isolation(board=41523156213493191139541809360791551, ply_count=3, locs=(67, 85)),
#   <Action.NNE: 25>): 0,
#  (Isolation(board=41523081975774246635104603857610751, ply_count=3, locs=(71, 17)),
#   <Action.NNW: 27>): 0,
#  (Isolation(board=41523161203939122082681433198929919, ply_count=3, locs=(41, 21)),
#   <Action.NNW: 27>): 0,
#  (Isolation(board=41198642650280695067670097904527359, ply_count=3, locs=(58, 108)),
#   <Action.WSW: -11>): 0,
#  (Isolation(board=41523161203939122082683625781782527, ply_count=3, locs=(31, 32)),
#   <Action.SSE: -27>): 0,
#  (Isolation(board=41523161203936760827314234619586559, ply_count=3, locs=(71, 46)),
#   <Action.WSW: -11>): 0,
#  (Isolation(board=41523161203939122082683614775993855, ply_count=3, locs=(34, 28)),
#   <Action.ESE: -15>): 0,
#  (Isolation(board=41523141396860714584454801699891199, ply_count=3, locs=(48, 94)),
#   <Action.SSW: -25>): 0,
#  (Isolation(board=41523161199103123647312736917907455, ply_count=3, locs=(68, 82)),
#   <Action.WSW: -11>): 0,
#  (Isolation(board=41523161202730195074118701423781887, ply_count=3, locs=(80, 60)),
#   <Action.WNW: 15>): 0,
#  (Isolation(board=41523161203939122082679234177755071, ply_count=3, locs=(42, 6)),
#   <Action.NNE: 25>): 0,
#  (Isolation(board=41523161203939119776840605830735869, ply_count=3, locs=(61, 1)),
#   <Action.NNW: 27>): 0,
#  (Isolation(board=41523161203939121487927006434682879, ply_count=3, locs=(48, 54)),
#   <Action.ESE: -15>): 0,
#  (Isolation(board=41523161203934399716183170393040895, ply_count=2, locs=(72, 44)),
#   <Action.NNW: 27>): 0,
#  (Isolation(board=41523158728059043511923082157615103, ply_count=2, locs=(91, 28)),
#   <Action.WNW: 15>): -6,
#  (Isolation(board=41523161203939121506222811201398783, ply_count=2, locs=(59, 36)),
#   <Action.NNE: 25>): -3,
#  (Isolation(board=41523161203939122082683612896946159, ply_count=3, locs=(4, 34)),
#   <Action.WNW: 15>): 0,
#  (Isolation(board=41523161203938826934215502913857535, ply_count=3, locs=(22, 68)),
#   <Action.SSW: -25>): 0,
#  (Isolation(board=20753973769799811568561646370547707, ply_count=3, locs=(2, 114)),
#   <Action.SSE: -27>): 0,
#  (Isolation(board=41523161203939122046654835196946431, ply_count=2, locs=(55, 23)),
#   <Action.ENE: 11>): 0,
#  (Isolation(board=41523161199102828490400358310340607, ply_count=3, locs=(69, 82)),
#   <Action.SSW: -25>): 0,
#  (Isolation(board=40874124091786565350658803484321790, ply_count=3, locs=(109, 0)),
#   <Action.NNW: 27>): 0,
#  (Isolation(board=41523161201521270443452174784522239, ply_count=3, locs=(41, 81)),
#   <Action.ENE: 11>): 0,
#  (Isolation(board=41523161203939121794453247482390527, ply_count=3, locs=(18, 58)),
#   <Action.SSE: -27>): 0,
#  (Isolation(board=41523161203939122082683631686379515, ply_count=3, locs=(29, 20)),
#   <Action.NNW: 27>): 0,
#  (Isolation(board=41522527378639007967982883872688123, ply_count=3, locs=(2, 99)),
#   <Action.WNW: 15>): 0,
#  (Isolation(board=41523161203934399572050390131140607, ply_count=3, locs=(72, 57)),
#   <Action.SSE: -27>): 0,
#  (Isolation(board=41523161203939121974597240630536191, ply_count=3, locs=(56, 55)),
#   <Action.ESE: -15>): 0,
#  (Isolation(board=41523161203939122082683632090015679, ply_count=3, locs=(27, 6)),
#   <Action.NNE: 25>): 0,
#  (Isolation(board=41522844291279620292367518221199359, ply_count=3, locs=(73, 29)),
#   <Action.ENE: 11>): 0,
#  (Isolation(board=41523161199101057620983676407900159, ply_count=3, locs=(82, 32)),
#   <Action.ESE: -15>): 0,
#  (Isolation(board=41523161203939122082525302549374975, ply_count=3, locs=(44, 47)),
#   <Action.NNE: 25>): 3,
#  (Isolation(board=41523161203939121938568444148443134, ply_count=2, locs=(0, 57)),
#   <Action.NNW: 27>): -4,
#  (Isolation(board=41523161203920232616752153642395615, ply_count=3, locs=(20, 74)),
#   <Action.ESE: -15>): 0,
#  (Isolation(board=41523161126567869627346264994605055, ply_count=3, locs=(29, 86)),
#   <Action.SSE: -27>): 0,
#  (Isolation(board=41522507571579489935967006905853951, ply_count=3, locs=(74, 94)),
#   <Action.SSE: -27>): 0,
#  (Isolation(board=41523161125963404411697041242056703, ply_count=3, locs=(61, 79)),
#   <Action.NNE: 25>): 0,
#  (Isolation(board=41523161203939048295706787093407743, ply_count=3, locs=(39, 29)),
#   <Action.WSW: -11>): 0,
#  (Isolation(board=41523161203938531192398122705741823, ply_count=3, locs=(54, 59)),
#   <Action.ENE: 11>): 0,
#  (Isolation(board=41523161203939122078169037480650751, ply_count=3, locs=(52, 43)),
#   <Action.SSW: -25>): 0,
#  (Isolation(board=41523161194267715237536222674937599, ply_count=3, locs=(58, 8)),
#   <Action.ENE: 11>): 0,
#  (Isolation(board=41523161203939122082683631686379519, ply_count=2, locs=(29, 20)),
#   <Action.NNW: 27>): 3,
#  (Isolation(board=41360901927109908431052881969276927, ply_count=3, locs=(43, 107)),
#   <Action.SSW: -25>): 0,
#  (Isolation(board=41523161202730196263069003049592799, ply_count=2, locs=(80, 5)),
#   <Action.NNE: 25>): -3,
#  (Isolation(board=41523002747612912962317358980917247, ply_count=3, locs=(70, 46)),
#   <Action.SSW: -25>): 0,
#  (Isolation(board=41523136445138336375078134241814527, ply_count=2, locs=(92, 94)),
#   <Action.SSE: -27>): 2,
#  (Isolation(board=41523161203938531768577400032454655, ply_count=3, locs=(54, 48)),
#   <Action.NNW: 27>): 0,
#  (Isolation(board=41523161165248771182689619774793727, ply_count=3, locs=(72, 85)),
#   <Action.ENE: 11>): 0,
#  (Isolation(board=41523161203920232616681782751782911, ply_count=3, locs=(31, 74)),
#   <Action.ENE: 11>): 0,
#  (Isolation(board=41523161203939122082666035742763007, ply_count=3, locs=(44, 32)),
#   <Action.WSW: -11>): 0,
#  (Isolation(board=41523161201521270443436781688317951, ply_count=3, locs=(44, 81)),
#   <Action.NNE: 25>): -2,
#  (Isolation(board=41522527378639007967982883872171775, ply_count=3, locs=(19, 99)),
#   <Action.ESE: -15>): 0,
#  (Isolation(board=41523161203936759746520692794845119, ply_count=3, locs=(60, 6)),
#   <Action.WNW: 15>): 0,
#  (Isolation(board=41523161182177867033809948373936127, ply_count=3, locs=(84, 81)),
#   <Action.NNE: 25>): 0,
#  (Isolation(board=41523161049196616018948855766706175, ply_count=3, locs=(87, 47)),
#   <Action.NNW: 27>): 0,
#  (Isolation(board=41523161203939119776840601535768575, ply_count=3, locs=(61, 32)),
#   <Action.NNW: 27>): 0,
#  (Isolation(board=41523161165253348281061809445660671, ply_count=3, locs=(67, 85)),
#   <Action.ESE: -15>): 0,
#  (Isolation(board=41521893553301114921401586173339647, ply_count=3, locs=(75, 44)),
#   <Action.SSE: -27>): 0,
#  (Isolation(board=41523161203901343150785490690500607, ply_count=2, locs=(45, 75)),
#   <Action.SSW: -25>): -1,
#  (Isolation(board=41523161203936759746520692793796607, ply_count=3, locs=(60, 20)),
#   <Action.WNW: 15>): 0,
#  (Isolation(board=41523161194265354342454795259865087, ply_count=3, locs=(71, 83)),
#   <Action.ENE: 11>): 0,
#  (Isolation(board=41523161203934399571804099526518783, ply_count=3, locs=(72, 48)),
#   <Action.ENE: 11>): 0,
#  (Isolation(board=41523161203939085189195484804671487, ply_count=2, locs=(19, 65)),
#   <Action.NNE: 25>): 3,
#  (Isolation(board=41523161203939122082666040038107135, ply_count=3, locs=(44, 14)),
#   <Action.NNW: 27>): 0,
#  (Isolation(board=41523161203939122073641248530360319, ply_count=3, locs=(26, 45)),
#   <Action.ENE: 11>): 0,
#  (Isolation(board=41520546674576151359543045273937919, ply_count=2, locs=(96, 101)),
#   <Action.ENE: 11>): -1,
#  (Isolation(board=41523161203939120929762119027386367, ply_count=3, locs=(33, 17)),
#   <Action.ENE: 11>): 0,
#  (Isolation(board=41523161203939119776840605293864959, ply_count=3, locs=(61, 29)),
#   <Action.SSW: -25>): 0,
#  (Isolation(board=41523161203938531786873273518647295, ply_count=1, locs=(69, None)),
#   47): -4,
#  (Isolation(board=41523161203939120929762050308040703, ply_count=3, locs=(33, 36)),
#   <Action.SSE: -27>): 0,
#  (Isolation(board=41523161202725473896550949032290303, ply_count=3, locs=(45, 80)),
#   <Action.NNW: 27>): 0,
#  (Isolation(board=41523161203934399698186363532732415, ply_count=3, locs=(54, 72)),
#   <Action.SSW: -25>): 0,
#  (Isolation(board=36330547423082830839885728321628159, ply_count=3, locs=(83, 112)),
#   <Action.SSW: -25>): 0,
#  (Isolation(board=41523161126567869627347364975962111, ply_count=3, locs=(26, 86)),
#   <Action.WNW: 15>): 0,
#  (Isolation(board=41523161203939122082666040029341695, ply_count=3, locs=(19, 23)),
#   <Action.ESE: -15>): 0,
#  (Isolation(board=41520625902715053791466290591819775, ply_count=3, locs=(74, 72)),
#   <Action.ENE: 11>): 0,
#  (Isolation(board=41523161126565508444105930212108287, ply_count=3, locs=(71, 23)),
#   <Action.ESE: -15>): 0,
#  (Isolation(board=41523161203939122010626021005977599, ply_count=3, locs=(34, 56)),
#   <Action.WNW: 15>): 0,
#  (Isolation(board=41523161203939122082682532710574079, ply_count=2, locs=(40, 21)),
#   <Action.WSW: -11>): 0,
#  (Isolation(board=41523161203938974508731042547886079, ply_count=1, locs=(67, None)),
#   78): 0,
#  (Isolation(board=41502868890815156057159891742091263, ply_count=3, locs=(93, 56)),
#   <Action.NNE: 25>): 0,
#  (Isolation(board=41523161203938974508729941962516479, ply_count=3, locs=(67, 30)),
#   <Action.WSW: -11>): 0,
#  (Isolation(board=41481962559412815161203510789269503, ply_count=3, locs=(74, 105)),
#   <Action.WSW: -11>): 0,
#  (Isolation(board=41523161203939122010626036038887359, ply_count=3, locs=(31, 56)),
#   <Action.SSE: -27>): 0,
#  (Isolation(board=41523161165253495566785122481989567, ply_count=3, locs=(58, 6)),
#   <Action.NNE: 25>): 0,
#  (Isolation(board=41522527069153998146637815147390975, ply_count=3, locs=(88, 19)),
#   <Action.WSW: -11>): 0,
#  (Isolation(board=41360901927109908719292054079793151, ply_count=2, locs=(27, 107)),
#   <Action.SSW: -25>): 3,
#  (Isolation(board=41523160894454112189245785089501183, ply_count=3, locs=(45, 88)),
#   <Action.NNE: 25>): 0,
#  (Isolation(board=41523161203929677349717884339742719, ply_count=3, locs=(22, 73)),
#   <Action.SSW: -25>): 0,
#  (Isolation(board=41523146346240799018891075085395967, ply_count=3, locs=(81, 93)),
#   <Action.WNW: 15>): 0,
#  (Isolation(board=41360901925900982899677407859435519, ply_count=3, locs=(107, 34)),
#   <Action.SSW: -25>): 0,
#  (Isolation(board=41523161203938531786873239158908927, ply_count=2, locs=(35, 69)),
#   <Action.NNE: 25>): 2,
#  (Isolation(board=41502868890815156129147117035841535, ply_count=3, locs=(104, 46)),
#   <Action.WSW: -11>): 0,
#  (Isolation(board=41523002742778390275549928437508095, ply_count=3, locs=(82, 16)),
#   <Action.ESE: -15>): 0,
#  (Isolation(board=41502878794335470412259650613274367, ply_count=3, locs=(35, 104)),
#   <Action.SSW: -25>): 0,
#  (Isolation(board=41523161203939122082681398841288703, ply_count=3, locs=(14, 35)),
#   <Action.SSE: -27>): 0,
#  (Isolation(board=41442029079973030273310260023257087, ply_count=3, locs=(106, 83)),
#   <Action.WNW: 15>): 0,
#  (Isolation(board=41523081975776607241867694190880767, ply_count=3, locs=(59, 96)),
#   <Action.SSE: -27>): 0,
#  (Isolation(board=41523161184596308968849565428737919, ply_count=3, locs=(7, 84)),
#   <Action.SSW: -25>): 0,
#  (Isolation(board=41523141396897903220788875132626943, ply_count=3, locs=(69, 15)),
#   <Action.NNW: 27>): 0,
#  (Isolation(board=41521893553338893853264542798178303, ply_count=3, locs=(29, 100)),
#   <Action.SSW: -25>): 0,
#  (Isolation(board=41523161203334659168372715862091775, ply_count=3, locs=(79, 31)),
#   <Action.ENE: 11>): 0,
#  (Isolation(board=41482596384731818741835737654585343, ply_count=3, locs=(26, 105)),
#   <Action.SSE: -27>): 0,
#  (Isolation(board=41523161182178457329620307079587839, ply_count=2, locs=(81, 84)),
#   <Action.ESE: -15>): 0,
#  (Isolation(board=41523161203934399716165578202802175, ply_count=3, locs=(72, 22)),
#   <Action.ENE: 11>): 0,
#  (Isolation(board=41523161203636890627779974796404731, ply_count=3, locs=(2, 78)),
#   <Action.SSW: -25>): 0,
#  (Isolation(board=41523161194267714372845059860064255, ply_count=3, locs=(35, 83)),
#   <Action.SSW: -25>): 0,
#  (Isolation(board=41482596384731818741800553348589567, ply_count=3, locs=(20, 105)),
#   <Action.SSE: -27>): 0,
#  (Isolation(board=41523161203938974508731042010753023, ply_count=3, locs=(29, 67)),
#   <Action.SSW: -25>): 0,
#  (Isolation(board=41523161203636743053686647765854207, ply_count=3, locs=(67, 47)),
#   <Action.NNW: 27>): 0,
#  (Isolation(board=41522685834959314130175201315383295, ply_count=3, locs=(72, 98)),
#   <Action.SSW: -25>): 0,
#  (Isolation(board=41523161202720751494074466740201471, ply_count=3, locs=(80, 73)),
#   <Action.ESE: -15>): 0,
#  (Isolation(board=41523161203939117470856876308555759, ply_count=3, locs=(62, 4)),
#   <Action.WNW: 15>): 0,
#  (Isolation(board=41523161203934399716060025090729983, ply_count=2, locs=(47, 72)),
#   <Action.NNW: 27>): 3,
#  (Isolation(board=41523161203939121794453238892193791, ply_count=3, locs=(34, 58)),
#   <Action.ENE: 11>): 0,
#  (Isolation(board=41520308990086247383288829819480063, ply_count=3, locs=(98, 101)),
#   <Action.SSE: -27>): 0,
#  (Isolation(board=41523161203939122082683615044429815, ply_count=2, locs=(34, 3)),
#   <Action.ESE: -15>): 0,
#  (Isolation(board=41523161203939122082683632224102367, ply_count=3, locs=(5, 17)),
#   <Action.WSW: -11>): 0,
#  (Isolation(board=38927012696695992903274802291140607, ply_count=3, locs=(111, 79)),
#   <Action.NNW: 27>): 0,
#  (Isolation(board=20753973615054945474647677722421247, ply_count=3, locs=(114, 71)),
#   <Action.ENE: 11>): 0,
#  (Isolation(board=41523161201521270425439975365404607, ply_count=3, locs=(81, 6)),
#   <Action.NNW: 27>): 0,
#  (Isolation(board=41522527378639007967982883604129791, ply_count=3, locs=(17, 99)),
#   <Action.SSW: -25>): 0,
#  (Isolation(board=41523141319527241061262966657116159, ply_count=2, locs=(94, 86)),
#   <Action.WNW: 15>): 3,
#  (Isolation(board=41523161184596308968847365332002815, ply_count=3, locs=(30, 84)),
#   <Action.NNE: 25>): 0,
#  (Isolation(board=41523161203939122082683632224298623, ply_count=2, locs=(8, 7)),
#   <Action.ENE: 11>): 1,
#  (Isolation(board=41523121570515051692565580581169151, ply_count=3, locs=(84, 57)),
#   <Action.WNW: 15>): 0,
#  (Isolation(board=41523161203939085188632534851774463, ply_count=2, locs=(65, 49)),
#   <Action.NNW: 27>): 4,
#  (Isolation(board=41360896970514048299312437918689279, ply_count=3, locs=(107, 82)),
#   <Action.NNW: 27>): 0,
#  (Isolation(board=41523161203939122082683631955863543, ply_count=2, locs=(28, 3)),
#   <Action.NNE: 25>): -3,
#  (Isolation(board=36328329044203837995349042977040383, ply_count=3, locs=(112, 40)),
#   <Action.WNW: 15>): 0,
#  (Isolation(board=41523161203937941455034083434293247, ply_count=3, locs=(70, 35)),
#   <Action.SSE: -27>): 0,
#  (Isolation(board=36330864190661789543480567172950015, ply_count=3, locs=(87, 35)),
#   <Action.NNW: 27>): 0,
#  (Isolation(board=41523161203636890627779974863513599, ply_count=2, locs=(78, 26)),
#   <Action.NNW: 27>): 4,
#  (Isolation(board=41523161203939122082648447852079103, ply_count=2, locs=(17, 45)),
#   <Action.NNE: 25>): 2,
#  (Isolation(board=41523161203938826934778450723989487, ply_count=3, locs=(31, 68)),
#   <Action.ESE: -15>): 0,
#  (Isolation(board=41523158728058969715939588333103103, ply_count=3, locs=(66, 53)),
#   <Action.SSW: -25>): 0,
#  (Isolation(board=41523161126567574479433389597255679, ply_count=3, locs=(43, 86)),
#   <Action.ENE: 11>): 0,
#  (Isolation(board=41523161203939122082683631418984447, ply_count=3, locs=(13, 29)),
#   <Action.SSE: -27>): 0,
#  (Isolation(board=41523161203938974508731042547623927, ply_count=3, locs=(18, 67)),
#   <Action.WNW: 15>): 0,
#  (Isolation(board=41523161203929677349647524189431807, ply_count=3, locs=(46, 18)),
#   <Action.WSW: -11>): 0,
#  (Isolation(board=41523156252178964905133735608838143, ply_count=2, locs=(55, 92)),
#   <Action.NNE: 25>): -3,
#  (Isolation(board=41523151300418660225687743843264511, ply_count=3, locs=(40, 93)),
#   <Action.ENE: 11>): 0,
#  (Isolation(board=41502878793731007502452370385643519, ply_count=3, locs=(79, 14)),
#   <Action.WNW: 15>): 0,
#  (Isolation(board=41523161203939121506222879920613247, ply_count=3, locs=(7, 59)),
#   <Action.SSE: -27>): 0,
#  (Isolation(board=41523161203939122082683632022906879, ply_count=3, locs=(27, 26)),
#   <Action.NNW: 27>): 0,
#  (Isolation(board=41523161203939122082119582759217151, ply_count=3, locs=(40, 49)),
#   <Action.ESE: -15>): 0,
#  (Isolation(board=20753934154509628616778220960737279, ply_count=3, locs=(80, 114)),
#   <Action.SSE: -27>): 0,
#  (Isolation(board=41523161165251134383543687659382783, ply_count=3, locs=(85, 71)),
#   <Action.SSW: -25>): 0,
#  (Isolation(board=41482596383522892922221108547020783, ply_count=3, locs=(80, 4)),
#   <Action.NNE: 25>): 0,
#  (Isolation(board=41502868890815156129217485780018687, ply_count=3, locs=(104, 9)),
#   <Action.NNE: 25>): -1,
#  (Isolation(board=41523161203939121794453238892718079, ply_count=2, locs=(58, 34)),
#   <Action.NNW: 27>): 0,
#  (Isolation(board=41522844281617658468416224650847999, ply_count=3, locs=(83, 8)),
#   <Action.ENE: 11>): 0,
#  (Isolation(board=41523161203939120929199177127159807, ply_count=3, locs=(60, 29)),
#   <Action.ESE: -15>): 0,
#  (Isolation(board=41523161203937941491026630929278975, ply_count=3, locs=(70, 40)),
#   <Action.SSE: -27>): 0,
#  (Isolation(board=41523161049196617172006699815266303, ply_count=3, locs=(42, 87)),
#   <Action.NNW: 27>): 0,
#  (Isolation(board=41523161203939122082648413492470783, ply_count=3, locs=(10, 45)),
#   <Action.ESE: -15>): 0,
#  (Isolation(board=41523161203939122082679234177525751, ply_count=3, locs=(18, 42)),
#   <Action.WNW: 15>): 0,
#  (Isolation(board=41523161203939122046654834936898559, ply_count=3, locs=(55, 10)),
#   <Action.NNE: 25>): 0,
#  (Isolation(board=40225086989286525133158777257715711, ply_count=3, locs=(74, 110)),
#   <Action.SSW: -25>): 0,
#  (Isolation(board=41523161203939122082402157239068671, ply_count=3, locs=(23, 17)),
#   <Action.NNE: 25>): 0,
#  (Isolation(board=41523160884782705416191153950156799, ply_count=3, locs=(83, 88)),
#   <Action.ESE: -15>): 0,
#  (Isolation(board=41523161203935580307812683897366527, ply_count=3, locs=(70, 71)),
#   <Action.NNW: 27>): 0,
#  (Isolation(board=41519992077419662043248411885430783, ply_count=3, locs=(101, 99)),
#   <Action.ENE: 11>): 0,
#  (Isolation(board=41198622840822215150586819468322815, ply_count=3, locs=(81, 94)),
#   <Action.SSE: -27>): 0,
#  (Isolation(board=41523161193663252611455684611926015, ply_count=3, locs=(79, 83)),
#   <Action.NNE: 25>): 0,
#  (Isolation(board=41523161199103418795217916203624447, ply_count=3, locs=(26, 82)),
#   <Action.WNW: 15>): 0,
#  (Isolation(board=41198642640606927615742007983466495, ply_count=3, locs=(83, 71)),
#   <Action.SSE: -27>): 0,
#  (Isolation(board=41360901922273615145023178809534463, ply_count=3, locs=(107, 69)),
#   <Action.SSE: -27>): 0,
#  (Isolation(board=36328329044203837995350140341184511, ply_count=3, locs=(112, 31)),
#   <Action.NNE: 25>): -3,
#  (Isolation(board=41522527378620118502051405291841471, ply_count=3, locs=(74, 6)),
#   <Action.ENE: 11>): 0,
#  (Isolation(board=31138567477193337902222736522995711, ply_count=3, locs=(83, 113)),
#   <Action.ESE: -15>): 0,
#  (Isolation(board=41523161199103416498382037592303615, ply_count=3, locs=(61, 82)),
#   <Action.NNW: 27>): 0,
#  (Isolation(board=41523161203939122082683631687428087, ply_count=2, locs=(3, 29)),
#   <Action.WNW: 15>): 3,
#  (Isolation(board=20753973615057306657889111471286271, ply_count=3, locs=(87, 30)),
#   <Action.WSW: -11>): 0,
#  (Isolation(board=41523161202730196263033801497634815, ply_count=3, locs=(45, 80)),
#   <Action.WSW: -11>): 0,
#  (Isolation(board=41523002747612912962387727725078527, ply_count=3, locs=(97, 14)),
#   <Action.WSW: -11>): 0,
#  (Isolation(board=40874124077279455515283253387847678, ply_count=3, locs=(109, 0)),
#   <Action.WNW: 15>): 1,
#  (Isolation(board=41523161203939122082674801771538175, ply_count=3, locs=(8, 43)),
#   <Action.ESE: -15>): 0,
#  (Isolation(board=41523161203939122082648447852209663, ply_count=2, locs=(45, 9)),
#   <Action.WSW: -11>): 0,
#  (Isolation(board=41523161203939122082683621486880751, ply_count=3, locs=(31, 33)),
#   <Action.WSW: -11>): 0,
#  (Isolation(board=41523161203636743053827385254208511, ply_count=3, locs=(78, 10)),
#   <Action.ENE: 11>): 0,
#  (Isolation(board=41523161203934399698186363935385599, ply_count=3, locs=(54, 72)),
#   <Action.ENE: 11>): 0,
#  (Isolation(board=41523151300418733976636341174134783, ply_count=3, locs=(55, 93)),
#   <Action.WSW: -11>): 0,
#  (Isolation(board=41523160894416331023632597124114431, ply_count=3, locs=(88, 75)),
#   <Action.SSE: -27>): 0,
#  (Isolation(board=41523161203938826925771245026797567, ply_count=3, locs=(53, 33)),
#   <Action.SSE: -27>): 0,
#  (Isolation(board=41522527378639007967982882798954495, ply_count=2, locs=(99, 30)),
#   <Action.SSW: -25>): -3,
#  (Isolation(board=41523161203334659172874118613690367, ply_count=2, locs=(41, 79)),
#   <Action.ENE: 11>): 0,
#  (Isolation(board=41523161199103418750181919997028351, ply_count=3, locs=(82, 54)),
#   <Action.WSW: -11>): 0,
#  (Isolation(board=41520625902738665623880638683670527, ply_count=2, locs=(101, 27)),
#   <Action.SSE: -27>): 6,
#  (Isolation(board=41523156252178964941162532627802111, ply_count=1, locs=(92, None)),
#   18): -10,
#  (Isolation(board=41523161203939084900964009141856255, ply_count=3, locs=(40, 58)),
#   <Action.ESE: -15>): 0,
#  (Isolation(board=41523161199103418804225115525212159, ply_count=2, locs=(18, 82)),
#   <Action.NNW: 27>): -1,
#  (Isolation(board=41523161203939122073394957990750207, ply_count=3, locs=(21, 53)),
#   <Action.NNW: 27>): 0,
#  (Isolation(board=41523121549963312903232072687020031, ply_count=3, locs=(95, 85)),
#   <Action.SSE: -27>): 0,
#  (Isolation(board=41523156249761108690247255851001855, ply_count=3, locs=(81, 62)),
#   <Action.ESE: -15>): 0,
#  (Isolation(board=41523161201520680129629616659752959, ply_count=3, locs=(54, 69)),
#   <Action.SSE: -27>): 0,
#  (Isolation(board=41482596384731818741835736647460863, ply_count=3, locs=(30, 105)),
#   <Action.SSW: -25>): 0,
#  (Isolation(board=41523161194267715525696230082471935, ply_count=2, locs=(83, 46)),
#   <Action.ENE: 11>): 0,
#  (Isolation(board=40873807164629398457932879212046335, ply_count=3, locs=(109, 98)),
#   <Action.ESE: -15>): -1,
#  (Isolation(board=41523121589857864950514835452323711, ply_count=2, locs=(7, 95)),
#   <Action.NNE: 25>): 3,
#  (Isolation(board=41523161189432012103192894051969023, ply_count=3, locs=(82, 83)),
#   <Action.NNW: 27>): 0,
#  (Isolation(board=41523161201521270443454373874755579, ply_count=3, locs=(2, 81)),
#   <Action.SSW: -25>): 0,
#  (Isolation(board=41523161203939122082681433196849151, ply_count=2, locs=(22, 41)),
#   <Action.NNE: 25>): -1,
#  (Isolation(board=41523161203937941491062914678777854, ply_count=3, locs=(27, 70)),
#   <Action.NNE: 25>): 0,
#  (Isolation(board=41523161203334364024971121104250879, ply_count=3, locs=(79, 34)),
#   <Action.ESE: -15>): 0,
#  (Isolation(board=41523081975776607818346021500479487, ply_count=2, locs=(34, 96)),
#   <Action.NNE: 25>): 3,
#  (Isolation(board=41523161203938974508729925856389119, ply_count=3, locs=(40, 34)),
#   <Action.ESE: -15>): 0,
#  (Isolation(board=41523161203939122064669199220860927, ply_count=3, locs=(54, 35)),
#   <Action.NNW: 27>): 0,
#  (Isolation(board=41502878794335322833803495669229567, ply_count=3, locs=(67, 104)),
#   <Action.WSW: -11>): 0,
#  (Isolation(board=41523161203939120929480652632352767, ply_count=3, locs=(23, 60)),
#   <Action.NNE: 25>): 0,
#  (Isolation(board=41523161199100983834007385864660991, ply_count=3, locs=(82, 66)),
#   <Action.WSW: -11>): 0,
#  (Isolation(board=41502878716964215651080408578123775, ply_count=3, locs=(86, 104)),
#   <Action.WSW: -11>): 0,
#  (Isolation(board=41523161203939121938498071109298175, ply_count=3, locs=(32, 46)),
#   <Action.WNW: 15>): 0,
#  (Isolation(board=41360901925900982899677356319827967, ply_count=3, locs=(80, 36)),
#   <Action.ESE: -15>): 0,
#  (Isolation(board=41523161203938826790663264795617151, ply_count=3, locs=(57, 7)),
#   <Action.NNW: 27>): 0,
#  (Isolation(board=41523156251574502031355218040449023, ply_count=2, locs=(92, 79)),
#   <Action.SSE: -27>): -2,
#  (Isolation(board=41523161202730196263051410326677503, ply_count=3, locs=(29, 80)),
#   <Action.NNE: 25>): 0,
#  (Isolation(board=41523156252178964941144939904886783, ply_count=3, locs=(44, 92)),
#   <Action.SSE: -27>): 0,
# ...
#   <Action.WNW: 15>): 0,
#  (Isolation(board=41523161203882453684748458993379327, ply_count=3, locs=(47, 75)),
#   <Action.ESE: -15>): 0,
#  (Isolation(board=41523160894444667528372824209090527, ply_count=3, locs=(88, 5)),
#   <Action.ENE: 11>): 0,
#  (Isolation(board=41523161183387346255746788835190783, ply_count=3, locs=(65, 84)),
#   <Action.SSW: -25>): 0,
#  (Isolation(board=41523151300418217503826676279142399, ply_count=3, locs=(69, 93)),
#   <Action.ENE: 11>): 0,
#  (Isolation(board=41523161202730196262787528070785023, ply_count=3, locs=(21, 80)),
#   <Action.SSW: -25>): 0,
#  (Isolation(board=41523161203929677345212094283245567, ply_count=3, locs=(41, 73)),
#   <Action.SSW: -25>): 0,
#  (Isolation(board=41523161201521270425439975365404670, ply_count=3, locs=(54, 0)),
#   <Action.WNW: 15>): 0,
#  (Isolation(board=41523161203939121938568439853475838, ply_count=3, locs=(32, 0)),
#   <Action.WNW: 15>): 0,
#  (Isolation(board=41523161203939122082683632219580159, ply_count=3, locs=(19, 22)),
#   <Action.ESE: -15>): 0,
#  (Isolation(board=41523161203939122073672034918852607, ply_count=3, locs=(42, 22)),
#   <Action.NNW: 27>): 0,
#  (Isolation(board=41502873842575165696785995700103167, ply_count=3, locs=(92, 104)),
#   <Action.SSW: -25>): -1,
#  (Isolation(board=41523161203920232616752119282657279, ply_count=3, locs=(35, 74)),
#   <Action.SSW: -25>): 0,
#  (Isolation(board=41360896975345029211288084972300287, ply_count=3, locs=(92, 72)),
#   <Action.NNW: 27>): 0,
#  (Isolation(board=40874104270238826949198855001860095, ply_count=3, locs=(84, 94)),
#   <Action.SSE: -27>): 0,
#  (Isolation(board=41523141396898493516599233838311423, ply_count=1, locs=(94, None)),
#   57): 8,
#  (Isolation(board=41523161203939121794451057049331711, ply_count=2, locs=(58, 41)),
#   <Action.ESE: -15>): 0,
#  (Isolation(board=41523161203939122082683632222201823, ply_count=2, locs=(21, 5)),
#   <Action.ESE: -15>): 3,
#  (Isolation(board=41482596384731818741826941628704767, ply_count=2, locs=(43, 105)),
#   <Action.NNE: 25>): 3,
#  (Isolation(board=41523161201521265831768355447498751, ply_count=2, locs=(81, 62)),
#   <Action.SSE: -27>): 3,
#  (Isolation(board=41522527069151636963396380325308415, ply_count=3, locs=(99, 71)),
#   <Action.ESE: -15>): 0,
#  (Isolation(board=41523161165253495566776326388967423, ply_count=3, locs=(58, 43)),
#   <Action.SSE: -27>): 0,
#  (Isolation(board=41198642647862843716671217720092671, ply_count=3, locs=(81, 27)),
#   <Action.NNE: 25>): 0,
#  (Isolation(board=41523161202730196254061803526416383, ply_count=3, locs=(53, 28)),
#   <Action.ENE: 11>): 0,
#  (Isolation(board=41360901927109613571378078768162815, ply_count=3, locs=(68, 107)),
#   <Action.SSW: -25>): 0,
#  (Isolation(board=38927012697300454660160612271646719, ply_count=3, locs=(86, 60)),
#   <Action.WNW: 15>): 0,
#  (Isolation(board=41523161203934397410357752828520447, ply_count=3, locs=(72, 29)),
#   <Action.NNE: 25>): 0,
#  (Isolation(board=31138567486869466825622639565334271, ply_count=3, locs=(19, 113)),
#   <Action.SSW: -25>): 0,
#  (Isolation(board=41523161203939122082683632157190141, ply_count=2, locs=(26, 1)),
#   <Action.WSW: -11>): -4,
#  (Isolation(board=41523161203939122082683629808379887, ply_count=3, locs=(31, 28)),
#   <Action.NNE: 25>): 0,
#  (Isolation(board=41523161203936760881427249136396287, ply_count=3, locs=(54, 71)),
#   <Action.ESE: -15>): 0,
#  (Isolation(board=41523161203929677061487516715051007, ply_count=3, locs=(58, 26)),
#   <Action.WNW: 15>): 0,
#  (Isolation(board=41502878794335396625282840378992639, ply_count=3, locs=(66, 104)),
#   <Action.SSW: -25>): 0,
#  (Isolation(board=41523161203939122082613263211677695, ply_count=3, locs=(28, 46)),
#   <Action.WSW: -11>): 0,
#  (Isolation(board=41523161199102238212604398114170879, ply_count=2, locs=(70, 82)),
#   <Action.SSE: -27>): -1,
#  (Isolation(board=41523161203939121938568422673606655, ply_count=3, locs=(57, 34)),
#   <Action.NNE: 25>): 1,
#  (Isolation(board=41523161203938531786872174007019519, ply_count=2, locs=(40, 69)),
#   <Action.NNW: 27>): -1,
#  (Isolation(board=41523161194265354270467569966114815, ply_count=3, locs=(71, 83)),
#   <Action.NNW: 27>): 0,
#  (Isolation(board=36330705889079265925477948807145471, ply_count=3, locs=(112, 15)),
#   <Action.WSW: -11>): 0,
#  (Isolation(board=41442031565524515400987843219089405, ply_count=3, locs=(1, 106)),
#   <Action.SSE: -27>): 0,
#  (Isolation(board=41441982047922943985776847254185983, ply_count=3, locs=(95, 93)),
#   <Action.SSE: -27>): 0,
#  (Isolation(board=41502878794335470412259684838795263, ply_count=2, locs=(27, 104)),
#   <Action.SSE: -27>): -1,
#  (Isolation(board=41523161203939122010623839096006655, ply_count=3, locs=(26, 56)),
#   <Action.NNW: 27>): 0,
#  (Isolation(board=41523161203939122082613263478024189, ply_count=3, locs=(46, 1)),
#   <Action.WNW: 15>): 0,
#  (Isolation(board=36330859393643989738679446622169087, ply_count=3, locs=(92, 112)),
#   <Action.ESE: -15>): -3,
#  (Isolation(board=41482497349528675911413745791789055, ply_count=3, locs=(105, 96)),
#   <Action.WNW: 15>): 0,
#  (Isolation(board=41481328733829359057530583724845055, ply_count=3, locs=(105, 100)),
#   <Action.SSW: -25>): 0,
#  (Isolation(board=41522844291279620292367510168135679, ply_count=3, locs=(98, 33)),
#   <Action.NNE: 25>): 3,
#  (Isolation(board=41523161203939122010626021006501887, ply_count=2, locs=(56, 34)),
#   <Action.WNW: 15>): 0,
#  (Isolation(board=41198642650275972989382422186420223, ply_count=3, locs=(72, 108)),
#   <Action.WSW: -11>): 0,
#  (Isolation(board=41522527378639007967982882798430207, ply_count=3, locs=(19, 99)),
#   <Action.ESE: -15>): 0,
#  (Isolation(board=41523161203937646307128938441205759, ply_count=3, locs=(70, 68)),
#   <Action.NNE: 25>): 0,
#  (Isolation(board=41523161203636890618737591303792639, ply_count=3, locs=(53, 45)),
#   <Action.NNE: 25>): 1,
#  (Isolation(board=41523161203938531786873273384364031, ply_count=3, locs=(16, 69)),
#   <Action.WSW: -11>): 0,
#  (Isolation(board=41523161203939122082666039232948223, ply_count=3, locs=(29, 28)),
#   <Action.NNW: 27>): 0,
#  (Isolation(board=41523161203939122082681432932476927, ply_count=3, locs=(17, 41)),
#   <Action.NNE: 25>): 0,
#  (Isolation(board=41523161203937940914602162442463231, ply_count=3, locs=(70, 26)),
#   <Action.WSW: -11>): 0,
#  (Isolation(board=40873965640292517733959263450032127, ply_count=3, locs=(97, 109)),
#   <Action.WSW: -11>): 0,
#  (Isolation(board=41522844291289065025333257780062207, ply_count=2, locs=(28, 98)),
#   <Action.WNW: 15>): 0,
#  (Isolation(board=41522527378639005662139805939525631, ply_count=3, locs=(61, 99)),
#   <Action.SSW: -25>): 0,
#  (Isolation(board=41523161201519942277881066787170303, ply_count=3, locs=(81, 67)),
#   <Action.NNE: 25>): 0,
#  (Isolation(board=41523161194248826059835120245794815, ply_count=2, locs=(74, 83)),
#   <Action.ESE: -15>): 0,
#  (Isolation(board=41523161203928492146411157095180287, ply_count=3, locs=(62, 70)),
#   <Action.SSE: -27>): 0,
#  (Isolation(board=41523161203939117398939985399244799, ply_count=3, locs=(62, 56)),
#   <Action.SSE: -27>): 0,
#  (Isolation(board=41523161203934397410357753365391355, ply_count=3, locs=(61, 2)),
#   <Action.NNW: 27>): 0,
#  (Isolation(board=31138250574219409732243468371093503, ply_count=3, locs=(98, 55)),
#   <Action.ENE: 11>): 0,
#  (Isolation(board=41360901927109908647234460176082943, ply_count=2, locs=(56, 107)),
#   <Action.ENE: 11>): 0,
#  (Isolation(board=41523161203939122082542826016458751, ply_count=3, locs=(36, 13)),
#   <Action.WSW: -11>): 0,
#  (Isolation(board=41523161203939122078180032596928479, ply_count=2, locs=(52, 5)),
#   <Action.WSW: -11>): 0,
#  (Isolation(board=41522844136546560114660723686041599, ply_count=3, locs=(98, 16)),
#   <Action.ESE: -15>): 0,
#  (Isolation(board=40062827711267275992544800956999679, ply_count=3, locs=(107, 110)),
#   <Action.SSE: -27>): 0,
#  (Isolation(board=41441991874072005813482779265984511, ply_count=3, locs=(106, 86)),
#   <Action.NNW: 27>): 0,
#  (Isolation(board=41523161203939122082682530028316671, ply_count=3, locs=(29, 31)),
#   <Action.SSW: -25>): 0,
#  (Isolation(board=41523161203939120911747728973752319, ply_count=3, locs=(54, 60)),
#   <Action.SSW: -25>): 0,
#  (Isolation(board=41523141396898493516581641652267007, ply_count=2, locs=(94, 44)),
#   <Action.ENE: 11>): 0,
#  (Isolation(board=41523081975776312526325671251666943, ply_count=3, locs=(57, 96)),
#   <Action.WNW: 15>): 0,
#  (Isolation(board=41521893553329449048258802192738303, ply_count=3, locs=(73, 56)),
#   <Action.WNW: 15>): 0,
#  (Isolation(board=41523161203939121217974911583119359, ply_count=3, locs=(44, 58)),
#   <Action.SSE: -27>): 0,
#  (Isolation(board=41523160894454112261338563231074303, ply_count=3, locs=(28, 88)),
#   <Action.ENE: 11>): 0,
#  (Isolation(board=41523161203939122010626037648451583, ply_count=3, locs=(29, 20)),
#   <Action.WSW: -11>): 0,
#  (Isolation(board=41523002742778389987319552285861887, ply_count=3, locs=(97, 58)),
#   <Action.WSW: -11>): 0,
#  (Isolation(board=41523160894442306345131389386483711, ply_count=3, locs=(88, 71)),
#   <Action.NNE: 25>): 0,
#  (Isolation(board=41523161126567869050877816646658047, ply_count=3, locs=(86, 43)),
#   <Action.SSE: -27>): 0,
#  (Isolation(board=41520625902737485032259921406584831, ply_count=2, locs=(70, 101)),
#   <Action.NNW: 27>): -1,
#  (Isolation(board=41523161203939117470997596616517631, ply_count=3, locs=(34, 62)),
#   <Action.ESE: -15>): 0,
#  (Isolation(board=41523161203939048295636966494431231, ply_count=3, locs=(31, 66)),
#   <Action.WSW: -11>): 0,
#  (Isolation(board=41198642647862696142718628177897471, ply_count=3, locs=(108, 67)),
#   <Action.WSW: -11>): 0,
#  (Isolation(board=41523161203938974436673448241522687, ply_count=3, locs=(67, 28)),
#   <Action.WNW: 15>): 0,
#  (Isolation(board=41198484193950944460742419470608383, ply_count=3, locs=(97, 72)),
#   <Action.WNW: 15>): 0,
#  (Isolation(board=41523161203939122082674836131145663, ply_count=3, locs=(17, 43)),
#   <Action.NNE: 25>): 0,
#  (Isolation(board=41523161203939085189195484801001471, ply_count=2, locs=(65, 22)),
#   <Action.SSW: -25>): 0,
#  (Isolation(board=41523161203920232616752153643411439, ply_count=3, locs=(4, 74)),
#   <Action.NNE: 25>): 0,
#  (Isolation(board=41482596384731671095825554007386111, ply_count=3, locs=(67, 105)),
#   <Action.SSE: -27>): 0,
#  (Isolation(board=38927012755328895154584317262292991, ply_count=3, locs=(84, 21)),
#   <Action.WSW: -11>): 0,
#  (Isolation(board=41523081975776607818346038411782143, ply_count=3, locs=(28, 96)),
#   <Action.WSW: -11>): 0,
#  (Isolation(board=36330863997233658405139933579700223, ply_count=3, locs=(112, 88)),
#   <Action.ESE: -15>): 0,
#  (Isolation(board=41523161203939121938568426960185343, ply_count=3, locs=(23, 57)),
#   <Action.ENE: 11>): 0,
#  (Isolation(board=41523161203939120929761028105816063, ply_count=3, locs=(13, 60)),
#   <Action.NNE: 25>): 0,
#  (Isolation(board=41523161203934399716060007910860799, ply_count=3, locs=(72, 34)),
#   <Action.SSE: -27>): 0,
#  (Isolation(board=40874124096621973481209941807065087, ply_count=3, locs=(41, 109)),
#   <Action.WSW: -11>): 0,
#  (Isolation(board=41523161203938974364615853398288383, ply_count=3, locs=(57, 67)),
#   <Action.WSW: -11>): 0,
#  (Isolation(board=41523161203939122082050296346830847, ply_count=3, locs=(34, 46)),
#   <Action.SSE: -27>): 0,
#  (Isolation(board=41523141396898493516581641652267007, ply_count=2, locs=(44, 94)),
#   <Action.WSW: -11>): 0,
#  (Isolation(board=41442031563106663473528208718030847, ply_count=3, locs=(106, 58)),
#   <Action.ENE: 11>): 0,
#  (Isolation(board=41521893514652972477708822577670143, ply_count=3, locs=(100, 68)),
#   <Action.SSW: -25>): 0,
#  (Isolation(board=41502868890815155552756733476595711, ply_count=3, locs=(93, 59)),
#   <Action.NNW: 27>): 0,
#  (Isolation(board=41523161203934399716200762042214395, ply_count=3, locs=(29, 72)),
#   <Action.NNW: 27>): 0,
#  (Isolation(board=41523161202730196263069003049576439, ply_count=3, locs=(3, 80)),
#   <Action.NNE: 25>): -3,
#  (Isolation(board=36330864345394849720905921627940863, ply_count=3, locs=(48, 112)),
#   <Action.ESE: -15>): 0,
#  (Isolation(board=41523161203939117470997613796878335, ply_count=2, locs=(15, 62)),
#   <Action.WSW: -11>): -1,
#  (Isolation(board=41523161203939121794444458905823231, ply_count=3, locs=(43, 30)),
#   <Action.SSW: -25>): 0,
#  (Isolation(board=41523161203939122082683632224274431, ply_count=2, locs=(14, 13)),
#   <Action.NNW: 27>): 3,
#  (Isolation(board=41523161203934399572085574436120575, ply_count=3, locs=(57, 26)),
#   <Action.WNW: 15>): 0,
#  (Isolation(board=41523161203939122082683632224282623, ply_count=1, locs=(14, None)),
#   42): -6,
#  (Isolation(board=41482596375060411896688328172365823, ply_count=3, locs=(58, 105)),
#   <Action.WSW: -11>): 0,
#  (Isolation(board=41502878793731007502452370384611327, ply_count=3, locs=(79, 20)),
#   <Action.NNW: 27>): 0,
#  (Isolation(board=41523161194267715525766598826387327, ply_count=3, locs=(18, 83)),
#   <Action.ENE: 11>): 0,
#  (Isolation(board=41523160893245186441723934324811775, ply_count=2, locs=(80, 88)),
#   <Action.SSW: -25>): 3,
#  (Isolation(board=41523161203939121488199685318371327, ply_count=3, locs=(54, 59)),
#   <Action.WNW: 15>): 0,
#  (Isolation(board=41522844136546559538199971382683647, ply_count=3, locs=(98, 59)),
#   <Action.SSE: -27>): 0,
#  (Isolation(board=41523161200311164032219027288877055, ply_count=3, locs=(81, 80)),
#   <Action.WSW: -11>): 0,
#  (Isolation(board=41523161203939122082683631150491647, ply_count=2, locs=(16, 30)),
#   <Action.ESE: -15>): 0,
#  (Isolation(board=41523161203938973932270290244462591, ply_count=2, locs=(67, 59)),
#   <Action.WSW: -11>): 0,
#  (Isolation(board=41523151300418807799641433031305207, ply_count=2, locs=(93, 3)),
#   <Action.ESE: -15>): 1,
#  (Isolation(board=41523002747614093554008444599511039, ply_count=3, locs=(14, 97)),
#   <Action.WSW: -11>): 0,
#  (Isolation(board=41523161203939122010626029596436223, ply_count=3, locs=(8, 56)),
#   <Action.WSW: -11>): 0,
#  (Isolation(board=41523161203939122082681432127268863, ply_count=3, locs=(30, 15)),
#   <Action.ESE: -15>): 0,
#  (Isolation(board=41523161203332297989634882814339071, ply_count=2, locs=(71, 79)),
#   <Action.WNW: 15>): 0,
#  (Isolation(board=41523161126567869627347365034714879, ply_count=3, locs=(23, 86)),
#   <Action.SSW: -25>): 0,
#  (Isolation(board=41523161203939122082677035154401279, ply_count=3, locs=(42, 41)),
#   <Action.SSE: -27>): 0,
#  (Isolation(board=36330864190661641969528011856275455, ply_count=3, locs=(87, 67)),
#   <Action.NNE: 25>): 0,
#  (Isolation(board=41521893514615488693751044768786431, ply_count=3, locs=(75, 85)),
#   <Action.NNE: 25>): 0,
#  (Isolation(board=41523161202730196263068994459657983, ply_count=3, locs=(8, 80)),
#   <Action.WSW: -11>): 0,
#  (Isolation(board=41523161203939122010623839162853375, ply_count=3, locs=(41, 18)),
#   <Action.ENE: 11>): 0,
#  (Isolation(board=41523161126565508444105929683625983, ply_count=3, locs=(71, 29)),
#   <Action.WNW: 15>): 0,
#  (Isolation(board=41523161203939121938286960581797887, ply_count=3, locs=(33, 57)),
#   <Action.NNW: 27>): 0,
#  (Isolation(board=41523161203920232616747755596933119, ply_count=2, locs=(42, 74)),
#   <Action.WNW: 15>): 0,
#  (Isolation(board=41523161202729569073770496924837887, ply_count=3, locs=(80, 69)),
#   <Action.SSE: -27>): 0,
#  (Isolation(board=41441991874072005813482779265984511, ply_count=3, locs=(95, 86)),
#   <Action.NNW: 27>): 0,
#  (Isolation(board=41523161203939122082683632219973503, ply_count=3, locs=(7, 17)),
#   <Action.NNE: 25>): 0,
#  (Isolation(board=41521893553301114921419177822513151, ply_count=3, locs=(75, 29)),
#   <Action.ENE: 11>): 0,
#  (Isolation(board=41523161203936760827384602290022399, ply_count=3, locs=(56, 30)),
#   <Action.ENE: 11>): 0,
#  (Isolation(board=41523161203939120929757695211202559, ply_count=3, locs=(60, 42)),
#   <Action.SSW: -25>): 0,
#  (Isolation(board=41523161203939121776298120074749951, ply_count=3, locs=(47, 54)),
#   <Action.ESE: -15>): 0,
#  (Isolation(board=41523161203636890623276375169034239, ply_count=3, locs=(52, 78)),
#   <Action.WNW: 15>): 0,
#  (Isolation(board=41523161203939119776840545701193727, ply_count=3, locs=(61, 33)),
#   <Action.WNW: 15>): 0,
#  (Isolation(board=41521893514653267625613984750626815, ply_count=3, locs=(85, 34)),
#   <Action.SSE: -27>): 0,
#  (Isolation(board=41198642650280104771859741346359295, ply_count=3, locs=(58, 108)),
#   <Action.WSW: -11>): 0,
#  ...}

# %% [markdown]
# ## Let's first create some conversion functions, between the "book" format and the "nodes" format, used by MCTS

# %%
with open('base_book.pkl', 'rb') as file:
    data = pickle.load(file)

# %%
data
# Out:
# {(Isolation(board=41198484184284260270308255718172671, ply_count=3, locs=(108, 83)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=40143957350286345584047904549496831, ply_count=3, locs=(106, 110)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523161126567869041879413484939263, ply_count=3, locs=(86, 53)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41523161203937941491027730440906719, ply_count=3, locs=(45, 5)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41523161203939122082683626855589879, ply_count=3, locs=(30, 32)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41198632737088974515941243613079551, ply_count=3, locs=(108, 83)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41520625901529739768237212624218111, ply_count=3, locs=(55, 101)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41523161203939122082679232029255679, ply_count=3, locs=(42, 20)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41523161203939122078180032462645247, ply_count=3, locs=(52, 16)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41523161203934397410357753298282495, ply_count=3, locs=(61, 26)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41523161203939122082683632224298879, ply_count=1, locs=(7, None)),
#   20): [4, 12],
#  (Isolation(board=41523161203939122010625488162121727, ply_count=3, locs=(39, 56)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41198632746760381072717539522373631, ply_count=3, locs=(108, 47)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41523161203939048259678539830257663, ply_count=3, locs=(66, 29)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41523161203929677349717892665436157, ply_count=3, locs=(28, 73)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=41523161203939122082401607483385855, ply_count=3, locs=(23, 39)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41523131493378031659604444968904703, ply_count=3, locs=(94, 93)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41523161165253495846008299110524927, ply_count=3, locs=(28, 85)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523161203938900685725950690715647, ply_count=3, locs=(55, 67)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=38927012755328895010469129188534271, ply_count=3, locs=(84, 111)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523161126530090690980808254023679, ply_count=3, locs=(75, 52)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41523161203939122082683630076618751, ply_count=3, locs=(31, 17)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41521893514048804715806687343142911, ply_count=3, locs=(100, 79)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523161202730011795628265954076671, ply_count=3, locs=(80, 67)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=40874124077279455515283253387585535, ply_count=3, locs=(84, 18)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523151300418807799641432964196349, ply_count=3, locs=(1, 93)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41520625902738665623880638817888255, ply_count=1, locs=(101, None)),
#   18): [10, 12],
#  (Isolation(board=41523161202730048689116413373179903, ply_count=2, locs=(67, 80)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523161203939122073676430553638911, ply_count=3, locs=(53, 31)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523161203939120893698146226399231, ply_count=3, locs=(60, 55)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41522527378639007967982883868501887, ply_count=3, locs=(22, 99)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41441714652874458343637469043353599, ply_count=2, locs=(106, 98)),
#   <Action.SSE: -27>): [3, 3],
#  (Isolation(board=41523002670242841098654585769158655, ply_count=3, locs=(86, 44)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41522527378610673769085666001414143, ply_count=3, locs=(99, 73)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41523161199103418804224016013813759, ply_count=3, locs=(40, 82)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41523161203334658019954804440164351, ply_count=3, locs=(60, 79)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41442031565524515400987826030897151, ply_count=3, locs=(23, 106)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41522527378636646784741449050089471, ply_count=2, locs=(99, 71)),
#   <Action.SSW: -25>): [2, 6],
#  (Isolation(board=41523161203939122064527946470647807, ply_count=3, locs=(39, 47)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523161203939122082683631687428095, ply_count=1, locs=(29, None)),
#   93): [-6, 12],
#  (Isolation(board=41521893553301114921401586173339647, ply_count=3, locs=(75, 44)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523161203939117470997613662693375, ply_count=2, locs=(27, 62)),
#   <Action.NNW: 27>): [-3, 3],
#  (Isolation(board=41523161203936759710491895775881215, ply_count=3, locs=(60, 55)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523161203939048259678540367112191, ply_count=3, locs=(55, 14)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=41523161203939122078177833573607423, ply_count=3, locs=(52, 16)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41523121589857569802609653952014335, ply_count=3, locs=(68, 31)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41523161203939121938568426968573823, ply_count=3, locs=(7, 57)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41523158728058969724876418843666431, ply_count=3, locs=(66, 46)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41523161199103271230272525849061375, ply_count=2, locs=(67, 82)),
#   <Action.NNE: 25>): [3, 3],
#  (Isolation(board=41198642650280695337886077694240767, ply_count=2, locs=(54, 108)),
#   <Action.NNE: 25>): [3, 3],
#  (Isolation(board=41523158728059043511923081889179647, ply_count=2, locs=(29, 91)),
#   <Action.NNE: 25>): [1, 3],
#  (Isolation(board=41523161203920232616189203690022909, ply_count=3, locs=(49, 1)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41522527378639007967978485826054143, ply_count=3, locs=(17, 99)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41523141396895984759405209339291647, ply_count=3, locs=(94, 71)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41360896970514048299312437918689279, ply_count=3, locs=(107, 82)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41523161194267678632277351895918591, ply_count=3, locs=(40, 83)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523158728058969715939588333103103, ply_count=3, locs=(66, 53)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41523161203334656866962939679074303, ply_count=3, locs=(61, 79)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41360901925900982899677425039304687, ply_count=3, locs=(80, 4)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=40225086950619788947882857371527167, ply_count=3, locs=(110, 34)),
#   <Action.NNE: 25>): [-1, 3],
#  (Isolation(board=41523161201521196656478079036680191, ply_count=2, locs=(81, 66)),
#   <Action.NNW: 27>): [3, 3],
#  (Isolation(board=41523161203939047142785283023431679, ply_count=3, locs=(66, 60)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41523121589857864950512636361959423, ply_count=3, locs=(26, 95)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=20753953962758592706666889815779327, ply_count=3, locs=(94, 114)),
#   <Action.ESE: -15>): [3, 3],
#  (Isolation(board=41523161203937941491062914812995567, ply_count=2, locs=(70, 4)),
#   <Action.SSW: -25>): [3, 3],
#  (Isolation(board=41522487745214937721980020305422335, ply_count=3, locs=(95, 99)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41523161203939122082683563236386815, ply_count=2, locs=(28, 36)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41522527378034545040161170775861247, ply_count=3, locs=(79, 99)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523161203938974508729940888774655, ply_count=3, locs=(40, 31)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=20753973769799811424446458831562751, ply_count=2, locs=(57, 114)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41523161203939048295143837676857343, ply_count=3, locs=(39, 49)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=41523161203938973932269190732834815, ply_count=3, locs=(67, 59)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523161126548980161415886462248959, ply_count=2, locs=(86, 74)),
#   <Action.SSE: -27>): [3, 3],
#  (Isolation(board=41523161203939122082683632224003967, ply_count=3, locs=(7, 15)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41523002747614093554008445128009471, ply_count=3, locs=(23, 97)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523161203939122010608445999802367, ply_count=3, locs=(44, 56)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41523161203901340844696190872184831, ply_count=3, locs=(75, 61)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=41482596384731818165093510441592831, ply_count=3, locs=(48, 105)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41198484193955666827084551627466751, ply_count=3, locs=(108, 47)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41523161184596308968849565429000191, ply_count=1, locs=(84, None)),
#   69): [4, 12],
#  (Isolation(board=41523161196685567128967060157097983, ply_count=3, locs=(55, 81)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=36328329044201476812108707666061311, ply_count=3, locs=(112, 71)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523161203939120929181585477986303, ply_count=3, locs=(49, 44)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=38927012774666985901935514414475263, ply_count=2, locs=(72, 111)),
#   <Action.SSE: -27>): [-1, 3],
#  (Isolation(board=41523151300116428770785186061215743, ply_count=3, locs=(93, 67)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523161203934399716165561027127295, ply_count=3, locs=(45, 34)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523161203939122046654818025465855, ply_count=2, locs=(55, 34)),
#   <Action.NNW: 27>): [-3, 3],
#  (Isolation(board=41523161203920230887369896733173759, ply_count=3, locs=(74, 60)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41523161203939122082384565059446783, ply_count=3, locs=(21, 44)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41523151300078797412874818575919103, ply_count=3, locs=(93, 75)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=40874124091786565350658803215886335, ply_count=3, locs=(109, 28)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=41523161203936760899424600920680447, ply_count=3, locs=(44, 32)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41522527339934492274383271701243903, ply_count=3, locs=(74, 85)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523161203636890618772775675881463, ply_count=3, locs=(53, 3)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41523161203939122082648447717992447, ply_count=2, locs=(45, 27)),
#   <Action.NNE: 25>): [-1, 3],
#  (Isolation(board=41523161203939119776838423920240639, ply_count=3, locs=(26, 61)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41523161203939121497215676371167231, ply_count=3, locs=(59, 53)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41523081975776607818275669936171007, ply_count=2, locs=(46, 96)),
#   <Action.NNE: 25>): [1, 3],
#  (Isolation(board=41523081975776607818346038680348671, ply_count=1, locs=(96, None)),
#   93): [-4, 12],
#  (Isolation(board=41523161203939121488190889225349119, ply_count=3, locs=(59, 54)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41523161184596308824664008608966655, ply_count=3, locs=(46, 84)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41523161199103381910735868594743295, ply_count=3, locs=(65, 82)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=36330824730114111502369709948397567, ply_count=3, locs=(95, 112)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523161202730196263069003049560047, ply_count=3, locs=(15, 80)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41523161203939121794453247480555519, ply_count=3, locs=(33, 21)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41523161203939122082681433199994879, ply_count=2, locs=(20, 41)),
#   <Action.ESE: -15>): [-3, 3],
#  (Isolation(board=41523161203939122082681433198929919, ply_count=3, locs=(14, 21)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523161203938531786868873324652543, ply_count=3, locs=(42, 69)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41522844281617658468411826604337151, ply_count=3, locs=(83, 42)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41520625902738665623878439794632703, ply_count=2, locs=(41, 101)),
#   <Action.SSE: -27>): [3, 3],
#  (Isolation(board=41523161203939122082120681734006779, ply_count=3, locs=(2, 49)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523161203939122082683065280227327, ply_count=3, locs=(23, 39)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=40874124096622268629117320183113711, ply_count=3, locs=(15, 109)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523161203939122082677034080790527, ply_count=3, locs=(41, 42)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41523161203939121505941403870423039, ply_count=3, locs=(48, 30)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41523161202730196254061803794327551, ply_count=3, locs=(80, 19)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41198642650280695211714919383689215, ply_count=3, locs=(46, 108)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523161203939122064669233177815039, ply_count=3, locs=(54, 17)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41360901922274205440833536978315263, ply_count=3, locs=(107, 29)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523161203939121506205286661089279, ply_count=3, locs=(44, 30)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523161203938527175046517602904063, ply_count=3, locs=(47, 69)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=40874124077279454938822501084424191, ply_count=3, locs=(84, 59)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41523161203937941490464780487485439, ply_count=3, locs=(70, 49)),
#   <Action.NNE: 25>): [1, 3],
#  (Isolation(board=41523161203929677349713494753142783, ply_count=3, locs=(27, 73)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=41523161203937941491027730440906747, ply_count=3, locs=(70, 2)),
#   <Action.NNE: 25>): [1, 3],
#  (Isolation(board=41482596228780388011548574184630271, ply_count=3, locs=(105, 87)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41523161203936760863395808196683775, ply_count=3, locs=(71, 55)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41523161203938531786873273518647231, ply_count=2, locs=(6, 69)),
#   <Action.NNW: 27>): [1, 3],
#  (Isolation(board=36330864340568443601742029519841279, ply_count=3, locs=(82, 112)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523161203938826934774052677478399, ply_count=3, locs=(42, 68)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41523161184596308968849565429000191, ply_count=1, locs=(84, None)),
#   66): [-8, 12],
#  (Isolation(board=41523161194267419801400667170400255, ply_count=3, locs=(68, 59)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523161203939122082683562967950847, ply_count=3, locs=(9, 29)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41523141396898493516590437745289215, ply_count=2, locs=(43, 94)),
#   <Action.NNW: 27>): [-3, 3],
#  (Isolation(board=41482596384429586134010575821203455, ply_count=3, locs=(105, 60)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41442031564920052491180528497584127, ply_count=3, locs=(106, 27)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523161184595718384808830571636735, ply_count=3, locs=(84, 58)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=41523161202730159369579756118861823, ply_count=3, locs=(80, 40)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41360822660261768227286327079462911, ply_count=3, locs=(85, 107)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41523161203939122073658840783513599, ply_count=2, locs=(53, 44)),
#   <Action.WNW: 15>): [1, 1],
#  (Isolation(board=41523161202730196254061786614982655, ply_count=3, locs=(80, 34)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41523161184596308968779196684822527, ply_count=2, locs=(84, 46)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41523161203939122082648447852177406, ply_count=3, locs=(15, 45)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523161203920232616611416154040319, ply_count=3, locs=(74, 20)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=38927012774671708268418384059688955, ply_count=2, locs=(2, 111)),
#   <Action.WNW: 15>): [-3, 3],
#  (Isolation(board=41523161126567869627347365041006591, ply_count=2, locs=(86, 21)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41523161126567869627347347854845951, ply_count=3, locs=(23, 86)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41523161201521270434447174620145663, ply_count=2, locs=(81, 53)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523161203939120929759894234458111, ply_count=3, locs=(60, 41)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=36330864345404294310033549772711935, ply_count=3, locs=(42, 112)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523161203933809420249666385078271, ply_count=3, locs=(47, 69)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41523161203334658591911965706151935, ply_count=3, locs=(79, 59)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41523161203939122082542877556074495, ply_count=2, locs=(34, 47)),
#   <Action.NNW: 27>): [-1, 3],
#  (Isolation(board=41523161203901343146035600458508287, ply_count=3, locs=(75, 52)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41523161126530090695484407344523263, ply_count=3, locs=(86, 29)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523161203939122082540691417720831, ply_count=3, locs=(32, 41)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41523161203939085171181086295713727, ply_count=3, locs=(65, 6)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41523161203939121794453255804151799, ply_count=3, locs=(3, 58)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41523101782816941236525257713510399, ply_count=3, locs=(68, 94)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41523161203934399572085573966358527, ply_count=3, locs=(72, 29)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=41523161203939122010617242093348863, ply_count=2, locs=(43, 56)),
#   <Action.NNE: 25>): [-1, 3],
#  (Isolation(board=41523158726848937100687735840040959, ply_count=3, locs=(80, 70)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41523161203920232616470670076798975, ply_count=3, locs=(48, 74)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523161203939122082666040038246399, ply_count=2, locs=(44, 13)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41523161203938531786851283286091775, ply_count=3, locs=(44, 42)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523161203939122078180032595879903, ply_count=3, locs=(5, 52)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523161203939122082683631150556663, ply_count=3, locs=(3, 9)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41523161184596308968848465917364223, ply_count=3, locs=(13, 84)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41523161203939122064660436548052991, ply_count=3, locs=(43, 30)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41523161203937941491054118719842303, ply_count=3, locs=(70, 17)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=40225086950619788947882874543007743, ply_count=3, locs=(110, 23)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41196107346662387257868224447899647, ply_count=3, locs=(108, 101)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523161202730196109946615718995967, ply_count=3, locs=(80, 57)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=41523161203939122010590819454543871, ply_count=3, locs=(56, 35)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41523161203939122082674836130162687, ply_count=3, locs=(16, 20)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41523161203939121938564045028190207, ply_count=3, locs=(57, 42)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523161203939122082683632090081279, ply_count=1, locs=(27, None)),
#   16): [2, 12],
#  (Isolation(board=41523161203939122082542894734894591, ply_count=3, locs=(9, 47)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=40874124096622268629117320183113727, ply_count=2, locs=(109, 15)),
#   <Action.ESE: -15>): [3, 3],
#  (Isolation(board=41523161049196617172011097593473021, ply_count=3, locs=(28, 87)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41523161203939122082683632089556975, ply_count=3, locs=(4, 27)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41523161203901305104411023036639231, ply_count=3, locs=(60, 65)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523002723435577161715861642274815, ply_count=3, locs=(97, 84)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523161203939117470997613796845567, ply_count=2, locs=(16, 62)),
#   <Action.WSW: -11>): [3, 3],
#  (Isolation(board=40225086989305415175550973782255359, ply_count=3, locs=(8, 110)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41523161203934104568293384203003903, ply_count=3, locs=(68, 72)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41523161203939122082683631150524411, ply_count=3, locs=(30, 2)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41523151300418807799641432494172159, ply_count=3, locs=(18, 93)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523161126529500399674049175742463, ply_count=3, locs=(86, 69)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41523161203933809276275215797577727, ply_count=3, locs=(57, 69)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41523161203939122082683597864297471, ply_count=3, locs=(35, 18)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41523081975776312670440859327522815, ply_count=2, locs=(68, 96)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41523141396895542037547440310052863, ply_count=3, locs=(69, 71)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41523161203938531498642897366935547, ply_count=3, locs=(69, 2)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=40224453164005301060850259790383103, ply_count=3, locs=(99, 13)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523161184586864235881627115317247, ply_count=3, locs=(84, 41)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41523161203939122082666040035633151, ply_count=3, locs=(19, 21)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41523161203636890627779974930491391, ply_count=2, locs=(78, 17)),
#   <Action.SSW: -25>): [-2, 6],
#  (Isolation(board=41523161199103418767914843529799679, ply_count=3, locs=(82, 48)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=39576049881988561721984696100841471, ply_count=2, locs=(110, 109)),
#   <Action.SSW: -25>): [-1, 3],
#  (Isolation(board=41502878794335470412255286926501887, ply_count=2, locs=(104, 42)),
#   <Action.WSW: -11>): [2, 6],
#  (Isolation(board=41523161203937941491062912665511935, ply_count=2, locs=(70, 31)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41523161203938530922182145063512063, ply_count=3, locs=(69, 59)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41523161203939121506222875357472767, ply_count=3, locs=(59, 28)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41522844291289065016326058726647807, ply_count=3, locs=(26, 98)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523161203937941455034117794031611, ply_count=3, locs=(55, 2)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=41360901927109908719292054213978111, ply_count=2, locs=(15, 107)),
#   <Action.ENE: 11>): [1, 3],
#  (Isolation(board=41523161203939122082613263480088559, ply_count=3, locs=(15, 46)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523161049196617172011097861646207, ply_count=3, locs=(18, 87)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=41502878794335470394236490370508799, ply_count=3, locs=(43, 104)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41523161203939048295689745200048127, ply_count=2, locs=(66, 44)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=41523161203939122082683563504297967, ply_count=3, locs=(4, 36)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523161201520680129629616659752959, ply_count=3, locs=(54, 69)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41523161202730196263069001975326719, ply_count=3, locs=(19, 80)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41523161203937941491062914745853951, ply_count=3, locs=(15, 70)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523161202730196263069003049592831, ply_count=1, locs=(80, None)),
#   70): [-6, 12],
#  (Isolation(board=40225086979634008618598790372255743, ply_count=3, locs=(83, 45)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41279772286277450398367006859454463, ply_count=3, locs=(106, 107)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41523161203939122082674836129179583, ply_count=3, locs=(21, 43)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41522527378620118502051405289744383, ply_count=3, locs=(74, 21)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=41523161203939120929726938950395903, ply_count=3, locs=(60, 32)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523161201520680147626422983190527, ply_count=3, locs=(69, 81)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41523081935882055771063275915044863, ply_count=3, locs=(85, 80)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41523002747614093554008445134301119, ply_count=3, locs=(6, 97)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41523151300418807799641430883821551, ply_count=3, locs=(4, 93)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41523161184596308248273625049720831, ply_count=3, locs=(84, 57)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523161203939122082639647464220671, ply_count=3, locs=(32, 45)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=41523161203939048295705138362836991, ply_count=2, locs=(41, 66)),
#   <Action.NNW: 27>): [-3, 3],
#  (Isolation(board=41523121531829425609012635066427391, ply_count=3, locs=(95, 85)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41522844291289065007318309783201791, ply_count=3, locs=(39, 98)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41523156213493191139541809360791551, ply_count=3, locs=(67, 85)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=41523161203936760899371828657383423, ply_count=3, locs=(71, 17)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41523161203939122082681433198929919, ply_count=3, locs=(41, 21)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41198642650280695067670097904527359, ply_count=3, locs=(58, 108)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41441358126143144154118298095577087, ply_count=3, locs=(106, 99)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523161203936760827314234619586559, ply_count=3, locs=(71, 46)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523161203939122082683614775993855, ply_count=3, locs=(34, 28)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41523141396860714584454801699891199, ply_count=3, locs=(48, 94)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41523161199103123647312736917907455, ply_count=3, locs=(68, 82)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523161202730195074118701423781887, ply_count=3, locs=(80, 60)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41523161203939122082679234177755071, ply_count=3, locs=(42, 6)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=41523161203939119776770254266427389, ply_count=3, locs=(61, 1)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41523161203939121487927006434682879, ply_count=3, locs=(48, 54)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41523161203934399716183170393040895, ply_count=2, locs=(72, 44)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41360822660261768227286327079462911, ply_count=3, locs=(96, 85)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41523158728059043511923082157615103, ply_count=2, locs=(91, 28)),
#   <Action.WNW: 15>): [-4, 6],
#  (Isolation(board=41523161203939121506222811201398783, ply_count=2, locs=(59, 36)),
#   <Action.NNE: 25>): [-3, 3],
#  (Isolation(board=41523161203939122082683614507558895, ply_count=3, locs=(4, 34)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41523161203938826934637715378923519, ply_count=3, locs=(22, 68)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=20753973769799811568561646370547707, ply_count=3, locs=(2, 114)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523161203936760899442197401692143, ply_count=2, locs=(4, 71)),
#   <Action.NNE: 25>): [1, 3],
#  (Isolation(board=41523161203334658596134090356811775, ply_count=3, locs=(59, 79)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523161201521270443452174784522239, ply_count=3, locs=(41, 81)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41523161203939121794444459979302911, ply_count=3, locs=(18, 58)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523161203939122082683631686379515, ply_count=3, locs=(29, 20)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41522527378639007967982883872688123, ply_count=3, locs=(2, 99)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41523161203934399572050390131140607, ply_count=3, locs=(72, 57)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523161203939121974597240630536191, ply_count=3, locs=(56, 55)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41523161203939122082683632090015679, ply_count=3, locs=(27, 6)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=41523160894444667528372823672219647, ply_count=3, locs=(73, 29)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41523161202730196262787519482947583, ply_count=3, locs=(48, 80)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41523161203939122082525302549374975, ply_count=3, locs=(44, 47)),
#   <Action.NNE: 25>): [3, 3],
#  (Isolation(board=41523161203939121938568444148443134, ply_count=2, locs=(0, 57)),
#   <Action.NNW: 27>): [2, 6],
#  (Isolation(board=41523161184596161322839381714659327, ply_count=3, locs=(67, 84)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41522507571579489935967006905853951, ply_count=3, locs=(74, 94)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523161125963404411697041242056703, ply_count=3, locs=(61, 79)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=41523161203901343150539200085878767, ply_count=3, locs=(75, 4)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41523161203939048295706787093407743, ply_count=3, locs=(39, 29)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523161203938531192398122705741823, ply_count=3, locs=(54, 59)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41523161203939122078171236369688575, ply_count=3, locs=(52, 43)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41523161194267715237536222674937599, ply_count=3, locs=(58, 8)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41523161203939122082683631686379519, ply_count=2, locs=(29, 20)),
#   <Action.NNW: 27>): [3, 3],
#  (Isolation(board=41360901927109908431052881969276927, ply_count=3, locs=(43, 107)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41523161202730196263069003049592799, ply_count=2, locs=(80, 5)),
#   <Action.NNE: 25>): [-3, 3],
#  (Isolation(board=41523002747612912962317358980917247, ply_count=3, locs=(70, 46)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41523136445138336375078134241814527, ply_count=2, locs=(92, 94)),
#   <Action.SSE: -27>): [-1, 5],
#  (Isolation(board=41523161203938531768577400032454655, ply_count=3, locs=(54, 48)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41522844291289065024770308095076351, ply_count=2, locs=(98, 49)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41523121589857864950512636429051903, ply_count=3, locs=(41, 95)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41523161203920232616681782751782911, ply_count=3, locs=(31, 74)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41523161203939122082666035742763007, ply_count=3, locs=(44, 32)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523161201521270443436781688317951, ply_count=3, locs=(44, 81)),
#   <Action.NNE: 25>): [-2, 2],
#  (Isolation(board=41522527378639007967982883872171775, ply_count=3, locs=(19, 99)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41523161203936759746520692794845119, ply_count=3, locs=(60, 6)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41523161182177867033809948373936127, ply_count=3, locs=(84, 81)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=41523161049196616018948855766706175, ply_count=3, locs=(87, 47)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41523160894454109955495549990856703, ply_count=3, locs=(61, 32)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41523156213493191139541809360791551, ply_count=3, locs=(67, 85)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41523161203901343150521607899834367, ply_count=3, locs=(75, 44)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523161203901343150785490690500607, ply_count=2, locs=(45, 75)),
#   <Action.SSW: -25>): [1, 3],
#  (Isolation(board=41523161203936759746520692793796607, ply_count=3, locs=(60, 20)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41523161049196617172011097859810303, ply_count=3, locs=(21, 87)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523161203934399571804099526518783, ply_count=3, locs=(72, 48)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41523161203939085189195484804671487, ply_count=2, locs=(19, 65)),
#   <Action.NNE: 25>): [3, 3],
#  (Isolation(board=41523161203939122082666040038107135, ply_count=3, locs=(44, 14)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41523161203939122073641248530360319, ply_count=3, locs=(26, 45)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41523161203939119200379870707181567, ply_count=2, locs=(59, 61)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41520546674576151359543045273937919, ply_count=2, locs=(96, 101)),
#   <Action.ENE: 11>): [-3, 3],
#  (Isolation(board=41523161203939120929762119027386367, ply_count=3, locs=(33, 17)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41523160894454109955495553748953087, ply_count=3, locs=(61, 29)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41523151300418807799641432494434299, ply_count=3, locs=(29, 93)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41523161203939120929762050308040703, ply_count=3, locs=(33, 36)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523161202725473896550949032290303, ply_count=3, locs=(45, 80)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41523161203934399698186363532732415, ply_count=3, locs=(54, 72)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=36006345782074461170452946476853247, ply_count=3, locs=(83, 112)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41523161126567869627347364975962111, ply_count=3, locs=(26, 86)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41523161203939122082666040029341695, ply_count=3, locs=(19, 23)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41523161165229884022601150407632895, ply_count=3, locs=(74, 72)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41523161126565508444105930212108287, ply_count=3, locs=(71, 23)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41523161203939122010626021005977599, ply_count=3, locs=(34, 56)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41523161203939122082682532710574079, ply_count=2, locs=(40, 21)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523161203938974508731042547886079, ply_count=1, locs=(67, None)),
#   78): [-2, 12],
#  (Isolation(board=41502868890815156057159891742091263, ply_count=3, locs=(93, 56)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=41523161203939120929199160484161535, ply_count=3, locs=(34, 60)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41523141396898345942646643088156671, ply_count=3, locs=(67, 30)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41481962559412815161203510789269503, ply_count=3, locs=(74, 105)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523161203939122010626036038887359, ply_count=3, locs=(31, 56)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523161165253495566785122481989567, ply_count=3, locs=(58, 6)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=41522527069153998146637815147390975, ply_count=3, locs=(88, 19)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41360901927109908719292054079793151, ply_count=2, locs=(27, 107)),
#   <Action.SSW: -25>): [-1, 3],
#  (Isolation(board=41523160894454111108381874520582143, ply_count=3, locs=(45, 88)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=41523161203929677349154942976255999, ply_count=3, locs=(22, 73)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41442021659586349478716385676748799, ply_count=3, locs=(81, 93)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41360901925900982899677407859435519, ply_count=3, locs=(107, 34)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41523161203920232616752153643443199, ply_count=2, locs=(74, 10)),
#   <Action.NNE: 25>): [3, 3],
#  (Isolation(board=41523161203938531786873239158908927, ply_count=2, locs=(35, 69)),
#   <Action.NNE: 25>): [0, 6],
#  (Isolation(board=41502868890815156129147117035841535, ply_count=3, locs=(104, 46)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523151295583104521182916332414975, ply_count=3, locs=(82, 16)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41502878794335470412259650613274367, ply_count=3, locs=(35, 104)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41523161203939122082683597327673343, ply_count=3, locs=(14, 35)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41442029079973030273310260023257087, ply_count=3, locs=(106, 83)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41523161184596308968849565428737919, ply_count=3, locs=(7, 84)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41523141396897903220788875132626943, ply_count=3, locs=(69, 15)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41523161203334659172875218125285375, ply_count=3, locs=(40, 79)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41521893553338893853264542798178303, ply_count=3, locs=(29, 100)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41442031564920052491180526484318207, ply_count=3, locs=(79, 31)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41482596384731818741835737654585343, ply_count=3, locs=(26, 105)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523161203939120929744535431276543, ply_count=3, locs=(17, 60)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41523161182178457329620307079587839, ply_count=2, locs=(81, 84)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41523002747609371187525575486990335, ply_count=3, locs=(72, 22)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41523161203636890627779974393751547, ply_count=3, locs=(2, 78)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41523161194267714372845059860064255, ply_count=3, locs=(35, 83)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41482596384731818741800553348589567, ply_count=3, locs=(20, 105)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523161203938974508731042010753023, ply_count=3, locs=(29, 67)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41523161203636743053686647765854207, ply_count=3, locs=(67, 47)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41522844291284342658815204031195135, ply_count=3, locs=(72, 98)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41523161202720751494074466740201471, ply_count=3, locs=(80, 73)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41523161203939117470856876308555759, ply_count=3, locs=(62, 4)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41523161203934399716060025090729983, ply_count=2, locs=(47, 72)),
#   <Action.NNW: 27>): [3, 3],
#  (Isolation(board=41523151295582809373277736979654655, ply_count=3, locs=(68, 82)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41523161203939121794453238892193791, ply_count=3, locs=(34, 58)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41520308990086247383288829819480063, ply_count=3, locs=(98, 101)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523161203939122082683615044429815, ply_count=2, locs=(34, 3)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41523161203939122082683632224102367, ply_count=3, locs=(5, 17)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523161203936760899442197400643583, ply_count=2, locs=(71, 20)),
#   <Action.NNE: 25>): [3, 3],
#  (Isolation(board=20753973615054945474647677722421247, ply_count=3, locs=(114, 71)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41523161201521270425439975365404607, ply_count=3, locs=(81, 6)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41522527378639007967982883604129791, ply_count=3, locs=(17, 99)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41523141319527241061262966657116159, ply_count=2, locs=(94, 86)),
#   <Action.WNW: 15>): [1, 3],
#  (Isolation(board=41523161184596308968847365332002815, ply_count=3, locs=(30, 84)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=41523161203939122082683627920942847, ply_count=3, locs=(23, 32)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523161203939122082683632224298623, ply_count=2, locs=(8, 7)),
#   <Action.ENE: 11>): [-3, 3],
#  (Isolation(board=41523161184596308248273625049720831, ply_count=3, locs=(84, 57)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41523161203939085188632534851774463, ply_count=2, locs=(65, 49)),
#   <Action.NNW: 27>): [2, 6],
#  (Isolation(board=41360822694111691176495943971235839, ply_count=3, locs=(107, 82)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41523161203939122082683631955863543, ply_count=2, locs=(28, 3)),
#   <Action.NNE: 25>): [-3, 3],
#  (Isolation(board=36330705889079265925476849295550463, ply_count=3, locs=(112, 40)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41523161203937941455034083434293247, ply_count=3, locs=(70, 35)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41522844136546560114660689326368767, ply_count=3, locs=(87, 35)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41523161203636890627779974863513599, ply_count=2, locs=(78, 26)),
#   <Action.NNW: 27>): [4, 6],
#  (Isolation(board=41523161203939122082648447852079103, ply_count=2, locs=(17, 45)),
#   <Action.NNE: 25>): [0, 6],
#  (Isolation(board=41523161203938826934778450723989487, ply_count=3, locs=(31, 68)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41523161203939048286699588375537663, ply_count=3, locs=(66, 53)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41523161126567574479433389597255679, ply_count=3, locs=(43, 86)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41523161203939122082682532175792127, ply_count=3, locs=(13, 29)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523161203938974508731042547623927, ply_count=3, locs=(18, 67)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41523161203929677349647524189431807, ply_count=3, locs=(46, 18)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523156252178964905133735608838143, ply_count=2, locs=(55, 92)),
#   <Action.NNE: 25>): [-1, 3],
#  (Isolation(board=41523151300418660225687743843264511, ply_count=3, locs=(40, 93)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41502878793731007502452370385643519, ply_count=3, locs=(79, 14)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41523161203939121506222879920613247, ply_count=3, locs=(7, 59)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523161203939122082683632022906879, ply_count=3, locs=(27, 26)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41523161203939122082119582759217151, ply_count=3, locs=(40, 49)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=20753971292710807178186467934463999, ply_count=3, locs=(80, 114)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523161165251133518852559204247551, ply_count=3, locs=(85, 71)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41482596383522892922221108547020783, ply_count=3, locs=(80, 4)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=41502868890815156129217485780018687, ply_count=3, locs=(104, 9)),
#   <Action.NNE: 25>): [1, 3],
#  (Isolation(board=41523161203939121794453238892718079, ply_count=2, locs=(58, 34)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41523141387227086959682200440661759, ply_count=3, locs=(83, 8)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41523161203937941491026630929278975, ply_count=3, locs=(70, 40)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523161203934397266242565289535487, ply_count=3, locs=(72, 57)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41523161203939122082648413492470783, ply_count=3, locs=(10, 45)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41523161203939122082679234177525751, ply_count=3, locs=(18, 42)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41523161203939122046654834936898559, ply_count=3, locs=(55, 10)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=41523161203938974508729940888774655, ply_count=3, locs=(40, 31)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41523161203939122082683615035910143, ply_count=3, locs=(23, 17)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=41523160884782705416191153950156799, ply_count=3, locs=(83, 88)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41523161203935580307812683897366527, ply_count=3, locs=(70, 71)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41519992077419662043248411885430783, ply_count=3, locs=(101, 99)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41523062166318127613032381944948735, ply_count=3, locs=(81, 94)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523161193663252611455684611926015, ply_count=3, locs=(79, 83)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=41523161199103418804222916435109887, ply_count=3, locs=(26, 82)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41523141387224725776440765618055167, ply_count=3, locs=(83, 71)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41360901922273615145023178809534463, ply_count=3, locs=(107, 69)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=36328329044203837995350140341184511, ply_count=3, locs=(112, 31)),
#   <Action.NNE: 25>): [-3, 3],
#  (Isolation(board=41522527378620118502051405291841471, ply_count=3, locs=(74, 6)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=31138567477193337902222736522995711, ply_count=3, locs=(83, 113)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41523161199103416498311737567602687, ply_count=3, locs=(61, 82)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41523161203939122082683631687428087, ply_count=2, locs=(3, 29)),
#   <Action.WNW: 15>): [1, 3],
#  (Isolation(board=20753973615057306657889111471286271, ply_count=3, locs=(87, 30)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523161203939048295707337386092543, ply_count=1, locs=(66, None)),
#   49): [0, 12],
#  (Isolation(board=41523002747612912962387727725078527, ply_count=3, locs=(97, 14)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=40874124077279455515283253387847678, ply_count=3, locs=(109, 0)),
#   <Action.WNW: 15>): [1, 3],
#  (Isolation(board=41523161203939122082674801771538175, ply_count=3, locs=(8, 43)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41523161203939122082648447852209663, ply_count=2, locs=(45, 9)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41198642647862839104985199426922495, ply_count=3, locs=(108, 62)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=41523161203636743053827385254208511, ply_count=3, locs=(78, 10)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41523158728058969724946787453626367, ply_count=3, locs=(66, 27)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523151300418733976636341174134783, ply_count=3, locs=(55, 93)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523160894416331023632597124114431, ply_count=3, locs=(88, 75)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523161203938826925771245026797567, ply_count=3, locs=(53, 33)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41522527378639007967982882798954495, ply_count=2, locs=(99, 30)),
#   <Action.SSW: -25>): [-1, 3],
#  (Isolation(board=38927012772253856557131531672348671, ply_count=3, locs=(56, 111)),
#   <Action.SSW: -25>): [0, 0],
# ...
#   <Action.NNE: 25>): [3, 3],
#  (Isolation(board=41523161203939120641496567093651455, ply_count=3, locs=(60, 58)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=41523161203938826934769656778434559, ply_count=3, locs=(68, 14)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523161203929672665974280468555775, ply_count=3, locs=(73, 56)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523161194258270792519384559511551, ply_count=3, locs=(48, 83)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=40873807183972211571766928827475967, ply_count=3, locs=(109, 34)),
#   <Action.NNE: 25>): [1, 3],
#  (Isolation(board=41523161203939121938567344636782591, ply_count=3, locs=(15, 57)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41523161203882453684748458993379327, ply_count=3, locs=(47, 75)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41523160894444667528372824209090527, ply_count=3, locs=(88, 5)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41523072072255703239493480781703167, ply_count=3, locs=(69, 93)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41523161203929677345212094283245567, ply_count=3, locs=(41, 73)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41523161201521270425439975365404670, ply_count=3, locs=(54, 0)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41523161203939121938568439853475838, ply_count=3, locs=(32, 0)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41523161203939122082683632219580159, ply_count=3, locs=(19, 22)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41523161203939122073672034918852607, ply_count=3, locs=(42, 22)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41502873842575165696785995700103167, ply_count=3, locs=(92, 104)),
#   <Action.SSW: -25>): [-1, 3],
#  (Isolation(board=41523161203920232616752119282657279, ply_count=3, locs=(35, 74)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41360896975345029211288084972300287, ply_count=3, locs=(92, 72)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=38926992948288266588499918878402559, ply_count=3, locs=(84, 94)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523141396898493516599233838311423, ply_count=1, locs=(94, None)),
#   57): [2, 12],
#  (Isolation(board=41523161203939121794451057049331711, ply_count=2, locs=(58, 41)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41523161203939122082683632222201823, ply_count=2, locs=(21, 5)),
#   <Action.ESE: -15>): [3, 3],
#  (Isolation(board=41523121589857863797593296485738495, ply_count=3, locs=(60, 95)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41482596384731818741826941628704767, ply_count=2, locs=(43, 105)),
#   <Action.NNE: 25>): [1, 3],
#  (Isolation(board=41523161201521265831768355447498751, ply_count=2, locs=(81, 62)),
#   <Action.SSE: -27>): [1, 3],
#  (Isolation(board=20753339944497336270619463733209087, ply_count=3, locs=(99, 71)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41523161203939121794303722491209727, ply_count=3, locs=(58, 43)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523156249761113301933274144172031, ply_count=3, locs=(81, 27)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=41523161202730196254061803526416383, ply_count=3, locs=(53, 28)),
#   <Action.ENE: 11>): [1, 1],
#  (Isolation(board=41360901922274205440833537510991871, ply_count=3, locs=(107, 22)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41523161126567867897965108132833279, ply_count=3, locs=(86, 60)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41523161203934397410357752828520447, ply_count=3, locs=(72, 29)),
#   <Action.NNE: 25>): [-1, 1],
#  (Isolation(board=31138567486869466825622639565334271, ply_count=3, locs=(19, 113)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41523141396898493516599233838311421, ply_count=2, locs=(94, 1)),
#   <Action.SSW: -25>): [-1, 3],
#  (Isolation(board=41523161184596308392353628753487871, ply_count=3, locs=(59, 45)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523161203939122082683632157190141, ply_count=2, locs=(26, 1)),
#   <Action.WSW: -11>): [-2, 6],
#  (Isolation(board=41523161203939122082683629808379887, ply_count=3, locs=(31, 28)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=41523161203936760881427249136396287, ply_count=3, locs=(54, 71)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41523161203929677061487516715051007, ply_count=3, locs=(58, 26)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41502878794335396625281191111550975, ply_count=3, locs=(66, 104)),
#   <Action.SSW: -25>): [3, 3],
#  (Isolation(board=41523161203939122082613263211677695, ply_count=3, locs=(28, 46)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523161199102238212604398114170879, ply_count=2, locs=(70, 82)),
#   <Action.SSE: -27>): [-1, 3],
#  (Isolation(board=41523161203939121938568425894832127, ply_count=3, locs=(57, 34)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=41523161203938531786872174007019519, ply_count=2, locs=(40, 69)),
#   <Action.NNW: 27>): [0, 4],
#  (Isolation(board=41523161194265353189603659397195775, ply_count=3, locs=(71, 83)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=36330864190661789543480601532655615, ply_count=3, locs=(112, 15)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41442031565524515400987843219089405, ply_count=3, locs=(1, 106)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523161197894345410657896674355199, ply_count=3, locs=(82, 80)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41441982047922943985776847254185983, ply_count=3, locs=(95, 93)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41502878794335470412259684838795263, ply_count=2, locs=(27, 104)),
#   <Action.SSE: -27>): [-3, 3],
#  (Isolation(board=41523151300116576344737775737628670, ply_count=3, locs=(78, 0)),
#   <Action.WNW: 15>): [-3, 3],
#  (Isolation(board=41523161203939122082613263478024189, ply_count=3, locs=(46, 1)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=36330859393643989738679446622169087, ply_count=3, locs=(92, 112)),
#   <Action.ESE: -15>): [-3, 3],
#  (Isolation(board=41482497349528675911413745791789055, ply_count=3, locs=(105, 96)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41481328733829359057530583724845055, ply_count=3, locs=(105, 100)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41522844291279620292367510168135679, ply_count=3, locs=(98, 33)),
#   <Action.NNE: 25>): [-1, 3],
#  (Isolation(board=41523161203636742477366632950786047, ply_count=3, locs=(78, 59)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41198008824975858874716858206906367, ply_count=3, locs=(72, 108)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=40874044863624051086321209940371455, ply_count=3, locs=(109, 96)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41523161203937645766696983156746239, ply_count=3, locs=(70, 68)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=36330705889079265925477948672960511, ply_count=3, locs=(112, 27)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523161203636890618737591303792639, ply_count=3, locs=(53, 45)),
#   <Action.NNE: 25>): [-3, 3],
#  (Isolation(board=41523161203938531786873271371098111, ply_count=3, locs=(16, 69)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523161203939122082682531907364863, ply_count=3, locs=(29, 28)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41523161203939122082681432932476927, ply_count=3, locs=(17, 41)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=41523161203937940914602162442463231, ply_count=3, locs=(70, 26)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=40873965640292517733959263450032127, ply_count=3, locs=(97, 109)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41522844291289065025333257780062207, ply_count=2, locs=(28, 98)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41522527069153995840794805934221311, ply_count=3, locs=(61, 99)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41523161201519942277881066787170303, ply_count=3, locs=(81, 67)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=41523161194248826059835120245794815, ply_count=2, locs=(74, 83)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41523161203928492146411157095180287, ply_count=3, locs=(62, 70)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523161203939117398799282270627839, ply_count=3, locs=(62, 56)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523161203934397410357753365391355, ply_count=3, locs=(61, 2)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=40873807183972211535738148988381183, ply_count=3, locs=(98, 55)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41360901927109908647234460176082943, ply_count=2, locs=(56, 107)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41523161203939122082683563502716927, ply_count=3, locs=(36, 13)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523161203939122078180032596928479, ply_count=2, locs=(52, 5)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=31138250574219409768272265389991935, ply_count=3, locs=(98, 16)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=40062827711267275992544800956999679, ply_count=3, locs=(107, 110)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41441991874072005813482779265984511, ply_count=3, locs=(106, 86)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41523161203939122082666037353900031, ply_count=3, locs=(29, 31)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41523161203939120911738933014947839, ply_count=3, locs=(54, 60)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41523141396898493516581641652267007, ply_count=2, locs=(94, 44)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41523081975776312526325671251666943, ply_count=3, locs=(57, 96)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41521893553329449048258802192738303, ply_count=3, locs=(73, 56)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41523161203939121217974911583119359, ply_count=3, locs=(44, 58)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523160894454112261338563231074303, ply_count=3, locs=(28, 88)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41523161203939122064669233176897535, ply_count=3, locs=(29, 20)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523161049196617172011097727690751, ply_count=2, locs=(27, 87)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523161126567869050877816646658047, ply_count=3, locs=(86, 43)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41520625902737485032259921406584831, ply_count=2, locs=(70, 101)),
#   <Action.NNW: 27>): [-1, 3],
#  (Isolation(board=41523161203939117470997596616517631, ply_count=3, locs=(34, 62)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41523161203939048295702937192097791, ply_count=3, locs=(31, 66)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41198642647862696142718628177897471, ply_count=3, locs=(108, 67)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41198484193950944460742419470608383, ply_count=3, locs=(97, 72)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41523161203939122082674836131145663, ply_count=3, locs=(17, 43)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=41523161203935579731360727686965247, ply_count=3, locs=(70, 71)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41482596384731671095825554007386111, ply_count=3, locs=(67, 105)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=38927012755328895154584317262292991, ply_count=3, locs=(84, 21)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523081975776607818346038411782143, ply_count=3, locs=(28, 96)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=36330863997233658405139933579700223, ply_count=3, locs=(112, 88)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41523161203939121938286969163343871, ply_count=3, locs=(23, 57)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41523161203939120929761028105816063, ply_count=3, locs=(13, 60)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=41522527378634285601499997047613439, ply_count=3, locs=(72, 34)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=40874124096621973481209941807065087, ply_count=3, locs=(41, 109)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523161203934399716165578206472191, ply_count=3, locs=(72, 19)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523161203939122082050296346830847, ply_count=3, locs=(34, 46)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523141396898493516581641652267007, ply_count=2, locs=(44, 94)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41442031563106663473528208718030847, ply_count=3, locs=(106, 58)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=38925745124071184891111708003657727, ply_count=3, locs=(100, 68)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41198632746760380496397524707305471, ply_count=3, locs=(93, 59)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41523161203934399716200762042214395, ply_count=3, locs=(29, 72)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41523161202730196263069003049576439, ply_count=3, locs=(3, 80)),
#   <Action.NNE: 25>): [-1, 1],
#  (Isolation(board=41523161201483417724615121874970623, ply_count=3, locs=(81, 75)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=41523161203939117470997613796878335, ply_count=2, locs=(15, 62)),
#   <Action.WSW: -11>): [-1, 3],
#  (Isolation(board=41523161203939121794444458905823231, ply_count=3, locs=(43, 30)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41523161203939122082683632224274431, ply_count=2, locs=(14, 13)),
#   <Action.NNW: 27>): [1, 3],
#  (Isolation(board=41523161203934399572085574436120575, ply_count=3, locs=(57, 26)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41523161203939122082683632224282623, ply_count=1, locs=(14, None)),
#   42): [-6, 12],
#  (Isolation(board=41482596375060411896688328172365823, ply_count=3, locs=(58, 105)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523161203334659168372718008526847, ply_count=3, locs=(79, 20)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41523161194267715525766598826387327, ply_count=3, locs=(18, 83)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41523160893245186441723934324811775, ply_count=2, locs=(80, 88)),
#   <Action.SSW: -25>): [3, 3],
#  (Isolation(board=41523161203939121488199685318371327, ply_count=3, locs=(54, 59)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41522844136546559538199971382683647, ply_count=3, locs=(98, 59)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523161200311164032219027288877055, ply_count=3, locs=(81, 80)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523161203939122082683631150491647, ply_count=2, locs=(16, 30)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41523161203938973932270290244462591, ply_count=2, locs=(67, 59)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523151300418807799641433031305207, ply_count=2, locs=(93, 3)),
#   <Action.ESE: -15>): [1, 3],
#  (Isolation(board=41523002747614093554007895380568063, ply_count=3, locs=(14, 97)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523161203939122010626003826632447, ply_count=3, locs=(8, 56)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523161203939122082648446778435583, ply_count=3, locs=(30, 15)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41523161203332297989634882814339071, ply_count=2, locs=(71, 79)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41523161126567869627347365034714879, ply_count=3, locs=(23, 86)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41523161203939122082677035154401279, ply_count=3, locs=(42, 41)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=36330864190661641969528011856275455, ply_count=3, locs=(87, 67)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=41523161087844464467816274290796543, ply_count=3, locs=(75, 85)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=41523161202730196263068968689854207, ply_count=3, locs=(8, 80)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523161203939122010623839162853375, ply_count=3, locs=(41, 18)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41523161126565508444105929683625983, ply_count=3, locs=(71, 29)),
#   <Action.WNW: 15>): [0, 0],
#  ...}

# %%
len(data.keys())
# Out:
# 374097

# %%
states = set(key[0] for key in data.keys())
len(states)
# Out:
# 64898

# %%
s = states.pop()

# %%
s
# Out:
# Isolation(board=41523161202125733317232891443275775, ply_count=3, locs=(80, 79))

# %%
from collections import defaultdict

# %%
def q_fun():
    return defaultdict(float)

def n_fun():
    return defaultdict(int)

# %%
def book2q(book):
    Q = defaultdict(q_fun)
    N = defaultdict(n_fun)
    for s_a, q_n in book.items():
        state, action = s_a
        q, n = q_n
        Q[state][action] = 0 if n==0 else q / n
        N[state][action] = n
    return Q, N

# %%
def to_dict(q_book):
    book = q_book.copy()
    for key, value in book.items():
        book[key] = dict(value)
    return dict(book)

# %%
q = to_dict(q_book)

# %%
q
# Out:
# {Isolation(board=41502858977623435289258253189375999, ply_count=3, locs=(83, 104)): {<Action.SSW: -25>: 0,
#   <Action.WSW: -11>: 0},
#  Isolation(board=31138250574200520302340786809202687, ply_count=3, locs=(113, 74)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41523161202125733317232891443275775, ply_count=3, locs=(80, 79)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41520625902733940951554759958980607, ply_count=3, locs=(61, 101)): {<Action.SSE: -27>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.ENE: 11>: 0},
#  Isolation(board=41502561881675968621943571506784255, ply_count=3, locs=(73, 104)): {<Action.SSW: -25>: 0,
#   <Action.WSW: -11>: 0},
#  Isolation(board=41523161201521270443454373338015743, ply_count=2, locs=(81, 29)): {<Action.SSE: -27>: -1.0,
#   <Action.SSW: -25>: -0.3333333333333333,
#   <Action.ESE: -15>: 1.0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 1.0,
#   <Action.NNW: 27>: 1.0},
#  Isolation(board=41523161203939122082683561357273087, ply_count=3, locs=(31, 36)): {<Action.SSE: -27>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.NNE: 25>: 0},
#  Isolation(board=41523161203939119488610244711409663, ply_count=3, locs=(31, 61)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41523161203937941491054118451537919, ply_count=3, locs=(70, 28)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41522527378639007967981784361035775, ply_count=3, locs=(40, 99)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0.3333333333333333,
#   <Action.WNW: 15>: 0},
#  Isolation(board=41523141396897903220784477086148607, ply_count=3, locs=(69, 94)): {<Action.SSE: -27>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0},
#  Isolation(board=41158058024032763448968183315163135, ply_count=3, locs=(105, 108)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 1.0,
#   <Action.WSW: -11>: 0},
#  Isolation(board=41523161165234606389075223959824383, ply_count=3, locs=(85, 43)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41523161203936759458290316643133439, ply_count=3, locs=(71, 58)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 1.0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41523161203938974436638264137869311, ply_count=3, locs=(45, 67)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41521893553301114885390381340420095, ply_count=3, locs=(100, 55)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 1.0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=31138567486869466825059672432568319, ply_count=3, locs=(49, 113)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0},
#  Isolation(board=41442031565524515382973444575455231, ply_count=3, locs=(27, 106)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0},
#  Isolation(board=41482596384731818741835720541857791, ply_count=2, locs=(105, 34)): {<Action.SSE: -27>: -0.6666666666666666,
#   <Action.SSW: -25>: 0.3333333333333333,
#   <Action.WSW: -11>: -0.3333333333333333},
#  Isolation(board=41523081975774246635104603857741819, ply_count=3, locs=(96, 2)): {<Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 1.0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41523161165253495855015496486217711, ply_count=3, locs=(4, 85)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41523161203939122082666037353900031, ply_count=3, locs=(44, 31)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41523161184596308392388810978093055, ply_count=3, locs=(59, 31)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41522844291284342514735200327428095, ply_count=3, locs=(72, 98)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0},
#  Isolation(board=41523161203939085171179986784086015, ply_count=3, locs=(65, 40)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41523161203938826934778452871473143, ply_count=2, locs=(68, 3)): {<Action.SSE: -27>: 0.3333333333333333,
#   <Action.SSW: -25>: 0.3333333333333333,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: -1.0,
#   <Action.NNW: 27>: 0.3333333333333333},
#  Isolation(board=40874124091786565350658803484320767, ply_count=3, locs=(82, 10)): {<Action.ENE: 11>: 0,
#   <Action.NNE: 25>: 0},
#  Isolation(board=41523161203939119776840623010539517, ply_count=3, locs=(1, 61)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41523121589857864950514801092585215, ply_count=3, locs=(8, 95)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0},
#  Isolation(board=41523161199103268924429516635367423, ply_count=3, locs=(82, 61)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41523161203939122082674831836178431, ply_count=3, locs=(32, 43)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41521891077449370549555846432417791, ply_count=3, locs=(73, 91)): {<Action.SSW: -25>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.WNW: 15>: 0},
#  Isolation(board=41523161203920232616752153642919935, ply_count=2, locs=(19, 74)): {<Action.ESE: -15>: -0.3333333333333333,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: -1.0,
#   <Action.NNE: 25>: -0.3333333333333333,
#   <Action.NNW: 27>: 0.0},
#  Isolation(board=41522844281617658463912625023477759, ply_count=3, locs=(83, 52)): {<Action.SSW: -25>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=31138567407080362731057114035251199, ply_count=3, locs=(113, 81)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41523161199103418804225046805997055, ply_count=3, locs=(9, 82)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=40225086989305415175269533165283327, ply_count=2, locs=(110, 48)): {<Action.SSE: -27>: 0.3333333333333333,
#   <Action.SSW: -25>: 0.3333333333333333,
#   <Action.ESE: -15>: 0.3333333333333333,
#   <Action.WSW: -11>: 1.0},
#  Isolation(board=41523161203934395104514744151697407, ply_count=2, locs=(72, 62)): {<Action.SSE: -27>: -0.3333333333333333,
#   <Action.SSW: -25>: 1.0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0.3333333333333333,
#   <Action.NNW: 27>: -0.3333333333333333},
#  Isolation(board=41523081975776017522535679840479231, ply_count=3, locs=(96, 27)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41442031565524515400987843219154943, ply_count=1, locs=(106, None)): {0: 0.16666666666666666,
#   1: 0.8666666666666667,
#   2: -0.3333333333333333,
#   3: 0.8333333333333334,
#   4: 0.16666666666666666,
#   5: 0.16666666666666666,
#   6: -0.5,
#   7: 0.6666666666666666,
#   8: -0.6666666666666666,
#   9: 0.14285714285714285,
#   10: -0.5,
#   13: -0.3333333333333333,
#   14: -0.3333333333333333,
#   15: 0.3333333333333333,
#   16: -0.5,
#   17: 0.6666666666666666,
#   18: -0.6666666666666666,
#   19: 0.3333333333333333,
#   20: -0.3333333333333333,
#   21: 0.5,
#   22: -0.3333333333333333,
#   23: 0.6666666666666666,
#   26: -0.16666666666666666,
#   27: -0.3333333333333333,
#   28: 0.0,
#   29: 0.8333333333333334,
#   30: -0.16666666666666666,
#   31: 0.8333333333333334,
#   32: -0.6666666666666666,
#   33: 0.16666666666666666,
#   34: -0.6666666666666666,
#   35: 1.0,
#   36: -0.5,
#   39: 0.8333333333333334,
#   40: 0.0,
#   41: 0.8333333333333334,
#   42: -0.16666666666666666,
#   43: 0.3333333333333333,
#   44: 0.0,
#   45: -0.16666666666666666,
#   46: -0.6666666666666666,
#   47: 0.8333333333333334,
#   48: -0.3333333333333333,
#   49: 0.16666666666666666,
#   52: -0.5,
#   53: 0.5,
#   54: -0.16666666666666666,
#   55: 0.6666666666666666,
#   56: -0.3333333333333333,
#   57: 0.16666666666666666,
#   58: -0.3333333333333333,
#   59: 0.16666666666666666,
#   60: -0.16666666666666666,
#   61: 0.3333333333333333,
#   62: -0.16666666666666666,
#   65: 0.5,
#   66: -0.16666666666666666,
#   67: 0.16666666666666666,
#   68: -1.0,
#   69: 0.5,
#   70: -0.5,
#   71: 0.5,
#   72: -0.3333333333333333,
#   73: 0.3333333333333333,
#   74: -0.6666666666666666,
#   75: 0.16666666666666666,
#   78: -0.3333333333333333,
#   79: 0.0,
#   80: -0.6666666666666666,
#   81: 0.2,
#   82: -0.6666666666666666,
#   83: 0.16666666666666666,
#   84: 0.16666666666666666,
#   85: 0.6666666666666666,
#   86: 0.0,
#   87: 0.5,
#   88: -0.6666666666666666,
#   91: 0.3333333333333333,
#   92: -0.3333333333333333,
#   93: 0.8333333333333334,
#   94: 0.16666666666666666,
#   95: 0.5,
#   96: -0.16666666666666666,
#   97: 0.5,
#   98: -0.3333333333333333,
#   99: 0.6666666666666666,
#   100: -0.6666666666666666,
#   101: 0.5,
#   104: -0.16666666666666666,
#   105: 0.6666666666666666,
#   107: 0.5384615384615384,
#   108: -0.8333333333333334,
#   109: 0.6666666666666666,
#   110: 0.3333333333333333,
#   111: 0.3333333333333333,
#   112: -0.5,
#   113: -0.06666666666666667,
#   114: -0.6666666666666666},
#  Isolation(board=41523141396898345798531456086042623, ply_count=3, locs=(67, 57)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41523161203939122082402156173846495, ply_count=3, locs=(30, 48)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.NNE: 25>: 0.3333333333333333,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41523141396596262061695576544634879, ply_count=2, locs=(94, 78)): {<Action.SSE: -27>: 0.3333333333333333,
#   <Action.SSW: -25>: -0.3333333333333333,
#   <Action.ESE: -15>: 1.0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 1.0},
#  Isolation(board=41523141396897903220788874864224255, ply_count=3, locs=(69, 28)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=36330864345404294418124337802373119, ply_count=3, locs=(55, 112)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0.3333333333333333,
#   <Action.WSW: -11>: 0},
#  Isolation(board=41523161203939122082674767411800063, ply_count=2, locs=(43, 36)): {<Action.SSE: -27>: -0.3333333333333333,
#   <Action.SSW: -25>: 1.0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0.3333333333333333,
#   <Action.NNW: 27>: -0.3333333333333333},
#  Isolation(board=41523161184596308968779162325084159, ply_count=3, locs=(35, 84)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41523161126567869627346815287273471, ply_count=3, locs=(14, 86)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: -0.3333333333333333,
#   <Action.NNW: 27>: 0},
#  Isolation(board=36330864340568591031579431120398335, ply_count=3, locs=(82, 112)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0.3333333333333333,
#   <Action.WSW: -11>: 0},
#  Isolation(board=41523161203936760899371794297776127, ply_count=3, locs=(46, 71)): {<Action.SSE: -27>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41523158689373416131333444228605951, ply_count=3, locs=(85, 91)): {<Action.SSW: -25>: 1.0,
#   <Action.WSW: -11>: 0,
#   <Action.WNW: 15>: 0},
#  Isolation(board=40225047375224158007353414351054847, ply_count=3, locs=(95, 55)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0.3333333333333333,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41442031555853108772013215783577599, ply_count=3, locs=(83, 106)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0},
#  Isolation(board=41523161203939122073676432969557983, ply_count=2, locs=(53, 5)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 1.0,
#   <Action.WSW: -11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: -0.3333333333333333,
#   <Action.NNW: 27>: 1.0},
#  Isolation(board=41523161202730196245054604405893119, ply_count=3, locs=(54, 80)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=40874124096622121055163630995105791, ply_count=3, locs=(40, 109)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0},
#  Isolation(board=41502878793731007497948770758289407, ply_count=3, locs=(79, 52)): {<Action.SSW: -25>: -0.3333333333333333,
#   <Action.WSW: -11>: 0,
#   <Action.WNW: 15>: 0},
#  Isolation(board=41523141396897903220771282946615295, ply_count=3, locs=(69, 94)): {<Action.SSE: -27>: 0,
#   <Action.ESE: -15>: -1.0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0},
#  Isolation(board=41523161049196617172011095713376255, ply_count=3, locs=(20, 87)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41523161203636890618772775667492863, ply_count=3, locs=(78, 23)): {<Action.ESE: -15>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.NNE: 25>: -1.0},
#  Isolation(board=41523161194267715237536153955461119, ply_count=3, locs=(58, 36)): {<Action.SSE: -27>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.NNE: 25>: 0},
#  Isolation(board=41523161203920232616681784897169407, ply_count=3, locs=(46, 74)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.ENE: 11>: -0.3333333333333333,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41523158728058748355010703818483711, ply_count=3, locs=(68, 91)): {<Action.SSW: -25>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.WNW: 15>: 0},
#  Isolation(board=41523161203901341997881578269698047, ply_count=3, locs=(60, 44)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=40874124096622268629117320182884343, ply_count=3, locs=(3, 109)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0},
#  Isolation(board=41523161203939121794453238892717951, ply_count=3, locs=(7, 58)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41523141396898345942646644161898491, ply_count=3, locs=(94, 2)): {<Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41523161203334511594420128333162495, ply_count=3, locs=(79, 67)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41520625902738665623880638817625983, ply_count=3, locs=(18, 101)): {<Action.SSE: -27>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.ENE: 11>: 0},
#  Isolation(board=41523161126567869627347365042972671, ply_count=2, locs=(17, 86)): {<Action.ESE: -15>: 1.0,
#   <Action.WSW: -11>: 0.3333333333333333,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: -0.3333333333333333,
#   <Action.NNW: 27>: -1.0},
#  Isolation(board=41360901927109908719292037034141567, ply_count=3, locs=(34, 107)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0},
#  Isolation(board=20753339944499697453860898555815933, ply_count=3, locs=(114, 1)): {<Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41158077829864466195437952526444543, ply_count=3, locs=(105, 108)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0},
#  Isolation(board=41523151276240291407348849537181695, ply_count=3, locs=(93, 84)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41523161203936760611203025156958207, ply_count=3, locs=(58, 71)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41523151223047553038462156636415999, ply_count=3, locs=(86, 93)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 1.0,
#   <Action.WNW: 15>: 0},
#  Isolation(board=41523161202730191651382950262466559, ply_count=3, locs=(35, 80)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41523161203939122082681433133934589, ply_count=3, locs=(1, 41)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0.0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41523161203934399716165577133254655, ply_count=3, locs=(45, 30)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41198484193950944460742419470608383, ply_count=3, locs=(97, 108)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0.3333333333333333},
#  Isolation(board=41523161203636890627779974930606079, ply_count=2, locs=(14, 78)): {<Action.WSW: -11>: -0.3333333333333333,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0.3333333333333333,
#   <Action.NNW: 27>: 1.0},
#  Isolation(board=41523161203920232616188104178395135, ply_count=3, locs=(49, 40)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=36330863997233658405139933579700223, ply_count=3, locs=(112, 88)): {<Action.SSE: -27>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.NNE: 25>: 0},
#  Isolation(board=41523161126567869050886612739680127, ply_count=3, locs=(86, 7)): {<Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41523161203938973355774353568950271, ply_count=3, locs=(45, 67)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41523161201521270443453824119056383, ply_count=3, locs=(39, 81)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: -0.3333333333333333,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41523161203937941491027721850972159, ply_count=3, locs=(45, 33)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41522527069153998146637815147915261, ply_count=3, locs=(88, 1)): {<Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41523161203939122010626038186239935, ply_count=3, locs=(17, 56)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41523161203938531786864477157189631, ply_count=3, locs=(28, 69)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41523141396294030534734325213030399, ply_count=3, locs=(79, 56)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41523161203939048295707337386092527, ply_count=2, locs=(66, 4)): {<Action.SSE: -27>: 1.0,
#   <Action.SSW: -25>: 0.0,
#   <Action.WSW: -11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0.0,
#   <Action.NNW: 27>: -0.2},
#  Isolation(board=41523161203939119776840554291128317, ply_count=3, locs=(36, 1)): {<Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41523161203939122010625967319410687, ply_count=3, locs=(31, 36)): {<Action.SSE: -27>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.NNE: 25>: 0},
#  Isolation(board=41523160894454112261338563499255807, ply_count=2, locs=(18, 88)): {<Action.ESE: -15>: 0.3333333333333333,
#   <Action.WSW: -11>: -0.3333333333333333,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: -0.3333333333333333,
#   <Action.NNW: 27>: 1.0},
#  Isolation(board=41523161203939122082111886177789951, ply_count=3, locs=(43, 49)): {<Action.SSE: -27>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.NNE: 25>: 0},
#  Isolation(board=41523161202729605967257544832313343, ply_count=3, locs=(69, 40)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41523141396898492363677729231464447, ply_count=2, locs=(60, 94)): {<Action.SSE: -27>: 1.0,
#   <Action.SSW: -25>: 1.0,
#   <Action.ESE: -15>: 1.0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: -0.3333333333333333,
#   <Action.NNW: 27>: -1.0},
#  Isolation(board=41522527378639007823867694723098623, ply_count=3, locs=(30, 99)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0},
#  Isolation(board=41523161203939122082683630009673727, ply_count=3, locs=(15, 31)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41523161203938826790663260500649983, ply_count=3, locs=(57, 68)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0.3333333333333333,
#   <Action.NNW: 27>: 0},
#  Isolation(board=31138567486869466825622639028971519, ply_count=3, locs=(14, 113)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0},
#  Isolation(board=41523161203938531768858874874947583, ply_count=3, locs=(27, 69)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=40225086989305415175410270649444351, ply_count=3, locs=(47, 110)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 1.0,
#   <Action.WSW: -11>: 0},
#  Isolation(board=41523081975771885307747980959279103, ply_count=3, locs=(72, 96)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0},
#  Isolation(board=41482596384731818741835737721726959, ply_count=2, locs=(105, 4)): {<Action.SSE: -27>: 0.0,
#   <Action.SSW: -25>: 0.3333333333333333,
#   <Action.WSW: -11>: -0.3333333333333333},
#  Isolation(board=41523161203937941490746255464196095, ply_count=3, locs=(45, 48)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41360901927109908719256869841922047, ply_count=2, locs=(45, 107)): {<Action.SSE: -27>: 1.0,
#   <Action.SSW: -25>: 1.0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: -0.3333333333333333,
#   <Action.NNW: 27>: 1.0},
#  Isolation(board=41523161201520975223491600484132863, ply_count=3, locs=(81, 68)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41523161203939122073672030628079615, ply_count=3, locs=(53, 32)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41442031562502200851951270282389503, ply_count=3, locs=(79, 81)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41523161049196617172011097861384191, ply_count=2, locs=(87, 19)): {<Action.SSE: -27>: 1.0,
#   <Action.SSW: -25>: 1.0,
#   <Action.ESE: -15>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.NNE: 25>: 0.3333333333333333,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41522844291289065025333255899965439, ply_count=3, locs=(31, 98)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0},
#  Isolation(board=41523161126567719747551766152996863, ply_count=3, locs=(61, 67)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41523161203939122082402157245490175, ply_count=3, locs=(21, 10)): {<Action.NNE: 25>: 0},
#  Isolation(board=41523161199084528761832884641196031, ply_count=3, locs=(59, 82)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41523161203334659154861850407987199, ply_count=3, locs=(79, 36)): {<Action.SSE: -27>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.NNE: 25>: -1.0},
#  Isolation(board=41522844291289065025332157999998975, ply_count=3, locs=(29, 98)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0},
#  Isolation(board=41523161203939121938286968097990655, ply_count=3, locs=(30, 48)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41523161203939122082648430672340863, ply_count=3, locs=(45, 7)): {<Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0},
#  Isolation(board=41360901927109318423481695508359167, ply_count=2, locs=(69, 107)): {<Action.SSE: -27>: -0.5,
#   <Action.SSW: -25>: -0.3333333333333333,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0.3333333333333333,
#   <Action.NNW: 27>: 0.3333333333333333},
#  Isolation(board=41442031565522154217746408396548095, ply_count=2, locs=(106, 71)): {<Action.SSE: -27>: -1.0,
#   <Action.SSW: -25>: -1.0,
#   <Action.ESE: -15>: 0.3333333333333333,
#   <Action.WSW: -11>: -0.3333333333333333},
#  Isolation(board=41523161203939122082683632224232445, ply_count=3, locs=(1, 10)): {<Action.ENE: 11>: 0,
#   <Action.NNE: 25>: 0},
#  Isolation(board=41523161125963406717540050455750655, ply_count=2, locs=(79, 86)): {<Action.SSE: -27>: 0.0,
#   <Action.SSW: -25>: 1.0,
#   <Action.WSW: -11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: -0.3333333333333333},
#  Isolation(board=41523161203939119776770253192685567, ply_count=3, locs=(61, 30)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=40874124096622268629115120086149119, ply_count=3, locs=(41, 109)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0},
#  Isolation(board=36330864345404294454153135357945855, ply_count=3, locs=(18, 112)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0},
#  Isolation(board=41523161203332297989564514070161407, ply_count=3, locs=(46, 79)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41522844271943890728257756430591999, ply_count=3, locs=(98, 84)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41523161203939122082683631016339451, ply_count=3, locs=(2, 30)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41523161203939120929199176590288895, ply_count=3, locs=(60, 30)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41523141387222364593199330795448319, ply_count=3, locs=(83, 94)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0},
#  Isolation(board=41523161203937941491027730440906747, ply_count=3, locs=(70, 2)): {<Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0.3333333333333333,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41523161049196617171975912416077823, ply_count=3, locs=(45, 87)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41441873108595023962505341543901183, ply_count=3, locs=(79, 97)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0},
#  Isolation(board=40874124091786564197737298877474815, ply_count=3, locs=(82, 60)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=31138567486869466825622639565850623, ply_count=2, locs=(13, 113)): {<Action.WSW: -11>: 0.5555555555555556,
#   <Action.WNW: 15>: 0,
#   <Action.NNW: 27>: -0.3333333333333333},
#  Isolation(board=41117510535986010103444137400330239, ply_count=3, locs=(106, 108)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0},
#  Isolation(board=41523161202730159369580855622100991, ply_count=3, locs=(65, 23)): {<Action.ESE: -15>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.NNE: 25>: 0},
#  Isolation(board=41523161203939122082120682270746619, ply_count=3, locs=(17, 49)): {<Action.SSE: -27>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.NNE: 25>: 0},
#  Isolation(board=40225086989305415031431422019627007, ply_count=3, locs=(42, 110)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0},
#  Isolation(board=40873173358672097457066197655742463, ply_count=3, locs=(109, 99)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 1.0,
#   <Action.WNW: 15>: 0},
#  Isolation(board=41523161203939121506187691253819391, ply_count=3, locs=(32, 45)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41523161199100467325173321997215743, ply_count=3, locs=(71, 69)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41360901921971973985929880221509631, ply_count=3, locs=(82, 78)): {<Action.SSW: -25>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41523161203634529372480946070087679, ply_count=3, locs=(71, 78)): {<Action.SSW: -25>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41523161203901343150820674995447807, ply_count=3, locs=(26, 75)): {<Action.SSE: -27>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.NNE: 25>: 0},
#  Isolation(board=41523161203939085189195484805195743, ply_count=2, locs=(65, 5)): {<Action.SSW: -25>: 0.3333333333333333,
#   <Action.WSW: -11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNW: 27>: 0.3333333333333333},
#  Isolation(board=41523161203939122082683632090081273, ply_count=3, locs=(2, 1)): {<Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41523161203334659172841133264594943, ply_count=3, locs=(45, 79)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41523161203929677349715693843507199, ply_count=3, locs=(41, 73)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41521893553301114921401586173339647, ply_count=3, locs=(75, 44)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41523161203939122082648443556980735, ply_count=3, locs=(18, 32)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41523161203901341997899170187307007, ply_count=3, locs=(60, 28)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41523161203937941491062912665511935, ply_count=2, locs=(70, 31)): {<Action.SSE: -27>: -0.3333333333333333,
#   <Action.SSW: -25>: -0.3333333333333333,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: -1.0,
#   <Action.NNW: 27>: -1.0},
#  Isolation(board=41523161203939121506222879920875487, ply_count=2, locs=(5, 59)): {<Action.ENE: 11>: 0.3333333333333333,
#   <Action.WNW: 15>: 0.3333333333333333,
#   <Action.NNE: 25>: -0.3333333333333333,
#   <Action.NNW: 27>: -1.0},
#  Isolation(board=41523161203939122082402079938177023, ply_count=3, locs=(48, 36)): {<Action.SSE: -27>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.NNE: 25>: 0},
#  Isolation(board=41523161203939122046654834934802431, ply_count=3, locs=(55, 21)): {<Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=33733448265536652410486391027263487, ply_count=3, locs=(111, 112)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: -1.0,
#   <Action.WSW: -11>: 0},
#  Isolation(board=41523161203936759746520684204910591, ply_count=3, locs=(60, 71)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41523161203936760322981445098268671, ply_count=2, locs=(71, 59)): {<Action.SSE: -27>: 1.0,
#   <Action.SSW: -25>: 1.0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 1.0,
#   <Action.NNW: 27>: -0.3333333333333333},
#  Isolation(board=41523161202730196254061795204917247, ply_count=3, locs=(80, 33)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41523161203938531786802870414731263, ply_count=3, locs=(35, 69)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41523161203937939761680657902725119, ply_count=3, locs=(70, 60)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41522844291286703841951085737535487, ply_count=3, locs=(71, 47)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41521893533995490443637710020143103, ply_count=3, locs=(84, 100)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.ENE: 11>: 0},
#  Isolation(board=41523161165253495855015498633701371, ply_count=2, locs=(2, 85)): {<Action.ENE: 11>: -0.3333333333333333,
#   <Action.WNW: 15>: -1.0,
#   <Action.NNE: 25>: 0.3333333333333333,
#   <Action.NNW: 27>: 0.3333333333333333},
#  Isolation(board=41523161203939122082679234043570111, ply_count=3, locs=(27, 6)): {<Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41523161203939117470434646663620607, ply_count=3, locs=(49, 62)): {<Action.SSE: -27>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.NNE: 25>: 0},
#  Isolation(board=41523161203939121938533258702612479, ply_count=3, locs=(30, 45)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41523141396898493516458427630479359, ply_count=3, locs=(36, 94)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0},
#  Isolation(board=41523161202730196263068968688805887, ply_count=3, locs=(35, 80)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41360901922274205440833537246750719, ply_count=3, locs=(107, 28)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: -1.0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41522487764538861369882608519866367, ply_count=3, locs=(99, 95)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0.3333333333333333,
#   <Action.WNW: 15>: 0},
#  Isolation(board=41521893359910762714941467568105471, ply_count=3, locs=(85, 87)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41523161203939122010623834868148223, ply_count=3, locs=(56, 32)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41523161194267715525766598759507967, ply_count=3, locs=(15, 83)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41523161126530090695484407881394175, ply_count=2, locs=(86, 75)): {<Action.SSE: -27>: -0.3333333333333333,
#   <Action.SSW: -25>: -0.3333333333333333,
#   <Action.ESE: -15>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: -1.0,
#   <Action.NNW: 27>: -1.0},
#  Isolation(board=41522527223891780690827479865092095, ply_count=3, locs=(99, 87)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41523161201521270371396779836957695, ply_count=3, locs=(81, 10)): {<Action.ENE: 11>: 0,
#   <Action.NNE: 25>: -1.0},
#  Isolation(board=41523161203939122082682532444235775, ply_count=2, locs=(28, 40)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0.3333333333333333,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0.0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0.0,
#   <Action.NNW: 27>: 1.0},
#  Isolation(board=41502878793731007502451820629846015, ply_count=3, locs=(104, 39)): {<Action.SSW: -25>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=31138488220021326333616912431310847, ply_count=3, locs=(85, 113)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0},
#  Isolation(board=41523161203939122078162440410753023, ply_count=3, locs=(17, 52)): {<Action.SSW: -25>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41502878794335470411978209994205183, ply_count=3, locs=(48, 104)): {<Action.SSW: -25>: 0,
#   <Action.WSW: -11>: 0},
#  Isolation(board=41523161203937904561545970374928383, ply_count=3, locs=(70, 65)): {<Action.SSW: -25>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41523161203939122082683632090081273, ply_count=3, locs=(27, 1)): {<Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 1.0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41442031565524515400986743707527167, ply_count=2, locs=(40, 106)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 1.0,
#   <Action.WSW: -11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0.14285714285714285,
#   <Action.NNW: 27>: -1.0},
#  Isolation(board=41521893553338892699797680960825343, ply_count=3, locs=(60, 100)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.ENE: 11>: 0},
#  Isolation(board=41421749153503012091334637618456575, ply_count=3, locs=(81, 104)): {<Action.SSW: -25>: 0,
#   <Action.WSW: -11>: 0},
#  Isolation(board=41482596373851486365304075149371391, ply_count=3, locs=(80, 83)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41523161203939122073676432902449143, ply_count=3, locs=(26, 3)): {<Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=31138250571801558129043007040645119, ply_count=3, locs=(98, 81)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: -1.0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41523161203939120929199169074096127, ply_count=3, locs=(60, 33)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0},
#  Isolation(board=41523161203939121506222811199301631, ply_count=3, locs=(21, 59)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41442031560688811978414138444474367, ply_count=3, locs=(57, 106)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0},
#  Isolation(board=41523161203939122046654832789415935, ply_count=3, locs=(55, 31)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=31138250573614946858464950802704383, ply_count=3, locs=(98, 79)): {<Action.SSE: -27>: 0.3333333333333333,
#   <Action.SSW: -25>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41521893552696652011611863772030975, ply_count=3, locs=(100, 79)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: -0.3333333333333333,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41523161202730196263069003049068543, ply_count=2, locs=(80, 19)): {<Action.SSE: -27>: -0.3333333333333333,
#   <Action.SSW: -25>: -1.0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: -0.3333333333333333,
#   <Action.NNW: 27>: -0.3333333333333333},
#  Isolation(board=41523161203939122082534094347954175, ply_count=3, locs=(32, 43)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41523161203936760890417405960906751, ply_count=3, locs=(71, 53)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41523161203636890627498499953911807, ply_count=2, locs=(78, 48)): {<Action.SSW: -25>: -0.6666666666666666,
#   <Action.WSW: -11>: 0,
#   <Action.WNW: 15>: 1.0,
#   <Action.NNW: 27>: 0},
# ...
#   <Action.WNW: 15>: 0,
#   <Action.NNW: 27>: 0.3333333333333333},
#  Isolation(board=41523161203939122064669233177683967, ply_count=3, locs=(54, 18)): {<Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: -0.3333333333333333,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41523161203937941491054118719711231, ply_count=3, locs=(18, 70)): {<Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41523161049191894805510636030650367, ply_count=3, locs=(72, 44)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41523161203939085189194385293043711, ply_count=3, locs=(40, 19)): {<Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0.3333333333333333,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41523161203334659172858725450770431, ply_count=3, locs=(17, 79)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41523161202730196082925017954772991, ply_count=3, locs=(80, 57)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41523151300418586438712548516685823, ply_count=3, locs=(93, 67)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41523161203938679288768269157132287, ply_count=3, locs=(67, 68)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41523081975776607818346038680348607, ply_count=2, locs=(6, 96)): {<Action.ENE: 11>: -1.0,
#   <Action.WNW: 15>: 0.3333333333333333,
#   <Action.NNE: 25>: -1.0,
#   <Action.NNW: 27>: 0.3333333333333333},
#  Isolation(board=41523161203334364024971138283595775, ply_count=3, locs=(79, 19)): {<Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=40225086950619788947847690179307519, ply_count=3, locs=(110, 45)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: -1.0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41522844291289065025332158536869887, ply_count=2, locs=(98, 40)): {<Action.SSE: -27>: 0.3333333333333333,
#   <Action.SSW: -25>: 0.3333333333333333,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: -1.0,
#   <Action.ENE: 11>: -0.3333333333333333,
#   <Action.WNW: 15>: 1.0},
#  Isolation(board=41439496263719596032377535225391103, ply_count=3, locs=(79, 101)): {<Action.SSE: -27>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.ENE: 11>: 0},
#  Isolation(board=41523151300116576344702591365539839, ply_count=3, locs=(78, 45)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: -0.3333333333333333,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41523156174807710179983256232912895, ply_count=3, locs=(61, 92)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.WNW: 15>: 0},
#  Isolation(board=41523161203939117470856876308555743, ply_count=3, locs=(47, 5)): {<Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41360901922274205440833503155447807, ply_count=3, locs=(82, 35)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41523161203939122082683631683233787, ply_count=3, locs=(2, 22)): {<Action.ESE: -15>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41523161184596308968847366338635775, ply_count=3, locs=(26, 84)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41523161203939121794444459979433983, ply_count=3, locs=(58, 17)): {<Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=36290299487511364885637107801909247, ply_count=3, locs=(112, 105)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.WSW: -11>: 0},
#  Isolation(board=41523161203939122082683082199787519, ply_count=3, locs=(28, 18)): {<Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=31138567177384457004277570832689151, ply_count=3, locs=(88, 23)): {<Action.ESE: -15>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.NNE: 25>: 0},
#  Isolation(board=41523161203939121506222878847100927, ply_count=3, locs=(30, 59)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41523161203939122082402157247522815, ply_count=2, locs=(48, 16)): {<Action.SSE: -27>: -0.3333333333333333,
#   <Action.SSW: -25>: 1.0,
#   <Action.ESE: -15>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.NNE: 25>: -0.3333333333333333,
#   <Action.NNW: 27>: 0.6},
#  Isolation(board=41523161203901343150539200085878782, ply_count=3, locs=(48, 0)): {<Action.WNW: 15>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41522844291289065025333258048235391, ply_count=3, locs=(18, 98)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0},
#  Isolation(board=41523141396898493516599233838245885, ply_count=3, locs=(1, 94)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0},
#  Isolation(board=40225047375223862895477032017192959, ply_count=3, locs=(95, 110)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.WSW: -11>: 0},
#  Isolation(board=41482596384712928699443506837448703, ply_count=3, locs=(74, 105)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.WSW: -11>: 0},
#  Isolation(board=41158077828655540375823323351738367, ply_count=3, locs=(81, 105)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.WSW: -11>: 0},
#  Isolation(board=41523161194267715525766598826649583, ply_count=2, locs=(83, 4)): {<Action.SSE: -27>: 1.0,
#   <Action.SSW: -25>: -1.0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 1.0,
#   <Action.NNW: 27>: -1.0},
#  Isolation(board=20753973769799806956875628480030719, ply_count=2, locs=(114, 62)): {<Action.SSE: -27>: 0.6666666666666666,
#   <Action.ESE: -15>: 1.0},
#  Isolation(board=41523161203938531786873239157860351, ply_count=3, locs=(35, 69)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41360901927109834932315759375804415, ply_count=2, locs=(107, 66)): {<Action.SSE: -27>: 0.3333333333333333,
#   <Action.SSW: -25>: -0.3333333333333333,
#   <Action.ESE: -15>: 0.3333333333333333,
#   <Action.WSW: -11>: 0.3333333333333333},
#  Isolation(board=41523161203939122082682497816061951, ply_count=3, locs=(29, 35)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41522527378633105009879296816179199, ply_count=3, locs=(72, 70)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41523002747612911809466223118247935, ply_count=3, locs=(70, 60)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41523161203934399716060025090721791, ply_count=3, locs=(72, 13)): {<Action.WSW: -11>: -1.0,
#   <Action.WNW: 15>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41523161203939122082681398840256511, ply_count=3, locs=(20, 41)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41523161203938974508695858175797247, ply_count=2, locs=(67, 45)): {<Action.SSE: -27>: 0.5,
#   <Action.SSW: -25>: 0.3333333333333333,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 1.0,
#   <Action.NNW: 27>: 1.0},
#  Isolation(board=41523161201521270443454373874886647, ply_count=2, locs=(81, 3)): {<Action.SSE: -27>: -0.3333333333333333,
#   <Action.SSW: -25>: 0.3333333333333333,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0.3333333333333333,
#   <Action.NNW: 27>: -0.3333333333333333},
#  Isolation(board=40224453164002939877608824967784447, ply_count=3, locs=(110, 71)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: -1.0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41522685834954591763692331670169599, ply_count=3, locs=(98, 97)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: -1.0,
#   <Action.WNW: 15>: 0},
#  Isolation(board=41523161203934399716060025086535679, ply_count=3, locs=(22, 72)): {<Action.SSE: -27>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=40225086979634008618633974744344571, ply_count=3, locs=(83, 2)): {<Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41523161203939121794453253925102591, ply_count=3, locs=(31, 10)): {<Action.ENE: 11>: 0,
#   <Action.NNE: 25>: 0},
#  Isolation(board=41523161203939122082542894601725947, ply_count=3, locs=(27, 47)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0.3333333333333333,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41198642640004825889176128218720255, ply_count=3, locs=(83, 79)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41523161202730196263069002512459775, ply_count=3, locs=(29, 80)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41522844291289065025333240868627967, ply_count=3, locs=(34, 98)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0.3333333333333333,
#   <Action.WNW: 15>: 0},
#  Isolation(board=41523161203334585385899473042925567, ply_count=3, locs=(39, 79)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41523161203939122082681982956840959, ply_count=3, locs=(14, 40)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 1.0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41523161203929677061487516781635583, ply_count=3, locs=(58, 19)): {<Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41523161203939122082402156710717439, ply_count=2, locs=(48, 29)): {<Action.SSE: -27>: -0.3333333333333333,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.NNE: 25>: -0.3333333333333333,
#   <Action.NNW: 27>: -0.3333333333333333},
#  Isolation(board=41523161203939122082683632223184863, ply_count=3, locs=(5, 20)): {<Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41523121589857864950514835318106111, ply_count=2, locs=(95, 27)): {<Action.SSE: -27>: 1.0,
#   <Action.SSW: -25>: -0.3333333333333333,
#   <Action.ESE: -15>: 0.3333333333333333,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0.3333333333333333},
#  Isolation(board=41523161203939122046654834936637439, ply_count=3, locs=(55, 18)): {<Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41360901925896260533194555394091007, ply_count=3, locs=(80, 72)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41523161203939121794444459979564991, ply_count=3, locs=(58, 6)): {<Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=38927012755328895154584317264381951, ply_count=3, locs=(84, 13)): {<Action.WSW: -11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=31138567482033763547164122867034111, ply_count=2, locs=(82, 113)): {<Action.SSE: -27>: -1.0,
#   <Action.SSW: -25>: -0.3333333333333333,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: -1.0,
#   <Action.NNW: 27>: -1.0},
#  Isolation(board=41523161203938974504227442912126975, ply_count=3, locs=(52, 23)): {<Action.ESE: -15>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.NNE: 25>: 0},
#  Isolation(board=41523161203939122082674835860744191, ply_count=3, locs=(43, 21)): {<Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=36328329044203837995279773744490495, ply_count=3, locs=(101, 46)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41522527378620118501981036547663871, ply_count=3, locs=(99, 46)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41522844291289065025333256974755839, ply_count=2, locs=(30, 98)): {<Action.SSE: -27>: 1.0,
#   <Action.SSW: -25>: 0.3333333333333333,
#   <Action.ESE: -15>: 0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0.3333333333333333,
#   <Action.NNW: 27>: 1.0},
#  Isolation(board=41523161203939122082683615044167551, ply_count=3, locs=(7, 18)): {<Action.ESE: -15>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0,
#   <Action.NNE: 25>: 0,
#   <Action.NNW: 27>: 0},
#  Isolation(board=41523141396898493516599233838303227, ply_count=3, locs=(2, 94)): {<Action.SSE: -27>: 0,
#   <Action.SSW: -25>: 0,
#   <Action.ESE: -15>: 1.0,
#   <Action.WSW: -11>: 0,
#   <Action.ENE: 11>: 0,
#   <Action.WNW: 15>: 0},
#  ...}

# %%
import os

def save_q(q_book, dirpath='..'):
    q = to_dict(q_book)
    with open(os.path.join(dirpath,'data.pickle'), 'wb') as file:
        pickle.dump(q, file)

# %%
save_q(q_book)

# %%
q_book, n_book = book2q(data)

# %%
q_book
# Out:
# defaultdict(<function __main__.q_fun()>,
#             {Isolation(board=41522527378610673769085666001414143, ply_count=3, locs=(74, 73)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203939122082683627920812031, ply_count=3, locs=(32, 23)): defaultdict(float,
#                          {<Action.ESE: -15>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.NNE: 25>: 0}),
#              Isolation(board=41502561872014006797992277399562239, ply_count=3, locs=(83, 104)): defaultdict(float,
#                          {<Action.SSW: -25>: 0, <Action.WSW: -11>: 0}),
#              Isolation(board=31138567409479324904354893803808767, ply_count=3, locs=(113, 74)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161202125733317232891443275775, ply_count=3, locs=(80, 79)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41520625902733940951554759958980607, ply_count=3, locs=(61, 101)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.ENE: 11>: 0}),
#              Isolation(board=41523161203939122082542886141814783, ply_count=3, locs=(47, 33)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 1.0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41502878794326025679223576938407935, ply_count=3, locs=(73, 104)): defaultdict(float,
#                          {<Action.SSW: -25>: 0, <Action.WSW: -11>: 0}),
#              Isolation(board=41523161201521270443454373338015743, ply_count=2, locs=(81, 29)): defaultdict(float,
#                          {<Action.SSE: -27>: -1.0,
#                           <Action.SSW: -25>: -0.3333333333333333,
#                           <Action.ESE: -15>: 1.0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 1.0,
#                           <Action.NNW: 27>: 1.0}),
#              Isolation(board=41522527378639007967981784361035775, ply_count=3, locs=(40, 99)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0.3333333333333333,
#                           <Action.WNW: 15>: 0}),
#              Isolation(board=41523141396897903220771282946615295, ply_count=3, locs=(69, 94)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.ESE: -15>: -1.0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0}),
#              Isolation(board=41158058024032763448968183315163135, ply_count=3, locs=(105, 108)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 1.0,
#                           <Action.WSW: -11>: 0}),
#              Isolation(board=41523161165234606389075223959824383, ply_count=3, locs=(85, 43)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203936760611141452505802751, ply_count=3, locs=(71, 58)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: -1.0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: -1.0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203938974436638264137869311, ply_count=3, locs=(45, 67)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203939122082644049805436927, ply_count=3, locs=(45, 42)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41521893553301114885390381340420095, ply_count=3, locs=(100, 55)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 1.0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161184596308896791971391072255, ply_count=2, locs=(84, 56)): defaultdict(float,
#                          {<Action.SSE: -27>: 1.0,
#                           <Action.SSW: -25>: 1.0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: -0.3333333333333333,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41482596384731818741835720541857791, ply_count=2, locs=(105, 34)): defaultdict(float,
#                          {<Action.SSE: -27>: -0.6666666666666666,
#                           <Action.SSW: -25>: 0.3333333333333333,
#                           <Action.WSW: -11>: -0.3333333333333333}),
#              Isolation(board=41523081975774246635104603857741819, ply_count=3, locs=(96, 2)): defaultdict(float,
#                          {<Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 1.0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161165253495855015498096830447, ply_count=3, locs=(4, 85)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203939122082666029300836351, ply_count=3, locs=(44, 31)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203939121506222873478424575, ply_count=3, locs=(59, 31)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203937941491060715789674495, ply_count=3, locs=(41, 70)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: -1.0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41522844291284342514735200327428095, ply_count=3, locs=(72, 98)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0}),
#              Isolation(board=41523161203938531786868875203700735, ply_count=3, locs=(42, 28)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203939085171179986784086015, ply_count=3, locs=(65, 40)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203938826934778452871473143, ply_count=2, locs=(68, 3)): defaultdict(float,
#                          {<Action.SSE: -27>: 0.3333333333333333,
#                           <Action.SSW: -25>: 0.3333333333333333,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: -1.0,
#                           <Action.NNW: 27>: 0.3333333333333333}),
#              Isolation(board=41523002742778390275549928437572607, ply_count=3, locs=(82, 10)): defaultdict(float,
#                          {<Action.ENE: 11>: 0, <Action.NNE: 25>: 0}),
#              Isolation(board=40225086989305267597094818838210559, ply_count=3, locs=(52, 110)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0}),
#              Isolation(board=41198484193955665674303784508975103, ply_count=3, locs=(97, 60)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161199103268924429516635367423, ply_count=3, locs=(82, 61)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41522527069153998146620222961870847, ply_count=3, locs=(99, 44)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: -1.0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203939122082674831836178431, ply_count=3, locs=(32, 43)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523158728049598778886974391445503, ply_count=3, locs=(73, 91)): defaultdict(float,
#                          {<Action.SSW: -25>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.WNW: 15>: 0}),
#              Isolation(board=41523161203920232616752153642919935, ply_count=2, locs=(19, 74)): defaultdict(float,
#                          {<Action.ESE: -15>: -0.3333333333333333,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: -1.0,
#                           <Action.NNE: 25>: -0.3333333333333333,
#                           <Action.NNW: 27>: 0.0}),
#              Isolation(board=41522844281617658463912625023477759, ply_count=3, locs=(83, 52)): defaultdict(float,
#                          {<Action.SSW: -25>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=31138250571801558129043007040645119, ply_count=3, locs=(113, 81)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161199103418804225046805997055, ply_count=3, locs=(9, 82)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=40225086989305415175269533165283327, ply_count=2, locs=(110, 48)): defaultdict(float,
#                          {<Action.SSE: -27>: 0.3333333333333333,
#                           <Action.SSW: -25>: 0.3333333333333333,
#                           <Action.ESE: -15>: 0.3333333333333333,
#                           <Action.WSW: -11>: 1.0}),
#              Isolation(board=41523161203939122082674835862841335, ply_count=3, locs=(28, 43)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: -1.0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203934399572085540143491071, ply_count=3, locs=(57, 35)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523081975776017522535679840479231, ply_count=3, locs=(96, 27)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523141396898345798531456086042623, ply_count=3, locs=(67, 57)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523141396596262061695576544634879, ply_count=2, locs=(94, 78)): defaultdict(float,
#                          {<Action.SSE: -27>: 0.3333333333333333,
#                           <Action.SSW: -25>: -0.3333333333333333,
#                           <Action.ESE: -15>: 1.0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 1.0}),
#              Isolation(board=41523161203938531786868875203700735, ply_count=3, locs=(69, 28)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203901343150820675062581247, ply_count=2, locs=(13, 75)): defaultdict(float,
#                          {<Action.WSW: -11>: 0.6666666666666666,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNW: 27>: 0.3333333333333333}),
#              Isolation(board=36330864345404294418124338607679487, ply_count=3, locs=(55, 112)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0}),
#              Isolation(board=41523161203939122082674767411800063, ply_count=2, locs=(43, 36)): defaultdict(float,
#                          {<Action.SSE: -27>: -0.3333333333333333,
#                           <Action.SSW: -25>: 1.0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0.3333333333333333,
#                           <Action.NNW: 27>: -0.3333333333333333}),
#              Isolation(board=41523161184596308968849531068213247, ply_count=3, locs=(35, 84)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161165248773200302252836775935, ply_count=3, locs=(58, 72)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161126567869627346815287273471, ply_count=3, locs=(14, 86)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: -0.3333333333333333,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=36330864340568591139665822177290239, ply_count=3, locs=(82, 112)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0}),
#              Isolation(board=41523161203936760899371794297776127, ply_count=3, locs=(46, 71)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523141087413481389411155899836415, ply_count=3, locs=(61, 94)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0}),
#              Isolation(board=41523158689373416131333444228605951, ply_count=3, locs=(85, 91)): defaultdict(float,
#                          {<Action.SSW: -25>: 1.0,
#                           <Action.WSW: -11>: 0,
#                           <Action.WNW: 15>: 0}),
#              Isolation(board=40225047375224158007353414351054847, ply_count=3, locs=(95, 55)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0.3333333333333333,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203939122073676432969557983, ply_count=2, locs=(53, 5)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 1.0,
#                           <Action.WSW: -11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: -0.3333333333333333,
#                           <Action.NNW: 27>: 1.0}),
#              Isolation(board=41523161202730196245045808447088639, ply_count=3, locs=(54, 80)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=40874124096622121055163630995105791, ply_count=3, locs=(40, 109)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0}),
#              Isolation(board=41442031564920052486676929004431359, ply_count=3, locs=(79, 52)): defaultdict(float,
#                          {<Action.SSW: -25>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.WNW: 15>: 0}),
#              Isolation(board=41523062168735388956451281588709375, ply_count=3, locs=(69, 94)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0}),
#              Isolation(board=41523161049196617171975913488771071, ply_count=3, locs=(20, 87)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203636890618772775667492863, ply_count=3, locs=(78, 23)): defaultdict(float,
#                          {<Action.ESE: -15>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.NNE: 25>: -1.0}),
#              Isolation(board=41523161165253495566785053762512895, ply_count=3, locs=(58, 36)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.NNE: 25>: 0}),
#              Isolation(board=41523161203920232616681784897169407, ply_count=3, locs=(46, 74)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.ENE: 11>: -0.3333333333333333,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523158728058748364015704049969151, ply_count=3, locs=(68, 91)): defaultdict(float,
#                          {<Action.SSW: -25>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.WNW: 15>: 0}),
#              Isolation(board=41523161203901341997881578269698047, ply_count=3, locs=(60, 44)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=40874124096622268629117320182884343, ply_count=3, locs=(3, 109)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0}),
#              Isolation(board=41523121588648939121893007022876671, ply_count=3, locs=(53, 95)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0}),
#              Isolation(board=41523161203939121794453238892717951, ply_count=3, locs=(7, 58)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203939122082683621486880751, ply_count=3, locs=(31, 33)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203334511594420128333162495, ply_count=3, locs=(79, 67)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523141396898493512095634210940927, ply_count=2, locs=(94, 52)): defaultdict(float,
#                          {<Action.SSE: -27>: 0.3333333333333333,
#                           <Action.SSW: -25>: 1.0,
#                           <Action.ESE: -15>: 0.3333333333333333,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0.3333333333333333}),
#              Isolation(board=41523161126567869627347365042972671, ply_count=2, locs=(17, 86)): defaultdict(float,
#                          {<Action.ESE: -15>: 1.0,
#                           <Action.WSW: -11>: 0.3333333333333333,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: -0.3333333333333333,
#                           <Action.NNW: 27>: -1.0}),
#              Isolation(board=41360901927109908719292037034141567, ply_count=3, locs=(34, 107)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0}),
#              Isolation(board=20753339944499697453860898555815933, ply_count=3, locs=(114, 1)): defaultdict(float,
#                          {<Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41158077829864466195437952526444543, ply_count=3, locs=(105, 108)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0}),
#              Isolation(board=41523151223047553038462156636415999, ply_count=3, locs=(86, 93)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 1.0,
#                           <Action.WNW: 15>: 0}),
#              Isolation(board=41523161202730191651382950262466559, ply_count=3, locs=(35, 80)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203939122082681433133934589, ply_count=3, locs=(1, 41)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0.0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203934399716165577133254655, ply_count=3, locs=(45, 30)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41198484193950944460742419470608383, ply_count=3, locs=(97, 108)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0.3333333333333333}),
#              Isolation(board=41523002747613945975552255832614911, ply_count=3, locs=(67, 97)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0}),
#              Isolation(board=41523161203636890627779974930606079, ply_count=2, locs=(14, 78)): defaultdict(float,
#                          {<Action.WSW: -11>: -0.3333333333333333,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0.3333333333333333,
#                           <Action.NNW: 27>: 1.0}),
#              Isolation(board=41523161203920232616188104178395135, ply_count=3, locs=(49, 40)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=36330863997233658405139933579700223, ply_count=3, locs=(112, 88)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.NNE: 25>: 0}),
#              Isolation(board=41523161126567869050886612739680127, ply_count=3, locs=(86, 7)): defaultdict(float,
#                          {<Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203938973355774353568950271, ply_count=3, locs=(45, 67)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161201521270443453824119056383, ply_count=3, locs=(39, 81)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: -0.3333333333333333,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203937941491027721850972159, ply_count=3, locs=(45, 33)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=31138567177384457004277570841077757, ply_count=3, locs=(88, 1)): defaultdict(float,
#                          {<Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203939122010626038186239935, ply_count=3, locs=(17, 56)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203938531786864477157189631, ply_count=3, locs=(28, 69)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523141396294030534734325213030399, ply_count=3, locs=(79, 56)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203939048295707337386092527, ply_count=2, locs=(66, 4)): defaultdict(float,
#                          {<Action.SSE: -27>: 1.0,
#                           <Action.SSW: -25>: 0.0,
#                           <Action.WSW: -11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0.0,
#                           <Action.NNW: 27>: -0.2}),
#              Isolation(board=41523161203939119776840554291128317, ply_count=3, locs=(36, 1)): defaultdict(float,
#                          {<Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203939122010625967319410687, ply_count=3, locs=(31, 36)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.NNE: 25>: 0}),
#              Isolation(board=41523160894454112261338563499255807, ply_count=2, locs=(18, 88)): defaultdict(float,
#                          {<Action.ESE: -15>: 0.3333333333333333,
#                           <Action.WSW: -11>: -0.3333333333333333,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: -0.3333333333333333,
#                           <Action.NNW: 27>: 1.0}),
#              Isolation(board=41523161203939122082111886177789951, ply_count=3, locs=(43, 49)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.NNE: 25>: 0}),
#              Isolation(board=41523141396898492363677729231464447, ply_count=2, locs=(60, 94)): defaultdict(float,
#                          {<Action.SSE: -27>: 1.0,
#                           <Action.SSW: -25>: 1.0,
#                           <Action.ESE: -15>: 1.0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: -0.3333333333333333,
#                           <Action.NNW: 27>: -1.0}),
#              Isolation(board=41522527378639007931954085779990527, ply_count=3, locs=(30, 99)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0}),
#              Isolation(board=41523161203938826790663260500649983, ply_count=3, locs=(57, 68)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0.3333333333333333,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=31138567486869466825620440542586879, ply_count=3, locs=(14, 113)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0}),
#              Isolation(board=41523161203938531786873273384429566, ply_count=3, locs=(27, 69)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=40225086989305415175410270649444351, ply_count=3, locs=(47, 110)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 1.0,
#                           <Action.WSW: -11>: 0}),
#              Isolation(board=41523081975771885307747980959279103, ply_count=3, locs=(72, 96)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0}),
#              Isolation(board=41360901927109908719256869841922047, ply_count=2, locs=(45, 107)): defaultdict(float,
#                          {<Action.SSE: -27>: 1.0,
#                           <Action.SSW: -25>: 1.0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: -0.3333333333333333,
#                           <Action.NNW: 27>: 1.0}),
#              Isolation(board=41523161201520975223491600484132863, ply_count=3, locs=(81, 68)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41198642647862843716671217854310271, ply_count=3, locs=(81, 7)): defaultdict(float,
#                          {<Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203939122073676428607481855, ply_count=3, locs=(53, 32)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41442031562502200851951270282389503, ply_count=3, locs=(79, 81)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161049196617172011097861384191, ply_count=2, locs=(87, 19)): defaultdict(float,
#                          {<Action.SSE: -27>: 1.0,
#                           <Action.SSW: -25>: 1.0,
#                           <Action.ESE: -15>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.NNE: 25>: 0.3333333333333333,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203938972202817664590014463, ply_count=3, locs=(61, 67)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203939122082613263478023167, ply_count=3, locs=(21, 10)): defaultdict(float,
#                          {<Action.NNE: 25>: 0}),
#              Isolation(board=41523161199084528761832884641196031, ply_count=3, locs=(59, 82)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203334659154861850407987199, ply_count=3, locs=(79, 36)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.NNE: 25>: -1.0}),
#              Isolation(board=31138567177384457004277570841012223, ply_count=3, locs=(113, 16)): defaultdict(float,
#                          {<Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: -1.0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203939121938286968097990655, ply_count=3, locs=(30, 48)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
# ...
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: -1.0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523081973358756179046411586758655, ply_count=3, locs=(96, 46)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41522844291289065025332158536869887, ply_count=2, locs=(98, 40)): defaultdict(float,
#                          {<Action.SSE: -27>: 0.3333333333333333,
#                           <Action.SSW: -25>: 0.3333333333333333,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: -1.0,
#                           <Action.ENE: 11>: -0.3333333333333333,
#                           <Action.WNW: 15>: 1.0}),
#              Isolation(board=41520625902134202709569724603164671, ply_count=3, locs=(79, 101)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.ENE: 11>: 0}),
#              Isolation(board=41523156174807710179983256232912895, ply_count=3, locs=(61, 92)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.WNW: 15>: 0}),
#              Isolation(board=41523161203939117470856876308555743, ply_count=3, locs=(47, 5)): defaultdict(float,
#                          {<Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=40874124091786565350658769124583423, ply_count=3, locs=(82, 35)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523160894444666951912071905667071, ply_count=3, locs=(73, 59)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203939122082683631683233787, ply_count=3, locs=(2, 22)): defaultdict(float,
#                          {<Action.ESE: -15>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523141396294030606791919250958327, ply_count=3, locs=(79, 3)): defaultdict(float,
#                          {<Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: -1.0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161184596308968847366338635775, ply_count=3, locs=(26, 84)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=36290299487511364885637107801909247, ply_count=3, locs=(112, 105)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.WSW: -11>: 0}),
#              Isolation(board=41523161203939122082683082199787519, ply_count=3, locs=(28, 18)): defaultdict(float,
#                          {<Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=31138567177384457004277570832689151, ply_count=3, locs=(88, 23)): defaultdict(float,
#                          {<Action.ESE: -15>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.NNE: 25>: 0}),
#              Isolation(board=41523161203939047142785283023431679, ply_count=3, locs=(39, 60)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0.0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203939121506222878847100927, ply_count=3, locs=(30, 59)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203939122082402157247522815, ply_count=2, locs=(48, 16)): defaultdict(float,
#                          {<Action.SSE: -27>: -0.3333333333333333,
#                           <Action.SSW: -25>: 1.0,
#                           <Action.ESE: -15>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.NNE: 25>: -0.3333333333333333,
#                           <Action.NNW: 27>: 0.6}),
#              Isolation(board=41523161203901343150539200085878782, ply_count=3, locs=(48, 0)): defaultdict(float,
#                          {<Action.WNW: 15>: 0, <Action.NNW: 27>: 0}),
#              Isolation(board=41522844291289065025333258048235391, ply_count=3, locs=(18, 98)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0}),
#              Isolation(board=40225047375223862895477032017192959, ply_count=3, locs=(95, 110)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.WSW: -11>: 0}),
#              Isolation(board=41482596384712928699443506837448703, ply_count=3, locs=(74, 105)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.WSW: -11>: 0}),
#              Isolation(board=41401466743899360420910690367170559, ply_count=3, locs=(81, 105)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.WSW: -11>: 0}),
#              Isolation(board=41523161194267715525766598826649583, ply_count=2, locs=(83, 4)): defaultdict(float,
#                          {<Action.SSE: -27>: 1.0,
#                           <Action.SSW: -25>: -1.0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 1.0,
#                           <Action.NNW: 27>: -1.0}),
#              Isolation(board=41523081975776607818346034385381343, ply_count=3, locs=(5, 96)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0}),
#              Isolation(board=20753973769799806956875628480030719, ply_count=2, locs=(114, 62)): defaultdict(float,
#                          {<Action.SSE: -27>: 0.6666666666666666,
#                           <Action.ESE: -15>: 1.0}),
#              Isolation(board=41523161203938531786873239157860351, ply_count=3, locs=(35, 69)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41360901927109834932315759375804415, ply_count=2, locs=(107, 66)): defaultdict(float,
#                          {<Action.SSE: -27>: 0.3333333333333333,
#                           <Action.SSW: -25>: -0.3333333333333333,
#                           <Action.ESE: -15>: 0.3333333333333333,
#                           <Action.WSW: -11>: 0.3333333333333333}),
#              Isolation(board=41523161203939122082682497816061951, ply_count=3, locs=(29, 35)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41522527378633105009879296816179199, ply_count=3, locs=(72, 70)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523002747612911809466223118247935, ply_count=3, locs=(70, 60)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203934399716165578206988287, ply_count=3, locs=(72, 13)): defaultdict(float,
#                          {<Action.WSW: -11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203939122082646248827906047, ply_count=3, locs=(20, 41)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203939120929762093257713663, ply_count=2, locs=(35, 60)): defaultdict(float,
#                          {<Action.SSE: -27>: -1.0,
#                           <Action.SSW: -25>: -1.0,
#                           <Action.ESE: -15>: 0,
#                           <Action.ENE: 11>: 0.3333333333333333,
#                           <Action.NNW: 27>: 0.3333333333333333}),
#              Isolation(board=41523161203938974508695858175797247, ply_count=2, locs=(67, 45)): defaultdict(float,
#                          {<Action.SSE: -27>: 0.5,
#                           <Action.SSW: -25>: 0.3333333333333333,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 1.0,
#                           <Action.NNW: 27>: 1.0}),
#              Isolation(board=41523161203937941491058516766484479, ply_count=2, locs=(70, 42)): defaultdict(float,
#                          {<Action.SSE: -27>: -0.3333333333333333,
#                           <Action.SSW: -25>: 1.0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 1.0,
#                           <Action.NNW: 27>: -1.0}),
#              Isolation(board=41522685834954591763692331670169599, ply_count=3, locs=(98, 97)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: -1.0,
#                           <Action.WNW: 15>: 0}),
#              Isolation(board=41523161203934399716060025086535679, ply_count=3, locs=(22, 72)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41522844281617658468416224650848251, ply_count=3, locs=(83, 2)): defaultdict(float,
#                          {<Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203939122064669233177945983, ply_count=3, locs=(54, 7)): defaultdict(float,
#                          {<Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0.3333333333333333,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=38927007803568738013063217667893247, ply_count=3, locs=(84, 92)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.WNW: 15>: 0}),
#              Isolation(board=41522844281013195558608910063495167, ply_count=3, locs=(83, 79)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41522844291289065025333240868627967, ply_count=3, locs=(34, 98)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0.3333333333333333,
#                           <Action.WNW: 15>: 0}),
#              ...})

# %%
q_book
# Out:
# defaultdict(<function __main__.q_fun()>,
#             {Isolation(board=41522527378610673769085666001414143, ply_count=3, locs=(74, 73)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203939122082683627920812031, ply_count=3, locs=(32, 23)): defaultdict(float,
#                          {<Action.ESE: -15>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.NNE: 25>: 0}),
#              Isolation(board=41502561872014006797992277399562239, ply_count=3, locs=(83, 104)): defaultdict(float,
#                          {<Action.SSW: -25>: 0, <Action.WSW: -11>: 0}),
#              Isolation(board=31138567409479324904354893803808767, ply_count=3, locs=(113, 74)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161202125733317232891443275775, ply_count=3, locs=(80, 79)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41520625902733940951554759958980607, ply_count=3, locs=(61, 101)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.ENE: 11>: 0}),
#              Isolation(board=41523161203939122082542886141814783, ply_count=3, locs=(47, 33)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 1.0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41502878794326025679223576938407935, ply_count=3, locs=(73, 104)): defaultdict(float,
#                          {<Action.SSW: -25>: 0, <Action.WSW: -11>: 0}),
#              Isolation(board=41523161201521270443454373338015743, ply_count=2, locs=(81, 29)): defaultdict(float,
#                          {<Action.SSE: -27>: -1.0,
#                           <Action.SSW: -25>: -0.3333333333333333,
#                           <Action.ESE: -15>: 1.0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 1.0,
#                           <Action.NNW: 27>: 1.0}),
#              Isolation(board=41522527378639007967981784361035775, ply_count=3, locs=(40, 99)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0.3333333333333333,
#                           <Action.WNW: 15>: 0}),
#              Isolation(board=41523141396897903220771282946615295, ply_count=3, locs=(69, 94)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.ESE: -15>: -1.0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0}),
#              Isolation(board=41158058024032763448968183315163135, ply_count=3, locs=(105, 108)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 1.0,
#                           <Action.WSW: -11>: 0}),
#              Isolation(board=41523161165234606389075223959824383, ply_count=3, locs=(85, 43)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203936760611141452505802751, ply_count=3, locs=(71, 58)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: -1.0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: -1.0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203938974436638264137869311, ply_count=3, locs=(45, 67)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203939122082644049805436927, ply_count=3, locs=(45, 42)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41521893553301114885390381340420095, ply_count=3, locs=(100, 55)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 1.0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161184596308896791971391072255, ply_count=2, locs=(84, 56)): defaultdict(float,
#                          {<Action.SSE: -27>: 1.0,
#                           <Action.SSW: -25>: 1.0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: -0.3333333333333333,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41482596384731818741835720541857791, ply_count=2, locs=(105, 34)): defaultdict(float,
#                          {<Action.SSE: -27>: -0.6666666666666666,
#                           <Action.SSW: -25>: 0.3333333333333333,
#                           <Action.WSW: -11>: -0.3333333333333333}),
#              Isolation(board=41523081975774246635104603857741819, ply_count=3, locs=(96, 2)): defaultdict(float,
#                          {<Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 1.0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161165253495855015498096830447, ply_count=3, locs=(4, 85)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203939122082666029300836351, ply_count=3, locs=(44, 31)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203939121506222873478424575, ply_count=3, locs=(59, 31)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203937941491060715789674495, ply_count=3, locs=(41, 70)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: -1.0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41522844291284342514735200327428095, ply_count=3, locs=(72, 98)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0}),
#              Isolation(board=41523161203938531786868875203700735, ply_count=3, locs=(42, 28)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203939085171179986784086015, ply_count=3, locs=(65, 40)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203938826934778452871473143, ply_count=2, locs=(68, 3)): defaultdict(float,
#                          {<Action.SSE: -27>: 0.3333333333333333,
#                           <Action.SSW: -25>: 0.3333333333333333,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: -1.0,
#                           <Action.NNW: 27>: 0.3333333333333333}),
#              Isolation(board=41523002742778390275549928437572607, ply_count=3, locs=(82, 10)): defaultdict(float,
#                          {<Action.ENE: 11>: 0, <Action.NNE: 25>: 0}),
#              Isolation(board=40225086989305267597094818838210559, ply_count=3, locs=(52, 110)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0}),
#              Isolation(board=41198484193955665674303784508975103, ply_count=3, locs=(97, 60)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161199103268924429516635367423, ply_count=3, locs=(82, 61)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41522527069153998146620222961870847, ply_count=3, locs=(99, 44)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: -1.0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203939122082674831836178431, ply_count=3, locs=(32, 43)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523158728049598778886974391445503, ply_count=3, locs=(73, 91)): defaultdict(float,
#                          {<Action.SSW: -25>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.WNW: 15>: 0}),
#              Isolation(board=41523161203920232616752153642919935, ply_count=2, locs=(19, 74)): defaultdict(float,
#                          {<Action.ESE: -15>: -0.3333333333333333,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: -1.0,
#                           <Action.NNE: 25>: -0.3333333333333333,
#                           <Action.NNW: 27>: 0.0}),
#              Isolation(board=41522844281617658463912625023477759, ply_count=3, locs=(83, 52)): defaultdict(float,
#                          {<Action.SSW: -25>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=31138250571801558129043007040645119, ply_count=3, locs=(113, 81)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161199103418804225046805997055, ply_count=3, locs=(9, 82)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=40225086989305415175269533165283327, ply_count=2, locs=(110, 48)): defaultdict(float,
#                          {<Action.SSE: -27>: 0.3333333333333333,
#                           <Action.SSW: -25>: 0.3333333333333333,
#                           <Action.ESE: -15>: 0.3333333333333333,
#                           <Action.WSW: -11>: 1.0}),
#              Isolation(board=41523161203939122082674835862841335, ply_count=3, locs=(28, 43)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: -1.0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203934399572085540143491071, ply_count=3, locs=(57, 35)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523081975776017522535679840479231, ply_count=3, locs=(96, 27)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523141396898345798531456086042623, ply_count=3, locs=(67, 57)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523141396596262061695576544634879, ply_count=2, locs=(94, 78)): defaultdict(float,
#                          {<Action.SSE: -27>: 0.3333333333333333,
#                           <Action.SSW: -25>: -0.3333333333333333,
#                           <Action.ESE: -15>: 1.0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 1.0}),
#              Isolation(board=41523161203938531786868875203700735, ply_count=3, locs=(69, 28)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203901343150820675062581247, ply_count=2, locs=(13, 75)): defaultdict(float,
#                          {<Action.WSW: -11>: 0.6666666666666666,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNW: 27>: 0.3333333333333333}),
#              Isolation(board=36330864345404294418124338607679487, ply_count=3, locs=(55, 112)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0}),
#              Isolation(board=41523161203939122082674767411800063, ply_count=2, locs=(43, 36)): defaultdict(float,
#                          {<Action.SSE: -27>: -0.3333333333333333,
#                           <Action.SSW: -25>: 1.0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0.3333333333333333,
#                           <Action.NNW: 27>: -0.3333333333333333}),
#              Isolation(board=41523161184596308968849531068213247, ply_count=3, locs=(35, 84)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161165248773200302252836775935, ply_count=3, locs=(58, 72)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161126567869627346815287273471, ply_count=3, locs=(14, 86)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: -0.3333333333333333,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=36330864340568591139665822177290239, ply_count=3, locs=(82, 112)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0}),
#              Isolation(board=41523161203936760899371794297776127, ply_count=3, locs=(46, 71)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523141087413481389411155899836415, ply_count=3, locs=(61, 94)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0}),
#              Isolation(board=41523158689373416131333444228605951, ply_count=3, locs=(85, 91)): defaultdict(float,
#                          {<Action.SSW: -25>: 1.0,
#                           <Action.WSW: -11>: 0,
#                           <Action.WNW: 15>: 0}),
#              Isolation(board=40225047375224158007353414351054847, ply_count=3, locs=(95, 55)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0.3333333333333333,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203939122073676432969557983, ply_count=2, locs=(53, 5)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 1.0,
#                           <Action.WSW: -11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: -0.3333333333333333,
#                           <Action.NNW: 27>: 1.0}),
#              Isolation(board=41523161202730196245045808447088639, ply_count=3, locs=(54, 80)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=40874124096622121055163630995105791, ply_count=3, locs=(40, 109)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0}),
#              Isolation(board=41442031564920052486676929004431359, ply_count=3, locs=(79, 52)): defaultdict(float,
#                          {<Action.SSW: -25>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.WNW: 15>: 0}),
#              Isolation(board=41523062168735388956451281588709375, ply_count=3, locs=(69, 94)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0}),
#              Isolation(board=41523161049196617171975913488771071, ply_count=3, locs=(20, 87)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203636890618772775667492863, ply_count=3, locs=(78, 23)): defaultdict(float,
#                          {<Action.ESE: -15>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.NNE: 25>: -1.0}),
#              Isolation(board=41523161165253495566785053762512895, ply_count=3, locs=(58, 36)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.NNE: 25>: 0}),
#              Isolation(board=41523161203920232616681784897169407, ply_count=3, locs=(46, 74)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.ENE: 11>: -0.3333333333333333,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523158728058748364015704049969151, ply_count=3, locs=(68, 91)): defaultdict(float,
#                          {<Action.SSW: -25>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.WNW: 15>: 0}),
#              Isolation(board=41523161203901341997881578269698047, ply_count=3, locs=(60, 44)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=40874124096622268629117320182884343, ply_count=3, locs=(3, 109)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0}),
#              Isolation(board=41523121588648939121893007022876671, ply_count=3, locs=(53, 95)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0}),
#              Isolation(board=41523161203939121794453238892717951, ply_count=3, locs=(7, 58)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203939122082683621486880751, ply_count=3, locs=(31, 33)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203334511594420128333162495, ply_count=3, locs=(79, 67)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523141396898493512095634210940927, ply_count=2, locs=(94, 52)): defaultdict(float,
#                          {<Action.SSE: -27>: 0.3333333333333333,
#                           <Action.SSW: -25>: 1.0,
#                           <Action.ESE: -15>: 0.3333333333333333,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0.3333333333333333}),
#              Isolation(board=41523161126567869627347365042972671, ply_count=2, locs=(17, 86)): defaultdict(float,
#                          {<Action.ESE: -15>: 1.0,
#                           <Action.WSW: -11>: 0.3333333333333333,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: -0.3333333333333333,
#                           <Action.NNW: 27>: -1.0}),
#              Isolation(board=41360901927109908719292037034141567, ply_count=3, locs=(34, 107)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0}),
#              Isolation(board=20753339944499697453860898555815933, ply_count=3, locs=(114, 1)): defaultdict(float,
#                          {<Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41158077829864466195437952526444543, ply_count=3, locs=(105, 108)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0}),
#              Isolation(board=41523151223047553038462156636415999, ply_count=3, locs=(86, 93)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 1.0,
#                           <Action.WNW: 15>: 0}),
#              Isolation(board=41523161202730191651382950262466559, ply_count=3, locs=(35, 80)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203939122082681433133934589, ply_count=3, locs=(1, 41)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0.0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203934399716165577133254655, ply_count=3, locs=(45, 30)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41198484193950944460742419470608383, ply_count=3, locs=(97, 108)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0.3333333333333333}),
#              Isolation(board=41523002747613945975552255832614911, ply_count=3, locs=(67, 97)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0}),
#              Isolation(board=41523161203636890627779974930606079, ply_count=2, locs=(14, 78)): defaultdict(float,
#                          {<Action.WSW: -11>: -0.3333333333333333,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0.3333333333333333,
#                           <Action.NNW: 27>: 1.0}),
#              Isolation(board=41523161203920232616188104178395135, ply_count=3, locs=(49, 40)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=36330863997233658405139933579700223, ply_count=3, locs=(112, 88)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.NNE: 25>: 0}),
#              Isolation(board=41523161126567869050886612739680127, ply_count=3, locs=(86, 7)): defaultdict(float,
#                          {<Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203938973355774353568950271, ply_count=3, locs=(45, 67)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161201521270443453824119056383, ply_count=3, locs=(39, 81)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: -0.3333333333333333,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203937941491027721850972159, ply_count=3, locs=(45, 33)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=31138567177384457004277570841077757, ply_count=3, locs=(88, 1)): defaultdict(float,
#                          {<Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203939122010626038186239935, ply_count=3, locs=(17, 56)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203938531786864477157189631, ply_count=3, locs=(28, 69)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523141396294030534734325213030399, ply_count=3, locs=(79, 56)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203939048295707337386092527, ply_count=2, locs=(66, 4)): defaultdict(float,
#                          {<Action.SSE: -27>: 1.0,
#                           <Action.SSW: -25>: 0.0,
#                           <Action.WSW: -11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0.0,
#                           <Action.NNW: 27>: -0.2}),
#              Isolation(board=41523161203939119776840554291128317, ply_count=3, locs=(36, 1)): defaultdict(float,
#                          {<Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203939122010625967319410687, ply_count=3, locs=(31, 36)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.NNE: 25>: 0}),
#              Isolation(board=41523160894454112261338563499255807, ply_count=2, locs=(18, 88)): defaultdict(float,
#                          {<Action.ESE: -15>: 0.3333333333333333,
#                           <Action.WSW: -11>: -0.3333333333333333,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: -0.3333333333333333,
#                           <Action.NNW: 27>: 1.0}),
#              Isolation(board=41523161203939122082111886177789951, ply_count=3, locs=(43, 49)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.NNE: 25>: 0}),
#              Isolation(board=41523141396898492363677729231464447, ply_count=2, locs=(60, 94)): defaultdict(float,
#                          {<Action.SSE: -27>: 1.0,
#                           <Action.SSW: -25>: 1.0,
#                           <Action.ESE: -15>: 1.0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: -0.3333333333333333,
#                           <Action.NNW: 27>: -1.0}),
#              Isolation(board=41522527378639007931954085779990527, ply_count=3, locs=(30, 99)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0}),
#              Isolation(board=41523161203938826790663260500649983, ply_count=3, locs=(57, 68)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0.3333333333333333,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=31138567486869466825620440542586879, ply_count=3, locs=(14, 113)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0}),
#              Isolation(board=41523161203938531786873273384429566, ply_count=3, locs=(27, 69)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=40225086989305415175410270649444351, ply_count=3, locs=(47, 110)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 1.0,
#                           <Action.WSW: -11>: 0}),
#              Isolation(board=41523081975771885307747980959279103, ply_count=3, locs=(72, 96)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0}),
#              Isolation(board=41360901927109908719256869841922047, ply_count=2, locs=(45, 107)): defaultdict(float,
#                          {<Action.SSE: -27>: 1.0,
#                           <Action.SSW: -25>: 1.0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: -0.3333333333333333,
#                           <Action.NNW: 27>: 1.0}),
#              Isolation(board=41523161201520975223491600484132863, ply_count=3, locs=(81, 68)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41198642647862843716671217854310271, ply_count=3, locs=(81, 7)): defaultdict(float,
#                          {<Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203939122073676428607481855, ply_count=3, locs=(53, 32)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41442031562502200851951270282389503, ply_count=3, locs=(79, 81)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161049196617172011097861384191, ply_count=2, locs=(87, 19)): defaultdict(float,
#                          {<Action.SSE: -27>: 1.0,
#                           <Action.SSW: -25>: 1.0,
#                           <Action.ESE: -15>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.NNE: 25>: 0.3333333333333333,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203938972202817664590014463, ply_count=3, locs=(61, 67)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203939122082613263478023167, ply_count=3, locs=(21, 10)): defaultdict(float,
#                          {<Action.NNE: 25>: 0}),
#              Isolation(board=41523161199084528761832884641196031, ply_count=3, locs=(59, 82)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203334659154861850407987199, ply_count=3, locs=(79, 36)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.NNE: 25>: -1.0}),
#              Isolation(board=31138567177384457004277570841012223, ply_count=3, locs=(113, 16)): defaultdict(float,
#                          {<Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: -1.0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203939121938286968097990655, ply_count=3, locs=(30, 48)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
# ...
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: -1.0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523081973358756179046411586758655, ply_count=3, locs=(96, 46)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41522844291289065025332158536869887, ply_count=2, locs=(98, 40)): defaultdict(float,
#                          {<Action.SSE: -27>: 0.3333333333333333,
#                           <Action.SSW: -25>: 0.3333333333333333,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: -1.0,
#                           <Action.ENE: 11>: -0.3333333333333333,
#                           <Action.WNW: 15>: 1.0}),
#              Isolation(board=41520625902134202709569724603164671, ply_count=3, locs=(79, 101)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.ENE: 11>: 0}),
#              Isolation(board=41523156174807710179983256232912895, ply_count=3, locs=(61, 92)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.WNW: 15>: 0}),
#              Isolation(board=41523161203939117470856876308555743, ply_count=3, locs=(47, 5)): defaultdict(float,
#                          {<Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=40874124091786565350658769124583423, ply_count=3, locs=(82, 35)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523160894444666951912071905667071, ply_count=3, locs=(73, 59)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203939122082683631683233787, ply_count=3, locs=(2, 22)): defaultdict(float,
#                          {<Action.ESE: -15>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523141396294030606791919250958327, ply_count=3, locs=(79, 3)): defaultdict(float,
#                          {<Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: -1.0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161184596308968847366338635775, ply_count=3, locs=(26, 84)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=36290299487511364885637107801909247, ply_count=3, locs=(112, 105)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.WSW: -11>: 0}),
#              Isolation(board=41523161203939122082683082199787519, ply_count=3, locs=(28, 18)): defaultdict(float,
#                          {<Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=31138567177384457004277570832689151, ply_count=3, locs=(88, 23)): defaultdict(float,
#                          {<Action.ESE: -15>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.NNE: 25>: 0}),
#              Isolation(board=41523161203939047142785283023431679, ply_count=3, locs=(39, 60)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0.0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203939121506222878847100927, ply_count=3, locs=(30, 59)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203939122082402157247522815, ply_count=2, locs=(48, 16)): defaultdict(float,
#                          {<Action.SSE: -27>: -0.3333333333333333,
#                           <Action.SSW: -25>: 1.0,
#                           <Action.ESE: -15>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.NNE: 25>: -0.3333333333333333,
#                           <Action.NNW: 27>: 0.6}),
#              Isolation(board=41523161203901343150539200085878782, ply_count=3, locs=(48, 0)): defaultdict(float,
#                          {<Action.WNW: 15>: 0, <Action.NNW: 27>: 0}),
#              Isolation(board=41522844291289065025333258048235391, ply_count=3, locs=(18, 98)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0}),
#              Isolation(board=40225047375223862895477032017192959, ply_count=3, locs=(95, 110)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.WSW: -11>: 0}),
#              Isolation(board=41482596384712928699443506837448703, ply_count=3, locs=(74, 105)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.WSW: -11>: 0}),
#              Isolation(board=41401466743899360420910690367170559, ply_count=3, locs=(81, 105)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.WSW: -11>: 0}),
#              Isolation(board=41523161194267715525766598826649583, ply_count=2, locs=(83, 4)): defaultdict(float,
#                          {<Action.SSE: -27>: 1.0,
#                           <Action.SSW: -25>: -1.0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 1.0,
#                           <Action.NNW: 27>: -1.0}),
#              Isolation(board=41523081975776607818346034385381343, ply_count=3, locs=(5, 96)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0}),
#              Isolation(board=20753973769799806956875628480030719, ply_count=2, locs=(114, 62)): defaultdict(float,
#                          {<Action.SSE: -27>: 0.6666666666666666,
#                           <Action.ESE: -15>: 1.0}),
#              Isolation(board=41523161203938531786873239157860351, ply_count=3, locs=(35, 69)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41360901927109834932315759375804415, ply_count=2, locs=(107, 66)): defaultdict(float,
#                          {<Action.SSE: -27>: 0.3333333333333333,
#                           <Action.SSW: -25>: -0.3333333333333333,
#                           <Action.ESE: -15>: 0.3333333333333333,
#                           <Action.WSW: -11>: 0.3333333333333333}),
#              Isolation(board=41523161203939122082682497816061951, ply_count=3, locs=(29, 35)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41522527378633105009879296816179199, ply_count=3, locs=(72, 70)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523002747612911809466223118247935, ply_count=3, locs=(70, 60)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203934399716165578206988287, ply_count=3, locs=(72, 13)): defaultdict(float,
#                          {<Action.WSW: -11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203939122082646248827906047, ply_count=3, locs=(20, 41)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203939120929762093257713663, ply_count=2, locs=(35, 60)): defaultdict(float,
#                          {<Action.SSE: -27>: -1.0,
#                           <Action.SSW: -25>: -1.0,
#                           <Action.ESE: -15>: 0,
#                           <Action.ENE: 11>: 0.3333333333333333,
#                           <Action.NNW: 27>: 0.3333333333333333}),
#              Isolation(board=41523161203938974508695858175797247, ply_count=2, locs=(67, 45)): defaultdict(float,
#                          {<Action.SSE: -27>: 0.5,
#                           <Action.SSW: -25>: 0.3333333333333333,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 1.0,
#                           <Action.NNW: 27>: 1.0}),
#              Isolation(board=41523161203937941491058516766484479, ply_count=2, locs=(70, 42)): defaultdict(float,
#                          {<Action.SSE: -27>: -0.3333333333333333,
#                           <Action.SSW: -25>: 1.0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 1.0,
#                           <Action.NNW: 27>: -1.0}),
#              Isolation(board=41522685834954591763692331670169599, ply_count=3, locs=(98, 97)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: -1.0,
#                           <Action.WNW: 15>: 0}),
#              Isolation(board=41523161203934399716060025086535679, ply_count=3, locs=(22, 72)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41522844281617658468416224650848251, ply_count=3, locs=(83, 2)): defaultdict(float,
#                          {<Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203939122064669233177945983, ply_count=3, locs=(54, 7)): defaultdict(float,
#                          {<Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0.3333333333333333,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=38927007803568738013063217667893247, ply_count=3, locs=(84, 92)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.WNW: 15>: 0}),
#              Isolation(board=41522844281013195558608910063495167, ply_count=3, locs=(83, 79)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41522844291289065025333240868627967, ply_count=3, locs=(34, 98)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0.3333333333333333,
#                           <Action.WNW: 15>: 0}),
#              ...})

# %%
with open('q_book.pkl', 'wb') as file:
    pickle.dump(q_book, file)
with open('../data.pickle', 'wb') as file:
    pickle.dump(q_book, file)
with open('n_book.pkl', 'wb') as file:
    pickle.dump(n_book, file)

# %%
from isolation.isolation import Isolation

test_state = Isolation(board=41523161203937941491058516766484479, ply_count=2, locs=(70, 42))

# %%
max(((k, v) for k, v in q_book[test_state].items()), key=lambda x: x[1])[0]
# Out:
# <Action.SSW: -25>

# %%
max(q_book[test_state].items(), key=lambda x: x[1])[0]
# Out:
# <Action.SSW: -25>

# %%
q_book[test_state]
# Out:
# defaultdict(float,
#             {<Action.SSE: -27>: -0.3333333333333333,
#              <Action.SSW: -25>: 1.0,
#              <Action.ESE: -15>: 0,
#              <Action.WSW: -11>: 0,
#              <Action.ENE: 11>: 0,
#              <Action.WNW: 15>: 0,
#              <Action.NNE: 25>: 1.0,
#              <Action.NNW: 27>: -1.0})

# %%
test_state in q_book.keys()
# Out:
# True

# %%
with open(os.path.join('..',"data.pickle"), "rb") as f:
    data = pickle.load(f)

# %%
data
# Out:
# defaultdict(<function __main__.q_fun()>,
#             {Isolation(board=41522527378610673769085666001414143, ply_count=3, locs=(74, 73)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41502858977623435289258253189375999, ply_count=3, locs=(83, 104)): defaultdict(float,
#                          {<Action.SSW: -25>: 0, <Action.WSW: -11>: 0}),
#              Isolation(board=31138250574200520302340786809202687, ply_count=3, locs=(113, 74)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161202125733317232891443275775, ply_count=3, locs=(80, 79)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41520625902733940951554759958980607, ply_count=3, locs=(61, 101)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.ENE: 11>: 0}),
#              Isolation(board=41523161201521270443454373338015743, ply_count=2, locs=(81, 29)): defaultdict(float,
#                          {<Action.SSE: -27>: -1.0,
#                           <Action.SSW: -25>: -0.3333333333333333,
#                           <Action.ESE: -15>: 1.0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 1.0,
#                           <Action.NNW: 27>: 1.0}),
#              Isolation(board=41523161203939122082683561357273087, ply_count=3, locs=(31, 36)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.NNE: 25>: 0}),
#              Isolation(board=41523161203939119704783026825193471, ply_count=3, locs=(31, 61)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203937941491054118451537919, ply_count=3, locs=(70, 28)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41522527378639007967981784361035775, ply_count=3, locs=(40, 99)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0.3333333333333333,
#                           <Action.WNW: 15>: 0}),
#              Isolation(board=41523062168735388956451281588709375, ply_count=3, locs=(69, 94)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0}),
#              Isolation(board=41158058024032763448968183315163135, ply_count=3, locs=(105, 108)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 1.0,
#                           <Action.WSW: -11>: 0}),
#              Isolation(board=41523161165234606389075223959824383, ply_count=3, locs=(85, 43)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203936760611194229063935999, ply_count=3, locs=(71, 58)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203938974436638264137869311, ply_count=3, locs=(45, 67)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203939122082683632224282615, ply_count=2, locs=(14, 3)): defaultdict(float,
#                          {<Action.WNW: 15>: -0.3333333333333333,
#                           <Action.NNE: 25>: 0.25,
#                           <Action.NNW: 27>: 0.3333333333333333}),
#              Isolation(board=41523161203939122082644049805436927, ply_count=3, locs=(45, 42)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41521893553301114885390381340420095, ply_count=3, locs=(100, 55)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 1.0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=31138567486869466825059672432568319, ply_count=3, locs=(49, 113)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0}),
#              Isolation(board=41442031565524515400987843084937214, ply_count=3, locs=(27, 106)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0}),
#              Isolation(board=41482596384731818741835720541857791, ply_count=2, locs=(105, 34)): defaultdict(float,
#                          {<Action.SSE: -27>: -0.6666666666666666,
#                           <Action.SSW: -25>: 0.3333333333333333,
#                           <Action.WSW: -11>: -0.3333333333333333}),
#              Isolation(board=41523081975774246635104603857741819, ply_count=3, locs=(96, 2)): defaultdict(float,
#                          {<Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 1.0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161165253495855015498096830447, ply_count=3, locs=(4, 85)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161184596308392388810978093055, ply_count=3, locs=(59, 31)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41522844291284342514735200327428095, ply_count=3, locs=(72, 98)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0}),
#              Isolation(board=41523161203939085171179986784086015, ply_count=3, locs=(65, 40)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41198642650275972845302418482653183, ply_count=3, locs=(72, 108)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0}),
#              Isolation(board=41523161203938826934778452871473143, ply_count=2, locs=(68, 3)): defaultdict(float,
#                          {<Action.SSE: -27>: 0.3333333333333333,
#                           <Action.SSW: -25>: 0.3333333333333333,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: -1.0,
#                           <Action.NNW: 27>: 0.3333333333333333}),
#              Isolation(board=40874124091786565350658803484320767, ply_count=3, locs=(82, 10)): defaultdict(float,
#                          {<Action.ENE: 11>: 0, <Action.NNE: 25>: 0}),
#              Isolation(board=41523121589857864950514801092585215, ply_count=3, locs=(8, 95)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0}),
#              Isolation(board=41523161199103268924429516635367423, ply_count=3, locs=(82, 61)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203939122082674831836178431, ply_count=3, locs=(32, 43)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523158728049598778886974391445503, ply_count=3, locs=(73, 91)): defaultdict(float,
#                          {<Action.SSW: -25>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.WNW: 15>: 0}),
#              Isolation(board=41523161203920232616752153642919935, ply_count=2, locs=(19, 74)): defaultdict(float,
#                          {<Action.ESE: -15>: -0.3333333333333333,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: -1.0,
#                           <Action.NNE: 25>: -0.3333333333333333,
#                           <Action.NNW: 27>: 0.0}),
#              Isolation(board=41523161203939120929199177659836415, ply_count=3, locs=(49, 22)): defaultdict(float,
#                          {<Action.ESE: -15>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.NNE: 25>: 0}),
#              Isolation(board=41198642640609288794479843178702847, ply_count=3, locs=(83, 52)): defaultdict(float,
#                          {<Action.SSW: -25>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=31138567407080362731057114035251199, ply_count=3, locs=(113, 81)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161199103418804225046805997055, ply_count=3, locs=(9, 82)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=40225086989305415175269533165283327, ply_count=2, locs=(110, 48)): defaultdict(float,
#                          {<Action.SSE: -27>: 0.3333333333333333,
#                           <Action.SSW: -25>: 0.3333333333333333,
#                           <Action.ESE: -15>: 0.3333333333333333,
#                           <Action.WSW: -11>: 1.0}),
#              Isolation(board=41523161203939122082674835862841335, ply_count=3, locs=(28, 43)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: -1.0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523081975776017522535679840479231, ply_count=3, locs=(96, 27)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523141396898345798531456086042623, ply_count=3, locs=(67, 57)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203939122082402156173846495, ply_count=3, locs=(30, 48)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.NNE: 25>: 0.3333333333333333,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523141396596262061695576544634879, ply_count=2, locs=(94, 78)): defaultdict(float,
#                          {<Action.SSE: -27>: 0.3333333333333333,
#                           <Action.SSW: -25>: -0.3333333333333333,
#                           <Action.ESE: -15>: 1.0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 1.0}),
#              Isolation(board=41523161203938531786868875203700735, ply_count=3, locs=(69, 28)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203901343150820675062581247, ply_count=2, locs=(13, 75)): defaultdict(float,
#                          {<Action.WSW: -11>: 0.6666666666666666,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNW: 27>: 0.3333333333333333}),
#              Isolation(board=36330864345404294418124337802373119, ply_count=3, locs=(55, 112)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0.3333333333333333,
#                           <Action.WSW: -11>: 0}),
#              Isolation(board=41523161203939122082674767411800063, ply_count=2, locs=(43, 36)): defaultdict(float,
#                          {<Action.SSE: -27>: -0.3333333333333333,
#                           <Action.SSW: -25>: 1.0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0.3333333333333333,
#                           <Action.NNW: 27>: -0.3333333333333333}),
#              Isolation(board=41523161184596308968849531068213247, ply_count=3, locs=(35, 84)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523141396898493516599233301440507, ply_count=3, locs=(29, 94)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0}),
#              Isolation(board=41523161126567869627346815287273471, ply_count=3, locs=(14, 86)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: -0.3333333333333333,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=36330864340568591031579431120398335, ply_count=3, locs=(82, 112)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0.3333333333333333,
#                           <Action.WSW: -11>: 0}),
#              Isolation(board=41523161203936760899371794297776127, ply_count=3, locs=(46, 71)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523158689373416131333444228605951, ply_count=3, locs=(85, 91)): defaultdict(float,
#                          {<Action.SSW: -25>: 1.0,
#                           <Action.WSW: -11>: 0,
#                           <Action.WNW: 15>: 0}),
#              Isolation(board=40225047375224158007353414351054847, ply_count=3, locs=(95, 55)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0.3333333333333333,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41442031555853108772013215783577599, ply_count=3, locs=(83, 106)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0}),
#              Isolation(board=41523161203939122073676432969557983, ply_count=2, locs=(53, 5)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 1.0,
#                           <Action.WSW: -11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: -0.3333333333333333,
#                           <Action.NNW: 27>: 1.0}),
#              Isolation(board=41523161202730196245054054784296959, ply_count=3, locs=(54, 80)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=40874124096622121055163630995105791, ply_count=3, locs=(40, 109)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0}),
#              Isolation(board=41442031564920052486676929004431359, ply_count=3, locs=(79, 52)): defaultdict(float,
#                          {<Action.SSW: -25>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.WNW: 15>: 0}),
#              Isolation(board=41523141396897903220771282946615295, ply_count=3, locs=(69, 94)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.ESE: -15>: -1.0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0}),
#              Isolation(board=41523161049196617172011095713376255, ply_count=3, locs=(20, 87)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203636890618772775667492863, ply_count=3, locs=(78, 23)): defaultdict(float,
#                          {<Action.ESE: -15>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.NNE: 25>: -1.0}),
#              Isolation(board=41523161203939121794312449864755199, ply_count=3, locs=(58, 36)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.NNE: 25>: 0}),
#              Isolation(board=41523161203920232616681784897169407, ply_count=3, locs=(46, 74)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.ENE: 11>: -0.3333333333333333,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523158728058748364009106980202495, ply_count=3, locs=(68, 91)): defaultdict(float,
#                          {<Action.SSW: -25>: 0.3333333333333333,
#                           <Action.WSW: -11>: 0,
#                           <Action.WNW: 15>: 0}),
#              Isolation(board=41523161203901341997881578269698047, ply_count=3, locs=(60, 44)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=40874124096622268629117320182884343, ply_count=3, locs=(3, 109)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0}),
#              Isolation(board=41523161203939121794453238892717951, ply_count=3, locs=(7, 58)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203939122082542889367234559, ply_count=3, locs=(32, 30)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203334511594420128333162495, ply_count=3, locs=(79, 67)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41520625902738665623880638817625983, ply_count=3, locs=(18, 101)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.ENE: 11>: 0}),
#              Isolation(board=41523161126567869627347365042972671, ply_count=2, locs=(17, 86)): defaultdict(float,
#                          {<Action.ESE: -15>: 1.0,
#                           <Action.WSW: -11>: 0.3333333333333333,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: -0.3333333333333333,
#                           <Action.NNW: 27>: -1.0}),
#              Isolation(board=41360901927109908719292037034141567, ply_count=3, locs=(34, 107)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0}),
#              Isolation(board=20753339944499697453860898555815933, ply_count=3, locs=(114, 1)): defaultdict(float,
#                          {<Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41158077829864466195437952526444543, ply_count=3, locs=(105, 108)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0}),
#              Isolation(board=41523151276240291407348849537181695, ply_count=3, locs=(93, 84)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523158726547886237404795957667839, ply_count=3, locs=(91, 78)): defaultdict(float,
#                          {<Action.SSW: -25>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523151223047553038462156636415999, ply_count=3, locs=(86, 93)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 1.0,
#                           <Action.WNW: 15>: 0}),
#              Isolation(board=41523161202730191651382950262466559, ply_count=3, locs=(35, 80)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203939122082681432932607997, ply_count=3, locs=(1, 41)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161126530090695475611788371967, ply_count=3, locs=(86, 43)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: -1.0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41198484193950944460742419470608383, ply_count=3, locs=(97, 108)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0.3333333333333333}),
#              Isolation(board=41523161203636890627779974930606079, ply_count=2, locs=(14, 78)): defaultdict(float,
#                          {<Action.WSW: -11>: -0.3333333333333333,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0.3333333333333333,
#                           <Action.NNW: 27>: 1.0}),
#              Isolation(board=41522844291289065025315665862453247, ply_count=2, locs=(44, 98)): defaultdict(float,
#                          {<Action.SSE: -27>: -0.3333333333333333,
#                           <Action.SSW: -25>: 0.3333333333333333,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 1.0,
#                           <Action.NNW: 27>: 1.0}),
#              Isolation(board=36330705579594256104132880082397183, ply_count=3, locs=(112, 88)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.NNE: 25>: 0}),
#              Isolation(board=41523161126567869050886612739680127, ply_count=3, locs=(86, 7)): defaultdict(float,
#                          {<Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203938973355774353568950271, ply_count=3, locs=(45, 67)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161201521270443453824119056383, ply_count=3, locs=(39, 81)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: -0.3333333333333333,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203937941491027721850972159, ply_count=3, locs=(45, 33)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41522527069153998146637815147915261, ply_count=3, locs=(88, 1)): defaultdict(float,
#                          {<Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203939122010626038186239935, ply_count=3, locs=(17, 56)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203938531786864477157189631, ply_count=3, locs=(28, 69)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41442031564920052419122934593873919, ply_count=3, locs=(79, 56)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: -1.0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203939048295707337386092527, ply_count=2, locs=(66, 4)): defaultdict(float,
#                          {<Action.SSE: -27>: 1.0,
#                           <Action.SSW: -25>: 0.0,
#                           <Action.WSW: -11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0.0,
#                           <Action.NNW: 27>: -0.2}),
#              Isolation(board=41523161203939119776840554291128317, ply_count=3, locs=(36, 1)): defaultdict(float,
#                          {<Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203939122010625967319410687, ply_count=3, locs=(31, 36)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.NNE: 25>: 0}),
#              Isolation(board=41523160894454112261338563499255807, ply_count=2, locs=(18, 88)): defaultdict(float,
#                          {<Action.ESE: -15>: 0.3333333333333333,
#                           <Action.WSW: -11>: -0.3333333333333333,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: -0.3333333333333333,
#                           <Action.NNW: 27>: 1.0}),
#              Isolation(board=41523161203939122082111886177789951, ply_count=3, locs=(43, 49)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.NNE: 25>: 0}),
#              Isolation(board=41523161202729605967257544832313343, ply_count=3, locs=(69, 40)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523141396898492363677729231464447, ply_count=2, locs=(60, 94)): defaultdict(float,
#                          {<Action.SSE: -27>: 1.0,
#                           <Action.SSW: -25>: 1.0,
#                           <Action.ESE: -15>: 1.0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: -0.3333333333333333,
#                           <Action.NNW: 27>: -1.0}),
#              Isolation(board=41522527378639007823867694723098623, ply_count=3, locs=(30, 99)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0}),
#              Isolation(board=41523161203938826790663260500649983, ply_count=3, locs=(57, 68)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0.3333333333333333,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=31138567486869466825622089810028543, ply_count=3, locs=(14, 113)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: -0.3333333333333333}),
#              Isolation(board=41523161203938531768858874874947583, ply_count=3, locs=(27, 69)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=40225086989305415175410201934161919, ply_count=3, locs=(47, 110)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0}),
#              Isolation(board=41523081975771885307747980959279103, ply_count=3, locs=(72, 96)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0}),
#              Isolation(board=41482596384731818741835737721726959, ply_count=2, locs=(105, 4)): defaultdict(float,
#                          {<Action.SSE: -27>: 0.0,
#                           <Action.SSW: -25>: 0.3333333333333333,
#                           <Action.WSW: -11>: -0.3333333333333333}),
#              Isolation(board=41523161203937941490746255464196095, ply_count=3, locs=(45, 48)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41360901927109908719256869841922047, ply_count=2, locs=(45, 107)): defaultdict(float,
#                          {<Action.SSE: -27>: 1.0,
#                           <Action.SSW: -25>: 1.0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: -0.3333333333333333,
#                           <Action.NNW: 27>: 1.0}),
#              Isolation(board=41523161201520975223491600484132863, ply_count=3, locs=(81, 68)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203636890618772771380914175, ply_count=3, locs=(53, 32)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: -0.3333333333333333,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41442031562502200851951270282389503, ply_count=3, locs=(79, 81)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161049196617172011097861384191, ply_count=2, locs=(87, 19)): defaultdict(float,
#                          {<Action.SSE: -27>: 1.0,
#                           <Action.SSW: -25>: 1.0,
#                           <Action.ESE: -15>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.NNE: 25>: 0.3333333333333333,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523160894453962381542964609411071, ply_count=3, locs=(61, 67)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203939122082683627927233535, ply_count=3, locs=(21, 10)): defaultdict(float,
#                          {<Action.NNE: 25>: 0}),
#              Isolation(board=41523161199084528761832884641196031, ply_count=3, locs=(59, 82)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203939122046654834131593207, ply_count=3, locs=(30, 55)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203334659154861850407987199, ply_count=3, locs=(79, 36)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.NNE: 25>: -1.0}),
#              Isolation(board=31138250574219409768272265389991935, ply_count=3, locs=(113, 16)): defaultdict(float,
#                          {<Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203939121938286968097990655, ply_count=3, locs=(30, 48)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.NNE: 25>: 0,
# ...
#                           <Action.SSW: -25>: 0,
#                           <Action.WSW: -11>: 0}),
#              Isolation(board=41523161203939122082683082199787519, ply_count=3, locs=(28, 18)): defaultdict(float,
#                          {<Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=31138567177384457004277570832689151, ply_count=3, locs=(88, 23)): defaultdict(float,
#                          {<Action.ESE: -15>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.NNE: 25>: 0}),
#              Isolation(board=41523161203939121506222878847100927, ply_count=3, locs=(30, 59)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203939122082666040038254559, ply_count=2, locs=(44, 5)): defaultdict(float,
#                          {<Action.SSE: -27>: 1.0,
#                           <Action.SSW: -25>: 1.0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: -0.3333333333333333,
#                           <Action.NNW: 27>: -0.3333333333333333}),
#              Isolation(board=41523161203939122082402157247522815, ply_count=2, locs=(48, 16)): defaultdict(float,
#                          {<Action.SSE: -27>: -0.3333333333333333,
#                           <Action.SSW: -25>: 1.0,
#                           <Action.ESE: -15>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.NNE: 25>: -0.3333333333333333,
#                           <Action.NNW: 27>: 0.6}),
#              Isolation(board=41523161203901343150539200085878782, ply_count=3, locs=(48, 0)): defaultdict(float,
#                          {<Action.WNW: 15>: 0, <Action.NNW: 27>: 0}),
#              Isolation(board=41522844291289065025333258048235391, ply_count=3, locs=(18, 98)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0}),
#              Isolation(board=41523141396898493516599233838245885, ply_count=3, locs=(1, 94)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0}),
#              Isolation(board=40225047375223862895477032017192959, ply_count=3, locs=(95, 110)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.WSW: -11>: 0}),
#              Isolation(board=41482596384712928699443506837448703, ply_count=3, locs=(74, 105)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.WSW: -11>: 0}),
#              Isolation(board=41401466743899360420910690367170559, ply_count=3, locs=(81, 105)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.WSW: -11>: 0}),
#              Isolation(board=41523161194267715525766598826649583, ply_count=2, locs=(83, 4)): defaultdict(float,
#                          {<Action.SSE: -27>: 1.0,
#                           <Action.SSW: -25>: -1.0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 1.0,
#                           <Action.NNW: 27>: -1.0}),
#              Isolation(board=20753973769799806956875628480030719, ply_count=2, locs=(114, 62)): defaultdict(float,
#                          {<Action.SSE: -27>: 0.6666666666666666,
#                           <Action.ESE: -15>: 1.0}),
#              Isolation(board=41523161203938531786873239157860351, ply_count=3, locs=(35, 69)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41360901927109834932315759375804415, ply_count=2, locs=(107, 66)): defaultdict(float,
#                          {<Action.SSE: -27>: 0.3333333333333333,
#                           <Action.SSW: -25>: -0.3333333333333333,
#                           <Action.ESE: -15>: 0.3333333333333333,
#                           <Action.WSW: -11>: 0.3333333333333333}),
#              Isolation(board=41523161203939122082682497816061951, ply_count=3, locs=(29, 35)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161049190714213907510805391359, ply_count=3, locs=(72, 70)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523002747612911809466223118247935, ply_count=3, locs=(70, 60)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203934399716060025090721791, ply_count=3, locs=(72, 13)): defaultdict(float,
#                          {<Action.WSW: -11>: -1.0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203939122082646248827906047, ply_count=3, locs=(20, 41)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203939120929762093257713663, ply_count=2, locs=(35, 60)): defaultdict(float,
#                          {<Action.SSE: -27>: -1.0,
#                           <Action.SSW: -25>: -1.0,
#                           <Action.ESE: -15>: 0,
#                           <Action.ENE: 11>: 0.3333333333333333,
#                           <Action.NNW: 27>: 0.3333333333333333}),
#              Isolation(board=41523161203938974508695858175797247, ply_count=2, locs=(67, 45)): defaultdict(float,
#                          {<Action.SSE: -27>: 0.5,
#                           <Action.SSW: -25>: 0.3333333333333333,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 1.0,
#                           <Action.NNW: 27>: 1.0}),
#              Isolation(board=41523161203937941491058516766484479, ply_count=2, locs=(70, 42)): defaultdict(float,
#                          {<Action.SSE: -27>: -0.3333333333333333,
#                           <Action.SSW: -25>: 1.0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 1.0,
#                           <Action.NNW: 27>: -1.0}),
#              Isolation(board=40225047375221796860140776547411967, ply_count=3, locs=(110, 71)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41522685834954591763692331670169599, ply_count=3, locs=(98, 97)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: -1.0,
#                           <Action.WNW: 15>: 0}),
#              Isolation(board=41523161203934399716060025086535679, ply_count=3, locs=(22, 72)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=40225086979634008618633974744344571, ply_count=3, locs=(83, 2)): defaultdict(float,
#                          {<Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203939121794453253925102591, ply_count=3, locs=(31, 10)): defaultdict(float,
#                          {<Action.ENE: 11>: 0, <Action.NNE: 25>: 0}),
#              Isolation(board=41523161203939122082542894601725947, ply_count=3, locs=(27, 47)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0.3333333333333333,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=40874119125519298373762153791350783, ply_count=3, locs=(84, 92)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.WNW: 15>: 0}),
#              Isolation(board=41522844281013195558608910063495167, ply_count=3, locs=(83, 79)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161202730196263069002512459775, ply_count=3, locs=(29, 80)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41522844291289065025333240868627967, ply_count=3, locs=(34, 98)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0.3333333333333333,
#                           <Action.WNW: 15>: 0}),
#              Isolation(board=41523161203334585385899473042925567, ply_count=3, locs=(39, 79)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203939122082680333689399295, ply_count=3, locs=(14, 40)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203929677061487516781635583, ply_count=3, locs=(58, 19)): defaultdict(float,
#                          {<Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161203939122082402156710717439, ply_count=2, locs=(48, 29)): defaultdict(float,
#                          {<Action.SSE: -27>: -0.3333333333333333,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.NNE: 25>: -0.3333333333333333,
#                           <Action.NNW: 27>: -0.3333333333333333}),
#              Isolation(board=41523161203939122082683632223184863, ply_count=3, locs=(5, 20)): defaultdict(float,
#                          {<Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41198484039213161916552754753431551, ply_count=3, locs=(108, 87)): defaultdict(float,
#                          {<Action.SSE: -27>: 0,
#                           <Action.SSW: -25>: 0,
#                           <Action.ESE: -15>: 0,
#                           <Action.ENE: 11>: -1.0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              Isolation(board=41523161199103418768196318506248191, ply_count=3, locs=(55, 18)): defaultdict(float,
#                          {<Action.ESE: -15>: 0,
#                           <Action.WSW: -11>: 0,
#                           <Action.ENE: 11>: 0,
#                           <Action.WNW: 15>: 0,
#                           <Action.NNE: 25>: 0,
#                           <Action.NNW: 27>: 0}),
#              ...})

# %%
[state for state in data.keys() if state.ply_count==0]
# Out:
# [Isolation(board=41523161203939122082683632224299007, ply_count=0, locs=(None, None))]

# %%
"""
book = {(state, action): [Q, N]}
nodes = {state0:[node_0_0, node_0_1, ...], state1:[node_1_0], ...}
node = {'state': state,
        'parent': parent,
        'from_action': from_action,
        'N': N,
        'Q': Q
        }
"""
# Out:
# "\nbook = {(state, action): [Q, N]}\nnodes = {state0:[node_0_0, node_0_1, ...], state1:[node_1_0], ...}\nnode = {'state': state,\n        'parent': parent,\n        'from_action': from_action,\n        'N': N,\n        'Q': Q\n        }\n"

# %% [markdown]
# ## Let's try to fill some book entries with MCTS

# %%
def new_node(state, parent=None, from_action=None, N=0, Q=0, children=None):
    node = {'state': state,
            'parent': parent,
            'from_action': from_action,
            'N': N,
            'Q': Q
            }
    if children is None:
        node['children'] = list()
    else:
        node['children'] = children
    if parent is not None:
        parent['children'].append(node)
    return node

def ucb(node, c=1):
    if node['N'] == 0:
        if c != 0:
            return float('inf')
        else:
            return 0
    return (node['Q'] / node['N']) + c * math.sqrt((2 * math.log(node['N'])) / node['N'])


def best_node(node_list, c=1):
    return max(node_list, key=partial(ucb, c=c))


def best_child(node, c=1):
    return best_node(node['children'], c)


def expand(node):
    a = random.choice(unexplored_actions(node))
    child = new_node(state=node['state'].result(a),
                                  parent=node,
                                  from_action=a)
    node['children'].append(child)
    return child


def unexplored_actions(node):
    return list(set(node['state'].actions()) -
                set(child['from_action'] for child in node['children']))


def is_fully_expanded(node):
    return len(unexplored_actions(node)) == 0


def backup_negamax(node, reward):
    temp_node = node
    temp_node['N'] += 1
    temp_node['Q'] += reward
    while temp_node['parent'] is not None:
        temp_node = temp_node['parent']
        temp_node['N'] += 1
        temp_node['Q'] += reward


def get_root_node(state, nodes=None):
    """
    nodes = {
        state1: [node1_1, node1_2],
        state2: [node2_1],
        state3: [node3_1, node3_2, node3_3]
    }
    """
    if nodes is None:
        nodes = dict()
    if state not in nodes.keys():
        node = new_node(state)
        nodes[state] = [node]
        return node, nodes
    else:
        return best_node(nodes[state]), nodes

# %% [markdown]
# ### The only thing to change is the default policy

# %%
import isolation
import sample_players
import run_match
import my_book_player as custom
import book as b

from multiprocessing.pool import ThreadPool as Pool

# %%
# Constant parameteres
time_limit = 150
depth = 4
full_search_depth = 2
matches_per_opening = 3

# Create the agents that will play
agent_names = ('CustomPlayer1', 'CustomPlayer2')
agent1 = isolation.Agent(custom.CustomPlayer, agent_names[0])
agent2 = isolation.Agent(custom.CustomPlayer, agent_names[1])
agents = (agent1, agent2)

#  (agents, state, time_limit, match_id)

# %%
from functools import partial

# %%
def tree_policy(node, nodes=None):
    if nodes is None:
        nodes = dict()
    temp_node = node
    tree_history = list()
    while not temp_node['state'].terminal_test():
        if is_fully_expanded(temp_node):
            temp_node = best_child(temp_node)
            tree_history.append(temp_node['from_action'])
        else:
            child = expand(temp_node)
            if child['state'] not in nodes.keys():
                nodes[child['state']] = [child]
            else:
                nodes[child['state']].append(child)
            tree_history.append(child['from_action'])
            return child, tree_history
    return temp_node, tree_history

# %%
def uct_search(root_n, book, depth, nodes=None):
    """
    nodes contains a dictionary of state:node with the nodes that have
    already been visited.
    """
    edge_node, tree_history = tree_policy(root_n, nodes)
    reward, game_history, winner_id = default_policy(edge_node['state'])
    # Add data to the book
    game_history = tree_history + game_history
    b.process_game_history(root_n['state'],
                         game_history,
                         book,
                         winner_id,
                         active_player=0,
                         depth=depth)
    backup_negamax(edge_node, reward)
    return best_child(root_n, 0)['from_action'], nodes  # Greedy, so c = 0

# %%
def default_policy(state):
    player_id = state.player()
    winner, game_history, match_id = isolation.play((agents, state, time_limit, 0))
    winner_id = agent_names.index(winner.name)
    game_value = 2 * (player_id == winner_id) - 1
    return game_value, game_history, winner_id

# %%
default_policy(isolation.isolation.Isolation())
# Out:
# (-1,
#  [44,
#   27,
#   <Action.NNE: 25>,
#   <Action.NNE: 25>,
#   <Action.NNE: 25>,
#   <Action.WSW: -11>,
#   <Action.ESE: -15>,
#   <Action.NNW: 27>,
#   <Action.SSW: -25>,
#   <Action.SSW: -25>,
#   <Action.SSW: -25>,
#   <Action.SSW: -25>,
#   <Action.ENE: 11>,
#   <Action.WNW: 15>,
#   <Action.NNE: 25>,
#   <Action.NNW: 27>,
#   <Action.WNW: 15>,
#   <Action.NNE: 25>,
#   <Action.SSE: -27>,
#   <Action.ENE: 11>,
#   <Action.WSW: -11>,
#   <Action.SSW: -25>,
#   <Action.SSW: -25>,
#   <Action.ESE: -15>,
#   <Action.WNW: 15>,
#   <Action.SSW: -25>,
#   <Action.NNE: 25>,
#   <Action.WNW: 15>,
#   <Action.SSE: -27>,
#   <Action.WSW: -11>,
#   <Action.NNE: 25>,
#   <Action.ESE: -15>,
#   <Action.WNW: 15>,
#   <Action.NNE: 25>,
#   <Action.NNE: 25>,
#   <Action.WSW: -11>,
#   <Action.WSW: -11>,
#   <Action.NNE: 25>,
#   <Action.WSW: -11>,
#   <Action.WNW: 15>,
#   <Action.NNE: 25>,
#   <Action.NNW: 27>,
#   <Action.ESE: -15>,
#   <Action.ENE: 11>,
#   <Action.WSW: -11>,
#   <Action.ESE: -15>,
#   <Action.SSW: -25>,
#   <Action.WSW: -11>,
#   <Action.ENE: 11>],
#  1)

# %%
# Load the last nodes and book, if wanted
with open('nodes.pkl', 'rb') as file:
    nodes = pickle.load(file)
with open('tree_book.pkl', 'rb') as file:
    book = pickle.load(file)

# %%
# Initialize book
depth = 4
root_s = isolation.isolation.Isolation()
book = b.get_empty_book(root_s, depth=depth)

# Get root node
root_n, nodes = get_root_node(root_s, nodes)
root_n['parent'] = None  # Set this one as the new root
root_n['from_action'] = None  # Just for completeness, not used by now

# %%
root_n
# Out:
# {'N': 592,
#  'Q': 52,
#  'children': [{'N': 8,
#    'Q': 0,
#    'children': [{'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 98,
#      'parent': {...},
#      'state': Isolation(board=41522844291270175559401779467642879, ply_count=2, locs=(74, 98))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 98,
#      'parent': {...},
#      'state': Isolation(board=41522844291270175559401779467642879, ply_count=2, locs=(74, 98))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 72,
#      'parent': {...},
#      'state': Isolation(board=41523161203915510250269283998230527, ply_count=2, locs=(74, 72))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 72,
#      'parent': {...},
#      'state': Isolation(board=41523161203915510250269283998230527, ply_count=2, locs=(74, 72))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 22,
#      'parent': {...},
#      'state': Isolation(board=41523161203920232616752153639249919, ply_count=2, locs=(74, 22))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 22,
#      'parent': {...},
#      'state': Isolation(board=41523161203920232616752153639249919, ply_count=2, locs=(74, 22))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 41,
#      'parent': {...},
#      'state': Isolation(board=41523161203920232616749954620188671, ply_count=2, locs=(74, 41))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 41,
#      'parent': {...},
#      'state': Isolation(board=41523161203920232616749954620188671, ply_count=2, locs=(74, 41))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 31,
#      'parent': {...},
#      'state': Isolation(board=41523161203920232616752151495960575, ply_count=2, locs=(74, 31))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 31,
#      'parent': {...},
#      'state': Isolation(board=41523161203920232616752151495960575, ply_count=2, locs=(74, 31))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 65,
#      'parent': {...},
#      'state': Isolation(board=41523161203920195723264006224340991, ply_count=2, locs=(74, 65))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 65,
#      'parent': {...},
#      'state': Isolation(board=41523161203920195723264006224340991, ply_count=2, locs=(74, 65))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 47,
#      'parent': {...},
#      'state': Isolation(board=41523161203920232616611416155088895, ply_count=2, locs=(74, 47))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 47,
#      'parent': {...},
#      'state': Isolation(board=41523161203920232616611416155088895, ply_count=2, locs=(74, 47))}],
#    'from_action': 74,
#    'parent': {...},
#    'state': Isolation(board=41523161203920232616752153643444223, ply_count=1, locs=(74, None))},
#   {'N': 8,
#    'Q': 0,
#    'children': [{'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 98,
#      'parent': {...},
#      'state': Isolation(board=41522844291270175559401779467642879, ply_count=2, locs=(74, 98))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 98,
#      'parent': {...},
#      'state': Isolation(board=41522844291270175559401779467642879, ply_count=2, locs=(74, 98))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 72,
#      'parent': {...},
#      'state': Isolation(board=41523161203915510250269283998230527, ply_count=2, locs=(74, 72))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 72,
#      'parent': {...},
#      'state': Isolation(board=41523161203915510250269283998230527, ply_count=2, locs=(74, 72))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 22,
#      'parent': {...},
#      'state': Isolation(board=41523161203920232616752153639249919, ply_count=2, locs=(74, 22))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 22,
#      'parent': {...},
#      'state': Isolation(board=41523161203920232616752153639249919, ply_count=2, locs=(74, 22))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 41,
#      'parent': {...},
#      'state': Isolation(board=41523161203920232616749954620188671, ply_count=2, locs=(74, 41))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 41,
#      'parent': {...},
#      'state': Isolation(board=41523161203920232616749954620188671, ply_count=2, locs=(74, 41))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 31,
#      'parent': {...},
#      'state': Isolation(board=41523161203920232616752151495960575, ply_count=2, locs=(74, 31))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 31,
#      'parent': {...},
#      'state': Isolation(board=41523161203920232616752151495960575, ply_count=2, locs=(74, 31))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 65,
#      'parent': {...},
#      'state': Isolation(board=41523161203920195723264006224340991, ply_count=2, locs=(74, 65))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 65,
#      'parent': {...},
#      'state': Isolation(board=41523161203920195723264006224340991, ply_count=2, locs=(74, 65))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 47,
#      'parent': {...},
#      'state': Isolation(board=41523161203920232616611416155088895, ply_count=2, locs=(74, 47))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 47,
#      'parent': {...},
#      'state': Isolation(board=41523161203920232616611416155088895, ply_count=2, locs=(74, 47))}],
#    'from_action': 74,
#    'parent': {...},
#    'state': Isolation(board=41523161203920232616752153643444223, ply_count=1, locs=(74, None))},
#   {'N': 42,
#    'Q': 16,
#    'children': [{'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 10,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122082683632223773695, ply_count=2, locs=(19, 10))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 10,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122082683632223773695, ply_count=2, locs=(19, 10))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 95,
#      'parent': {...},
#      'state': Isolation(board=41523121589857864950514835451799551, ply_count=2, locs=(19, 95))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 95,
#      'parent': {...},
#      'state': Isolation(board=41523121589857864950514835451799551, ply_count=2, locs=(19, 95))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 92,
#      'parent': {...},
#      'state': Isolation(board=41523156252178964941162532627277823, ply_count=2, locs=(19, 92))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 92,
#      'parent': {...},
#      'state': Isolation(board=41523156252178964941162532627277823, ply_count=2, locs=(19, 92))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 79,
#      'parent': {...},
#      'state': Isolation(board=41523161203334659172876317636421631, ply_count=2, locs=(19, 79))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 79,
#      'parent': {...},
#      'state': Isolation(board=41523161203334659172876317636421631, ply_count=2, locs=(19, 79))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 67,
#      'parent': {...},
#      'state': Isolation(board=41523161203938974508731042547361791, ply_count=2, locs=(19, 67))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 67,
#      'parent': {...},
#      'state': Isolation(board=41523161203938974508731042547361791, ply_count=2, locs=(19, 67))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 105,
#      'parent': {...},
#      'state': Isolation(board=41482596384731818741835737721202687, ply_count=2, locs=(19, 105))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 105,
#      'parent': {...},
#      'state': Isolation(board=41482596384731818741835737721202687, ply_count=2, locs=(19, 105))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 54,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122064669233714292735, ply_count=2, locs=(19, 54))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 54,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122064669233714292735, ply_count=2, locs=(19, 54))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 34,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122082683615043905535, ply_count=2, locs=(19, 34))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 34,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122082683615043905535, ply_count=2, locs=(19, 34))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 42,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122082679234177263615, ply_count=2, locs=(19, 42))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 42,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122082679234177263615, ply_count=2, locs=(19, 42))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 28,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122082683631955339263, ply_count=2, locs=(19, 28))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 28,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122082683631955339263, ply_count=2, locs=(19, 28))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 41,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122082681433200519167, ply_count=2, locs=(19, 41))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 41,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122082681433200519167, ply_count=2, locs=(19, 41))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 53,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122073676432969033727, ply_count=2, locs=(19, 53))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 53,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122073676432969033727, ply_count=2, locs=(19, 53))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 40,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122082682532712146943, ply_count=2, locs=(19, 40))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 40,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122082682532712146943, ply_count=2, locs=(19, 40))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 62,
#      'parent': {...},
#      'state': Isolation(board=41523161203939117470997613796386815, ply_count=2, locs=(19, 62))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 62,
#      'parent': {...},
#      'state': Isolation(board=41523161203939117470997613796386815, ply_count=2, locs=(19, 62))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 75,
#      'parent': {...},
#      'state': Isolation(board=41523161203901343150820675062065151, ply_count=2, locs=(19, 75))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 75,
#      'parent': {...},
#      'state': Isolation(board=41523161203901343150820675062065151, ply_count=2, locs=(19, 75))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 97,
#      'parent': {...},
#      'state': Isolation(board=41523002747614093554008445135874047, ply_count=2, locs=(19, 97))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 97,
#      'parent': {...},
#      'state': Isolation(board=41523002747614093554008445135874047, ply_count=2, locs=(19, 97))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 66,
#      'parent': {...},
#      'state': Isolation(board=41523161203939048295707337385568255, ply_count=2, locs=(19, 66))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 66,
#      'parent': {...},
#      'state': Isolation(board=41523161203939048295707337385568255, ply_count=2, locs=(19, 66))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 86,
#      'parent': {...},
#      'state': Isolation(board=41523161126567869627347365042579455, ply_count=2, locs=(19, 86))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 86,
#      'parent': {...},
#      'state': Isolation(board=41523161126567869627347365042579455, ply_count=2, locs=(19, 86))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 109,
#      'parent': {...},
#      'state': Isolation(board=40874124096622268629117320182622207, ply_count=2, locs=(19, 109))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 109,
#      'parent': {...},
#      'state': Isolation(board=40874124096622268629117320182622207, ply_count=2, locs=(19, 109))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 39,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122082683082467960831, ply_count=2, locs=(19, 39))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 39,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122082683082467960831, ply_count=2, locs=(19, 39))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 71,
#      'parent': {...},
#      'state': Isolation(board=41523161203936760899442197401167871, ply_count=2, locs=(19, 71))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 71,
#      'parent': {...},
#      'state': Isolation(board=41523161203936760899442197401167871, ply_count=2, locs=(19, 71))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 73,
#      'parent': {...},
#      'state': Isolation(board=41523161203929677349717892933347327, ply_count=2, locs=(19, 73))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 73,
#      'parent': {...},
#      'state': Isolation(board=41523161203929677349717892933347327, ply_count=2, locs=(19, 73))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 44,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122082666040037730303, ply_count=2, locs=(19, 44))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 44,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122082666040037730303, ply_count=2, locs=(19, 44))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 56,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122010626038185846783, ply_count=2, locs=(19, 56))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 56,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122010626038185846783, ply_count=2, locs=(19, 56))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 70,
#      'parent': {...},
#      'state': Isolation(board=41523161203937941491062914812471295, ply_count=2, locs=(19, 70))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 70,
#      'parent': {...},
#      'state': Isolation(board=41523161203937941491062914812471295, ply_count=2, locs=(19, 70))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 88,
#      'parent': {...},
#      'state': Isolation(board=41523160894454112261338563498993663, ply_count=2, locs=(19, 88))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 88,
#      'parent': {...},
#      'state': Isolation(board=41523160894454112261338563498993663, ply_count=2, locs=(19, 88))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 99,
#      'parent': {...},
#      'state': Isolation(board=41522527378639007967982883872172031, ply_count=2, locs=(19, 99))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 99,
#      'parent': {...},
#      'state': Isolation(board=41522527378639007967982883872172031, ply_count=2, locs=(19, 99))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 6,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122082683632223774655, ply_count=2, locs=(19, 6))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 6,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122082683632223774655, ply_count=2, locs=(19, 6))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 5,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122082683632223774687, ply_count=2, locs=(19, 5))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 5,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122082683632223774687, ply_count=2, locs=(19, 5))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 94,
#      'parent': {...},
#      'state': Isolation(board=41523141396898493516599233837787135, ply_count=2, locs=(19, 94))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 94,
#      'parent': {...},
#      'state': Isolation(board=41523141396898493516599233837787135, ply_count=2, locs=(19, 94))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 110,
#      'parent': {...},
#      'state': Isolation(board=40225086989305415175551008141469695, ply_count=2, locs=(19, 110))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 110,
#      'parent': {...},
#      'state': Isolation(board=40225086989305415175551008141469695, ply_count=2, locs=(19, 110))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 1,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122082683632223774717, ply_count=2, locs=(19, 1))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 1,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122082683632223774717, ply_count=2, locs=(19, 1))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 111,
#      'parent': {...},
#      'state': Isolation(board=38927012774671708268418384059164671, ply_count=2, locs=(19, 111))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 111,
#      'parent': {...},
#      'state': Isolation(board=38927012774671708268418384059164671, ply_count=2, locs=(19, 111))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 65,
#      'parent': {...},
#      'state': Isolation(board=41523161203939085189195484804671487, ply_count=2, locs=(19, 65))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 65,
#      'parent': {...},
#      'state': Isolation(board=41523161203939085189195484804671487, ply_count=2, locs=(19, 65))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 32,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122082683627928807423, ply_count=2, locs=(19, 32))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 32,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122082683627928807423, ply_count=2, locs=(19, 32))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 22,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122082683632219580415, ply_count=2, locs=(19, 22))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 22,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122082683632219580415, ply_count=2, locs=(19, 22))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 55,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122046654835204810751, ply_count=2, locs=(19, 55))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 55,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122046654835204810751, ply_count=2, locs=(19, 55))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 108,
#      'parent': {...},
#      'state': Isolation(board=41198642650280695355900476203198463, ply_count=2, locs=(19, 108))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 108,
#      'parent': {...},
#      'state': Isolation(board=41198642650280695355900476203198463, ply_count=2, locs=(19, 108))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 52,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122078180032596404223, ply_count=2, locs=(19, 52))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 52,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122078180032596404223, ply_count=2, locs=(19, 52))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 4,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122082683632223774703, ply_count=2, locs=(19, 4))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 4,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122082683632223774703, ply_count=2, locs=(19, 4))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 87,
#      'parent': {...},
#      'state': Isolation(board=41523161049196617172011097861384191, ply_count=2, locs=(19, 87))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 87,
#      'parent': {...},
#      'state': Isolation(board=41523161049196617172011097861384191, ply_count=2, locs=(19, 87))}],
#    'from_action': 19,
#    'parent': {...},
#    'state': Isolation(board=41523161203939122082683632223774719, ply_count=1, locs=(19, None))},
#   {'N': 42,
#    'Q': 16,
#    'children': [{'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 10,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122082683632223773695, ply_count=2, locs=(19, 10))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 10,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122082683632223773695, ply_count=2, locs=(19, 10))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 95,
#      'parent': {...},
#      'state': Isolation(board=41523121589857864950514835451799551, ply_count=2, locs=(19, 95))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 95,
#      'parent': {...},
#      'state': Isolation(board=41523121589857864950514835451799551, ply_count=2, locs=(19, 95))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 92,
#      'parent': {...},
#      'state': Isolation(board=41523156252178964941162532627277823, ply_count=2, locs=(19, 92))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 92,
#      'parent': {...},
#      'state': Isolation(board=41523156252178964941162532627277823, ply_count=2, locs=(19, 92))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 79,
#      'parent': {...},
#      'state': Isolation(board=41523161203334659172876317636421631, ply_count=2, locs=(19, 79))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 79,
#      'parent': {...},
#      'state': Isolation(board=41523161203334659172876317636421631, ply_count=2, locs=(19, 79))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 67,
#      'parent': {...},
#      'state': Isolation(board=41523161203938974508731042547361791, ply_count=2, locs=(19, 67))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 67,
#      'parent': {...},
#      'state': Isolation(board=41523161203938974508731042547361791, ply_count=2, locs=(19, 67))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 105,
#      'parent': {...},
#      'state': Isolation(board=41482596384731818741835737721202687, ply_count=2, locs=(19, 105))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 105,
#      'parent': {...},
#      'state': Isolation(board=41482596384731818741835737721202687, ply_count=2, locs=(19, 105))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 54,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122064669233714292735, ply_count=2, locs=(19, 54))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 54,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122064669233714292735, ply_count=2, locs=(19, 54))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 34,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122082683615043905535, ply_count=2, locs=(19, 34))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 34,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122082683615043905535, ply_count=2, locs=(19, 34))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 42,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122082679234177263615, ply_count=2, locs=(19, 42))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 42,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122082679234177263615, ply_count=2, locs=(19, 42))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 28,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122082683631955339263, ply_count=2, locs=(19, 28))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 28,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122082683631955339263, ply_count=2, locs=(19, 28))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 41,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122082681433200519167, ply_count=2, locs=(19, 41))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 41,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122082681433200519167, ply_count=2, locs=(19, 41))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 53,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122073676432969033727, ply_count=2, locs=(19, 53))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 53,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122073676432969033727, ply_count=2, locs=(19, 53))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 40,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122082682532712146943, ply_count=2, locs=(19, 40))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 40,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122082682532712146943, ply_count=2, locs=(19, 40))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 62,
#      'parent': {...},
#      'state': Isolation(board=41523161203939117470997613796386815, ply_count=2, locs=(19, 62))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 62,
#      'parent': {...},
#      'state': Isolation(board=41523161203939117470997613796386815, ply_count=2, locs=(19, 62))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 75,
#      'parent': {...},
#      'state': Isolation(board=41523161203901343150820675062065151, ply_count=2, locs=(19, 75))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 75,
#      'parent': {...},
#      'state': Isolation(board=41523161203901343150820675062065151, ply_count=2, locs=(19, 75))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 97,
#      'parent': {...},
#      'state': Isolation(board=41523002747614093554008445135874047, ply_count=2, locs=(19, 97))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 97,
#      'parent': {...},
#      'state': Isolation(board=41523002747614093554008445135874047, ply_count=2, locs=(19, 97))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 66,
#      'parent': {...},
#      'state': Isolation(board=41523161203939048295707337385568255, ply_count=2, locs=(19, 66))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 66,
#      'parent': {...},
#      'state': Isolation(board=41523161203939048295707337385568255, ply_count=2, locs=(19, 66))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 86,
#      'parent': {...},
#      'state': Isolation(board=41523161126567869627347365042579455, ply_count=2, locs=(19, 86))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 86,
#      'parent': {...},
#      'state': Isolation(board=41523161126567869627347365042579455, ply_count=2, locs=(19, 86))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 109,
#      'parent': {...},
#      'state': Isolation(board=40874124096622268629117320182622207, ply_count=2, locs=(19, 109))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 109,
#      'parent': {...},
#      'state': Isolation(board=40874124096622268629117320182622207, ply_count=2, locs=(19, 109))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 39,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122082683082467960831, ply_count=2, locs=(19, 39))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 39,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122082683082467960831, ply_count=2, locs=(19, 39))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 71,
#      'parent': {...},
#      'state': Isolation(board=41523161203936760899442197401167871, ply_count=2, locs=(19, 71))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 71,
#      'parent': {...},
#      'state': Isolation(board=41523161203936760899442197401167871, ply_count=2, locs=(19, 71))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 73,
#      'parent': {...},
#      'state': Isolation(board=41523161203929677349717892933347327, ply_count=2, locs=(19, 73))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 73,
#      'parent': {...},
#      'state': Isolation(board=41523161203929677349717892933347327, ply_count=2, locs=(19, 73))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 44,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122082666040037730303, ply_count=2, locs=(19, 44))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 44,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122082666040037730303, ply_count=2, locs=(19, 44))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 56,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122010626038185846783, ply_count=2, locs=(19, 56))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 56,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122010626038185846783, ply_count=2, locs=(19, 56))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 70,
#      'parent': {...},
#      'state': Isolation(board=41523161203937941491062914812471295, ply_count=2, locs=(19, 70))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 70,
#      'parent': {...},
#      'state': Isolation(board=41523161203937941491062914812471295, ply_count=2, locs=(19, 70))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 88,
#      'parent': {...},
#      'state': Isolation(board=41523160894454112261338563498993663, ply_count=2, locs=(19, 88))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 88,
#      'parent': {...},
#      'state': Isolation(board=41523160894454112261338563498993663, ply_count=2, locs=(19, 88))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 99,
#      'parent': {...},
#      'state': Isolation(board=41522527378639007967982883872172031, ply_count=2, locs=(19, 99))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 99,
#      'parent': {...},
#      'state': Isolation(board=41522527378639007967982883872172031, ply_count=2, locs=(19, 99))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 6,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122082683632223774655, ply_count=2, locs=(19, 6))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 6,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122082683632223774655, ply_count=2, locs=(19, 6))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 5,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122082683632223774687, ply_count=2, locs=(19, 5))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 5,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122082683632223774687, ply_count=2, locs=(19, 5))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 94,
#      'parent': {...},
#      'state': Isolation(board=41523141396898493516599233837787135, ply_count=2, locs=(19, 94))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 94,
#      'parent': {...},
#      'state': Isolation(board=41523141396898493516599233837787135, ply_count=2, locs=(19, 94))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 110,
#      'parent': {...},
#      'state': Isolation(board=40225086989305415175551008141469695, ply_count=2, locs=(19, 110))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 110,
#      'parent': {...},
#      'state': Isolation(board=40225086989305415175551008141469695, ply_count=2, locs=(19, 110))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 1,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122082683632223774717, ply_count=2, locs=(19, 1))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 1,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122082683632223774717, ply_count=2, locs=(19, 1))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 111,
#      'parent': {...},
#      'state': Isolation(board=38927012774671708268418384059164671, ply_count=2, locs=(19, 111))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 111,
#      'parent': {...},
#      'state': Isolation(board=38927012774671708268418384059164671, ply_count=2, locs=(19, 111))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 65,
#      'parent': {...},
#      'state': Isolation(board=41523161203939085189195484804671487, ply_count=2, locs=(19, 65))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 65,
#      'parent': {...},
#      'state': Isolation(board=41523161203939085189195484804671487, ply_count=2, locs=(19, 65))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 32,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122082683627928807423, ply_count=2, locs=(19, 32))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 32,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122082683627928807423, ply_count=2, locs=(19, 32))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 22,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122082683632219580415, ply_count=2, locs=(19, 22))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 22,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122082683632219580415, ply_count=2, locs=(19, 22))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 55,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122046654835204810751, ply_count=2, locs=(19, 55))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 55,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122046654835204810751, ply_count=2, locs=(19, 55))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 108,
#      'parent': {...},
#      'state': Isolation(board=41198642650280695355900476203198463, ply_count=2, locs=(19, 108))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 108,
#      'parent': {...},
#      'state': Isolation(board=41198642650280695355900476203198463, ply_count=2, locs=(19, 108))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 52,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122078180032596404223, ply_count=2, locs=(19, 52))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 52,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122078180032596404223, ply_count=2, locs=(19, 52))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 4,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122082683632223774703, ply_count=2, locs=(19, 4))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 4,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122082683632223774703, ply_count=2, locs=(19, 4))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 87,
#      'parent': {...},
#      'state': Isolation(board=41523161049196617172011097861384191, ply_count=2, locs=(19, 87))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 87,
#      'parent': {...},
#      'state': Isolation(board=41523161049196617172011097861384191, ply_count=2, locs=(19, 87))}],
#    'from_action': 19,
#    'parent': {...},
#    'state': Isolation(board=41523161203939122082683632223774719, ply_count=1, locs=(19, None))},
#   {'N': 6,
#    'Q': 0,
#    'children': [{'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 98,
#      'parent': {...},
#      'state': Isolation(board=41522824484248436459248859662510079, ply_count=2, locs=(94, 98))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 98,
#      'parent': {...},
#      'state': Isolation(board=41522824484248436459248859662510079, ply_count=2, locs=(94, 98))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 41,
#      'parent': {...},
#      'state': Isolation(board=41523141396898493516597034815055871, ply_count=2, locs=(94, 41))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 41,
#      'parent': {...},
#      'state': Isolation(board=41523141396898493516597034815055871, ply_count=2, locs=(94, 41))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 31,
#      'parent': {...},
#      'state': Isolation(board=41523141396898493516599231690827775, ply_count=2, locs=(94, 31))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 31,
#      'parent': {...},
#      'state': Isolation(board=41523141396898493516599231690827775, ply_count=2, locs=(94, 31))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 105,
#      'parent': {...},
#      'state': Isolation(board=41482576577691190175751339335739391, ply_count=2, locs=(94, 105))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 105,
#      'parent': {...},
#      'state': Isolation(board=41482576577691190175751339335739391, ply_count=2, locs=(94, 105))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 19,
#      'parent': {...},
#      'state': Isolation(board=41523141396898493516599233837787135, ply_count=2, locs=(94, 19))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 19,
#      'parent': {...},
#      'state': Isolation(board=41523141396898493516599233837787135, ply_count=2, locs=(94, 19))}],
#    'from_action': 94,
#    'parent': {...},
#    'state': Isolation(board=41523141396898493516599233838311423, ply_count=1, locs=(94, None))},
#   {'N': 6,
#    'Q': 0,
#    'children': [{'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 98,
#      'parent': {...},
#      'state': Isolation(board=41522824484248436459248859662510079, ply_count=2, locs=(94, 98))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 98,
#      'parent': {...},
#      'state': Isolation(board=41522824484248436459248859662510079, ply_count=2, locs=(94, 98))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 41,
#      'parent': {...},
#      'state': Isolation(board=41523141396898493516597034815055871, ply_count=2, locs=(94, 41))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 41,
#      'parent': {...},
#      'state': Isolation(board=41523141396898493516597034815055871, ply_count=2, locs=(94, 41))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 31,
#      'parent': {...},
#      'state': Isolation(board=41523141396898493516599231690827775, ply_count=2, locs=(94, 31))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 31,
#      'parent': {...},
#      'state': Isolation(board=41523141396898493516599231690827775, ply_count=2, locs=(94, 31))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 105,
#      'parent': {...},
#      'state': Isolation(board=41482576577691190175751339335739391, ply_count=2, locs=(94, 105))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 105,
#      'parent': {...},
#      'state': Isolation(board=41482576577691190175751339335739391, ply_count=2, locs=(94, 105))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 19,
#      'parent': {...},
#      'state': Isolation(board=41523141396898493516599233837787135, ply_count=2, locs=(94, 19))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 19,
#      'parent': {...},
#      'state': Isolation(board=41523141396898493516599233837787135, ply_count=2, locs=(94, 19))}],
#    'from_action': 94,
#    'parent': {...},
#    'state': Isolation(board=41523141396898493516599233838311423, ply_count=1, locs=(94, None))},
#   {'N': 6,
#    'Q': 0,
#    'children': [{'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 48,
#      'parent': {...},
#      'state': Isolation(board=41523161165253495854734023656990719, ply_count=2, locs=(85, 48))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 48,
#      'parent': {...},
#      'state': Isolation(board=41523161165253495854734023656990719, ply_count=2, locs=(85, 48))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 40,
#      'parent': {...},
#      'state': Isolation(board=41523161165253495855014399122073599, ply_count=2, locs=(85, 40))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 40,
#      'parent': {...},
#      'state': Isolation(board=41523161165253495855014399122073599, ply_count=2, locs=(85, 40))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 68,
#      'parent': {...},
#      'state': Isolation(board=41523161165253200707110319280875519, ply_count=2, locs=(85, 68))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 68,
#      'parent': {...},
#      'state': Isolation(board=41523161165253200707110319280875519, ply_count=2, locs=(85, 68))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 69,
#      'parent': {...},
#      'state': Isolation(board=41523161165252905559205139928049663, ply_count=2, locs=(85, 69))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 69,
#      'parent': {...},
#      'state': Isolation(board=41523161165252905559205139928049663, ply_count=2, locs=(85, 69))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 96,
#      'parent': {...},
#      'state': Isolation(board=41523081937090981590677905089751039, ply_count=2, locs=(85, 96))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 96,
#      'parent': {...},
#      'state': Isolation(board=41523081937090981590677905089751039, ply_count=2, locs=(85, 96))}],
#    'from_action': 85,
#    'parent': {...},
#    'state': Isolation(board=41523161165253495855015498633701375, ply_count=1, locs=(85, None))},
#   {'N': 6,
#    'Q': 0,
#    'children': [{'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 48,
#      'parent': {...},
#      'state': Isolation(board=41523161165253495854734023656990719, ply_count=2, locs=(85, 48))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 48,
#      'parent': {...},
#      'state': Isolation(board=41523161165253495854734023656990719, ply_count=2, locs=(85, 48))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 40,
#      'parent': {...},
#      'state': Isolation(board=41523161165253495855014399122073599, ply_count=2, locs=(85, 40))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 40,
#      'parent': {...},
#      'state': Isolation(board=41523161165253495855014399122073599, ply_count=2, locs=(85, 40))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 68,
#      'parent': {...},
#      'state': Isolation(board=41523161165253200707110319280875519, ply_count=2, locs=(85, 68))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 68,
#      'parent': {...},
#      'state': Isolation(board=41523161165253200707110319280875519, ply_count=2, locs=(85, 68))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 69,
#      'parent': {...},
#      'state': Isolation(board=41523161165252905559205139928049663, ply_count=2, locs=(85, 69))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 69,
#      'parent': {...},
#      'state': Isolation(board=41523161165252905559205139928049663, ply_count=2, locs=(85, 69))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 96,
#      'parent': {...},
#      'state': Isolation(board=41523081937090981590677905089751039, ply_count=2, locs=(85, 96))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 96,
#      'parent': {...},
#      'state': Isolation(board=41523081937090981590677905089751039, ply_count=2, locs=(85, 96))}],
#    'from_action': 85,
#    'parent': {...},
#    'state': Isolation(board=41523161165253495855015498633701375, ply_count=1, locs=(85, None))},
#   {'N': 1,
#    'Q': -1,
#    'children': [],
#    'from_action': 33,
#    'parent': {...},
#    'state': Isolation(board=41523161203939122082683623634364415, ply_count=1, locs=(33, None))},
#   {'N': 1,
#    'Q': -1,
#    'children': [],
#    'from_action': 33,
#    'parent': {...},
#    'state': Isolation(board=41523161203939122082683623634364415, ply_count=1, locs=(33, None))},
#   {'N': 3,
#    'Q': -1,
#    'children': [{'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 44,
#      'parent': {...},
#      'state': Isolation(board=41523161203929677349700300747827199, ply_count=2, locs=(73, 44))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 44,
#      'parent': {...},
#      'state': Isolation(board=41523161203929677349700300747827199, ply_count=2, locs=(73, 44))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 40,
#      'parent': {...},
#      'state': Isolation(board=41523161203929677349716793422243839, ply_count=2, locs=(73, 40))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 40,
#      'parent': {...},
#      'state': Isolation(board=41523161203929677349716793422243839, ply_count=2, locs=(73, 40))}],
#    'from_action': 73,
#    'parent': {...},
#    'state': Isolation(board=41523161203929677349717892933871615, ply_count=1, locs=(73, None))},
#   {'N': 3,
#    'Q': -1,
#    'children': [{'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 44,
#      'parent': {...},
#      'state': Isolation(board=41523161203929677349700300747827199, ply_count=2, locs=(73, 44))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 44,
#      'parent': {...},
#      'state': Isolation(board=41523161203929677349700300747827199, ply_count=2, locs=(73, 44))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 40,
#      'parent': {...},
#      'state': Isolation(board=41523161203929677349716793422243839, ply_count=2, locs=(73, 40))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 40,
#      'parent': {...},
#      'state': Isolation(board=41523161203929677349716793422243839, ply_count=2, locs=(73, 40))}],
#    'from_action': 73,
#    'parent': {...},
#    'state': Isolation(board=41523161203929677349717892933871615, ply_count=1, locs=(73, None))},
#   {'N': 15,
#    'Q': 3,
#    'children': [{'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 73,
#      'parent': {...},
# ...
#      'from_action': 14,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122082683632224282591, ply_count=2, locs=(5, 14))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 20,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122082683632223250399, ply_count=2, locs=(5, 20))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 20,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122082683632223250399, ply_count=2, locs=(5, 20))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 61,
#      'parent': {...},
#      'state': Isolation(board=41523161203939119776840623010605023, ply_count=2, locs=(5, 61))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 61,
#      'parent': {...},
#      'state': Isolation(board=41523161203939119776840623010605023, ply_count=2, locs=(5, 61))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 39,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122082683082468485087, ply_count=2, locs=(5, 39))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 39,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122082683082468485087, ply_count=2, locs=(5, 39))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 94,
#      'parent': {...},
#      'state': Isolation(board=41523141396898493516599233838311391, ply_count=2, locs=(5, 94))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 94,
#      'parent': {...},
#      'state': Isolation(board=41523141396898493516599233838311391, ply_count=2, locs=(5, 94))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 15,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122082683632224266207, ply_count=2, locs=(5, 15))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 15,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122082683632224266207, ply_count=2, locs=(5, 15))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 13,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122082683632224290783, ply_count=2, locs=(5, 13))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 13,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122082683632224290783, ply_count=2, locs=(5, 13))}],
#    'from_action': 5,
#    'parent': {...},
#    'state': Isolation(board=41523161203939122082683632224298975, ply_count=1, locs=(5, None))},
#   {'N': 25,
#    'Q': 7,
#    'children': [{'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 2,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122082683632224298971, ply_count=2, locs=(5, 2))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 2,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122082683632224298971, ply_count=2, locs=(5, 2))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 106,
#      'parent': {...},
#      'state': Isolation(board=41442031565524515400987843219154911, ply_count=2, locs=(5, 106))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 106,
#      'parent': {...},
#      'state': Isolation(board=41442031565524515400987843219154911, ply_count=2, locs=(5, 106))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 107,
#      'parent': {...},
#      'state': Isolation(board=41360901927109908719292054214010847, ply_count=2, locs=(5, 107))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 107,
#      'parent': {...},
#      'state': Isolation(board=41360901927109908719292054214010847, ply_count=2, locs=(5, 107))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 27,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122082683632090081247, ply_count=2, locs=(5, 27))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 27,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122082683632090081247, ply_count=2, locs=(5, 27))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 3,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122082683632224298967, ply_count=2, locs=(5, 3))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 3,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122082683632224298967, ply_count=2, locs=(5, 3))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 46,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122082613263480121311, ply_count=2, locs=(5, 46))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 46,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122082613263480121311, ply_count=2, locs=(5, 46))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 96,
#      'parent': {...},
#      'state': Isolation(board=41523081975776607818346038680348639, ply_count=2, locs=(5, 96))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 96,
#      'parent': {...},
#      'state': Isolation(board=41523081975776607818346038680348639, ply_count=2, locs=(5, 96))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 60,
#      'parent': {...},
#      'state': Isolation(board=41523161203939120929762127617451999, ply_count=2, locs=(5, 60))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 60,
#      'parent': {...},
#      'state': Isolation(board=41523161203939120929762127617451999, ply_count=2, locs=(5, 60))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 47,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122082542894735943647, ply_count=2, locs=(5, 47))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 47,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122082542894735943647, ply_count=2, locs=(5, 47))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 22,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122082683632220104671, ply_count=2, locs=(5, 22))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 22,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122082683632220104671, ply_count=2, locs=(5, 22))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 19,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122082683632223774687, ply_count=2, locs=(5, 19))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 19,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122082683632223774687, ply_count=2, locs=(5, 19))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 55,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122046654835205335007, ply_count=2, locs=(5, 55))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 55,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122046654835205335007, ply_count=2, locs=(5, 55))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 101,
#      'parent': {...},
#      'state': Isolation(board=41520625902738665623880638817888223, ply_count=2, locs=(5, 101))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 101,
#      'parent': {...},
#      'state': Isolation(board=41520625902738665623880638817888223, ply_count=2, locs=(5, 101))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 104,
#      'parent': {...},
#      'state': Isolation(board=41502878794335470412259684973012959, ply_count=2, locs=(5, 104))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 104,
#      'parent': {...},
#      'state': Isolation(board=41502878794335470412259684973012959, ply_count=2, locs=(5, 104))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 87,
#      'parent': {...},
#      'state': Isolation(board=41523161049196617172011097861908447, ply_count=2, locs=(5, 87))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 87,
#      'parent': {...},
#      'state': Isolation(board=41523161049196617172011097861908447, ply_count=2, locs=(5, 87))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 17,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122082683632224167903, ply_count=2, locs=(5, 17))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 17,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122082683632224167903, ply_count=2, locs=(5, 17))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 82,
#      'parent': {...},
#      'state': Isolation(board=41523161199103418804225115525474271, ply_count=2, locs=(5, 82))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 82,
#      'parent': {...},
#      'state': Isolation(board=41523161199103418804225115525474271, ply_count=2, locs=(5, 82))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 14,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122082683632224282591, ply_count=2, locs=(5, 14))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 14,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122082683632224282591, ply_count=2, locs=(5, 14))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 20,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122082683632223250399, ply_count=2, locs=(5, 20))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 20,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122082683632223250399, ply_count=2, locs=(5, 20))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 61,
#      'parent': {...},
#      'state': Isolation(board=41523161203939119776840623010605023, ply_count=2, locs=(5, 61))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 61,
#      'parent': {...},
#      'state': Isolation(board=41523161203939119776840623010605023, ply_count=2, locs=(5, 61))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 39,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122082683082468485087, ply_count=2, locs=(5, 39))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 39,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122082683082468485087, ply_count=2, locs=(5, 39))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 94,
#      'parent': {...},
#      'state': Isolation(board=41523141396898493516599233838311391, ply_count=2, locs=(5, 94))},
#     {'N': 1,
#      'Q': 1,
#      'children': [],
#      'from_action': 94,
#      'parent': {...},
#      'state': Isolation(board=41523141396898493516599233838311391, ply_count=2, locs=(5, 94))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 15,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122082683632224266207, ply_count=2, locs=(5, 15))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 15,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122082683632224266207, ply_count=2, locs=(5, 15))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 13,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122082683632224290783, ply_count=2, locs=(5, 13))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 13,
#      'parent': {...},
#      'state': Isolation(board=41523161203939122082683632224290783, ply_count=2, locs=(5, 13))}],
#    'from_action': 5,
#    'parent': {...},
#    'state': Isolation(board=41523161203939122082683632224298975, ply_count=1, locs=(5, None))},
#   {'N': 1,
#    'Q': -1,
#    'children': [],
#    'from_action': 48,
#    'parent': {...},
#    'state': Isolation(board=41523161203939122082402157247588351, ply_count=1, locs=(48, None))},
#   {'N': 1,
#    'Q': -1,
#    'children': [],
#    'from_action': 48,
#    'parent': {...},
#    'state': Isolation(board=41523161203939122082402157247588351, ply_count=1, locs=(48, None))},
#   {'N': 1,
#    'Q': -1,
#    'children': [],
#    'from_action': 36,
#    'parent': {...},
#    'state': Isolation(board=41523161203939122082683563504822271, ply_count=1, locs=(36, None))},
#   {'N': 1,
#    'Q': -1,
#    'children': [],
#    'from_action': 36,
#    'parent': {...},
#    'state': Isolation(board=41523161203939122082683563504822271, ply_count=1, locs=(36, None))},
#   {'N': 2,
#    'Q': 0,
#    'children': [{'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 17,
#      'parent': {...},
#      'state': Isolation(board=41523156252178964941162532627671039, ply_count=2, locs=(92, 17))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 17,
#      'parent': {...},
#      'state': Isolation(board=41523156252178964941162532627671039, ply_count=2, locs=(92, 17))}],
#    'from_action': 92,
#    'parent': {...},
#    'state': Isolation(board=41523156252178964941162532627802111, ply_count=1, locs=(92, None))},
#   {'N': 2,
#    'Q': 0,
#    'children': [{'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 17,
#      'parent': {...},
#      'state': Isolation(board=41523156252178964941162532627671039, ply_count=2, locs=(92, 17))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 17,
#      'parent': {...},
#      'state': Isolation(board=41523156252178964941162532627671039, ply_count=2, locs=(92, 17))}],
#    'from_action': 92,
#    'parent': {...},
#    'state': Isolation(board=41523156252178964941162532627802111, ply_count=1, locs=(92, None))},
#   {'N': 2,
#    'Q': 0,
#    'children': [{'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 53,
#      'parent': {...},
#      'state': Isolation(board=41523161203938531777866074263906303, ply_count=2, locs=(69, 53))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 53,
#      'parent': {...},
#      'state': Isolation(board=41523161203938531777866074263906303, ply_count=2, locs=(69, 53))}],
#    'from_action': 69,
#    'parent': {...},
#    'state': Isolation(board=41523161203938531786873273518647295, ply_count=1, locs=(69, None))},
#   {'N': 2,
#    'Q': 0,
#    'children': [{'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 53,
#      'parent': {...},
#      'state': Isolation(board=41523161203938531777866074263906303, ply_count=2, locs=(69, 53))},
#     {'N': 1,
#      'Q': -1,
#      'children': [],
#      'from_action': 53,
#      'parent': {...},
#      'state': Isolation(board=41523161203938531777866074263906303, ply_count=2, locs=(69, 53))}],
#    'from_action': 69,
#    'parent': {...},
#    'state': Isolation(board=41523161203938531786873273518647295, ply_count=1, locs=(69, None))},
#   {'N': 1,
#    'Q': -1,
#    'children': [],
#    'from_action': 42,
#    'parent': {...},
#    'state': Isolation(board=41523161203939122082679234177787903, ply_count=1, locs=(42, None))},
#   {'N': 1,
#    'Q': -1,
#    'children': [],
#    'from_action': 42,
#    'parent': {...},
#    'state': Isolation(board=41523161203939122082679234177787903, ply_count=1, locs=(42, None))},
#   {'N': 1,
#    'Q': -1,
#    'children': [],
#    'from_action': 31,
#    'parent': {...},
#    'state': Isolation(board=41523161203939122082683630076815359, ply_count=1, locs=(31, None))},
#   {'N': 1,
#    'Q': -1,
#    'children': [],
#    'from_action': 31,
#    'parent': {...},
#    'state': Isolation(board=41523161203939122082683630076815359, ply_count=1, locs=(31, None))},
#   {'N': 1,
#    'Q': -1,
#    'children': [],
#    'from_action': 28,
#    'parent': {...},
#    'state': Isolation(board=41523161203939122082683631955863551, ply_count=1, locs=(28, None))},
#   {'N': 1,
#    'Q': -1,
#    'children': [],
#    'from_action': 28,
#    'parent': {...},
#    'state': Isolation(board=41523161203939122082683631955863551, ply_count=1, locs=(28, None))}],
#  'from_action': None,
#  'parent': None,
#  'state': Isolation(board=41523161203939122082683632224299007, ply_count=0, locs=(None, None))}

# %%
from time import time
batch_size = 10

while True:
    t0 = time()
    for i in range(batch_size):
        action, nodes = uct_search(root_n, book, depth, nodes)
        print('iter {}: action {}, nodes {}'.format(i, action, len(nodes)))
    # print([str(state) for state in nodes.keys()])
    print('Saving nodes...')
    with open('nodes.pkl', 'wb') as file:
        pickle.dump(nodes, file)
    print('Saving book...')
    with open('tree_book.pkl', 'wb') as file:
        pickle.dump(book, file)
    batch_time = time() - t0
    print('Elapsed time: {} ({} seconds per iter)'.format(batch_time, batch_time/ batch_size))
# Out:
# iter 0: action 19, nodes 4029
# iter 1: action 19, nodes 4030
# iter 2: action 19, nodes 4030
# iter 3: action 61, nodes 4030
# iter 4: action 61, nodes 4031
# iter 5: action 61, nodes 4032
# iter 6: action 61, nodes 4033
# iter 7: action 61, nodes 4034
# iter 8: action 19, nodes 4035
# iter 9: action 19, nodes 4036
# Saving nodes...
# Saving book...
# Elapsed time: 122.22043561935425 (12.222043561935426 seconds per iter)
# iter 0: action 19, nodes 4037
# iter 1: action 19, nodes 4038
# iter 2: action 19, nodes 4039
# iter 3: action 80, nodes 4040
# iter 4: action 80, nodes 4040
# iter 5: action 19, nodes 4041
# iter 6: action 19, nodes 4042
# iter 7: action 19, nodes 4043
# iter 8: action 19, nodes 4044
# iter 9: action 19, nodes 4044
# Saving nodes...
# Saving book...
# Elapsed time: 134.82866883277893 (13.482866883277893 seconds per iter)
# iter 0: action 19, nodes 4044
# iter 1: action 29, nodes 4044
# iter 2: action 29, nodes 4045
# iter 3: action 29, nodes 4045
# iter 4: action 29, nodes 4046
# iter 5: action 29, nodes 4047
# iter 6: action 19, nodes 4047
# iter 7: action 29, nodes 4047
# iter 8: action 19, nodes 4048
# iter 9: action 19, nodes 4048
# Saving nodes...
# Saving book...
# Elapsed time: 126.71288561820984 (12.671288561820983 seconds per iter)
# iter 0: action 19, nodes 4049
# iter 1: action 29, nodes 4050
# iter 2: action 19, nodes 4050
# iter 3: action 19, nodes 4050
# iter 4: action 19, nodes 4050
# iter 5: action 19, nodes 4050
# iter 6: action 19, nodes 4051
# iter 7: action 19, nodes 4052
# iter 8: action 19, nodes 4053
# iter 9: action 19, nodes 4054
# Saving nodes...
# Saving book...
# Elapsed time: 132.47190761566162 (13.247190761566163 seconds per iter)
# iter 0: action 19, nodes 4055
# iter 1: action 19, nodes 4056
# iter 2: action 19, nodes 4057
# iter 3: action 19, nodes 4057
# iter 4: action 19, nodes 4058
# iter 5: action 19, nodes 4059
# iter 6: action 19, nodes 4059
# iter 7: action 19, nodes 4059
# iter 8: action 22, nodes 4060
# iter 9: action 19, nodes 4060
# Saving nodes...
# Saving book...
# Elapsed time: 128.6633641719818 (12.86633641719818 seconds per iter)
# iter 0: action 19, nodes 4061
# iter 1: action 19, nodes 4061
# iter 2: action 19, nodes 4061
# iter 3: action 19, nodes 4062
# iter 4: action 101, nodes 4063
# iter 5: action 101, nodes 4064
# iter 6: action 101, nodes 4065
# iter 7: action 101, nodes 4066
# iter 8: action 101, nodes 4067
# iter 9: action 19, nodes 4068
# Saving nodes...
# Saving book...
# Elapsed time: 140.15850377082825 (14.015850377082824 seconds per iter)
# iter 0: action 19, nodes 4069
# iter 1: action 19, nodes 4070
# iter 2: action 19, nodes 4071
# iter 3: action 19, nodes 4071
# iter 4: action 19, nodes 4071
# iter 5: action 4, nodes 4071
# iter 6: action 4, nodes 4072
# iter 7: action 4, nodes 4073
# iter 8: action 4, nodes 4074
# iter 9: action 4, nodes 4074
# Saving nodes...
# Saving book...
# Elapsed time: 117.42412185668945 (11.742412185668945 seconds per iter)
# iter 0: action 19, nodes 4075
# iter 1: action 19, nodes 4075
# iter 2: action 19, nodes 4075
# iter 3: action 19, nodes 4076
# iter 4: action 19, nodes 4077
# iter 5: action 19, nodes 4078
# iter 6: action 19, nodes 4078
# iter 7: action 19, nodes 4078
# iter 8: action 19, nodes 4078
# iter 9: action 79, nodes 4079
# Saving nodes...
# Saving book...
# Elapsed time: 147.21325731277466 (14.721325731277465 seconds per iter)
# iter 0: action 19, nodes 4079
# iter 1: action 19, nodes 4079
# iter 2: action 19, nodes 4079
# iter 3: action 19, nodes 4080
# iter 4: action 19, nodes 4081
# iter 5: action 19, nodes 4082
# iter 6: action 19, nodes 4082
# iter 7: action 19, nodes 4083
# iter 8: action 19, nodes 4084
# iter 9: action 19, nodes 4085
# Saving nodes...
# Saving book...
# Elapsed time: 132.77141547203064 (13.277141547203064 seconds per iter)
# iter 0: action 19, nodes 4086
# iter 1: action 1, nodes 4087
# iter 2: action 1, nodes 4088
# iter 3: action 19, nodes 4088
# iter 4: action 19, nodes 4088
# iter 5: action 19, nodes 4089
# iter 6: action 19, nodes 4090
# iter 7: action 19, nodes 4091
# iter 8: action 19, nodes 4092
# iter 9: action 19, nodes 4093
# Saving nodes...
# Saving book...
# Elapsed time: 142.66927576065063 (14.266927576065063 seconds per iter)
# iter 0: action 19, nodes 4094
# iter 1: action 19, nodes 4094
# iter 2: action 19, nodes 4094
# iter 3: action 69, nodes 4095
# iter 4: action 19, nodes 4096
# iter 5: action 19, nodes 4097
# iter 6: action 69, nodes 4098
# iter 7: action 69, nodes 4099
# iter 8: action 69, nodes 4100
# iter 9: action 69, nodes 4101
# Saving nodes...
# Saving book...
# Elapsed time: 144.45229578018188 (14.44522957801819 seconds per iter)
# iter 0: action 69, nodes 4102
# iter 1: action 69, nodes 4103
# iter 2: action 69, nodes 4104
# iter 3: action 69, nodes 4105
# iter 4: action 69, nodes 4106
# iter 5: action 69, nodes 4107
# iter 6: action 69, nodes 4108
# iter 7: action 69, nodes 4109
# iter 8: action 69, nodes 4110
# iter 9: action 69, nodes 4111
# Saving nodes...
# Saving book...
# Elapsed time: 118.34033226966858 (11.834033226966858 seconds per iter)
# iter 0: action 19, nodes 4112
# iter 1: action 19, nodes 4113
# iter 2: action 19, nodes 4114
# iter 3: action 19, nodes 4115
# iter 4: action 19, nodes 4115
# iter 5: action 19, nodes 4116
# iter 6: action 19, nodes 4116
# iter 7: action 19, nodes 4117
# iter 8: action 19, nodes 4117
# iter 9: action 19, nodes 4117
# Saving nodes...
# Saving book...
# Elapsed time: 135.11070346832275 (13.511070346832275 seconds per iter)
# iter 0: action 19, nodes 4117
# iter 1: action 19, nodes 4117
# iter 2: action 19, nodes 4117
# iter 3: action 19, nodes 4118
# iter 4: action 19, nodes 4119
# iter 5: action 19, nodes 4120
# iter 6: action 19, nodes 4121
# iter 7: action 19, nodes 4122
# iter 8: action 19, nodes 4122
# iter 9: action 19, nodes 4123
# Saving nodes...
# Saving book...
# Elapsed time: 150.0983636379242 (15.00983636379242 seconds per iter)
# iter 0: action 19, nodes 4123
# iter 1: action 19, nodes 4124
# iter 2: action 19, nodes 4125
# iter 3: action 19, nodes 4126
# iter 4: action 19, nodes 4127
# iter 5: action 19, nodes 4128
# iter 6: action 19, nodes 4129
# iter 7: action 19, nodes 4130
# iter 8: action 19, nodes 4131
# iter 9: action 19, nodes 4132
# Saving nodes...
# Saving book...
# Elapsed time: 128.08443880081177 (12.808443880081176 seconds per iter)
# iter 0: action 19, nodes 4133
# iter 1: action 19, nodes 4134
# iter 2: action 19, nodes 4134
# iter 3: action 19, nodes 4135
# iter 4: action 19, nodes 4135
# iter 5: action 19, nodes 4136
# iter 6: action 75, nodes 4137
# iter 7: action 19, nodes 4138
# iter 8: action 75, nodes 4139
# iter 9: action 75, nodes 4140
# Saving nodes...
# Saving book...
# Elapsed time: 130.53457021713257 (13.053457021713257 seconds per iter)
# iter 0: action 75, nodes 4141
# iter 1: action 75, nodes 4142
# iter 2: action 75, nodes 4143
# iter 3: action 75, nodes 4144
# iter 4: action 75, nodes 4144
# iter 5: action 19, nodes 4145
# iter 6: action 19, nodes 4146
# iter 7: action 19, nodes 4147
# iter 8: action 19, nodes 4148
# iter 9: action 54, nodes 4149
# Saving nodes...
# Saving book...
# Elapsed time: 119.34754729270935 (11.934754729270935 seconds per iter)
# iter 0: action 54, nodes 4149
# iter 1: action 19, nodes 4150
# iter 2: action 54, nodes 4151
# iter 3: action 54, nodes 4151
# iter 4: action 19, nodes 4152
# iter 5: action 19, nodes 4153
# iter 6: action 19, nodes 4154
# iter 7: action 19, nodes 4155
# iter 8: action 19, nodes 4156
# iter 9: action 19, nodes 4157
# Saving nodes...
# Saving book...
# Elapsed time: 122.27409291267395 (12.227409291267396 seconds per iter)
# iter 0: action 19, nodes 4158
# iter 1: action 19, nodes 4159
# iter 2: action 19, nodes 4160
# iter 3: action 19, nodes 4160
# iter 4: action 19, nodes 4161
# iter 5: action 19, nodes 4162
# iter 6: action 19, nodes 4162
# iter 7: action 19, nodes 4163
# iter 8: action 19, nodes 4164
# iter 9: action 19, nodes 4164
# Saving nodes...
# Saving book...
# Elapsed time: 125.28871870040894 (12.528871870040893 seconds per iter)
# iter 0: action 19, nodes 4164
# iter 1: action 19, nodes 4164
# iter 2: action 17, nodes 4165
# iter 3: action 17, nodes 4165
# iter 4: action 19, nodes 4166
# iter 5: action 19, nodes 4167
# iter 6: action 19, nodes 4168
# iter 7: action 19, nodes 4169
# iter 8: action 19, nodes 4169
# iter 9: action 19, nodes 4169
# Saving nodes...
# Saving book...
# Elapsed time: 131.76088690757751 (13.176088690757751 seconds per iter)
# iter 0: action 19, nodes 4169
# iter 1: action 19, nodes 4169
# iter 2: action 19, nodes 4169
# iter 3: action 19, nodes 4170
# iter 4: action 19, nodes 4170
# iter 5: action 19, nodes 4170
# iter 6: action 19, nodes 4170
# iter 7: action 19, nodes 4171
# iter 8: action 19, nodes 4172
# iter 9: action 19, nodes 4172
# Saving nodes...
# Saving book...
# Elapsed time: 133.7318274974823 (13.37318274974823 seconds per iter)
# iter 0: action 19, nodes 4172
# iter 1: action 19, nodes 4172
# iter 2: action 19, nodes 4173
# iter 3: action 19, nodes 4174
# iter 4: action 19, nodes 4175
# iter 5: action 19, nodes 4176
# iter 6: action 19, nodes 4177
# iter 7: action 19, nodes 4178
# iter 8: action 19, nodes 4178
# iter 9: action 19, nodes 4179
# Saving nodes...
# Saving book...
# Elapsed time: 152.14204239845276 (15.214204239845277 seconds per iter)
# iter 0: action 19, nodes 4180
# iter 1: action 19, nodes 4181
# iter 2: action 19, nodes 4182
# iter 3: action 19, nodes 4183
# iter 4: action 19, nodes 4184
# iter 5: action 19, nodes 4185
# iter 6: action 19, nodes 4186
# iter 7: action 19, nodes 4186
# iter 8: action 19, nodes 4186
# iter 9: action 19, nodes 4186
# Saving nodes...
# Saving book...
# Elapsed time: 139.11575198173523 (13.911575198173523 seconds per iter)
# iter 0: action 19, nodes 4187
# iter 1: action 19, nodes 4188
# iter 2: action 19, nodes 4188
# iter 3: action 19, nodes 4188
# iter 4: action 19, nodes 4189
# iter 5: action 19, nodes 4190
# iter 6: action 19, nodes 4190
# iter 7: action 19, nodes 4191
# iter 8: action 19, nodes 4192
# iter 9: action 19, nodes 4192
# Saving nodes...
# Saving book...
# Elapsed time: 115.26894545555115 (11.526894545555114 seconds per iter)
# iter 0: action 19, nodes 4193
# iter 1: action 19, nodes 4194
# iter 2: action 19, nodes 4194
# iter 3: action 19, nodes 4195
# iter 4: action 19, nodes 4196
# iter 5: action 19, nodes 4197
# iter 6: action 84, nodes 4197
# iter 7: action 19, nodes 4197
# iter 8: action 19, nodes 4198
# iter 9: action 19, nodes 4198
# Saving nodes...
# Saving book...
# Elapsed time: 123.54060196876526 (12.354060196876526 seconds per iter)
# iter 0: action 19, nodes 4198
# iter 1: action 19, nodes 4198
# iter 2: action 19, nodes 4199
# iter 3: action 19, nodes 4200
# iter 4: action 19, nodes 4201
# iter 5: action 19, nodes 4202
# iter 6: action 19, nodes 4203
# iter 7: action 19, nodes 4204
# iter 8: action 19, nodes 4205
# iter 9: action 19, nodes 4205
# Saving nodes...
# Saving book...
# Elapsed time: 122.23161029815674 (12.223161029815675 seconds per iter)
# iter 0: action 19, nodes 4205
# iter 1: action 19, nodes 4205
# iter 2: action 19, nodes 4205
# iter 3: action 75, nodes 4206
# iter 4: action 75, nodes 4207
# iter 5: action 75, nodes 4208
# iter 6: action 75, nodes 4209
# iter 7: action 75, nodes 4210
# iter 8: action 75, nodes 4211
# iter 9: action 75, nodes 4212
# Saving nodes...
# Saving book...
# Elapsed time: 132.0658311843872 (13.20658311843872 seconds per iter)
# iter 0: action 75, nodes 4213
# iter 1: action 75, nodes 4214
# iter 2: action 75, nodes 4215
# iter 3: action 75, nodes 4216
# iter 4: action 75, nodes 4217
# iter 5: action 75, nodes 4218
# iter 6: action 75, nodes 4219
# iter 7: action 75, nodes 4220
# iter 8: action 75, nodes 4221
# iter 9: action 75, nodes 4222
# Saving nodes...
# Saving book...
# Elapsed time: 123.26558780670166 (12.326558780670165 seconds per iter)
# iter 0: action 75, nodes 4223
# iter 1: action 75, nodes 4224
# iter 2: action 75, nodes 4225
# iter 3: action 75, nodes 4225
# iter 4: action 75, nodes 4226
# iter 5: action 75, nodes 4227
# iter 6: action 75, nodes 4227
# iter 7: action 75, nodes 4228
# iter 8: action 75, nodes 4228
# iter 9: action 75, nodes 4229
# Saving nodes...
# Saving book...
# Elapsed time: 129.80227375030518 (12.980227375030518 seconds per iter)
# iter 0: action 75, nodes 4229
# iter 1: action 75, nodes 4230
# iter 2: action 75, nodes 4231
# iter 3: action 75, nodes 4232
# iter 4: action 75, nodes 4233
# iter 5: action 75, nodes 4234
# iter 6: action 75, nodes 4234
# iter 7: action 75, nodes 4235
# iter 8: action 75, nodes 4236
# iter 9: action 75, nodes 4236
# Saving nodes...
# Saving book...
# Elapsed time: 134.6335597038269 (13.46335597038269 seconds per iter)
# iter 0: action 75, nodes 4236
# iter 1: action 75, nodes 4237
# iter 2: action 75, nodes 4238
# iter 3: action 75, nodes 4239
# iter 4: action 75, nodes 4240
# iter 5: action 75, nodes 4241
# iter 6: action 75, nodes 4241
# iter 7: action 75, nodes 4241
# iter 8: action 75, nodes 4242
# iter 9: action 75, nodes 4243
# Saving nodes...
# Saving book...
# Elapsed time: 129.75818967819214 (12.975818967819214 seconds per iter)
# iter 0: action 75, nodes 4244
# iter 1: action 75, nodes 4245
# iter 2: action 75, nodes 4245
# iter 3: action 75, nodes 4246
# iter 4: action 75, nodes 4247
# iter 5: action 75, nodes 4247
# iter 6: action 75, nodes 4247
# iter 7: action 75, nodes 4247
# iter 8: action 75, nodes 4248
# iter 9: action 75, nodes 4249
# Saving nodes...
# Saving book...
# Elapsed time: 124.63516473770142 (12.463516473770142 seconds per iter)
# iter 0: action 75, nodes 4250
# iter 1: action 75, nodes 4251
# iter 2: action 75, nodes 4252
# iter 3: action 75, nodes 4253
# iter 4: action 75, nodes 4253
# iter 5: action 75, nodes 4254
# iter 6: action 75, nodes 4255
# iter 7: action 75, nodes 4255
# iter 8: action 75, nodes 4255
# iter 9: action 75, nodes 4255
# Saving nodes...
# Saving book...
# Elapsed time: 135.80708122253418 (13.580708122253418 seconds per iter)
# iter 0: action 75, nodes 4255
# iter 1: action 75, nodes 4256
# iter 2: action 75, nodes 4257
# iter 3: action 75, nodes 4257
# iter 4: action 75, nodes 4257
# iter 5: action 75, nodes 4257
# iter 6: action 75, nodes 4258
# iter 7: action 75, nodes 4258
# iter 8: action 75, nodes 4258
# iter 9: action 75, nodes 4258
# Saving nodes...
# Saving book...
# Elapsed time: 143.42114877700806 (14.342114877700805 seconds per iter)
# iter 0: action 75, nodes 4259
# iter 1: action 75, nodes 4259
# iter 2: action 75, nodes 4259
# iter 3: action 75, nodes 4259
# iter 4: action 75, nodes 4260
# iter 5: action 75, nodes 4260
# iter 6: action 75, nodes 4260
# iter 7: action 75, nodes 4260
# iter 8: action 75, nodes 4260
# iter 9: action 75, nodes 4260
# Saving nodes...
# Saving book...
# Elapsed time: 139.22425484657288 (13.922425484657287 seconds per iter)
# iter 0: action 75, nodes 4260
# iter 1: action 75, nodes 4260
# iter 2: action 75, nodes 4261
# iter 3: action 75, nodes 4262
# iter 4: action 75, nodes 4262
# iter 5: action 75, nodes 4262
# iter 6: action 75, nodes 4262
# iter 7: action 75, nodes 4263
# iter 8: action 75, nodes 4263
# iter 9: action 75, nodes 4264
# Saving nodes...
# Saving book...
# Elapsed time: 134.07242727279663 (13.407242727279662 seconds per iter)
# iter 0: action 75, nodes 4265
# iter 1: action 75, nodes 4265
# iter 2: action 75, nodes 4265
# iter 3: action 75, nodes 4266
# iter 4: action 75, nodes 4267
# iter 5: action 75, nodes 4268
# iter 6: action 75, nodes 4269
# iter 7: action 75, nodes 4270
# iter 8: action 75, nodes 4270
# iter 9: action 75, nodes 4271
# Saving nodes...
# Saving book...
# Elapsed time: 133.28690004348755 (13.328690004348754 seconds per iter)
# iter 0: action 75, nodes 4272
# iter 1: action 75, nodes 4273
# iter 2: action 75, nodes 4274
# iter 3: action 75, nodes 4275
# iter 4: action 75, nodes 4276
# iter 5: action 75, nodes 4277
# iter 6: action 75, nodes 4277
# iter 7: action 75, nodes 4278
# iter 8: action 75, nodes 4278
# iter 9: action 75, nodes 4278
# Saving nodes...
# Saving book...
# Elapsed time: 133.20017433166504 (13.320017433166504 seconds per iter)
# iter 0: action 75, nodes 4279
# iter 1: action 75, nodes 4280
# iter 2: action 75, nodes 4281
# iter 3: action 75, nodes 4281
# iter 4: action 75, nodes 4281
# iter 5: action 75, nodes 4282
# iter 6: action 75, nodes 4283
# iter 7: action 75, nodes 4284
# iter 8: action 75, nodes 4284
# iter 9: action 75, nodes 4284
# Saving nodes...
# Saving book...
# Elapsed time: 120.97548842430115 (12.097548842430115 seconds per iter)
# iter 0: action 75, nodes 4284
# iter 1: action 29, nodes 4284
# iter 2: action 75, nodes 4285
# iter 3: action 75, nodes 4285
# iter 4: action 75, nodes 4285
# iter 5: action 75, nodes 4285
# iter 6: action 75, nodes 4285
# iter 7: action 75, nodes 4285
# iter 8: action 75, nodes 4286
# iter 9: action 75, nodes 4287
# Saving nodes...
# Saving book...
# Elapsed time: 129.6055347919464 (12.96055347919464 seconds per iter)
# iter 0: action 75, nodes 4288
# iter 1: action 75, nodes 4289
# iter 2: action 75, nodes 4290
# iter 3: action 75, nodes 4291
# iter 4: action 75, nodes 4292
# iter 5: action 75, nodes 4293
# iter 6: action 75, nodes 4294
# iter 7: action 75, nodes 4295
# iter 8: action 75, nodes 4296
# iter 9: action 75, nodes 4297
# Saving nodes...
# Saving book...
# Elapsed time: 113.4459285736084 (11.34459285736084 seconds per iter)
# iter 0: action 75, nodes 4297
# iter 1: action 75, nodes 4297
# iter 2: action 75, nodes 4297
# iter 3: action 75, nodes 4298
# iter 4: action 75, nodes 4298
# iter 5: action 75, nodes 4298
# iter 6: action 75, nodes 4299
# iter 7: action 75, nodes 4299
# iter 8: action 75, nodes 4299
# iter 9: action 75, nodes 4300
# Saving nodes...
# Saving book...
# Elapsed time: 132.08648705482483 (13.208648705482483 seconds per iter)
# iter 0: action 75, nodes 4300
# iter 1: action 75, nodes 4300
# iter 2: action 75, nodes 4300
# iter 3: action 75, nodes 4300
# iter 4: action 75, nodes 4301
# iter 5: action 75, nodes 4302
# iter 6: action 75, nodes 4302
# iter 7: action 75, nodes 4303
# iter 8: action 75, nodes 4304
# iter 9: action 75, nodes 4305
# Saving nodes...
# Saving book...
# Elapsed time: 118.65562057495117 (11.865562057495117 seconds per iter)
# iter 0: action 75, nodes 4306
# iter 1: action 75, nodes 4307
# iter 2: action 75, nodes 4308
# iter 3: action 75, nodes 4309
# iter 4: action 75, nodes 4310
# iter 5: action 75, nodes 4311
# iter 6: action 75, nodes 4311
# iter 7: action 75, nodes 4312
# iter 8: action 75, nodes 4312
# iter 9: action 75, nodes 4312
# Saving nodes...
# Saving book...
# Elapsed time: 129.20964121818542 (12.920964121818542 seconds per iter)
# iter 0: action 75, nodes 4312
# iter 1: action 75, nodes 4313
# iter 2: action 75, nodes 4314
# iter 3: action 75, nodes 4315
# iter 4: action 75, nodes 4316
# iter 5: action 75, nodes 4317
# iter 6: action 75, nodes 4318
# iter 7: action 75, nodes 4318
# iter 8: action 75, nodes 4319
# iter 9: action 75, nodes 4319
# Saving nodes...
# Saving book...
# Elapsed time: 134.11361527442932 (13.411361527442931 seconds per iter)
# iter 0: action 75, nodes 4320
# iter 1: action 75, nodes 4321
# iter 2: action 75, nodes 4322
# iter 3: action 75, nodes 4323
# iter 4: action 70, nodes 4324
# iter 5: action 70, nodes 4325
# iter 6: action 70, nodes 4326
# iter 7: action 70, nodes 4327
# iter 8: action 70, nodes 4328
# iter 9: action 70, nodes 4329
# Saving nodes...
# Saving book...
# Elapsed time: 135.30800557136536 (13.530800557136535 seconds per iter)
# iter 0: action 70, nodes 4330
# iter 1: action 75, nodes 4331
# iter 2: action 75, nodes 4331
# iter 3: action 70, nodes 4332
# iter 4: action 75, nodes 4333
# iter 5: action 75, nodes 4334
# iter 6: action 75, nodes 4334
# iter 7: action 75, nodes 4335
# iter 8: action 75, nodes 4336
# iter 9: action 75, nodes 4337
# Saving nodes...
# Saving book...
# Elapsed time: 119.48825407028198 (11.948825407028199 seconds per iter)
# iter 0: action 75, nodes 4338
# iter 1: action 75, nodes 4339
# iter 2: action 75, nodes 4340
# iter 3: action 75, nodes 4340
# iter 4: action 75, nodes 4341
# iter 5: action 75, nodes 4342
# iter 6: action 75, nodes 4343
# iter 7: action 75, nodes 4344
# iter 8: action 75, nodes 4344
# iter 9: action 75, nodes 4344
# Saving nodes...
# Saving book...
# Elapsed time: 132.62229752540588 (13.262229752540588 seconds per iter)
# iter 0: action 75, nodes 4344
# iter 1: action 75, nodes 4345
# iter 2: action 75, nodes 4346
# iter 3: action 75, nodes 4347
# iter 4: action 75, nodes 4348
# iter 5: action 75, nodes 4349
# iter 6: action 75, nodes 4349
# iter 7: action 75, nodes 4350
# iter 8: action 75, nodes 4350
# iter 9: action 75, nodes 4350
# Saving nodes...
# Saving book...
# Elapsed time: 133.7312421798706 (13.37312421798706 seconds per iter)
# iter 0: action 75, nodes 4351
# iter 1: action 75, nodes 4351
# iter 2: action 75, nodes 4352
# iter 3: action 75, nodes 4353
# iter 4: action 75, nodes 4354
# iter 5: action 75, nodes 4355
# iter 6: action 75, nodes 4355
# iter 7: action 75, nodes 4355
# iter 8: action 75, nodes 4356
# iter 9: action 75, nodes 4357
# Saving nodes...
# Saving book...
# Elapsed time: 128.38821172714233 (12.838821172714233 seconds per iter)
# iter 0: action 75, nodes 4358
# iter 1: action 75, nodes 4358
# iter 2: action 75, nodes 4359
# iter 3: action 75, nodes 4359
# iter 4: action 75, nodes 4360
# iter 5: action 75, nodes 4361
# iter 6: action 75, nodes 4362
# iter 7: action 75, nodes 4362
# iter 8: action 75, nodes 4363
# iter 9: action 75, nodes 4363
# Saving nodes...
# Saving book...
# Elapsed time: 116.9838662147522 (11.698386621475219 seconds per iter)
# iter 0: action 75, nodes 4364
# iter 1: action 75, nodes 4365
# iter 2: action 75, nodes 4366
# iter 3: action 75, nodes 4367
# iter 4: action 75, nodes 4368
# iter 5: action 75, nodes 4369
# iter 6: action 75, nodes 4370
# iter 7: action 75, nodes 4371
# iter 8: action 75, nodes 4371
# iter 9: action 75, nodes 4371
# Saving nodes...
# Saving book...
# Elapsed time: 128.63041710853577 (12.863041710853576 seconds per iter)
# iter 0: action 75, nodes 4372
# iter 1: action 75, nodes 4372
# iter 2: action 75, nodes 4372
# iter 3: action 75, nodes 4372
# iter 4: action 75, nodes 4373
# iter 5: action 75, nodes 4374
# iter 6: action 75, nodes 4375
# iter 7: action 75, nodes 4376
# iter 8: action 75, nodes 4376
# iter 9: action 75, nodes 4377
# Saving nodes...
# Saving book...
# Elapsed time: 150.4018530845642 (15.04018530845642 seconds per iter)
# iter 0: action 75, nodes 4378
# iter 1: action 29, nodes 4378
# iter 2: action 75, nodes 4378
# iter 3: action 75, nodes 4379
# iter 4: action 75, nodes 4379
# iter 5: action 75, nodes 4380
# iter 6: action 75, nodes 4381
# iter 7: action 75, nodes 4382
# iter 8: action 75, nodes 4383
# iter 9: action 75, nodes 4384
# Saving nodes...
# Saving book...
# Elapsed time: 130.56063961982727 (13.056063961982726 seconds per iter)
# iter 0: action 75, nodes 4385
# iter 1: action 75, nodes 4385
# iter 2: action 75, nodes 4385
# iter 3: action 75, nodes 4385
# iter 4: action 75, nodes 4386
# iter 5: action 75, nodes 4387
# iter 6: action 75, nodes 4388
# iter 7: action 75, nodes 4389
# iter 8: action 75, nodes 4389
# iter 9: action 75, nodes 4390
# Saving nodes...
# Saving book...
# Elapsed time: 121.91967964172363 (12.191967964172363 seconds per iter)
# iter 0: action 75, nodes 4391
# iter 1: action 75, nodes 4392
# iter 2: action 75, nodes 4392
# iter 3: action 75, nodes 4392
# iter 4: action 75, nodes 4392
# iter 5: action 75, nodes 4393
# iter 6: action 75, nodes 4393
# iter 7: action 75, nodes 4393
# iter 8: action 75, nodes 4393
# iter 9: action 75, nodes 4393
# Saving nodes...
# Saving book...
# Elapsed time: 127.73657989501953 (12.773657989501952 seconds per iter)
# iter 0: action 75, nodes 4393
# iter 1: action 75, nodes 4394
# iter 2: action 75, nodes 4394
# iter 3: action 75, nodes 4395
# iter 4: action 75, nodes 4395
# iter 5: action 75, nodes 4395
# iter 6: action 75, nodes 4396
# iter 7: action 75, nodes 4397
# iter 8: action 75, nodes 4398
# iter 9: action 75, nodes 4399
# Saving nodes...
# Saving book...
# Elapsed time: 121.9172215461731 (12.19172215461731 seconds per iter)
# iter 0: action 75, nodes 4399
# iter 1: action 75, nodes 4400
# iter 2: action 75, nodes 4401
# iter 3: action 75, nodes 4402
# iter 4: action 75, nodes 4403
# iter 5: action 75, nodes 4403
# iter 6: action 75, nodes 4404
# iter 7: action 75, nodes 4404
# iter 8: action 75, nodes 4405
# iter 9: action 75, nodes 4405
# Saving nodes...
# Saving book...
# Elapsed time: 131.42308259010315 (13.142308259010315 seconds per iter)
# iter 0: action 75, nodes 4405
# iter 1: action 75, nodes 4405
# iter 2: action 75, nodes 4405
# iter 3: action 75, nodes 4405
# iter 4: action 75, nodes 4406
# iter 5: action 75, nodes 4407
# iter 6: action 75, nodes 4408
# iter 7: action 75, nodes 4409
# iter 8: action 75, nodes 4410
# iter 9: action 75, nodes 4411
# Saving nodes...
# Saving book...
# Elapsed time: 135.27436566352844 (13.527436566352844 seconds per iter)
# iter 0: action 75, nodes 4412
# iter 1: action 75, nodes 4413
# iter 2: action 75, nodes 4414
# iter 3: action 75, nodes 4414
# iter 4: action 75, nodes 4415
# iter 5: action 75, nodes 4416
# iter 6: action 75, nodes 4417
# iter 7: action 75, nodes 4417
# iter 8: action 75, nodes 4417
# iter 9: action 75, nodes 4417
# Saving nodes...
# Saving book...
# Elapsed time: 115.99936079978943 (11.599936079978942 seconds per iter)
# iter 0: action 75, nodes 4417
# iter 1: action 75, nodes 4417
# iter 2: action 75, nodes 4417
# iter 3: action 75, nodes 4418
# iter 4: action 75, nodes 4419
# iter 5: action 75, nodes 4419
# iter 6: action 75, nodes 4419
# iter 7: action 75, nodes 4419
# iter 8: action 75, nodes 4420
# iter 9: action 75, nodes 4421
# Saving nodes...
# Saving book...
# Elapsed time: 123.06228446960449 (12.30622844696045 seconds per iter)
# iter 0: action 75, nodes 4422
# iter 1: action 75, nodes 4423
# iter 2: action 75, nodes 4423
# iter 3: action 75, nodes 4423
# iter 4: action 75, nodes 4424
# iter 5: action 75, nodes 4425
# iter 6: action 75, nodes 4426
# iter 7: action 75, nodes 4426
# iter 8: action 75, nodes 4426
# iter 9: action 75, nodes 4426
# Saving nodes...
# Saving book...
# Elapsed time: 125.4368040561676 (12.54368040561676 seconds per iter)
# iter 0: action 75, nodes 4427
# iter 1: action 75, nodes 4428
# iter 2: action 75, nodes 4429
# iter 3: action 75, nodes 4430
# iter 4: action 75, nodes 4431
# iter 5: action 75, nodes 4432
# iter 6: action 75, nodes 4433
# iter 7: action 75, nodes 4433
# iter 8: action 75, nodes 4434
# iter 9: action 75, nodes 4435
# Saving nodes...
# Saving book...
# Elapsed time: 135.07256770133972 (13.507256770133973 seconds per iter)
# iter 0: action 75, nodes 4435
# iter 1: action 75, nodes 4436
# iter 2: action 75, nodes 4437
# iter 3: action 75, nodes 4438
# iter 4: action 75, nodes 4438
# iter 5: action 75, nodes 4439
# iter 6: action 75, nodes 4439
# iter 7: action 75, nodes 4439
# iter 8: action 75, nodes 4439
# iter 9: action 75, nodes 4439
# Saving nodes...
# Saving book...
# Elapsed time: 138.08851838111877 (13.808851838111877 seconds per iter)
# iter 0: action 46, nodes 4439
# iter 1: action 46, nodes 4440
# iter 2: action 75, nodes 4441
# iter 3: action 75, nodes 4442
# iter 4: action 75, nodes 4442
# iter 5: action 75, nodes 4443
# iter 6: action 75, nodes 4444
# iter 7: action 75, nodes 4444
# iter 8: action 46, nodes 4444
# iter 9: action 75, nodes 4444
# Saving nodes...
# Saving book...
# Elapsed time: 129.78352689743042 (12.978352689743042 seconds per iter)
# iter 0: action 75, nodes 4445
# iter 1: action 75, nodes 4445
# iter 2: action 75, nodes 4446
# iter 3: action 75, nodes 4446
# iter 4: action 75, nodes 4446
# iter 5: action 75, nodes 4447
# iter 6: action 75, nodes 4447
# iter 7: action 75, nodes 4448
# iter 8: action 75, nodes 4449
# iter 9: action 75, nodes 4449
# Saving nodes...
# Saving book...
# Elapsed time: 129.2866587638855 (12.92866587638855 seconds per iter)
# iter 0: action 75, nodes 4449
# iter 1: action 75, nodes 4450
# iter 2: action 75, nodes 4450
# iter 3: action 75, nodes 4451
# iter 4: action 75, nodes 4452
# iter 5: action 75, nodes 4453
# iter 6: action 75, nodes 4453
# iter 7: action 75, nodes 4454
# iter 8: action 75, nodes 4455
# iter 9: action 75, nodes 4456
# Saving nodes...
# Saving book...
# Elapsed time: 140.55582523345947 (14.055582523345947 seconds per iter)
# iter 0: action 75, nodes 4457
# iter 1: action 75, nodes 4457
# iter 2: action 75, nodes 4458
# iter 3: action 75, nodes 4459
# iter 4: action 75, nodes 4460
# iter 5: action 75, nodes 4461
# iter 6: action 75, nodes 4462
# iter 7: action 75, nodes 4462
# iter 8: action 75, nodes 4463
# iter 9: action 75, nodes 4464
# Saving nodes...
# Saving book...
# Elapsed time: 124.5988450050354 (12.45988450050354 seconds per iter)
# iter 0: action 75, nodes 4464
# iter 1: action 75, nodes 4465
# iter 2: action 75, nodes 4466
# iter 3: action 75, nodes 4467
# iter 4: action 75, nodes 4467
# iter 5: action 75, nodes 4467
# iter 6: action 75, nodes 4468
# iter 7: action 75, nodes 4469
# iter 8: action 75, nodes 4469
# iter 9: action 75, nodes 4470
# Saving nodes...
# Saving book...
# Elapsed time: 130.08676886558533 (13.008676886558533 seconds per iter)
# iter 0: action 75, nodes 4470
# iter 1: action 75, nodes 4471
# iter 2: action 75, nodes 4472
# iter 3: action 75, nodes 4473
# iter 4: action 75, nodes 4474
# iter 5: action 75, nodes 4474
# iter 6: action 75, nodes 4474
# iter 7: action 75, nodes 4475
# iter 8: action 75, nodes 4475
# iter 9: action 75, nodes 4476
# Saving nodes...
# Saving book...
# Elapsed time: 125.46343088150024 (12.546343088150024 seconds per iter)
# iter 0: action 75, nodes 4476
# iter 1: action 75, nodes 4476
# iter 2: action 75, nodes 4477
# iter 3: action 75, nodes 4477
# iter 4: action 75, nodes 4478
# iter 5: action 75, nodes 4479
# iter 6: action 75, nodes 4480
# iter 7: action 75, nodes 4481
# iter 8: action 75, nodes 4481
# iter 9: action 75, nodes 4481
# Saving nodes...
# Saving book...
# Elapsed time: 126.84131932258606 (12.684131932258605 seconds per iter)
# iter 0: action 29, nodes 4482
# iter 1: action 29, nodes 4482
# iter 2: action 29, nodes 4482
# iter 3: action 29, nodes 4482
# iter 4: action 29, nodes 4482
# iter 5: action 29, nodes 4483
# iter 6: action 29, nodes 4483
# iter 7: action 75, nodes 4483
# iter 8: action 75, nodes 4483
# iter 9: action 75, nodes 4483
# Saving nodes...
# Saving book...
# Elapsed time: 132.46372961997986 (13.246372961997986 seconds per iter)
# iter 0: action 75, nodes 4484
# iter 1: action 75, nodes 4485
# iter 2: action 75, nodes 4486
# iter 3: action 75, nodes 4487
# iter 4: action 75, nodes 4488
# iter 5: action 75, nodes 4489
# iter 6: action 75, nodes 4490
# iter 7: action 75, nodes 4491
# iter 8: action 75, nodes 4492
# iter 9: action 75, nodes 4493
# Saving nodes...
# Saving book...
# Elapsed time: 136.76513600349426 (13.676513600349427 seconds per iter)
# iter 0: action 75, nodes 4494
# iter 1: action 75, nodes 4495
# iter 2: action 75, nodes 4496
# iter 3: action 75, nodes 4497
# iter 4: action 75, nodes 4498
# iter 5: action 75, nodes 4499
# iter 6: action 75, nodes 4500
# iter 7: action 75, nodes 4501
# iter 8: action 75, nodes 4502
# iter 9: action 75, nodes 4503
# Saving nodes...
# Saving book...
# Elapsed time: 123.13560080528259 (12.313560080528259 seconds per iter)
# iter 0: action 75, nodes 4504
# iter 1: action 75, nodes 4505
# iter 2: action 75, nodes 4505
# iter 3: action 75, nodes 4506
# iter 4: action 75, nodes 4507
# iter 5: action 75, nodes 4508
# iter 6: action 75, nodes 4509
# iter 7: action 75, nodes 4510
# iter 8: action 75, nodes 4511
# iter 9: action 75, nodes 4512
# Saving nodes...
# Saving book...
# Elapsed time: 127.98320031166077 (12.798320031166076 seconds per iter)
# iter 0: action 75, nodes 4513
# iter 1: action 75, nodes 4514
# iter 2: action 75, nodes 4515
# iter 3: action 75, nodes 4516
# iter 4: action 75, nodes 4517
# iter 5: action 75, nodes 4518
# iter 6: action 75, nodes 4519
# iter 7: action 75, nodes 4520
# iter 8: action 75, nodes 4521
# iter 9: action 75, nodes 4522
# Saving nodes...
# Saving book...
# Elapsed time: 131.18913865089417 (13.118913865089416 seconds per iter)
# iter 0: action 75, nodes 4522
# iter 1: action 75, nodes 4523
# iter 2: action 75, nodes 4523
# iter 3: action 75, nodes 4523
# iter 4: action 75, nodes 4524
# iter 5: action 75, nodes 4524
# iter 6: action 75, nodes 4525
# iter 7: action 75, nodes 4526
# iter 8: action 75, nodes 4526
# iter 9: action 75, nodes 4527
# Saving nodes...
# Saving book...
# Elapsed time: 131.43963193893433 (13.143963193893432 seconds per iter)
# iter 0: action 75, nodes 4527
# iter 1: action 75, nodes 4527
# iter 2: action 75, nodes 4527
# iter 3: action 75, nodes 4527
# iter 4: action 75, nodes 4528
# iter 5: action 75, nodes 4529
# iter 6: action 75, nodes 4529
# iter 7: action 75, nodes 4530
# iter 8: action 75, nodes 4530
# iter 9: action 75, nodes 4531
# Saving nodes...
# Saving book...
# Elapsed time: 141.82821607589722 (14.182821607589721 seconds per iter)
# iter 0: action 75, nodes 4531
# iter 1: action 75, nodes 4531
# iter 2: action 75, nodes 4532
# iter 3: action 75, nodes 4532
# iter 4: action 75, nodes 4533
# iter 5: action 75, nodes 4534
# iter 6: action 75, nodes 4535
# iter 7: action 75, nodes 4535
# iter 8: action 75, nodes 4536
# iter 9: action 75, nodes 4536
# Saving nodes...
# Saving book...
# Elapsed time: 129.09720277786255 (12.909720277786255 seconds per iter)
# iter 0: action 75, nodes 4537
# iter 1: action 17, nodes 4538
# iter 2: action 17, nodes 4539
# iter 3: action 17, nodes 4540
# iter 4: action 17, nodes 4540
# iter 5: action 17, nodes 4541
# iter 6: action 17, nodes 4542
# iter 7: action 17, nodes 4542
# iter 8: action 17, nodes 4542
# iter 9: action 17, nodes 4542
# Saving nodes...
# Saving book...
# Elapsed time: 124.07604336738586 (12.407604336738586 seconds per iter)
# iter 0: action 17, nodes 4542
# iter 1: action 17, nodes 4543
# iter 2: action 17, nodes 4543
# iter 3: action 17, nodes 4544
# iter 4: action 17, nodes 4544
# iter 5: action 17, nodes 4544
# iter 6: action 17, nodes 4544
# iter 7: action 17, nodes 4545
# iter 8: action 17, nodes 4545
# iter 9: action 17, nodes 4545
# Saving nodes...
# Saving book...
# Elapsed time: 121.41274881362915 (12.141274881362914 seconds per iter)
# iter 0: action 17, nodes 4546
# iter 1: action 17, nodes 4546
# iter 2: action 17, nodes 4546
# iter 3: action 17, nodes 4547
# iter 4: action 17, nodes 4548
# iter 5: action 17, nodes 4548
# iter 6: action 17, nodes 4548
# iter 7: action 17, nodes 4548
# iter 8: action 17, nodes 4548
# iter 9: action 17, nodes 4548
# Saving nodes...
# Saving book...
# Elapsed time: 135.55555653572083 (13.555555653572082 seconds per iter)
# iter 0: action 17, nodes 4549
# iter 1: action 75, nodes 4550
# iter 2: action 17, nodes 4551
# iter 3: action 75, nodes 4551
# iter 4: action 75, nodes 4551
# iter 5: action 75, nodes 4552
# iter 6: action 75, nodes 4552
# iter 7: action 75, nodes 4553
# iter 8: action 75, nodes 4553
# iter 9: action 75, nodes 4554
# Saving nodes...
# Saving book...
# Elapsed time: 121.56619167327881 (12.15661916732788 seconds per iter)
# iter 0: action 75, nodes 4555
# iter 1: action 75, nodes 4556
# iter 2: action 75, nodes 4556
# iter 3: action 75, nodes 4557
# iter 4: action 75, nodes 4558
# iter 5: action 75, nodes 4558
# iter 6: action 75, nodes 4559
# iter 7: action 75, nodes 4560
# iter 8: action 75, nodes 4560
# iter 9: action 75, nodes 4561
# Saving nodes...
# Saving book...
# Elapsed time: 136.13228797912598 (13.613228797912598 seconds per iter)
# iter 0: action 75, nodes 4562
# iter 1: action 75, nodes 4563
# iter 2: action 75, nodes 4564
# iter 3: action 75, nodes 4565
# iter 4: action 75, nodes 4566
# iter 5: action 75, nodes 4567
# iter 6: action 75, nodes 4568
# iter 7: action 75, nodes 4569
# iter 8: action 75, nodes 4570
# iter 9: action 75, nodes 4570
# Saving nodes...
# Saving book...
# Elapsed time: 155.06005263328552 (15.506005263328552 seconds per iter)
# iter 0: action 75, nodes 4571
# iter 1: action 75, nodes 4572
# iter 2: action 75, nodes 4573
# iter 3: action 75, nodes 4574
# iter 4: action 75, nodes 4575
# iter 5: action 75, nodes 4576
# iter 6: action 75, nodes 4576
# iter 7: action 75, nodes 4576
# iter 8: action 75, nodes 4576
# iter 9: action 75, nodes 4576
# Saving nodes...
# Saving book...
# Elapsed time: 142.1852526664734 (14.218525266647339 seconds per iter)
# iter 0: action 75, nodes 4576
# iter 1: action 75, nodes 4576
# iter 2: action 75, nodes 4576
# iter 3: action 75, nodes 4576
# iter 4: action 75, nodes 4577
# iter 5: action 75, nodes 4578
# iter 6: action 75, nodes 4579
# iter 7: action 75, nodes 4579
# iter 8: action 75, nodes 4579
# iter 9: action 54, nodes 4579
# Saving nodes...
# Saving book...
# Elapsed time: 137.6668553352356 (13.76668553352356 seconds per iter)
# iter 0: action 75, nodes 4580
# iter 1: action 75, nodes 4581
# iter 2: action 75, nodes 4582
# iter 3: action 75, nodes 4582
# iter 4: action 75, nodes 4583
# iter 5: action 75, nodes 4583
# iter 6: action 75, nodes 4584
# iter 7: action 75, nodes 4585
# iter 8: action 75, nodes 4586
# iter 9: action 75, nodes 4587
# Saving nodes...
# Saving book...
# Elapsed time: 145.1724238395691 (14.517242383956908 seconds per iter)
# iter 0: action 75, nodes 4587
# iter 1: action 75, nodes 4588
# iter 2: action 75, nodes 4589
# iter 3: action 75, nodes 4590
# iter 4: action 75, nodes 4590
# iter 5: action 75, nodes 4590
# iter 6: action 75, nodes 4591
# iter 7: action 75, nodes 4591
# iter 8: action 75, nodes 4591
# iter 9: action 75, nodes 4591
# Saving nodes...
# Saving book...
# Elapsed time: 148.158442735672 (14.8158442735672 seconds per iter)
# iter 0: action 75, nodes 4591
# iter 1: action 75, nodes 4591
# iter 2: action 75, nodes 4591
# iter 3: action 75, nodes 4591
# iter 4: action 75, nodes 4592
# iter 5: action 75, nodes 4593
# iter 6: action 75, nodes 4594
# iter 7: action 75, nodes 4595
# iter 8: action 75, nodes 4596
# iter 9: action 75, nodes 4596
# Saving nodes...
# Saving book...
# Elapsed time: 132.09959030151367 (13.209959030151367 seconds per iter)
# iter 0: action 75, nodes 4596
# iter 1: action 75, nodes 4596
# iter 2: action 75, nodes 4597
# iter 3: action 75, nodes 4597
# iter 4: action 75, nodes 4597
# iter 5: action 75, nodes 4598
# iter 6: action 75, nodes 4598
# iter 7: action 75, nodes 4598
# iter 8: action 75, nodes 4598
# iter 9: action 75, nodes 4598
# Saving nodes...
# Saving book...
# Elapsed time: 140.12542033195496 (14.012542033195496 seconds per iter)
# iter 0: action 75, nodes 4598
# iter 1: action 75, nodes 4599
# iter 2: action 75, nodes 4600
# iter 3: action 75, nodes 4601
# iter 4: action 75, nodes 4602
# iter 5: action 75, nodes 4603
# iter 6: action 75, nodes 4604
# iter 7: action 75, nodes 4604
# iter 8: action 75, nodes 4604
# iter 9: action 75, nodes 4605
# Saving nodes...
# Saving book...
# Elapsed time: 127.44855546951294 (12.744855546951294 seconds per iter)
# iter 0: action 75, nodes 4605
# iter 1: action 75, nodes 4605
# iter 2: action 75, nodes 4605
# iter 3: action 75, nodes 4606
# iter 4: action 75, nodes 4606
# iter 5: action 75, nodes 4606
# iter 6: action 75, nodes 4607
# iter 7: action 75, nodes 4607
# iter 8: action 75, nodes 4608
# iter 9: action 75, nodes 4608
# Saving nodes...
# Saving book...
# Elapsed time: 128.70523166656494 (12.870523166656493 seconds per iter)
# iter 0: action 75, nodes 4609
# iter 1: action 75, nodes 4609
# iter 2: action 75, nodes 4610
# iter 3: action 75, nodes 4611
# iter 4: action 75, nodes 4612
# iter 5: action 75, nodes 4612
# iter 6: action 75, nodes 4612
# iter 7: action 75, nodes 4612
# iter 8: action 75, nodes 4613
# iter 9: action 75, nodes 4614
# Saving nodes...
# Saving book...
# Elapsed time: 120.4268867969513 (12.042688679695129 seconds per iter)
# iter 0: action 75, nodes 4614
# iter 1: action 75, nodes 4615
# iter 2: action 75, nodes 4615
# iter 3: action 75, nodes 4616
# iter 4: action 75, nodes 4617
# iter 5: action 75, nodes 4618
# iter 6: action 75, nodes 4619
# iter 7: action 75, nodes 4619
# iter 8: action 75, nodes 4620
# iter 9: action 75, nodes 4621
# Saving nodes...
# Saving book...
# Elapsed time: 133.6492280960083 (13.36492280960083 seconds per iter)
# iter 0: action 75, nodes 4622
# iter 1: action 75, nodes 4623
# iter 2: action 75, nodes 4623
# iter 3: action 75, nodes 4623
# iter 4: action 75, nodes 4623
# iter 5: action 75, nodes 4623
# iter 6: action 75, nodes 4623
# iter 7: action 75, nodes 4624
# iter 8: action 75, nodes 4625
# iter 9: action 75, nodes 4626
# Saving nodes...
# Saving book...
# Elapsed time: 130.69169116020203 (13.069169116020202 seconds per iter)
# iter 0: action 75, nodes 4626
# iter 1: action 75, nodes 4627
# iter 2: action 75, nodes 4628
# iter 3: action 75, nodes 4628
# iter 4: action 75, nodes 4629
# iter 5: action 75, nodes 4630
# iter 6: action 75, nodes 4630
# iter 7: action 75, nodes 4631
# iter 8: action 75, nodes 4632
# iter 9: action 75, nodes 4632
# Saving nodes...
# Saving book...
# Elapsed time: 140.09906315803528 (14.009906315803528 seconds per iter)
# iter 0: action 75, nodes 4633
# iter 1: action 75, nodes 4633
# iter 2: action 75, nodes 4633
# iter 3: action 5, nodes 4633
# iter 4: action 75, nodes 4634
# iter 5: action 75, nodes 4635
# iter 6: action 75, nodes 4636
# iter 7: action 75, nodes 4636
# iter 8: action 75, nodes 4637
# iter 9: action 75, nodes 4638
# Saving nodes...
# Saving book...
# Elapsed time: 138.24010634422302 (13.824010634422303 seconds per iter)
# iter 0: action 75, nodes 4639
# iter 1: action 75, nodes 4640
# iter 2: action 73, nodes 4641
# iter 3: action 75, nodes 4642
# iter 4: action 75, nodes 4643
# iter 5: action 75, nodes 4643
# iter 6: action 75, nodes 4644
# iter 7: action 73, nodes 4645
# iter 8: action 73, nodes 4646
# iter 9: action 75, nodes 4647
# Saving nodes...
# Saving book...
# Elapsed time: 123.28460741043091 (12.328460741043092 seconds per iter)
# iter 0: action 73, nodes 4648
# iter 1: action 73, nodes 4649
# iter 2: action 73, nodes 4650
# iter 3: action 73, nodes 4651
# iter 4: action 75, nodes 4652
# iter 5: action 75, nodes 4653
# iter 6: action 75, nodes 4653
# iter 7: action 75, nodes 4654
# iter 8: action 75, nodes 4655
# iter 9: action 75, nodes 4655
# Saving nodes...
# Saving book...
# Elapsed time: 141.07154893875122 (14.107154893875123 seconds per iter)
# iter 0: action 75, nodes 4656
# iter 1: action 75, nodes 4657
# iter 2: action 75, nodes 4658
# iter 3: action 75, nodes 4658
# iter 4: action 75, nodes 4659
# iter 5: action 75, nodes 4660
# iter 6: action 75, nodes 4661
# iter 7: action 75, nodes 4662
# iter 8: action 75, nodes 4663
# iter 9: action 75, nodes 4664
# Saving nodes...
# Saving book...
# Elapsed time: 127.33489108085632 (12.733489108085632 seconds per iter)
# iter 0: action 75, nodes 4665
# iter 1: action 75, nodes 4666
# iter 2: action 75, nodes 4667
# iter 3: action 75, nodes 4667
# iter 4: action 75, nodes 4668
# iter 5: action 105, nodes 4668
# iter 6: action 75, nodes 4668
# iter 7: action 75, nodes 4669
# iter 8: action 75, nodes 4670
# iter 9: action 75, nodes 4671
# Saving nodes...
# Saving book...
# Elapsed time: 119.18678379058838 (11.918678379058838 seconds per iter)
# iter 0: action 75, nodes 4672
# iter 1: action 75, nodes 4673
# iter 2: action 75, nodes 4674
# iter 3: action 75, nodes 4675
# iter 4: action 75, nodes 4675
# iter 5: action 75, nodes 4676
# iter 6: action 75, nodes 4677
# iter 7: action 75, nodes 4678
# iter 8: action 18, nodes 4678
# iter 9: action 18, nodes 4678
# Saving nodes...
# Saving book...
# Elapsed time: 118.79461693763733 (11.879461693763734 seconds per iter)
# iter 0: action 18, nodes 4679
# iter 1: action 18, nodes 4679
# iter 2: action 18, nodes 4680
# iter 3: action 18, nodes 4681
# iter 4: action 18, nodes 4681
# iter 5: action 75, nodes 4682
# iter 6: action 75, nodes 4683
# iter 7: action 75, nodes 4684
# iter 8: action 75, nodes 4684
# iter 9: action 75, nodes 4685
# Saving nodes...
# Saving book...
# Elapsed time: 141.09904527664185 (14.109904527664185 seconds per iter)
# iter 0: action 75, nodes 4686
# iter 1: action 75, nodes 4687
# iter 2: action 75, nodes 4688
# iter 3: action 75, nodes 4689
# iter 4: action 75, nodes 4689
# iter 5: action 75, nodes 4690
# iter 6: action 75, nodes 4691
# iter 7: action 75, nodes 4692
# iter 8: action 75, nodes 4693
# iter 9: action 75, nodes 4693
# Saving nodes...
# Saving book...
# Elapsed time: 134.05135107040405 (13.405135107040405 seconds per iter)
# iter 0: action 75, nodes 4694
# iter 1: action 75, nodes 4695
# iter 2: action 75, nodes 4695
# iter 3: action 75, nodes 4695
# iter 4: action 75, nodes 4695
# iter 5: action 75, nodes 4696
# iter 6: action 75, nodes 4696
# iter 7: action 75, nodes 4696
# iter 8: action 75, nodes 4697
# iter 9: action 75, nodes 4698
# Saving nodes...
# Saving book...
# Elapsed time: 115.20003771781921 (11.520003771781921 seconds per iter)
# iter 0: action 75, nodes 4699
# iter 1: action 75, nodes 4700
# iter 2: action 75, nodes 4701
# iter 3: action 75, nodes 4701
# iter 4: action 75, nodes 4702
# iter 5: action 75, nodes 4703
# iter 6: action 75, nodes 4704
# iter 7: action 75, nodes 4705
# iter 8: action 75, nodes 4706
# iter 9: action 75, nodes 4707
# Saving nodes...
# Saving book...
# Elapsed time: 136.70826387405396 (13.670826387405395 seconds per iter)
# iter 0: action 75, nodes 4708
# iter 1: action 75, nodes 4708
# iter 2: action 75, nodes 4708
# iter 3: action 75, nodes 4708
# iter 4: action 75, nodes 4709
# iter 5: action 75, nodes 4709
# iter 6: action 75, nodes 4709
# iter 7: action 75, nodes 4710
# iter 8: action 75, nodes 4710
# iter 9: action 75, nodes 4711
# Saving nodes...
# Saving book...
# Elapsed time: 122.79879379272461 (12.279879379272462 seconds per iter)
# iter 0: action 75, nodes 4712
# iter 1: action 75, nodes 4713
# iter 2: action 75, nodes 4714
# iter 3: action 75, nodes 4715
# iter 4: action 75, nodes 4716
# iter 5: action 75, nodes 4716
# iter 6: action 75, nodes 4717
# iter 7: action 75, nodes 4718
# iter 8: action 75, nodes 4719
# iter 9: action 75, nodes 4719
# Saving nodes...
# Saving book...
# Elapsed time: 135.83000302314758 (13.583000302314758 seconds per iter)
# iter 0: action 75, nodes 4719
# iter 1: action 75, nodes 4720
# iter 2: action 75, nodes 4721
# iter 3: action 75, nodes 4722
# iter 4: action 75, nodes 4722
# iter 5: action 75, nodes 4723
# iter 6: action 75, nodes 4724
# iter 7: action 75, nodes 4725
# iter 8: action 75, nodes 4725
# iter 9: action 75, nodes 4726
# Saving nodes...
# Saving book...
# Elapsed time: 141.89656257629395 (14.189656257629395 seconds per iter)
# iter 0: action 75, nodes 4727
# iter 1: action 75, nodes 4727
# iter 2: action 75, nodes 4727
# iter 3: action 75, nodes 4727
# iter 4: action 75, nodes 4728
# iter 5: action 75, nodes 4729
# iter 6: action 75, nodes 4730
# iter 7: action 75, nodes 4730
# iter 8: action 75, nodes 4731
# iter 9: action 75, nodes 4732
# Saving nodes...
# Saving book...
# Elapsed time: 129.9767508506775 (12.99767508506775 seconds per iter)
# iter 0: action 75, nodes 4733
# iter 1: action 75, nodes 4734
# iter 2: action 75, nodes 4735
# iter 3: action 75, nodes 4736
# iter 4: action 75, nodes 4737
# iter 5: action 75, nodes 4738
# iter 6: action 75, nodes 4739
# iter 7: action 75, nodes 4740
# iter 8: action 75, nodes 4741
# iter 9: action 75, nodes 4742
# Saving nodes...
# Saving book...
# Elapsed time: 127.7899489402771 (12.77899489402771 seconds per iter)
# iter 0: action 75, nodes 4742
# iter 1: action 75, nodes 4743
# iter 2: action 75, nodes 4744
# iter 3: action 75, nodes 4744
# iter 4: action 75, nodes 4744
# iter 5: action 75, nodes 4744
# iter 6: action 75, nodes 4744
# iter 7: action 75, nodes 4744
# iter 8: action 75, nodes 4745
# iter 9: action 75, nodes 4746
# Saving nodes...
# Saving book...
# Elapsed time: 136.5865740776062 (13.65865740776062 seconds per iter)
# iter 0: action 75, nodes 4747
# iter 1: action 75, nodes 4747
# iter 2: action 29, nodes 4747
# iter 3: action 29, nodes 4747
# iter 4: action 75, nodes 4747
# iter 5: action 75, nodes 4748
# iter 6: action 75, nodes 4749
# iter 7: action 75, nodes 4750
# iter 8: action 75, nodes 4751
# iter 9: action 75, nodes 4752
# Saving nodes...
# Saving book...
# Elapsed time: 128.02131175994873 (12.802131175994873 seconds per iter)
# iter 0: action 75, nodes 4753
# iter 1: action 75, nodes 4754
# iter 2: action 75, nodes 4755
# iter 3: action 75, nodes 4756
# iter 4: action 75, nodes 4757
# iter 5: action 75, nodes 4758
# iter 6: action 29, nodes 4758
# iter 7: action 75, nodes 4758
# iter 8: action 75, nodes 4758
# iter 9: action 75, nodes 4758
# Saving nodes...
# Saving book...
# Elapsed time: 137.33370852470398 (13.733370852470397 seconds per iter)
# iter 0: action 75, nodes 4758
# iter 1: action 75, nodes 4759
# iter 2: action 75, nodes 4760
# iter 3: action 75, nodes 4761
# iter 4: action 75, nodes 4761
# iter 5: action 75, nodes 4761
# iter 6: action 75, nodes 4762
# iter 7: action 75, nodes 4763
# iter 8: action 75, nodes 4763
# iter 9: action 75, nodes 4763
# Saving nodes...
# Saving book...
# Elapsed time: 123.54847717285156 (12.354847717285157 seconds per iter)
# iter 0: action 75, nodes 4764
# iter 1: action 75, nodes 4765
# iter 2: action 75, nodes 4765
# iter 3: action 75, nodes 4765
# iter 4: action 75, nodes 4765
# iter 5: action 75, nodes 4765
# iter 6: action 75, nodes 4766
# iter 7: action 75, nodes 4766
# iter 8: action 75, nodes 4767
# iter 9: action 75, nodes 4768
# Saving nodes...
# Saving book...
# Elapsed time: 123.8506212234497 (12.385062122344971 seconds per iter)
# iter 0: action 75, nodes 4769
# iter 1: action 75, nodes 4770
# iter 2: action 75, nodes 4771
# iter 3: action 75, nodes 4772
# iter 4: action 75, nodes 4773
# iter 5: action 75, nodes 4774
# iter 6: action 75, nodes 4775
# iter 7: action 75, nodes 4776
# iter 8: action 75, nodes 4777
# iter 9: action 75, nodes 4778
# Saving nodes...
# Saving book...
# Elapsed time: 131.09683990478516 (13.109683990478516 seconds per iter)
# iter 0: action 75, nodes 4779
# iter 1: action 75, nodes 4780
# iter 2: action 75, nodes 4781
# iter 3: action 75, nodes 4782
# iter 4: action 75, nodes 4783
# iter 5: action 75, nodes 4783
# iter 6: action 75, nodes 4784
# iter 7: action 75, nodes 4784
# iter 8: action 75, nodes 4784
# iter 9: action 75, nodes 4785
# Saving nodes...
# Saving book...
# Elapsed time: 131.70708584785461 (13.170708584785462 seconds per iter)
# iter 0: action 75, nodes 4786
# iter 1: action 75, nodes 4787
# iter 2: action 75, nodes 4788
# iter 3: action 75, nodes 4789
# iter 4: action 75, nodes 4790
# iter 5: action 75, nodes 4791
# iter 6: action 75, nodes 4792
# ...
# iter 9: action 5, nodes 5517
# Saving nodes...
# Saving book...
# Elapsed time: 134.45900797843933 (13.445900797843933 seconds per iter)
# iter 0: action 5, nodes 5518
# iter 1: action 5, nodes 5519
# iter 2: action 5, nodes 5520
# iter 3: action 5, nodes 5521
# iter 4: action 5, nodes 5522
# iter 5: action 5, nodes 5523
# iter 6: action 5, nodes 5524
# iter 7: action 5, nodes 5525
# iter 8: action 5, nodes 5526
# iter 9: action 5, nodes 5527
# Saving nodes...
# Saving book...
# Elapsed time: 115.42327928543091 (11.542327928543092 seconds per iter)
# iter 0: action 5, nodes 5528
# iter 1: action 5, nodes 5528
# iter 2: action 5, nodes 5529
# iter 3: action 5, nodes 5529
# iter 4: action 5, nodes 5529
# iter 5: action 5, nodes 5529
# iter 6: action 5, nodes 5529
# iter 7: action 5, nodes 5530
# iter 8: action 5, nodes 5531
# iter 9: action 5, nodes 5532
# Saving nodes...
# Saving book...
# Elapsed time: 136.14751482009888 (13.614751482009888 seconds per iter)
# iter 0: action 5, nodes 5533
# iter 1: action 5, nodes 5533
# iter 2: action 5, nodes 5534
# iter 3: action 5, nodes 5535
# iter 4: action 5, nodes 5535
# iter 5: action 5, nodes 5535
# iter 6: action 5, nodes 5536
# iter 7: action 5, nodes 5536
# iter 8: action 5, nodes 5537
# iter 9: action 5, nodes 5538
# Saving nodes...
# Saving book...
# Elapsed time: 130.7092878818512 (13.07092878818512 seconds per iter)
# iter 0: action 5, nodes 5538
# iter 1: action 5, nodes 5539
# iter 2: action 5, nodes 5540
# iter 3: action 5, nodes 5540
# iter 4: action 5, nodes 5540
# iter 5: action 5, nodes 5540
# iter 6: action 5, nodes 5541
# iter 7: action 5, nodes 5541
# iter 8: action 5, nodes 5541
# iter 9: action 5, nodes 5542
# Saving nodes...
# Saving book...
# Elapsed time: 138.74061799049377 (13.874061799049377 seconds per iter)
# iter 0: action 5, nodes 5542
# iter 1: action 5, nodes 5543
# iter 2: action 5, nodes 5544
# iter 3: action 5, nodes 5545
# iter 4: action 5, nodes 5545
# iter 5: action 5, nodes 5546
# iter 6: action 5, nodes 5547
# iter 7: action 5, nodes 5548
# iter 8: action 5, nodes 5549
# iter 9: action 5, nodes 5550
# Saving nodes...
# Saving book...
# Elapsed time: 129.33167099952698 (12.933167099952698 seconds per iter)
# iter 0: action 5, nodes 5551
# iter 1: action 10, nodes 5552
# iter 2: action 5, nodes 5552
# iter 3: action 10, nodes 5552
# iter 4: action 10, nodes 5552
# iter 5: action 10, nodes 5553
# iter 6: action 10, nodes 5554
# iter 7: action 10, nodes 5554
# iter 8: action 10, nodes 5554
# iter 9: action 5, nodes 5555
# Saving nodes...
# Saving book...
# Elapsed time: 124.11266160011292 (12.41126616001129 seconds per iter)
# iter 0: action 5, nodes 5556
# iter 1: action 5, nodes 5556
# iter 2: action 5, nodes 5556
# iter 3: action 5, nodes 5556
# iter 4: action 5, nodes 5557
# iter 5: action 5, nodes 5558
# iter 6: action 5, nodes 5558
# iter 7: action 5, nodes 5558
# iter 8: action 5, nodes 5559
# iter 9: action 5, nodes 5559
# Saving nodes...
# Saving book...
# Elapsed time: 129.46245574951172 (12.946245574951172 seconds per iter)
# iter 0: action 5, nodes 5560
# iter 1: action 5, nodes 5560
# iter 2: action 5, nodes 5560
# iter 3: action 5, nodes 5560
# iter 4: action 5, nodes 5560
# iter 5: action 5, nodes 5561
# iter 6: action 5, nodes 5561
# iter 7: action 5, nodes 5562
# iter 8: action 5, nodes 5563
# iter 9: action 5, nodes 5564
# Saving nodes...
# Saving book...
# Elapsed time: 131.7545747756958 (13.17545747756958 seconds per iter)
# iter 0: action 5, nodes 5565
# iter 1: action 5, nodes 5565
# iter 2: action 5, nodes 5566
# iter 3: action 5, nodes 5566
# iter 4: action 5, nodes 5567
# iter 5: action 5, nodes 5567
# iter 6: action 5, nodes 5567
# iter 7: action 5, nodes 5567
# iter 8: action 5, nodes 5568
# iter 9: action 5, nodes 5569
# Saving nodes...
# Saving book...
# Elapsed time: 146.86757564544678 (14.686757564544678 seconds per iter)
# iter 0: action 5, nodes 5570
# iter 1: action 85, nodes 5571
# iter 2: action 5, nodes 5572
# iter 3: action 5, nodes 5573
# iter 4: action 5, nodes 5574
# iter 5: action 5, nodes 5574
# iter 6: action 5, nodes 5575
# iter 7: action 5, nodes 5575
# iter 8: action 5, nodes 5575
# iter 9: action 5, nodes 5575
# Saving nodes...
# Saving book...
# Elapsed time: 146.61199855804443 (14.661199855804444 seconds per iter)
# iter 0: action 5, nodes 5576
# iter 1: action 5, nodes 5577
# iter 2: action 5, nodes 5578
# iter 3: action 5, nodes 5579
# iter 4: action 5, nodes 5580
# iter 5: action 5, nodes 5581
# iter 6: action 5, nodes 5582
# iter 7: action 5, nodes 5583
# iter 8: action 5, nodes 5584
# iter 9: action 5, nodes 5585
# Saving nodes...
# Saving book...
# Elapsed time: 155.94306445121765 (15.594306445121765 seconds per iter)
# iter 0: action 5, nodes 5585
# iter 1: action 5, nodes 5586
# iter 2: action 5, nodes 5587
# iter 3: action 5, nodes 5588
# iter 4: action 5, nodes 5589
# iter 5: action 5, nodes 5590
# iter 6: action 5, nodes 5591
# iter 7: action 5, nodes 5591
# iter 8: action 5, nodes 5592
# iter 9: action 5, nodes 5593
# Saving nodes...
# Saving book...
# Elapsed time: 132.84002900123596 (13.284002900123596 seconds per iter)
# iter 0: action 5, nodes 5594
# iter 1: action 5, nodes 5594
# iter 2: action 5, nodes 5595
# iter 3: action 5, nodes 5596
# iter 4: action 5, nodes 5597
# iter 5: action 5, nodes 5598
# iter 6: action 5, nodes 5599
# iter 7: action 5, nodes 5600
# iter 8: action 5, nodes 5601
# iter 9: action 5, nodes 5602
# Saving nodes...
# Saving book...
# Elapsed time: 125.88790893554688 (12.588790893554688 seconds per iter)
# iter 0: action 5, nodes 5603
# iter 1: action 5, nodes 5604
# iter 2: action 5, nodes 5605
# iter 3: action 5, nodes 5606
# iter 4: action 5, nodes 5606
# iter 5: action 5, nodes 5607
# iter 6: action 5, nodes 5607
# iter 7: action 5, nodes 5608
# iter 8: action 5, nodes 5609
# iter 9: action 5, nodes 5609
# Saving nodes...
# Saving book...
# Elapsed time: 122.72041273117065 (12.272041273117065 seconds per iter)
# iter 0: action 5, nodes 5609
# iter 1: action 5, nodes 5609
# iter 2: action 5, nodes 5609
# iter 3: action 5, nodes 5609
# iter 4: action 5, nodes 5609
# iter 5: action 5, nodes 5610
# iter 6: action 5, nodes 5611
# iter 7: action 5, nodes 5612
# iter 8: action 94, nodes 5613
# iter 9: action 94, nodes 5614
# Saving nodes...
# Saving book...
# Elapsed time: 131.54395484924316 (13.154395484924317 seconds per iter)
# iter 0: action 94, nodes 5615
# iter 1: action 94, nodes 5616
# iter 2: action 94, nodes 5617
# iter 3: action 94, nodes 5618
# iter 4: action 94, nodes 5619
# iter 5: action 5, nodes 5620
# iter 6: action 5, nodes 5621
# iter 7: action 5, nodes 5622
# iter 8: action 5, nodes 5623
# iter 9: action 5, nodes 5624
# Saving nodes...
# Saving book...
# Elapsed time: 125.01872301101685 (12.501872301101685 seconds per iter)
# iter 0: action 5, nodes 5624
# iter 1: action 5, nodes 5625
# iter 2: action 5, nodes 5626
# iter 3: action 5, nodes 5627
# iter 4: action 5, nodes 5628
# iter 5: action 5, nodes 5629
# iter 6: action 94, nodes 5630
# iter 7: action 94, nodes 5631
# iter 8: action 94, nodes 5632
# iter 9: action 94, nodes 5633
# Saving nodes...
# Saving book...
# Elapsed time: 135.34016489982605 (13.534016489982605 seconds per iter)
# iter 0: action 94, nodes 5634
# iter 1: action 94, nodes 5635
# iter 2: action 94, nodes 5636
# iter 3: action 94, nodes 5637
# iter 4: action 94, nodes 5638
# iter 5: action 94, nodes 5639
# iter 6: action 94, nodes 5640
# iter 7: action 94, nodes 5641
# iter 8: action 94, nodes 5642
# iter 9: action 94, nodes 5643
# Saving nodes...
# Saving book...
# Elapsed time: 134.15353441238403 (13.415353441238404 seconds per iter)
# iter 0: action 94, nodes 5644
# iter 1: action 94, nodes 5645
# iter 2: action 94, nodes 5645
# iter 3: action 94, nodes 5646
# iter 4: action 94, nodes 5647
# iter 5: action 94, nodes 5648
# iter 6: action 94, nodes 5649
# iter 7: action 94, nodes 5650
# iter 8: action 94, nodes 5651
# iter 9: action 94, nodes 5652
# Saving nodes...
# Saving book...
# Elapsed time: 134.49251627922058 (13.449251627922058 seconds per iter)
# iter 0: action 94, nodes 5653
# iter 1: action 94, nodes 5654
# iter 2: action 94, nodes 5655
# iter 3: action 94, nodes 5656
# iter 4: action 29, nodes 5657
# iter 5: action 94, nodes 5658
# iter 6: action 94, nodes 5659
# iter 7: action 94, nodes 5660
# iter 8: action 94, nodes 5661
# iter 9: action 94, nodes 5662
# Saving nodes...
# Saving book...
# Elapsed time: 126.92085242271423 (12.692085242271423 seconds per iter)
# iter 0: action 94, nodes 5663
# iter 1: action 94, nodes 5664
# iter 2: action 94, nodes 5665
# iter 3: action 94, nodes 5666
# iter 4: action 94, nodes 5666
# iter 5: action 5, nodes 5667
# iter 6: action 5, nodes 5668
# iter 7: action 5, nodes 5669
# iter 8: action 94, nodes 5670
# iter 9: action 94, nodes 5671
# Saving nodes...
# Saving book...
# Elapsed time: 143.89537501335144 (14.389537501335145 seconds per iter)
# iter 0: action 94, nodes 5672
# iter 1: action 5, nodes 5673
# iter 2: action 5, nodes 5674
# iter 3: action 5, nodes 5675
# iter 4: action 5, nodes 5676
# iter 5: action 5, nodes 5677
# iter 6: action 88, nodes 5678
# iter 7: action 88, nodes 5679
# iter 8: action 5, nodes 5680
# iter 9: action 5, nodes 5680
# Saving nodes...
# Saving book...
# Elapsed time: 119.04290127754211 (11.904290127754212 seconds per iter)
# iter 0: action 5, nodes 5681
# iter 1: action 5, nodes 5682
# iter 2: action 5, nodes 5683
# iter 3: action 5, nodes 5684
# iter 4: action 5, nodes 5685
# iter 5: action 5, nodes 5686
# iter 6: action 5, nodes 5687
# iter 7: action 5, nodes 5688
# iter 8: action 5, nodes 5689
# iter 9: action 5, nodes 5690
# Saving nodes...
# Saving book...
# Elapsed time: 143.2165870666504 (14.321658706665039 seconds per iter)
# iter 0: action 5, nodes 5691
# iter 1: action 5, nodes 5691
# iter 2: action 5, nodes 5692
# iter 3: action 5, nodes 5693
# iter 4: action 5, nodes 5693
# iter 5: action 5, nodes 5694
# iter 6: action 5, nodes 5695
# iter 7: action 5, nodes 5696
# iter 8: action 5, nodes 5697
# iter 9: action 5, nodes 5698
# Saving nodes...
# Saving book...
# Elapsed time: 141.53135418891907 (14.153135418891907 seconds per iter)
# iter 0: action 5, nodes 5699
# iter 1: action 5, nodes 5700
# iter 2: action 5, nodes 5700
# iter 3: action 5, nodes 5700
# iter 4: action 5, nodes 5701
# iter 5: action 5, nodes 5701
# iter 6: action 5, nodes 5702
# iter 7: action 5, nodes 5703
# iter 8: action 5, nodes 5703
# iter 9: action 5, nodes 5703
# Saving nodes...
# Saving book...
# Elapsed time: 135.0867567062378 (13.508675670623779 seconds per iter)
# iter 0: action 5, nodes 5704
# iter 1: action 5, nodes 5705
# iter 2: action 5, nodes 5706
# iter 3: action 5, nodes 5706
# iter 4: action 5, nodes 5707
# iter 5: action 5, nodes 5707
# iter 6: action 5, nodes 5708
# iter 7: action 5, nodes 5709
# iter 8: action 5, nodes 5710
# iter 9: action 5, nodes 5711
# Saving nodes...
# Saving book...
# Elapsed time: 126.61345314979553 (12.661345314979553 seconds per iter)
# iter 0: action 5, nodes 5712
# iter 1: action 5, nodes 5713
# iter 2: action 5, nodes 5714
# iter 3: action 5, nodes 5715
# iter 4: action 5, nodes 5716
# iter 5: action 5, nodes 5716
# iter 6: action 5, nodes 5716
# iter 7: action 5, nodes 5717
# iter 8: action 5, nodes 5718
# iter 9: action 5, nodes 5719
# Saving nodes...
# Saving book...
# Elapsed time: 127.69715237617493 (12.769715237617493 seconds per iter)
# iter 0: action 5, nodes 5719
# iter 1: action 5, nodes 5720
# iter 2: action 5, nodes 5721
# iter 3: action 5, nodes 5722
# iter 4: action 5, nodes 5722
# iter 5: action 5, nodes 5723
# iter 6: action 5, nodes 5723
# iter 7: action 5, nodes 5724
# iter 8: action 5, nodes 5724
# iter 9: action 5, nodes 5724
# Saving nodes...
# Saving book...
# Elapsed time: 147.91759300231934 (14.791759300231934 seconds per iter)
# iter 0: action 5, nodes 5725
# iter 1: action 5, nodes 5726
# iter 2: action 5, nodes 5727
# iter 3: action 5, nodes 5728
# iter 4: action 5, nodes 5729
# iter 5: action 5, nodes 5730
# iter 6: action 5, nodes 5731
# iter 7: action 5, nodes 5732
# iter 8: action 94, nodes 5733
# iter 9: action 94, nodes 5734
# Saving nodes...
# Saving book...
# Elapsed time: 124.42120838165283 (12.442120838165284 seconds per iter)
# iter 0: action 94, nodes 5734
# iter 1: action 94, nodes 5734
# iter 2: action 94, nodes 5735
# iter 3: action 94, nodes 5736
# iter 4: action 94, nodes 5736
# iter 5: action 94, nodes 5737
# iter 6: action 94, nodes 5738
# iter 7: action 17, nodes 5739
# iter 8: action 17, nodes 5740
# iter 9: action 17, nodes 5741
# Saving nodes...
# Saving book...
# Elapsed time: 135.23183822631836 (13.523183822631836 seconds per iter)
# iter 0: action 17, nodes 5742
# iter 1: action 94, nodes 5742
# iter 2: action 17, nodes 5743
# iter 3: action 17, nodes 5744
# iter 4: action 17, nodes 5745
# iter 5: action 17, nodes 5746
# iter 6: action 17, nodes 5747
# iter 7: action 94, nodes 5748
# iter 8: action 94, nodes 5749
# iter 9: action 94, nodes 5750
# Saving nodes...
# Saving book...
# Elapsed time: 128.750741481781 (12.8750741481781 seconds per iter)
# iter 0: action 94, nodes 5751
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-014d3f5ff0be> in <module>()
#       5     t0 = time()
#       6     for i in range(batch_size):
# ----> 7         action, nodes = uct_search(root_n, book, depth, nodes)
#       8         print('iter {}: action {}, nodes {}'.format(i, action, len(nodes)))
#       9     # print([str(state) for state in nodes.keys()])
#
# <ipython-input-13-87711fc4b245> in uct_search(root_n, book, depth, nodes)
#       5     """
#       6     edge_node, tree_history = tree_policy(root_n, nodes)
# ----> 7     reward, game_history, winner_id = default_policy(edge_node['state'])
#       8     # Add data to the book
#       9     game_history = tree_history + game_history
#
# <ipython-input-14-3ce0ad380e4e> in default_policy(state)
#       1 def default_policy(state):
#       2     player_id = state.player()
# ----> 3     winner, game_history, match_id = isolation.play((agents, state, time_limit, 0))
#       4     winner_id = agent_names.index(winner.name)
#       5     game_value = 2 * (player_id == winner_id) - 1
#
# ~/udacity/artificial-intelligence/Projects/3_Adversarial Search/isolation/__init__.py in play(args)
#      66
#      67
# ---> 68 def play(args): return _play(*args)  # multithreading ThreadPool.map doesn't expand args
#      69
#      70
#
# ~/udacity/artificial-intelligence/Projects/3_Adversarial Search/isolation/__init__.py in _play(agents, game_state, time_limit, match_id)
#     103
#     104         try:
# --> 105             action = fork_get_action(game_state, players[active_idx], time_limit)
#     106         except Empty:
#     107             logger.info(
#
# ~/udacity/artificial-intelligence/Projects/3_Adversarial Search/isolation/__init__.py in fork_get_action(game_state, active_player, time_limit)
#     158     # comment out these lines for debugging mode
#     159     p = Process(target=_request_action, args=(active_player, game_state, time_limit, client))
# --> 160     p.start()
#     161     p.join(timeout=PROCESS_TIMEOUT)
#     162     if p and p.is_alive(): p.terminate()
#
# ~/anaconda3/envs/aind/lib/python3.5/multiprocessing/process.py in start(self)
#     103                'daemonic processes are not allowed to have children'
#     104         _cleanup()
# --> 105         self._popen = self._Popen(self)
#     106         self._sentinel = self._popen.sentinel
#     107         # Avoid a refcycle if the target function holds an indirect
#
# ~/anaconda3/envs/aind/lib/python3.5/multiprocessing/context.py in _Popen(process_obj)
#     210     @staticmethod
#     211     def _Popen(process_obj):
# --> 212         return _default_context.get_context().Process._Popen(process_obj)
#     213
#     214 class DefaultContext(BaseContext):
#
# ~/anaconda3/envs/aind/lib/python3.5/multiprocessing/context.py in _Popen(process_obj)
#     265         def _Popen(process_obj):
#     266             from .popen_fork import Popen
# --> 267             return Popen(process_obj)
#     268
#     269     class SpawnProcess(process.BaseProcess):
#
# ~/anaconda3/envs/aind/lib/python3.5/multiprocessing/popen_fork.py in __init__(self, process_obj)
#      18         sys.stderr.flush()
#      19         self.returncode = None
# ---> 20         self._launch(process_obj)
#      21
#      22     def duplicate_for_child(self, fd):
#
# ~/anaconda3/envs/aind/lib/python3.5/multiprocessing/popen_fork.py in _launch(self, process_obj)
#      65         code = 1
#      66         parent_r, child_w = os.pipe()
# ---> 67         self.pid = os.fork()
#      68         if self.pid == 0:
#      69             try:
#
# KeyboardInterrupt:

# %%
# Show the best first moves...
# %pylab inline
pylab.rcParams['figure.figsize'] = (20.0, 10.0)

import seaborn as sns

first = {item:value[0]/value[1] for item, value in book.items() if item[0].ply_count==0 and value[1] != 0}
pos_value = {key[1]:value for key,value in first.items()}
filled_vals = dict(zip(range(115),[0]*115))
filled_vals.update(pos_value)
W = 11
x = list(filled_vals.values())
rows = [x[i*(W+2):(i+1)*(W+2)] 
           for i in range(len(x) // (W+2) + (len(x) % (W+2) != 0))]
for i in range(len(rows)-1):
    rows[i] =rows[i][:-2]
rows = np.array(rows)
sns.heatmap(rows)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Combine 2 books...

# %%
def combine_books(b1, b2):
    comb = dict()
    keys = set(b1.keys()) | set(b2.keys())
    for k in keys:
        comb[k] = [0, 0]
        if k in b1.keys():
            comb[k][0] += b1[k][0]
            comb[k][1] += b1[k][1]
        if k in b2.keys():
            comb[k][0] += b2[k][0]
            comb[k][1] += b2[k][1]
    return comb

# %%
b1 = {'a':[3, 10], 'c':[1,57]}
b2 = {'a':[5,11], 'b':[-34, 1892]}

# %%
combine_books(b1, b2)
# Out:
# {'a': [8, 21], 'b': [-34, 1892], 'c': [1, 57]}

# %%
book
# Out:
# {(Isolation(board=41198632737088974515941243613079551, ply_count=3, locs=(108, 83)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=40143957350286345584047904549496831, ply_count=3, locs=(106, 110)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523161126567867312497156574668799, ply_count=3, locs=(86, 53)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41523161203937941491027730440906719, ply_count=3, locs=(45, 5)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41523161203939122082683626855589879, ply_count=3, locs=(30, 32)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41198484184284260270308255718172671, ply_count=3, locs=(108, 83)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41520625901529739768237212624218111, ply_count=3, locs=(55, 101)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41523161203939122082679232029255679, ply_count=3, locs=(42, 20)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41523161203939122078180032462645247, ply_count=3, locs=(52, 16)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41523161203934397410357753298282495, ply_count=3, locs=(61, 26)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41523161203939122010625488162121727, ply_count=3, locs=(39, 56)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41522834387768455594385879502678015, ply_count=3, locs=(68, 98)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41198632746760381072717539522373631, ply_count=3, locs=(108, 47)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=20753339944499623666884603717609471, ply_count=3, locs=(99, 66)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523161203939048259678539830257663, ply_count=3, locs=(66, 29)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41523161049196615442628840951638015, ply_count=3, locs=(60, 59)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41523161203929677349717892665436157, ply_count=3, locs=(28, 73)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=41523161203939122082683065280227327, ply_count=3, locs=(23, 39)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41523131493378031659604444968904703, ply_count=3, locs=(94, 93)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41523161203938900685725950690715647, ply_count=3, locs=(55, 67)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523161203939122082674836131276799, ply_count=1, locs=(43, None)),
#   40): [1, 1],
#  (Isolation(board=38927012755328895010469129188534271, ply_count=3, locs=(84, 111)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523161126530090690980808254023679, ply_count=3, locs=(75, 52)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41523161203939122082683630076618751, ply_count=3, locs=(31, 17)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41523161203920232616752149348345855, ply_count=3, locs=(17, 74)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41523161202730011795628265954076671, ply_count=3, locs=(80, 67)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523161203939122082683632224036863, ply_count=1, locs=(18, None)),
#   107): [1, 3],
#  (Isolation(board=41522527359296194854148817077135359, ply_count=3, locs=(84, 18)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523156252178964941162532627802111, ply_count=1, locs=(92, None)),
#   43): [0, 2],
#  (Isolation(board=41523151300418807799641432964196349, ply_count=3, locs=(1, 93)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523161202730048689116413373179903, ply_count=2, locs=(67, 80)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523161203939120893733322008553471, ply_count=3, locs=(60, 55)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41441714652874458343637469043353599, ply_count=2, locs=(106, 98)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=31138567409498214370268780198619135, ply_count=3, locs=(86, 44)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41522527378610673769085666001414143, ply_count=3, locs=(99, 73)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41523161199103418804224016013813759, ply_count=3, locs=(40, 82)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41523161203334658019954804440164351, ply_count=3, locs=(60, 79)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41442031565524515400987826030897151, ply_count=3, locs=(23, 106)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523161184596308392380017032554495, ply_count=3, locs=(59, 43)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41522527378636646784741449050089471, ply_count=2, locs=(99, 71)),
#   <Action.SSW: -25>): [1, 1],
#  (Isolation(board=41523161203939122064527946470647807, ply_count=3, locs=(39, 47)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523161203901343150521607899834367, ply_count=3, locs=(75, 44)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523161203939117470997613662693375, ply_count=2, locs=(27, 62)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41523161203936759710491895775881215, ply_count=3, locs=(60, 55)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523161203938826934760860148557823, ply_count=3, locs=(44, 68)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=41523161203939048259678540367112191, ply_count=3, locs=(55, 14)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=41523161203939122078177833573607423, ply_count=3, locs=(52, 16)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41523151300418512651736251530995711, ply_count=3, locs=(68, 31)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41523161203939121938568426968573823, ply_count=3, locs=(7, 57)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41523161203939048295634769618659327, ply_count=3, locs=(66, 46)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41523161199103271230272525849061375, ply_count=2, locs=(67, 82)),
#   <Action.NNE: 25>): [-1, 1],
#  (Isolation(board=41198642650280695337886077694240767, ply_count=2, locs=(54, 108)),
#   <Action.NNE: 25>): [-1, 1],
#  (Isolation(board=41523158728059043511923081889179647, ply_count=2, locs=(29, 91)),
#   <Action.NNE: 25>): [-1, 1],
#  (Isolation(board=41523161203920232616189203690022909, ply_count=3, locs=(49, 1)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41522527378639007967978485826054143, ply_count=3, locs=(17, 99)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41523141396895984759405209339291647, ply_count=3, locs=(94, 71)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41360896970514048299312437918689279, ply_count=3, locs=(107, 82)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41523161194267678632277351895918591, ply_count=3, locs=(40, 83)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523158728058969715939588333103103, ply_count=3, locs=(66, 53)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41523161203334656867033239703775231, ply_count=3, locs=(61, 79)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41360901925900982899677425039304687, ply_count=3, locs=(80, 4)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=41523161201521196656478079036680191, ply_count=2, locs=(81, 66)),
#   <Action.NNW: 27>): [1, 1],
#  (Isolation(board=41523161203939047142785283023431679, ply_count=3, locs=(66, 60)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41523121589857864941507636130473983, ply_count=3, locs=(26, 95)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=20753953962758592706666889815779327, ply_count=3, locs=(94, 114)),
#   <Action.ESE: -15>): [1, 1],
#  (Isolation(board=41523161203937941491062914812995567, ply_count=2, locs=(70, 4)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41523161203939121506222871326746623, ply_count=3, locs=(22, 59)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41523161203939122082683563236386815, ply_count=2, locs=(28, 36)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41522527378034545040161170775861247, ply_count=3, locs=(79, 99)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523161203938974508729940888774655, ply_count=3, locs=(40, 31)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=20753973769799811424446458831562751, ply_count=2, locs=(57, 114)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41523161203939048295143837676857343, ply_count=3, locs=(39, 49)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=41523161203938973932269190732834815, ply_count=3, locs=(67, 59)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523161126548980161415886462248959, ply_count=2, locs=(86, 74)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523161203939122082683632224003967, ply_count=3, locs=(7, 15)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41523002747614093554008445128009471, ply_count=3, locs=(23, 97)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523161203939122010608445999802367, ply_count=3, locs=(44, 56)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41521893553301112615576169145690111, ply_count=3, locs=(75, 61)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=41482596384731818165093510441592831, ply_count=3, locs=(48, 105)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41198484193955666827084551627466751, ply_count=3, locs=(108, 47)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41523161199099877029362963291564031, ply_count=3, locs=(71, 70)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=36330864190659428360239166710081535, ply_count=3, locs=(112, 71)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523161203939120929181585477986303, ply_count=3, locs=(49, 44)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=38927012774666985901935514414475263, ply_count=2, locs=(72, 111)),
#   <Action.SSE: -27>): [-1, 1],
#  (Isolation(board=41523151300116428770785186061215743, ply_count=3, locs=(93, 67)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523161203934399716165561027127295, ply_count=3, locs=(45, 34)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523161203939122046654818025465855, ply_count=2, locs=(55, 34)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41520625902719775005027655630186495, ply_count=3, locs=(74, 60)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41523161203939122082595671291979775, ply_count=3, locs=(21, 44)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41523151300078797412874818575919103, ply_count=3, locs=(93, 75)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=40874124077279455515283253119412223, ply_count=3, locs=(109, 28)),
#   <Action.NNE: 25>): [1, 1],
#  (Isolation(board=41523161203936760899424600920680447, ply_count=3, locs=(44, 32)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523161203936759746520692794845179, ply_count=3, locs=(60, 2)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41523161203636890618772775675881463, ply_count=3, locs=(53, 3)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41523161203939122082648447717992447, ply_count=2, locs=(45, 27)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=41523161203939119776838423920240639, ply_count=3, locs=(26, 61)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41523161203939121496934205689423871, ply_count=3, locs=(59, 53)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41523081975776607818275669936171007, ply_count=2, locs=(46, 96)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=41523161203920231463689911548241919, ply_count=3, locs=(74, 60)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523161203939121488190889225349119, ply_count=3, locs=(59, 54)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41523161184596306662936187471128575, ply_count=3, locs=(46, 84)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41523161199103381910735868594743295, ply_count=3, locs=(65, 82)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=36330824730114111502369709948397567, ply_count=3, locs=(95, 112)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523161202730196263069003049560047, ply_count=3, locs=(15, 80)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41523161203939122082680883176794111, ply_count=3, locs=(28, 41)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41523161203939120929762119025420287, ply_count=3, locs=(33, 21)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41523161203939122082681433199994879, ply_count=2, locs=(20, 41)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41523161203939122082681433198929919, ply_count=3, locs=(14, 21)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523161165234606389084020052846590, ply_count=3, locs=(74, 0)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41523161203938531777861676217395199, ply_count=3, locs=(42, 69)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41523141387227086959677802394150911, ply_count=3, locs=(83, 42)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523161203632168117181917209552895, ply_count=3, locs=(72, 78)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41523161203939122082120681734006779, ply_count=3, locs=(2, 49)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523161203939122082401607483385855, ply_count=3, locs=(23, 39)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=40874124096622268629117320183113711, ply_count=3, locs=(15, 109)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523161203939121505941403870423039, ply_count=3, locs=(48, 30)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41360901925900982899677425038780415, ply_count=3, locs=(80, 19)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523161203929677349717892933871615, ply_count=1, locs=(73, None)),
#   67): [0, 0],
#  (Isolation(board=41198642650280695211714919383689215, ply_count=3, locs=(46, 108)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523161203939122064669233580468223, ply_count=3, locs=(54, 17)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41360901922274205440833536978315263, ply_count=3, locs=(107, 29)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523161203939121506205286661089279, ply_count=3, locs=(44, 30)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523161203938527175046517602904063, ply_count=3, locs=(47, 69)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41522527359296194277688064773974015, ply_count=3, locs=(84, 59)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41523161203937941490464780487485439, ply_count=3, locs=(70, 49)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=41523161203929677349713494753142783, ply_count=3, locs=(27, 73)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=41523161203937941491027730440906747, ply_count=3, locs=(70, 2)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=41482596228780388011548574184630271, ply_count=3, locs=(105, 87)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41523161203939122064669233714817023, ply_count=1, locs=(54, None)),
#   112): [-2, 2],
#  (Isolation(board=41523161203938531786873273518647231, ply_count=2, locs=(6, 69)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=36330864340568443601742029519841279, ply_count=3, locs=(82, 112)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523161203938826934774052677478399, ply_count=3, locs=(42, 68)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=40874104289581640063032921796110335, ply_count=3, locs=(94, 20)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41523161203939122082683614507558399, ply_count=3, locs=(9, 29)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41523141396898493516590437745289215, ply_count=2, locs=(43, 94)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41523161203939121794453256072587263, ply_count=1, locs=(58, None)),
#   87): [-1, 1],
#  (Isolation(board=41442031564920052491180528497584127, ply_count=3, locs=(106, 27)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41482596384429587286932080293832703, ply_count=3, locs=(78, 27)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523161184595718384808830571636735, ply_count=3, locs=(84, 58)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=41523161202730159369579756118861823, ply_count=3, locs=(80, 40)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=36168605029889454863093424294193151, ply_count=3, locs=(85, 107)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41523161203939122073658840783513599, ply_count=2, locs=(53, 44)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41482596383522892922221091367151615, ply_count=3, locs=(80, 34)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41523161184596308968779196684822527, ply_count=2, locs=(84, 46)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41523161203939122082648447852177406, ply_count=3, locs=(15, 45)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41520625902719776157949160235984895, ply_count=3, locs=(74, 20)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=38927012774671708268418384059688955, ply_count=2, locs=(2, 111)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41523161126567869627347365041006591, ply_count=2, locs=(86, 21)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41523161126567869627065890058004479, ply_count=3, locs=(23, 86)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41523161201521270434447174620145663, ply_count=2, locs=(81, 53)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=36330864345404294310033549772711935, ply_count=3, locs=(42, 112)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523161203933809420249666385078271, ply_count=3, locs=(47, 69)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41502878793731006925991618082236415, ply_count=3, locs=(79, 59)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41523161203939122082542877556074495, ply_count=2, locs=(34, 47)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41523161203901343146035600458508287, ply_count=3, locs=(75, 52)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41523161126530090695484407344523263, ply_count=3, locs=(86, 29)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523161203939122082672632813053951, ply_count=3, locs=(32, 41)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41523161203939121506222875625908222, ply_count=3, locs=(32, 0)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41523161203939121794453255804151799, ply_count=3, locs=(3, 58)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41523101782816941236525257713510399, ply_count=3, locs=(68, 94)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41523161203934399572085573966358527, ply_count=3, locs=(72, 29)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=41523161203939122010617242093348863, ply_count=2, locs=(43, 56)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=41523158726848937100687735840040959, ply_count=3, locs=(80, 70)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41523161203920232616470670076798975, ply_count=3, locs=(48, 74)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523161203939122082666040038246399, ply_count=2, locs=(44, 13)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41523161203929677349647524185499647, ply_count=3, locs=(73, 22)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41523161126567869627347347863234431, ply_count=3, locs=(7, 86)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41523161203938531786851283286091775, ply_count=3, locs=(44, 42)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523161203939122078180032595879903, ply_count=3, locs=(5, 52)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523161203939122082683631955863031, ply_count=3, locs=(3, 9)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41523161203939122082683632224298991, ply_count=1, locs=(4, None)),
#   1): [0, 0],
#  (Isolation(board=41523161184596308968848465917364223, ply_count=3, locs=(13, 84)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41523161203939122064660436548052991, ply_count=3, locs=(43, 30)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41522923519449218106429416769841151, ply_count=3, locs=(71, 97)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523002747612912962387727724963839, ply_count=3, locs=(70, 17)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=40225086950619788947882874543007743, ply_count=3, locs=(110, 23)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41196107346662387257868224447899647, ply_count=3, locs=(108, 101)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41360901925900982755562236963448831, ply_count=3, locs=(80, 57)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=41523161203939122010626001679149055, ply_count=3, locs=(56, 35)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41523161203939122082683630075701247, ply_count=3, locs=(16, 20)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41523161203939121938564045028190207, ply_count=3, locs=(57, 42)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41521893553301114921419177822513151, ply_count=3, locs=(75, 29)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523161203939122082542894734894591, ply_count=3, locs=(9, 47)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=40874124096622268629117320183113727, ply_count=2, locs=(109, 15)),
#   <Action.ESE: -15>): [1, 1],
#  (Isolation(board=41523161203937941346912542365050879, ply_count=3, locs=(70, 57)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523161049196617172011097593473021, ply_count=3, locs=(28, 87)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41523161203939122082683632089556975, ply_count=3, locs=(4, 27)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41523161203901305104411023036639231, ply_count=3, locs=(60, 65)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523002723435577161715861642274815, ply_count=3, locs=(97, 84)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523161203939117470997613796845567, ply_count=2, locs=(16, 62)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=40225086989305415175550973782255359, ply_count=3, locs=(8, 110)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41523161203939122082683631150524411, ply_count=3, locs=(30, 2)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41523161203928496469866799370856447, ply_count=3, locs=(73, 70)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=41523160894453964687381575776593919, ply_count=3, locs=(67, 88)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41523151300418807799606248658954239, ply_count=3, locs=(18, 93)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523161126529500399674049175742463, ply_count=3, locs=(86, 69)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41523161203933809276275215797577727, ply_count=3, locs=(57, 69)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41523161203939122082683597864297471, ply_count=3, locs=(35, 18)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41523081975776312670440859327522815, ply_count=2, locs=(68, 96)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41523141396895542037547440310052863, ply_count=3, locs=(69, 71)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41523161203938531498642897366935547, ply_count=3, locs=(69, 2)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=40224453164005301060850259790383103, ply_count=3, locs=(99, 13)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523161184586864235881627115317247, ply_count=3, locs=(84, 41)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41523161203939122082683631147935743, ply_count=3, locs=(19, 21)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41523161203636890627779974930491391, ply_count=2, locs=(78, 17)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41523161199103418767914843529799679, ply_count=3, locs=(82, 48)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=39576049881988561721984696100841471, ply_count=2, locs=(110, 109)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=36330705889079265925469152714156031, ply_count=3, locs=(97, 43)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523161203939121506222875357472767, ply_count=3, locs=(59, 28)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41522844291289065025331058958133247, ply_count=3, locs=(26, 98)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523161203937941455034117794031611, ply_count=3, locs=(55, 2)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=41523151300418807799641424441108479, ply_count=3, locs=(18, 93)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41360901927109908719292054213978111, ply_count=2, locs=(15, 107)),
#   <Action.ENE: 11>): [1, 1],
#  (Isolation(board=41523161203939122082613263480088559, ply_count=3, locs=(15, 46)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523161049196617172011097861646207, ply_count=3, locs=(18, 87)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=41523161203934397410357753365129215, ply_count=3, locs=(61, 18)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41502878794335470124020512728279039, ply_count=3, locs=(43, 104)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41523161203939048295689745200048127, ply_count=2, locs=(66, 44)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=41523161203939122082683563504297967, ply_count=3, locs=(4, 36)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523161203938531768858874874947583, ply_count=3, locs=(54, 69)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41523161202730196263068985869199359, ply_count=3, locs=(19, 80)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41523161203937941491062914745853951, ply_count=3, locs=(15, 70)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41522844281617658468381040278759423, ply_count=3, locs=(83, 45)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41279772286277450398367006859454463, ply_count=3, locs=(106, 107)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41523161203939122082674836129179583, ply_count=3, locs=(21, 43)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=40874124096622266323203942225274879, ply_count=3, locs=(61, 109)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41522527378620118502051405289744383, ply_count=3, locs=(74, 21)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=41523161203939120929762114732550143, ply_count=3, locs=(60, 32)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523141394480051581559616783247359, ply_count=3, locs=(69, 81)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=36330864305509742406870373129775103, ply_count=3, locs=(85, 80)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41523002747614093554008442988914623, ply_count=3, locs=(6, 97)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41523151300418807799641430883821551, ply_count=3, locs=(4, 93)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41523161203939122082639647464220671, ply_count=3, locs=(32, 45)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=41523161203939048295705138362836991, ply_count=2, locs=(41, 66)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=40225047336538531815714077779421183, ply_count=3, locs=(95, 85)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41522844291289065007318309783201791, ply_count=3, locs=(39, 98)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41523081975774246635104603857610751, ply_count=3, locs=(71, 17)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41523161203939122082681433198929919, ply_count=3, locs=(41, 21)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41523161203939122082683632157190143, ply_count=1, locs=(26, None)),
#   79): [-1, 1],
#  (Isolation(board=41198642650280695067670091462076415, ply_count=3, locs=(58, 108)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41441358126143144154118298095577087, ply_count=3, locs=(106, 99)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523161203936760827314234619586559, ply_count=3, locs=(71, 46)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523161203939122082683614775993855, ply_count=3, locs=(34, 28)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41523161202730195686326775769458687, ply_count=3, locs=(59, 80)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=41523141396860714584454801699891199, ply_count=3, locs=(48, 94)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41523161199103123647312736917907455, ply_count=3, locs=(68, 82)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41482596383522891769299603940173823, ply_count=3, locs=(80, 60)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41523161203939122082679234177755071, ply_count=3, locs=(42, 6)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=41523161203939119776840554291128317, ply_count=3, locs=(61, 1)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41523161203939121487927006434682879, ply_count=3, locs=(48, 54)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41523161202730196263067903537965055, ply_count=2, locs=(80, 40)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41360822660261768227286327079462911, ply_count=3, locs=(96, 85)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41523158728059043511923082157615103, ply_count=2, locs=(91, 28)),
#   <Action.WNW: 15>): [1, 1],
#  (Isolation(board=41523161203939121506222811201398783, ply_count=2, locs=(59, 36)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=41523161203939122082683612896946159, ply_count=3, locs=(4, 34)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41523161203938826934637715378923519, ply_count=3, locs=(22, 68)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=20753973769799811568561646370547707, ply_count=3, locs=(2, 114)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523161203939122046654835196946431, ply_count=2, locs=(55, 23)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41523161199102828490400358310340607, ply_count=3, locs=(69, 82)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41523161201521270443452174784522239, ply_count=3, locs=(41, 81)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41523161203939121794444459979302911, ply_count=3, locs=(18, 58)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523161203939122082683631686379515, ply_count=3, locs=(29, 20)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41522527378639007967982883872688123, ply_count=3, locs=(2, 99)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41523161203934399572050390131140607, ply_count=3, locs=(72, 57)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523161203939121974597240630536191, ply_count=3, locs=(56, 55)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41523161203939122082683632090015679, ply_count=3, locs=(27, 6)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=41523160894444667528372823672219647, ply_count=3, locs=(73, 29)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41523161199101057620983676407900159, ply_count=3, locs=(82, 32)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41523161203939122082525302549374975, ply_count=3, locs=(44, 47)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=41523161203939121938568444148443134, ply_count=2, locs=(0, 57)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41523161203920232616752153642395615, ply_count=3, locs=(20, 74)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41523161126567869627329772320188415, ply_count=3, locs=(29, 86)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41520606095679147591864761851045887, ply_count=3, locs=(74, 94)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523161203334656867033291243382783, ply_count=3, locs=(61, 79)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=41523161203939048295706787093407743, ply_count=3, locs=(39, 29)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523161203938531192398122705741823, ply_count=3, locs=(54, 59)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41523161203939122078171236369688575, ply_count=3, locs=(52, 43)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41523161203939122082683631686379519, ply_count=2, locs=(29, 20)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41360901927109908701268859611506687, ply_count=3, locs=(43, 107)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41523161202730196263069003049592799, ply_count=2, locs=(80, 5)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=41523161203937941490983749975795711, ply_count=3, locs=(70, 46)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41198632746760381072858276876511231, ply_count=3, locs=(93, 27)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=38927012774671708268418384059688959, ply_count=1, locs=(111, None)),
#   27): [0, 0],
#  (Isolation(board=41523161203938531768577400032454655, ply_count=3, locs=(54, 48)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41198642650280695355900476203722751, ply_count=1, locs=(108, None)),
#   31): [0, 0],
#  (Isolation(board=41522844291289065024770308095076351, ply_count=2, locs=(98, 49)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41523161203920232616681782751782911, ply_count=3, locs=(31, 74)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41523161203939122082666035742763007, ply_count=3, locs=(44, 32)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523161201521270443436781688317951, ply_count=3, locs=(44, 81)),
#   <Action.NNE: 25>): [-1, 1],
#  (Isolation(board=41522527378639007967982883872171775, ply_count=3, locs=(19, 99)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41523161203936759746520692794845119, ply_count=3, locs=(60, 6)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41523161182177867033809948373936127, ply_count=3, locs=(84, 81)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=41523161049196616018948855766706175, ply_count=3, locs=(87, 47)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41523161203939119776840549996161023, ply_count=3, locs=(61, 32)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41523161165253348281058510910777343, ply_count=3, locs=(67, 85)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41523161126530090695466815695349759, ply_count=3, locs=(75, 44)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523161203901343150785490690500607, ply_count=2, locs=(45, 75)),
#   <Action.SSW: -25>): [1, 1],
#  (Isolation(board=41523161203936759746520692793796607, ply_count=3, locs=(60, 20)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41523161194265354342454795259865087, ply_count=3, locs=(71, 83)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41523161203934399571804099526518783, ply_count=3, locs=(72, 48)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41523161203939085189195484804671487, ply_count=2, locs=(19, 65)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=41523161203939122082666040038107135, ply_count=3, locs=(44, 14)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41523161203939122073641248530360319, ply_count=3, locs=(26, 45)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41520546674576151359543045273937919, ply_count=2, locs=(96, 101)),
#   <Action.ENE: 11>): [-1, 1],
#  (Isolation(board=41523161203939119776770253729556479, ply_count=3, locs=(61, 29)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41523161202725473896550949032290303, ply_count=3, locs=(45, 80)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41523161203934399698186363532732415, ply_count=3, locs=(54, 72)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=36006345782074461170452946476853247, ply_count=3, locs=(83, 112)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41523161126567869627347364975962111, ply_count=3, locs=(26, 86)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41523161203939122082666040029341695, ply_count=3, locs=(19, 23)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41520625902715053791466290591819775, ply_count=3, locs=(74, 72)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41523161126565508444105930212108287, ply_count=3, locs=(71, 23)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41523161203939122010626021005977599, ply_count=3, locs=(34, 56)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41523161203939122082683632215910399, ply_count=1, locs=(23, None)),
#   82): [0, 0],
#  (Isolation(board=41523161203939122082682532710574079, ply_count=2, locs=(40, 21)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41502868890815156057159891742091263, ply_count=3, locs=(93, 56)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=41523161203938974504227441846773759, ply_count=3, locs=(67, 30)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41481962559412815161203510789269503, ply_count=3, locs=(74, 105)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523161203939122010626036038887359, ply_count=3, locs=(31, 56)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41522527069153998146637815147390975, ply_count=3, locs=(88, 19)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41360901927109908719292054079793151, ply_count=2, locs=(27, 107)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41523160894454111108381874520582143, ply_count=3, locs=(45, 88)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=41520625902738665623880638549444607, ply_count=3, locs=(28, 101)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41523072069838441896074581137942527, ply_count=3, locs=(81, 93)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41523161203920232616752153643443199, ply_count=2, locs=(74, 10)),
#   <Action.NNE: 25>): [1, 1],
#  (Isolation(board=41523161203938531786873239158908927, ply_count=2, locs=(35, 69)),
#   <Action.NNE: 25>): [1, 1],
#  (Isolation(board=41502868890815156129147117035841535, ply_count=3, locs=(104, 46)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523151295583104521182916332414975, ply_count=3, locs=(82, 16)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41502878794335470412259650613274367, ply_count=3, locs=(35, 104)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41523161203939122082683597327673343, ply_count=3, locs=(14, 35)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41441991941771851711902013049530367, ply_count=3, locs=(106, 83)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41523161184596308968849565428737919, ply_count=3, locs=(7, 84)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41523141396897903220788875132626943, ply_count=3, locs=(69, 15)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41523161203334659172875218125285375, ply_count=3, locs=(40, 79)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41521893553338893853281035472594943, ply_count=3, locs=(29, 100)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41523141396294030606791917103474687, ply_count=3, locs=(79, 31)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41482596384731818741835737654585343, ply_count=3, locs=(26, 105)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523161182178457329620307079587839, ply_count=2, locs=(81, 84)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41523161203934399716165578202802175, ply_count=3, locs=(72, 22)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41523161203636890627779974393751547, ply_count=3, locs=(2, 78)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41523161194267714372845059860064255, ply_count=3, locs=(35, 83)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41482596384731818741695000232323071, ply_count=3, locs=(20, 105)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523161203938974508731042010753023, ply_count=3, locs=(29, 67)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41523161203636743053686647765854207, ply_count=3, locs=(67, 47)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41522844291284342658815204031195135, ply_count=3, locs=(72, 98)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41523161202720751494074466740201471, ply_count=3, locs=(80, 73)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41523161203939117470997579437172719, ply_count=3, locs=(62, 4)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=31138567486869466249161870082566143, ply_count=3, locs=(59, 113)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41523161203934399716060025090729983, ply_count=2, locs=(47, 72)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41523151295582809373277736979654655, ply_count=3, locs=(68, 82)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41523161203939121794453238892193791, ply_count=3, locs=(34, 58)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41520308990086247383288829819480063, ply_count=3, locs=(98, 101)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523161203939122082683615044429815, ply_count=2, locs=(34, 3)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41523161203939122082683632224102367, ply_count=3, locs=(5, 17)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523161203936760899442197400643583, ply_count=2, locs=(71, 20)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=20753973615054945474647677722421247, ply_count=3, locs=(114, 71)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41523161201521270371396779836958655, ply_count=3, locs=(81, 6)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41522527378639007967982883604129791, ply_count=3, locs=(17, 99)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41523141319527241061262966657116159, ply_count=2, locs=(94, 86)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41523161184596308968847365332002815, ply_count=3, locs=(30, 84)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=41523161203939122082683632224298623, ply_count=2, locs=(8, 7)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41523121570515051692565580581169151, ply_count=3, locs=(84, 57)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41523161203939085188632534851774463, ply_count=2, locs=(65, 49)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41360822694111691176495943971235839, ply_count=3, locs=(107, 82)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41523161203939122082683631955863543, ply_count=2, locs=(28, 3)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=36328329044203837995349042977040383, ply_count=3, locs=(112, 40)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41523161203937941455034083434293247, ply_count=3, locs=(70, 35)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41522844136546560114660689326368767, ply_count=3, locs=(87, 35)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41523161203636890627779974863513599, ply_count=2, locs=(78, 26)),
#   <Action.NNW: 27>): [1, 1],
#  (Isolation(board=41523161203939122082648447852079103, ply_count=2, locs=(17, 45)),
#   <Action.NNE: 25>): [1, 1],
#  (Isolation(board=41523161203938826934778450723989487, ply_count=3, locs=(31, 68)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41523161201521196647470879781939199, ply_count=3, locs=(66, 53)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41523161126567574479433389597255679, ply_count=3, locs=(43, 86)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41523161203939122082682532175792127, ply_count=3, locs=(13, 29)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523161203938974508731042547623927, ply_count=3, locs=(18, 67)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41523161203929677349647524189431807, ply_count=3, locs=(46, 18)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523156252178964905133735608838143, ply_count=2, locs=(55, 92)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=41523151300418660225687743843264511, ply_count=3, locs=(40, 93)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41442031564920052491180528631785471, ply_count=3, locs=(79, 14)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41523161203939121506222879920613247, ply_count=3, locs=(7, 59)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523161203939122082683632022906879, ply_count=3, locs=(27, 26)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=36330705889069821192512209516750847, ply_count=3, locs=(97, 73)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523161203939122082119582759217151, ply_count=3, locs=(40, 49)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=20753971292710807178186467934463999, ply_count=3, locs=(80, 114)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41482596383522892922221108547020783, ply_count=3, locs=(80, 4)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=41523151300418807799641433031305215, ply_count=1, locs=(93, None)),
#   9): [0, 0],
#  (Isolation(board=41502868890815156129217485780018687, ply_count=3, locs=(104, 9)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=41523161203939121794453238892718079, ply_count=2, locs=(58, 34)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41522844281617658468416224650847999, ply_count=3, locs=(83, 8)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41523161203939120929726942708492287, ply_count=3, locs=(60, 29)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41521873736626858730280703737456639, ply_count=3, locs=(83, 100)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41523161203937941491026630929278975, ply_count=3, locs=(70, 40)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523161203934397266242565289535487, ply_count=3, locs=(72, 57)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41523161203939122082648447850111999, ply_count=3, locs=(10, 45)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41523161203939122082679234177525751, ply_count=3, locs=(18, 42)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41523161203938974508729940888774655, ply_count=3, locs=(40, 31)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41522844291289065020827459397871615, ply_count=3, locs=(52, 98)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523161203939122082683615035910143, ply_count=3, locs=(23, 17)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=41523160884782705416191153950156799, ply_count=3, locs=(83, 88)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41523161203935580307812683897366527, ply_count=3, locs=(70, 71)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41519992077419662043248411885430783, ply_count=3, locs=(101, 99)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41442011756066035195674186483755007, ply_count=3, locs=(81, 94)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523141386622624049874885853308927, ply_count=3, locs=(79, 83)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=41523161199103418804222916435109887, ply_count=3, locs=(26, 82)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41523158728059043511923082426050559, ply_count=1, locs=(91, None)),
#   88): [0, 2],
#  (Isolation(board=41522844281615297285174789828241407, ply_count=3, locs=(83, 71)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41360822698946804159144101964408831, ply_count=3, locs=(107, 69)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=36328329044203837995350140341184511, ply_count=3, locs=(112, 31)),
#   <Action.NNE: 25>): [-1, 1],
#  (Isolation(board=41522527378620118502051405291841471, ply_count=3, locs=(74, 6)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=31138567477193337902222736522995711, ply_count=3, locs=(83, 113)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41523161199103416498382037592303615, ply_count=3, locs=(61, 82)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41523161203939122082683631687428087, ply_count=2, locs=(3, 29)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=20753973615057306657889111471286271, ply_count=3, locs=(87, 30)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523161202730196263033817603762175, ply_count=3, locs=(45, 80)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523002747612912962387727725078527, ply_count=3, locs=(97, 14)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41198632746760380784627900859017215, ply_count=3, locs=(108, 58)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41523161203939122082648447852209663, ply_count=2, locs=(45, 9)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41198642647862839104985199426922495, ply_count=3, locs=(108, 62)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=41523161203636743053827385254208511, ply_count=3, locs=(78, 10)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=40224928455609134191539553872898047, ply_count=3, locs=(97, 110)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523151300418733976636341174134783, ply_count=3, locs=(55, 93)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523160894416331023632597124114431, ply_count=3, locs=(88, 75)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523161203938826925771245026797567, ply_count=3, locs=(53, 33)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41522527378639007967982882798954495, ply_count=2, locs=(99, 30)),
#   <Action.SSW: -25>): [0, 0],
# ...
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523161165253495566776326388967423, ply_count=3, locs=(85, 43)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41523161165253494702093994026723327, ply_count=3, locs=(85, 17)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41523161203939121506222862204135423, ply_count=3, locs=(34, 29)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=41522527359296194854148816808962047, ply_count=3, locs=(84, 28)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41482596384429587286914488242006015, ply_count=3, locs=(78, 44)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523156252178964941162532627785719, ply_count=3, locs=(3, 92)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=40225027568183529477297812984031231, ply_count=3, locs=(95, 94)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523121589857864949951885494708223, ply_count=3, locs=(22, 95)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41523161203939122082683631687362559, ply_count=2, locs=(16, 29)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=41523081975776607818346038680086519, ply_count=3, locs=(3, 96)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41523161203939121938568443074701307, ply_count=3, locs=(57, 2)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41523161203934399716200762310649855, ply_count=2, locs=(28, 72)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523161203939122082120682270877679, ply_count=2, locs=(4, 49)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41523161184595718673021614537304063, ply_count=3, locs=(44, 84)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41523161194267420377861419205388287, ply_count=3, locs=(83, 28)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523161201521270371396779836958715, ply_count=3, locs=(81, 2)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=41523161203939120641496567093651455, ply_count=3, locs=(60, 58)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=41523161203938826934769656778434559, ply_count=3, locs=(68, 14)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523161203929672665974280468555775, ply_count=3, locs=(73, 56)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523161194258270792519384559511551, ply_count=3, locs=(48, 83)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523161203939121938568444081301503, ply_count=3, locs=(15, 57)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41523161203882453684748458993379327, ply_count=3, locs=(47, 75)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41523160894444667528372824209090527, ply_count=3, locs=(88, 5)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41523161183387346255746788835190783, ply_count=3, locs=(65, 84)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41523151300418217503813482139609087, ply_count=3, locs=(69, 93)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41523161203929677345212094283245567, ply_count=3, locs=(41, 73)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41523161201521270425439975365404670, ply_count=3, locs=(54, 0)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41523161203939121938568439853475838, ply_count=3, locs=(32, 0)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41523161203939122082683632219580159, ply_count=3, locs=(19, 22)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41523161184596308392371220939532287, ply_count=3, locs=(84, 44)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41523161203939122073672034918852607, ply_count=3, locs=(42, 22)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41502873842575165696785995700103167, ply_count=3, locs=(92, 104)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41523161203920232616752119282657279, ply_count=3, locs=(35, 74)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41360896975345029211288084972300287, ply_count=3, locs=(92, 72)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=40874104270238826949198855001860095, ply_count=3, locs=(84, 94)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523161203939121794451057049331711, ply_count=2, locs=(58, 41)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41523161203939122082683632222201823, ply_count=2, locs=(21, 5)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41482596384731818741826941628704767, ply_count=2, locs=(43, 105)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=41523161201521265831768355447498751, ply_count=2, locs=(81, 62)),
#   <Action.SSE: -27>): [1, 1],
#  (Isolation(board=41522527069151636963396380325308415, ply_count=3, locs=(99, 71)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41523161203939121794303722491209727, ply_count=3, locs=(58, 43)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41442031563106663761758584735524863, ply_count=3, locs=(81, 27)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=41523161202730196254061803526416383, ply_count=3, locs=(53, 28)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41360901927109613562379675606444031, ply_count=3, locs=(68, 107)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41523002670242839945750673348356095, ply_count=3, locs=(86, 60)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41523161203934397410357752828520447, ply_count=3, locs=(72, 29)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=31138567486869466825622639565334271, ply_count=3, locs=(19, 113)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41523141396898493516599233838311421, ply_count=2, locs=(94, 1)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41523161203939121506222879920744443, ply_count=3, locs=(2, 59)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41523161203939122082683629808379887, ply_count=3, locs=(31, 28)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=41523161203936760881427249136396287, ply_count=3, locs=(54, 71)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41523161203929677061487516715051007, ply_count=3, locs=(58, 26)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41502878791917544986054131785394175, ply_count=3, locs=(66, 104)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41523161203939122010623839163114495, ply_count=3, locs=(56, 10)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41523161203939122082613263211677695, ply_count=3, locs=(28, 46)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523161199102238212604398114170879, ply_count=2, locs=(70, 82)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523161199103418660109910269749247, ply_count=3, locs=(57, 34)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=41523161203938531786872174007019519, ply_count=2, locs=(40, 69)),
#   <Action.NNW: 27>): [-1, 1],
#  (Isolation(board=41523161194265354270467569966114815, ply_count=3, locs=(71, 83)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41523161203938826934769656777402367, ply_count=3, locs=(68, 20)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=36328329044203837995350142488635391, ply_count=3, locs=(112, 15)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41442031565524515400987843219089405, ply_count=3, locs=(1, 106)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41441982047922943985776847254185983, ply_count=3, locs=(95, 93)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41502878794335470412259684838795263, ply_count=2, locs=(27, 104)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523161203939122010623839096006655, ply_count=3, locs=(26, 56)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41523161203939122082613263478024189, ply_count=3, locs=(46, 1)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=36330859393643989738679446622169087, ply_count=3, locs=(92, 112)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41482497349528675911413745791789055, ply_count=3, locs=(105, 96)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41481328733829359057530583724845055, ply_count=3, locs=(105, 100)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41522844291279620292367510168135679, ply_count=3, locs=(98, 33)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=41523161203636742477366632950786047, ply_count=3, locs=(78, 59)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41198008824975858874716858206906367, ply_count=3, locs=(72, 108)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523161203937646307128938441205759, ply_count=3, locs=(70, 68)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=36328329044203837995350142354450431, ply_count=3, locs=(112, 27)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523161203636890618737591303792639, ply_count=3, locs=(53, 45)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=41523161203938531786873271371098111, ply_count=3, locs=(16, 69)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523002670242840810441801803491327, ply_count=3, locs=(86, 58)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41523161203939122082682531907364863, ply_count=3, locs=(29, 28)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41523161203939122082681432932476927, ply_count=3, locs=(17, 41)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=41523161203937941455034117726922751, ply_count=3, locs=(70, 26)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=40873965640292517733959263450032127, ply_count=3, locs=(97, 109)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41522844291289065025333257780062207, ply_count=2, locs=(28, 98)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41522527378639005662139857479133183, ply_count=3, locs=(61, 99)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41523161201519942277881066787170303, ply_count=3, locs=(81, 67)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=41523161194248826059835120245794815, ply_count=2, locs=(74, 83)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41523161203928492146411157095180287, ply_count=3, locs=(62, 70)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523161049196612488267485396592639, ply_count=3, locs=(62, 56)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523161203934397410357753365391355, ply_count=3, locs=(61, 2)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=31138250574219409732243468371093503, ply_count=3, locs=(98, 55)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41360901927109908647234460176082943, ply_count=2, locs=(56, 107)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41523161203939122082683563502716927, ply_count=3, locs=(36, 13)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523161203939122078180032596928479, ply_count=2, locs=(52, 5)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=31138250574219409768272265389991935, ply_count=3, locs=(98, 16)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=40062827711267275992544800956999679, ply_count=3, locs=(107, 110)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523161203939120911747728571099135, ply_count=3, locs=(54, 60)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41523141396898493516581641652267007, ply_count=2, locs=(94, 44)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41523081975776312526325671251666943, ply_count=3, locs=(57, 96)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41523161203929676989429922744231935, ply_count=3, locs=(73, 56)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41523161203939121758406866867578879, ply_count=3, locs=(44, 58)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523160894454112261338563231074303, ply_count=3, locs=(28, 88)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41523161203939122064669233176897535, ply_count=3, locs=(29, 20)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523161049196617172011097727690751, ply_count=2, locs=(27, 87)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523161126567869050877816646658047, ply_count=3, locs=(86, 43)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41520625902737485032259921406584831, ply_count=2, locs=(70, 101)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41523161203939117470997596616517631, ply_count=3, locs=(34, 62)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41523161203939048295702937192097791, ply_count=3, locs=(31, 66)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41198642647862696142718628177897471, ply_count=3, locs=(108, 67)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41198484193950944460742419470608383, ply_count=3, locs=(97, 72)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41523161203939122082674836131145663, ply_count=3, locs=(17, 43)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=41523161203939085189195484801001471, ply_count=2, locs=(65, 22)),
#   <Action.SSW: -25>): [-1, 1],
#  (Isolation(board=41523161203935579731360727686965247, ply_count=3, locs=(70, 71)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41482596384731671095825554007386111, ply_count=3, locs=(67, 105)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41522527359296194854148817075300351, ply_count=3, locs=(84, 21)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523081975776607818346038411782143, ply_count=3, locs=(28, 96)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=36330705579594256104132880082397183, ply_count=3, locs=(112, 88)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41523161203939121938286969163343871, ply_count=3, locs=(23, 57)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41523161203939120929761028105816063, ply_count=3, locs=(13, 60)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=41522527378634285601499997047613439, ply_count=3, locs=(72, 34)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41522997793436084773258087190489087, ply_count=3, locs=(92, 97)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=40874124096621973481209941807065087, ply_count=3, locs=(41, 109)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523161203938974364615853398288383, ply_count=3, locs=(57, 67)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523161203939122082050296346830847, ply_count=3, locs=(34, 46)),
#   <Action.SSE: -27>): [0, 0],
#  (Isolation(board=41523141396898493516581641652267007, ply_count=2, locs=(44, 94)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41442031563106663473528208718030847, ply_count=3, locs=(106, 58)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=38925745124071184891111708003657727, ply_count=3, locs=(100, 68)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41198632746760380496397524707305471, ply_count=3, locs=(93, 59)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41523161203934399716200762042214395, ply_count=3, locs=(29, 72)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41523161202730196263069003049576439, ply_count=3, locs=(3, 80)),
#   <Action.NNE: 25>): [1, 1],
#  (Isolation(board=41523161201483417724615121874970623, ply_count=3, locs=(81, 75)),
#   <Action.NNE: 25>): [0, 0],
#  (Isolation(board=41523002747612912962246990236739583, ply_count=3, locs=(70, 47)),
#   <Action.ESE: -15>): [0, 0],
#  (Isolation(board=41523161203939117470997613796878335, ply_count=2, locs=(15, 62)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41523161203939121794444458905823231, ply_count=3, locs=(43, 30)),
#   <Action.SSW: -25>): [0, 0],
#  (Isolation(board=41523161203939122082683632224274431, ply_count=2, locs=(14, 13)),
#   <Action.NNW: 27>): [1, 1],
#  (Isolation(board=41523161203934399572085574436120575, ply_count=3, locs=(57, 26)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41482596375060411896688328172365823, ply_count=3, locs=(58, 105)),
#   <Action.WSW: -11>): [0, 0],
#  (Isolation(board=41502878793731007502452370384611327, ply_count=3, locs=(79, 20)),
#   <Action.NNW: 27>): [0, 0],
#  (Isolation(board=41523161194267715525766598826387327, ply_count=3, locs=(18, 83)),
#   <Action.ENE: 11>): [0, 0],
#  (Isolation(board=41523161203939122082683632223250431, ply_count=1, locs=(20, None)),
#   86): [-1, 1],
#  (Isolation(board=41523161203939121488208480874522623, ply_count=3, locs=(54, 59)),
#   <Action.WNW: 15>): [0, 0],
#  (Isolation(board=41522844136546559538199971382683647, ply_count=3, locs=(98, 59)),
#   <Action.SSE: -27>): [0, 0],
#  ...}

# %%
print(isolation.DebugState.from_state(root_s.result(52)))
# Out:
# + - + - + - + - + - + - + - + - + - + - + - +
# |   |   |   |   |   |   |   |   |   |   |   |
# + - + - + - + - + - + - + - + - + - + - + - +
# |   |   |   |   |   |   |   |   |   |   |   |
# + - + - + - + - + - + - + - + - + - + - + - +
# |   |   |   |   |   |   |   |   |   |   |   |
# + - + - + - + - + - + - + - + - + - + - + - +
# |   |   |   |   |   |   |   |   |   |   |   |
# + - + - + - + - + - + - + - + - + - + - + - +
# |   |   |   |   |   |   |   |   |   |   | 1 |
# + - + - + - + - + - + - + - + - + - + - + - +
# |   |   |   |   |   |   |   |   |   |   |   |
# + - + - + - + - + - + - + - + - + - + - + - +
# |   |   |   |   |   |   |   |   |   |   |   |
# + - + - + - + - + - + - + - + - + - + - + - +
# |   |   |   |   |   |   |   |   |   |   |   |
# + - + - + - + - + - + - + - + - + - + - + - +
# |   |   |   |   |   |   |   |   |   |   |   |
# + - + - + - + - + - + - + - + - + - + - + - +

# %%
visited = [key for key, v in book.items() if v[1]>0]

# %%
len(visited)
# Out:
# 19191

# %%
max_key = max(book.keys(), key=lambda x: book[x][1])

# %%
max_key
# Out:
# (Isolation(board=41523161203939122082683632224299007, ply_count=0, locs=(None, None)),
#  109)

# %%
book[max_key]
# Out:
# [12, 340]

# %%
with open('base_book.pkl', 'rb') as file:
    base_book = pickle.load(file)

# %%
full_book = combine_books(base_book, book)

# %%
first = {item:value[0]/value[1] for item, value in full_book.items() if item[0].ply_count==0}
pos_value = {key[1]:value for key,value in first.items()}
filled_vals = dict(zip(range(115),[0]*115))
filled_vals.update(pos_value)
W = 11
x = list(filled_vals.values())
rows = [x[i*(W+2):(i+1)*(W+2)] 
           for i in range(len(x) // (W+2) + (len(x) % (W+2) != 0))]
for i in range(len(rows)-1):
    rows[i] =rows[i][:-2]
rows = np.array(rows)
sns.heatmap(rows)

# %%
with open('full_book.pkl', 'wb') as file:
    pickle.dump(full_book, file)
